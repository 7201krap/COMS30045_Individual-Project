# %%
import matplotlib.pyplot as plt
import numpy as np
import re
import ast 
import torch

# %%
def val_extractor(file_name1, file_name2, file_name3):    
    
    test_accuracy_seed1 = 0
    sparsity_average_seed1 = 0
    selectivity_average_seed1 = 0
    
    test_accuracy_seed2 = 0
    sparsity_average_seed2 = 0
    selectivity_average_seed2 = 0
    
    test_accuracy_seed3 = 0
    sparsity_average_seed3 = 0
    selectivity_average_seed3 = 0
    
    # index 0 --> test acc (list)
    # index 1 --> sparsity (list) 
    # index 2 --> selectivity (list)
    
    with open(file_name1) as fi:
        for i, line in enumerate(fi):
            if i == 0:
                test_accuracy_seed1 = ast.literal_eval(line)     
            if i == 1:
                sparsity_average_seed1 = ast.literal_eval(line)
            if i == 2:
                selectivity_average_seed1 = ast.literal_eval(line)
                
    with open(file_name2) as fi:
        for i, line in enumerate(fi):
            if i == 0:
                test_accuracy_seed2 = ast.literal_eval(line)     
            if i == 1:
                sparsity_average_seed2 = ast.literal_eval(line)
            if i == 2:
                selectivity_average_seed2 = ast.literal_eval(line)
                
    with open(file_name3) as fi:
        for i, line in enumerate(fi):
            if i == 0:
                test_accuracy_seed3 = ast.literal_eval(line)     
            if i == 1:
                sparsity_average_seed3 = ast.literal_eval(line)
            if i == 2:
                selectivity_average_seed3 = ast.literal_eval(line)
    
    acc_avg = list()
    acc_se  = list()

    spar_avg = list()
    spar_se  = list()

    selec_avg = list()
    selec_se  = list()

    for i in range(len(test_accuracy_seed1)):
        acc_avg.append(np.mean([test_accuracy_seed1[i], test_accuracy_seed2[i], test_accuracy_seed3[i]]))
        acc_se .append(np.std ([test_accuracy_seed1[i], test_accuracy_seed2[i], test_accuracy_seed3[i]]) / np.sqrt(3))

        spar_avg.append(np.mean([sparsity_average_seed1[i], sparsity_average_seed2[i], sparsity_average_seed3[i]]))
        spar_se .append(np.std ([sparsity_average_seed1[i], sparsity_average_seed2[i], sparsity_average_seed3[i]]) / np.sqrt(3))

        selec_avg.append(np.mean([selectivity_average_seed1[i], selectivity_average_seed2[i], selectivity_average_seed3[i]]))
        selec_se .append(np.std ([selectivity_average_seed1[i], selectivity_average_seed2[i], selectivity_average_seed3[i]]) / np.sqrt(3))
    
                
    return acc_avg, acc_se, spar_avg, spar_se, selec_avg, selec_se

# %%
def val_extractor_extract_last(file_name1, file_name2, file_name3):    
    
    test_accuracy_seed1 = 0
    sparsity_average_seed1 = 0
    selectivity_average_seed1 = 0
    
    test_accuracy_seed2 = 0
    sparsity_average_seed2 = 0
    selectivity_average_seed2 = 0
    
    test_accuracy_seed3 = 0
    sparsity_average_seed3 = 0
    selectivity_average_seed3 = 0
    
    # index 0 --> test acc (list)
    # index 1 --> sparsity (list) 
    # index 2 --> selectivity (list)
    
    with open(file_name1) as fi:
        for i, line in enumerate(fi):
            if i == 0:
                test_accuracy_seed1 = ast.literal_eval(line)     
            if i == 1:
                sparsity_average_seed1 = ast.literal_eval(line)
            if i == 2:
                selectivity_average_seed1 = ast.literal_eval(line)
                
    with open(file_name2) as fi:
        for i, line in enumerate(fi):
            if i == 0:
                test_accuracy_seed2 = ast.literal_eval(line)     
            if i == 1:
                sparsity_average_seed2 = ast.literal_eval(line)
            if i == 2:
                selectivity_average_seed2 = ast.literal_eval(line)
                
    with open(file_name3) as fi:
        for i, line in enumerate(fi):
            if i == 0:
                test_accuracy_seed3 = ast.literal_eval(line)     
            if i == 1:
                sparsity_average_seed3 = ast.literal_eval(line)
            if i == 2:
                selectivity_average_seed3 = ast.literal_eval(line)
    
    acc_avg = list()
    acc_se  = list()

    spar_avg = list()
    spar_se  = list()

    selec_avg = list()
    selec_se  = list()

    for i in range(len(test_accuracy_seed1)):
        acc_avg.append(np.mean([test_accuracy_seed1[i], test_accuracy_seed2[i], test_accuracy_seed3[i]]))
        acc_se .append(np.std ([test_accuracy_seed1[i], test_accuracy_seed2[i], test_accuracy_seed3[i]]) / np.sqrt(3))

        spar_avg.append(np.mean([sparsity_average_seed1[i], sparsity_average_seed2[i], sparsity_average_seed3[i]]))
        spar_se .append(np.std ([sparsity_average_seed1[i], sparsity_average_seed2[i], sparsity_average_seed3[i]]) / np.sqrt(3))

        selec_avg.append(np.mean([selectivity_average_seed1[i], selectivity_average_seed2[i], selectivity_average_seed3[i]]))
        selec_se .append(np.std ([selectivity_average_seed1[i], selectivity_average_seed2[i], selectivity_average_seed3[i]]) / np.sqrt(3))
    
                
    return acc_avg[-1], acc_se[-1], spar_avg[-1], spar_se[-1], selec_avg[-1], selec_se[-1]

# %%
# batch 50

# %%
# 64
b50_sgd_64_acc_avg, b50_sgd_64_acc_se, b50_sgd_64_spar_avg, b50_sgd_64_spar_se, b50_sgd_64_selec_avg, b50_sgd_64_selec_se = val_extractor('seed1/batch50/64/seed1_batch50_neuronsize64_SGD.txt', 'seed100/batch50/64/seed100_batch50_neuronsize64_SGD.txt', 'seed1234/batch50/64/seed1234_batch50_neuronsize64_SGD.txt')
b50_grad_64_acc_avg, b50_grad_64_acc_se, b50_grad_64_spar_avg, b50_grad_64_spar_se, b50_grad_64_selec_avg, b50_grad_64_selec_se = val_extractor('seed1/batch50/64/seed1_batch50_neuronsize64_Adagrad.txt', 'seed100/batch50/64/seed100_batch50_neuronsize64_Adagrad.txt', 'seed1234/batch50/64/seed1234_batch50_neuronsize64_Adagrad.txt')
b50_delta_64_acc_avg, b50_delta_64_acc_se, b50_delta_64_spar_avg, b50_delta_64_spar_se, b50_delta_64_selec_avg, b50_delta_64_selec_se = val_extractor('seed1/batch50/64/seed1_batch50_neuronsize64_Adadelta.txt', 'seed100/batch50/64/seed100_batch50_neuronsize64_Adadelta.txt', 'seed1234/batch50/64/seed1234_batch50_neuronsize64_Adadelta.txt')
b50_adam_64_acc_avg, b50_adam_64_acc_se, b50_adam_64_spar_avg, b50_adam_64_spar_se, b50_adam_64_selec_avg, b50_adam_64_selec_se = val_extractor('seed1/batch50/64/seed1_batch50_neuronsize64_Adam.txt', 'seed100/batch50/64/seed100_batch50_neuronsize64_Adam.txt', 'seed1234/batch50/64/seed1234_batch50_neuronsize64_Adam.txt')

# 128 
b50_sgd_128_acc_avg, b50_sgd_128_acc_se, b50_sgd_128_spar_avg, b50_sgd_128_spar_se, b50_sgd_128_selec_avg, b50_sgd_128_selec_se = val_extractor('seed1/batch50/128/seed1_batch50_neuronsize128_SGD.txt', 'seed100/batch50/128/seed100_batch50_neuronsize128_SGD.txt', 'seed1234/batch50/128/seed1234_batch50_neuronsize128_SGD.txt')
b50_grad_128_acc_avg, b50_grad_128_acc_se, b50_grad_128_spar_avg, b50_grad_128_spar_se, b50_grad_128_selec_avg, b50_grad_128_selec_se = val_extractor('seed1/batch50/128/seed1_batch50_neuronsize128_Adagrad.txt', 'seed100/batch50/128/seed100_batch50_neuronsize128_Adagrad.txt', 'seed1234/batch50/128/seed1234_batch50_neuronsize128_Adagrad.txt')
b50_delta_128_acc_avg, b50_delta_128_acc_se, b50_delta_128_spar_avg, b50_delta_128_spar_se, b50_delta_128_selec_avg, b50_delta_128_selec_se = val_extractor('seed1/batch50/128/seed1_batch50_neuronsize128_Adadelta.txt', 'seed100/batch50/128/seed100_batch50_neuronsize128_Adadelta.txt', 'seed1234/batch50/128/seed1234_batch50_neuronsize128_Adadelta.txt')
b50_adam_128_acc_avg, b50_adam_128_acc_se, b50_adam_128_spar_avg, b50_adam_128_spar_se, b50_adam_128_selec_avg, b50_adam_128_selec_se = val_extractor('seed1/batch50/128/seed1_batch50_neuronsize128_Adam.txt', 'seed100/batch50/128/seed100_batch50_neuronsize128_Adam.txt', 'seed1234/batch50/128/seed1234_batch50_neuronsize128_Adam.txt')

# 256
b50_sgd_256_acc_avg, b50_sgd_256_acc_se, b50_sgd_256_spar_avg, b50_sgd_256_spar_se, b50_sgd_256_selec_avg, b50_sgd_256_selec_se = val_extractor('seed1/batch50/256/seed1_batch50_neuronsize256_SGD.txt', 'seed100/batch50/256/seed100_batch50_neuronsize256_SGD.txt', 'seed1234/batch50/256/seed1234_batch50_neuronsize256_SGD.txt')
b50_grad_256_acc_avg, b50_grad_256_acc_se, b50_grad_256_spar_avg, b50_grad_256_spar_se, b50_grad_256_selec_avg, b50_grad_256_selec_se = val_extractor('seed1/batch50/256/seed1_batch50_neuronsize256_Adagrad.txt', 'seed100/batch50/256/seed100_batch50_neuronsize256_Adagrad.txt', 'seed1234/batch50/256/seed1234_batch50_neuronsize256_Adagrad.txt')
b50_delta_256_acc_avg, b50_delta_256_acc_se, b50_delta_256_spar_avg, b50_delta_256_spar_se, b50_delta_256_selec_avg, b50_delta_256_selec_se = val_extractor('seed1/batch50/256/seed1_batch50_neuronsize256_Adadelta.txt', 'seed100/batch50/256/seed100_batch50_neuronsize256_Adadelta.txt', 'seed1234/batch50/256/seed1234_batch50_neuronsize256_Adadelta.txt')
b50_adam_256_acc_avg, b50_adam_256_acc_se, b50_adam_256_spar_avg, b50_adam_256_spar_se, b50_adam_256_selec_avg, b50_adam_256_selec_se = val_extractor('seed1/batch50/256/seed1_batch50_neuronsize256_Adam.txt', 'seed100/batch50/256/seed100_batch50_neuronsize256_Adam.txt', 'seed1234/batch50/256/seed1234_batch50_neuronsize256_Adam.txt')

# 384 
b50_sgd_384_acc_avg, b50_sgd_384_acc_se, b50_sgd_384_spar_avg, b50_sgd_384_spar_se, b50_sgd_384_selec_avg, b50_sgd_384_selec_se = val_extractor('seed1/batch50/384/seed1_batch50_neuronsize384_SGD.txt', 'seed100/batch50/384/seed100_batch50_neuronsize384_SGD.txt', 'seed1234/batch50/384/seed1234_batch50_neuronsize384_SGD.txt')
b50_grad_384_acc_avg, b50_grad_384_acc_se, b50_grad_384_spar_avg, b50_grad_384_spar_se, b50_grad_384_selec_avg, b50_grad_384_selec_se = val_extractor('seed1/batch50/384/seed1_batch50_neuronsize384_Adagrad.txt', 'seed100/batch50/384/seed100_batch50_neuronsize384_Adagrad.txt', 'seed1234/batch50/384/seed1234_batch50_neuronsize384_Adagrad.txt')
b50_delta_384_acc_avg, b50_delta_384_acc_se, b50_delta_384_spar_avg, b50_delta_384_spar_se, b50_delta_384_selec_avg, b50_delta_384_selec_se = val_extractor('seed1/batch50/384/seed1_batch50_neuronsize384_Adadelta.txt', 'seed100/batch50/384/seed100_batch50_neuronsize384_Adadelta.txt', 'seed1234/batch50/384/seed1234_batch50_neuronsize384_Adadelta.txt')
b50_adam_384_acc_avg, b50_adam_384_acc_se, b50_adam_384_spar_avg, b50_adam_384_spar_se, b50_adam_384_selec_avg, b50_adam_384_selec_se = val_extractor('seed1/batch50/384/seed1_batch50_neuronsize384_Adam.txt', 'seed100/batch50/384/seed100_batch50_neuronsize384_Adam.txt', 'seed1234/batch50/384/seed1234_batch50_neuronsize384_Adam.txt')

# 512
b50_sgd_512_acc_avg, b50_sgd_512_acc_se, b50_sgd_512_spar_avg, b50_sgd_512_spar_se, b50_sgd_512_selec_avg, b50_sgd_512_selec_se = val_extractor('seed1/batch50/512/seed1_batch50_neuronsize512_SGD.txt', 'seed100/batch50/512/seed100_batch50_neuronsize512_SGD.txt', 'seed1234/batch50/512/seed1234_batch50_neuronsize512_SGD.txt')
b50_grad_512_acc_avg, b50_grad_512_acc_se, b50_grad_512_spar_avg, b50_grad_512_spar_se, b50_grad_512_selec_avg, b50_grad_512_selec_se = val_extractor('seed1/batch50/512/seed1_batch50_neuronsize512_Adagrad.txt', 'seed100/batch50/512/seed100_batch50_neuronsize512_Adagrad.txt', 'seed1234/batch50/512/seed1234_batch50_neuronsize512_Adagrad.txt')
b50_delta_512_acc_avg, b50_delta_512_acc_se, b50_delta_512_spar_avg, b50_delta_512_spar_se, b50_delta_512_selec_avg, b50_delta_512_selec_se = val_extractor('seed1/batch50/512/seed1_batch50_neuronsize512_Adadelta.txt', 'seed100/batch50/512/seed100_batch50_neuronsize512_Adadelta.txt', 'seed1234/batch50/512/seed1234_batch50_neuronsize512_Adadelta.txt')
b50_adam_512_acc_avg, b50_adam_512_acc_se, b50_adam_512_spar_avg, b50_adam_512_spar_se, b50_adam_512_selec_avg, b50_adam_512_selec_se = val_extractor('seed1/batch50/512/seed1_batch50_neuronsize512_Adam.txt', 'seed100/batch50/512/seed100_batch50_neuronsize512_Adam.txt', 'seed1234/batch50/512/seed1234_batch50_neuronsize512_Adam.txt')

# 640 
b50_sgd_640_acc_avg, b50_sgd_640_acc_se, b50_sgd_640_spar_avg, b50_sgd_640_spar_se, b50_sgd_640_selec_avg, b50_sgd_640_selec_se = val_extractor('seed1/batch50/640/seed1_batch50_neuronsize640_SGD.txt', 'seed100/batch50/640/seed100_batch50_neuronsize640_SGD.txt', 'seed1234/batch50/640/seed1234_batch50_neuronsize640_SGD.txt')
b50_grad_640_acc_avg, b50_grad_640_acc_se, b50_grad_640_spar_avg, b50_grad_640_spar_se, b50_grad_640_selec_avg, b50_grad_640_selec_se = val_extractor('seed1/batch50/640/seed1_batch50_neuronsize640_Adagrad.txt', 'seed100/batch50/640/seed100_batch50_neuronsize640_Adagrad.txt', 'seed1234/batch50/640/seed1234_batch50_neuronsize640_Adagrad.txt')
b50_delta_640_acc_avg, b50_delta_640_acc_se, b50_delta_640_spar_avg, b50_delta_640_spar_se, b50_delta_640_selec_avg, b50_delta_640_selec_se = val_extractor('seed1/batch50/640/seed1_batch50_neuronsize640_Adadelta.txt', 'seed100/batch50/640/seed100_batch50_neuronsize640_Adadelta.txt', 'seed1234/batch50/640/seed1234_batch50_neuronsize640_Adadelta.txt')
b50_adam_640_acc_avg, b50_adam_640_acc_se, b50_adam_640_spar_avg, b50_adam_640_spar_se, b50_adam_640_selec_avg, b50_adam_640_selec_se = val_extractor('seed1/batch50/640/seed1_batch50_neuronsize640_Adam.txt', 'seed100/batch50/640/seed100_batch50_neuronsize640_Adam.txt', 'seed1234/batch50/640/seed1234_batch50_neuronsize640_Adam.txt')

# 768
b50_sgd_768_acc_avg, b50_sgd_768_acc_se, b50_sgd_768_spar_avg, b50_sgd_768_spar_se, b50_sgd_768_selec_avg, b50_sgd_768_selec_se = val_extractor('seed1/batch50/768/seed1_batch50_neuronsize768_SGD.txt', 'seed100/batch50/768/seed100_batch50_neuronsize768_SGD.txt', 'seed1234/batch50/768/seed1234_batch50_neuronsize768_SGD.txt')
b50_grad_768_acc_avg, b50_grad_768_acc_se, b50_grad_768_spar_avg, b50_grad_768_spar_se, b50_grad_768_selec_avg, b50_grad_768_selec_se = val_extractor('seed1/batch50/768/seed1_batch50_neuronsize768_Adagrad.txt', 'seed100/batch50/768/seed100_batch50_neuronsize768_Adagrad.txt', 'seed1234/batch50/768/seed1234_batch50_neuronsize768_Adagrad.txt')
b50_delta_768_acc_avg, b50_delta_768_acc_se, b50_delta_768_spar_avg, b50_delta_768_spar_se, b50_delta_768_selec_avg, b50_delta_768_selec_se = val_extractor('seed1/batch50/768/seed1_batch50_neuronsize768_Adadelta.txt', 'seed100/batch50/768/seed100_batch50_neuronsize768_Adadelta.txt', 'seed1234/batch50/768/seed1234_batch50_neuronsize768_Adadelta.txt')
b50_adam_768_acc_avg, b50_adam_768_acc_se, b50_adam_768_spar_avg, b50_adam_768_spar_se, b50_adam_768_selec_avg, b50_adam_768_selec_se = val_extractor('seed1/batch50/768/seed1_batch50_neuronsize768_Adam.txt', 'seed100/batch50/768/seed100_batch50_neuronsize768_Adam.txt', 'seed1234/batch50/768/seed1234_batch50_neuronsize768_Adam.txt')

# %%
# batch 1

# %%
# 64
b1_sgd_64_acc_avg, b1_sgd_64_acc_se, b1_sgd_64_spar_avg, b1_sgd_64_spar_se, b1_sgd_64_selec_avg, b1_sgd_64_selec_se = val_extractor('seed1/batch1/64/seed1_batch1_neuronsize64_SGD.txt', 'seed100/batch1/64/seed100_batch1_neuronsize64_SGD.txt', 'seed1234/batch1/64/seed1234_batch1_neuronsize64_SGD.txt')
b1_grad_64_acc_avg, b1_grad_64_acc_se, b1_grad_64_spar_avg, b1_grad_64_spar_se, b1_grad_64_selec_avg, b1_grad_64_selec_se = val_extractor('seed1/batch1/64/seed1_batch1_neuronsize64_Adagrad.txt', 'seed100/batch1/64/seed100_batch1_neuronsize64_Adagrad.txt', 'seed1234/batch1/64/seed1234_batch1_neuronsize64_Adagrad.txt')
b1_delta_64_acc_avg, b1_delta_64_acc_se, b1_delta_64_spar_avg, b1_delta_64_spar_se, b1_delta_64_selec_avg, b1_delta_64_selec_se = val_extractor('seed1/batch1/64/seed1_batch1_neuronsize64_Adadelta.txt', 'seed100/batch1/64/seed100_batch1_neuronsize64_Adadelta.txt', 'seed1234/batch1/64/seed1234_batch1_neuronsize64_Adadelta.txt')
b1_adam_64_acc_avg, b1_adam_64_acc_se, b1_adam_64_spar_avg, b1_adam_64_spar_se, b1_adam_64_selec_avg, b1_adam_64_selec_se = val_extractor('seed1/batch1/64/seed1_batch1_neuronsize64_Adam.txt', 'seed100/batch1/64/seed100_batch1_neuronsize64_Adam.txt', 'seed1234/batch1/64/seed1234_batch1_neuronsize64_Adam.txt')

# 128 
b1_sgd_128_acc_avg, b1_sgd_128_acc_se, b1_sgd_128_spar_avg, b1_sgd_128_spar_se, b1_sgd_128_selec_avg, b1_sgd_128_selec_se = val_extractor('seed1/batch1/128/seed1_batch1_neuronsize128_SGD.txt', 'seed100/batch1/128/seed100_batch1_neuronsize128_SGD.txt', 'seed1234/batch1/128/seed1234_batch1_neuronsize128_SGD.txt')
b1_grad_128_acc_avg, b1_grad_128_acc_se, b1_grad_128_spar_avg, b1_grad_128_spar_se, b1_grad_128_selec_avg, b1_grad_128_selec_se = val_extractor('seed1/batch1/128/seed1_batch1_neuronsize128_Adagrad.txt', 'seed100/batch1/128/seed100_batch1_neuronsize128_Adagrad.txt', 'seed1234/batch1/128/seed1234_batch1_neuronsize128_Adagrad.txt')
b1_delta_128_acc_avg, b1_delta_128_acc_se, b1_delta_128_spar_avg, b1_delta_128_spar_se, b1_delta_128_selec_avg, b1_delta_128_selec_se = val_extractor('seed1/batch1/128/seed1_batch1_neuronsize128_Adadelta.txt', 'seed100/batch1/128/seed100_batch1_neuronsize128_Adadelta.txt', 'seed1234/batch1/128/seed1234_batch1_neuronsize128_Adadelta.txt')
b1_adam_128_acc_avg, b1_adam_128_acc_se, b1_adam_128_spar_avg, b1_adam_128_spar_se, b1_adam_128_selec_avg, b1_adam_128_selec_se = val_extractor('seed1/batch1/128/seed1_batch1_neuronsize128_Adam.txt', 'seed100/batch1/128/seed100_batch1_neuronsize128_Adam.txt', 'seed1234/batch1/128/seed1234_batch1_neuronsize128_Adam.txt')

# 256
b1_sgd_256_acc_avg, b1_sgd_256_acc_se, b1_sgd_256_spar_avg, b1_sgd_256_spar_se, b1_sgd_256_selec_avg, b1_sgd_256_selec_se = val_extractor('seed1/batch1/256/seed1_batch1_neuronsize256_SGD.txt', 'seed100/batch1/256/seed100_batch1_neuronsize256_SGD.txt', 'seed1234/batch1/256/seed1234_batch1_neuronsize256_SGD.txt')
b1_grad_256_acc_avg, b1_grad_256_acc_se, b1_grad_256_spar_avg, b1_grad_256_spar_se, b1_grad_256_selec_avg, b1_grad_256_selec_se = val_extractor('seed1/batch1/256/seed1_batch1_neuronsize256_Adagrad.txt', 'seed100/batch1/256/seed100_batch1_neuronsize256_Adagrad.txt', 'seed1234/batch1/256/seed1234_batch1_neuronsize256_Adagrad.txt')
b1_delta_256_acc_avg, b1_delta_256_acc_se, b1_delta_256_spar_avg, b1_delta_256_spar_se, b1_delta_256_selec_avg, b1_delta_256_selec_se = val_extractor('seed1/batch1/256/seed1_batch1_neuronsize256_Adadelta.txt', 'seed100/batch1/256/seed100_batch1_neuronsize256_Adadelta.txt', 'seed1234/batch1/256/seed1234_batch1_neuronsize256_Adadelta.txt')
b1_adam_256_acc_avg, b1_adam_256_acc_se, b1_adam_256_spar_avg, b1_adam_256_spar_se, b1_adam_256_selec_avg, b1_adam_256_selec_se = val_extractor('seed1/batch1/256/seed1_batch1_neuronsize256_Adam.txt', 'seed100/batch1/256/seed100_batch1_neuronsize256_Adam.txt', 'seed1234/batch1/256/seed1234_batch1_neuronsize256_Adam.txt')

# 384 
b1_sgd_384_acc_avg, b1_sgd_384_acc_se, b1_sgd_384_spar_avg, b1_sgd_384_spar_se, b1_sgd_384_selec_avg, b1_sgd_384_selec_se = val_extractor('seed1/batch1/384/seed1_batch1_neuronsize384_SGD.txt', 'seed100/batch1/384/seed100_batch1_neuronsize384_SGD.txt', 'seed1234/batch1/384/seed1234_batch1_neuronsize384_SGD.txt')
b1_grad_384_acc_avg, b1_grad_384_acc_se, b1_grad_384_spar_avg, b1_grad_384_spar_se, b1_grad_384_selec_avg, b1_grad_384_selec_se = val_extractor('seed1/batch1/384/seed1_batch1_neuronsize384_Adagrad.txt', 'seed100/batch1/384/seed100_batch1_neuronsize384_Adagrad.txt', 'seed1234/batch1/384/seed1234_batch1_neuronsize384_Adagrad.txt')
b1_delta_384_acc_avg, b1_delta_384_acc_se, b1_delta_384_spar_avg, b1_delta_384_spar_se, b1_delta_384_selec_avg, b1_delta_384_selec_se = val_extractor('seed1/batch1/384/seed1_batch1_neuronsize384_Adadelta.txt', 'seed100/batch1/384/seed100_batch1_neuronsize384_Adadelta.txt', 'seed1234/batch1/384/seed1234_batch1_neuronsize384_Adadelta.txt')
b1_adam_384_acc_avg, b1_adam_384_acc_se, b1_adam_384_spar_avg, b1_adam_384_spar_se, b1_adam_384_selec_avg, b1_adam_384_selec_se = val_extractor('seed1/batch1/384/seed1_batch1_neuronsize384_Adam.txt', 'seed100/batch1/384/seed100_batch1_neuronsize384_Adam.txt', 'seed1234/batch1/384/seed1234_batch1_neuronsize384_Adam.txt')

# 512
b1_sgd_512_acc_avg, b1_sgd_512_acc_se, b1_sgd_512_spar_avg, b1_sgd_512_spar_se, b1_sgd_512_selec_avg, b1_sgd_512_selec_se = val_extractor('seed1/batch1/512/seed1_batch1_neuronsize512_SGD.txt', 'seed100/batch1/512/seed100_batch1_neuronsize512_SGD.txt', 'seed1234/batch1/512/seed1234_batch1_neuronsize512_SGD.txt')
b1_grad_512_acc_avg, b1_grad_512_acc_se, b1_grad_512_spar_avg, b1_grad_512_spar_se, b1_grad_512_selec_avg, b1_grad_512_selec_se = val_extractor('seed1/batch1/512/seed1_batch1_neuronsize512_Adagrad.txt', 'seed100/batch1/512/seed100_batch1_neuronsize512_Adagrad.txt', 'seed1234/batch1/512/seed1234_batch1_neuronsize512_Adagrad.txt')
b1_delta_512_acc_avg, b1_delta_512_acc_se, b1_delta_512_spar_avg, b1_delta_512_spar_se, b1_delta_512_selec_avg, b1_delta_512_selec_se = val_extractor('seed1/batch1/512/seed1_batch1_neuronsize512_Adadelta.txt', 'seed100/batch1/512/seed100_batch1_neuronsize512_Adadelta.txt', 'seed1234/batch1/512/seed1234_batch1_neuronsize512_Adadelta.txt')
b1_adam_512_acc_avg, b1_adam_512_acc_se, b1_adam_512_spar_avg, b1_adam_512_spar_se, b1_adam_512_selec_avg, b1_adam_512_selec_se = val_extractor('seed1/batch1/512/seed1_batch1_neuronsize512_Adam.txt', 'seed100/batch1/512/seed100_batch1_neuronsize512_Adam.txt', 'seed1234/batch1/512/seed1234_batch1_neuronsize512_Adam.txt')

# 640 
b1_sgd_640_acc_avg, b1_sgd_640_acc_se, b1_sgd_640_spar_avg, b1_sgd_640_spar_se, b1_sgd_640_selec_avg, b1_sgd_640_selec_se = val_extractor('seed1/batch1/640/seed1_batch1_neuronsize640_SGD.txt', 'seed100/batch1/640/seed100_batch1_neuronsize640_SGD.txt', 'seed1234/batch1/640/seed1234_batch1_neuronsize640_SGD.txt')
b1_grad_640_acc_avg, b1_grad_640_acc_se, b1_grad_640_spar_avg, b1_grad_640_spar_se, b1_grad_640_selec_avg, b1_grad_640_selec_se = val_extractor('seed1/batch1/640/seed1_batch1_neuronsize640_Adagrad.txt', 'seed100/batch1/640/seed100_batch1_neuronsize640_Adagrad.txt', 'seed1234/batch1/640/seed1234_batch1_neuronsize640_Adagrad.txt')
b1_delta_640_acc_avg, b1_delta_640_acc_se, b1_delta_640_spar_avg, b1_delta_640_spar_se, b1_delta_640_selec_avg, b1_delta_640_selec_se = val_extractor('seed1/batch1/640/seed1_batch1_neuronsize640_Adadelta.txt', 'seed100/batch1/640/seed100_batch1_neuronsize640_Adadelta.txt', 'seed1234/batch1/640/seed1234_batch1_neuronsize640_Adadelta.txt')
b1_adam_640_acc_avg, b1_adam_640_acc_se, b1_adam_640_spar_avg, b1_adam_640_spar_se, b1_adam_640_selec_avg, b1_adam_640_selec_se = val_extractor('seed1/batch1/640/seed1_batch1_neuronsize640_Adam.txt', 'seed100/batch1/640/seed100_batch1_neuronsize640_Adam.txt', 'seed1234/batch1/640/seed1234_batch1_neuronsize640_Adam.txt')

# 768
b1_sgd_768_acc_avg, b1_sgd_768_acc_se, b1_sgd_768_spar_avg, b1_sgd_768_spar_se, b1_sgd_768_selec_avg, b1_sgd_768_selec_se = val_extractor('seed1/batch1/768/seed1_batch1_neuronsize768_SGD.txt', 'seed100/batch1/768/seed100_batch1_neuronsize768_SGD.txt', 'seed1234/batch1/768/seed1234_batch1_neuronsize768_SGD.txt')
b1_grad_768_acc_avg, b1_grad_768_acc_se, b1_grad_768_spar_avg, b1_grad_768_spar_se, b1_grad_768_selec_avg, b1_grad_768_selec_se = val_extractor('seed1/batch1/768/seed1_batch1_neuronsize768_Adagrad.txt', 'seed100/batch1/768/seed100_batch1_neuronsize768_Adagrad.txt', 'seed1234/batch1/768/seed1234_batch1_neuronsize768_Adagrad.txt')
b1_delta_768_acc_avg, b1_delta_768_acc_se, b1_delta_768_spar_avg, b1_delta_768_spar_se, b1_delta_768_selec_avg, b1_delta_768_selec_se = val_extractor('seed1/batch1/768/seed1_batch1_neuronsize768_Adadelta.txt', 'seed100/batch1/768/seed100_batch1_neuronsize768_Adadelta.txt', 'seed1234/batch1/768/seed1234_batch1_neuronsize768_Adadelta.txt')
b1_adam_768_acc_avg, b1_adam_768_acc_se, b1_adam_768_spar_avg, b1_adam_768_spar_se, b1_adam_768_selec_avg, b1_adam_768_selec_se = val_extractor('seed1/batch1/768/seed1_batch1_neuronsize768_Adam.txt', 'seed100/batch1/768/seed100_batch1_neuronsize768_Adam.txt', 'seed1234/batch1/768/seed1234_batch1_neuronsize768_Adam.txt')

# %%
# extract last

# %%
# 64
last_b50_sgd_64_acc_avg, last_b50_sgd_64_acc_se, last_b50_sgd_64_spar_avg, last_b50_sgd_64_spar_se, last_b50_sgd_64_selec_avg, last_b50_sgd_64_selec_se = val_extractor_extract_last('seed1/batch50/64/seed1_batch50_neuronsize64_SGD.txt', 'seed100/batch50/64/seed100_batch50_neuronsize64_SGD.txt', 'seed1234/batch50/64/seed1234_batch50_neuronsize64_SGD.txt')
last_b50_grad_64_acc_avg, last_b50_grad_64_acc_se, last_b50_grad_64_spar_avg, last_b50_grad_64_spar_se, last_b50_grad_64_selec_avg, last_b50_grad_64_selec_se = val_extractor_extract_last('seed1/batch50/64/seed1_batch50_neuronsize64_Adagrad.txt', 'seed100/batch50/64/seed100_batch50_neuronsize64_Adagrad.txt', 'seed1234/batch50/64/seed1234_batch50_neuronsize64_Adagrad.txt')
last_b50_delta_64_acc_avg, last_b50_delta_64_acc_se, last_b50_delta_64_spar_avg, last_b50_delta_64_spar_se, last_b50_delta_64_selec_avg, last_b50_delta_64_selec_se = val_extractor_extract_last('seed1/batch50/64/seed1_batch50_neuronsize64_Adadelta.txt', 'seed100/batch50/64/seed100_batch50_neuronsize64_Adadelta.txt', 'seed1234/batch50/64/seed1234_batch50_neuronsize64_Adadelta.txt')
last_b50_adam_64_acc_avg, last_b50_adam_64_acc_se, last_b50_adam_64_spar_avg, last_b50_adam_64_spar_se, last_b50_adam_64_selec_avg, last_b50_adam_64_selec_se = val_extractor_extract_last('seed1/batch50/64/seed1_batch50_neuronsize64_Adam.txt', 'seed100/batch50/64/seed100_batch50_neuronsize64_Adam.txt', 'seed1234/batch50/64/seed1234_batch50_neuronsize64_Adam.txt')

# 128 
last_b50_sgd_128_acc_avg, last_b50_sgd_128_acc_se, last_b50_sgd_128_spar_avg, last_b50_sgd_128_spar_se, last_b50_sgd_128_selec_avg, last_b50_sgd_128_selec_se = val_extractor_extract_last('seed1/batch50/128/seed1_batch50_neuronsize128_SGD.txt', 'seed100/batch50/128/seed100_batch50_neuronsize128_SGD.txt', 'seed1234/batch50/128/seed1234_batch50_neuronsize128_SGD.txt')
last_b50_grad_128_acc_avg, last_b50_grad_128_acc_se, last_b50_grad_128_spar_avg, last_b50_grad_128_spar_se, last_b50_grad_128_selec_avg, last_b50_grad_128_selec_se = val_extractor_extract_last('seed1/batch50/128/seed1_batch50_neuronsize128_Adagrad.txt', 'seed100/batch50/128/seed100_batch50_neuronsize128_Adagrad.txt', 'seed1234/batch50/128/seed1234_batch50_neuronsize128_Adagrad.txt')
last_b50_delta_128_acc_avg, last_b50_delta_128_acc_se, last_b50_delta_128_spar_avg, last_b50_delta_128_spar_se, last_b50_delta_128_selec_avg, last_b50_delta_128_selec_se = val_extractor_extract_last('seed1/batch50/128/seed1_batch50_neuronsize128_Adadelta.txt', 'seed100/batch50/128/seed100_batch50_neuronsize128_Adadelta.txt', 'seed1234/batch50/128/seed1234_batch50_neuronsize128_Adadelta.txt')
last_b50_adam_128_acc_avg, last_b50_adam_128_acc_se, last_b50_adam_128_spar_avg, last_b50_adam_128_spar_se, last_b50_adam_128_selec_avg, last_b50_adam_128_selec_se = val_extractor_extract_last('seed1/batch50/128/seed1_batch50_neuronsize128_Adam.txt', 'seed100/batch50/128/seed100_batch50_neuronsize128_Adam.txt', 'seed1234/batch50/128/seed1234_batch50_neuronsize128_Adam.txt')

# 256
last_b50_sgd_256_acc_avg, last_b50_sgd_256_acc_se, last_b50_sgd_256_spar_avg, last_b50_sgd_256_spar_se, last_b50_sgd_256_selec_avg, last_b50_sgd_256_selec_se = val_extractor_extract_last('seed1/batch50/256/seed1_batch50_neuronsize256_SGD.txt', 'seed100/batch50/256/seed100_batch50_neuronsize256_SGD.txt', 'seed1234/batch50/256/seed1234_batch50_neuronsize256_SGD.txt')
last_b50_grad_256_acc_avg, last_b50_grad_256_acc_se, last_b50_grad_256_spar_avg, last_b50_grad_256_spar_se, last_b50_grad_256_selec_avg, last_b50_grad_256_selec_se = val_extractor_extract_last('seed1/batch50/256/seed1_batch50_neuronsize256_Adagrad.txt', 'seed100/batch50/256/seed100_batch50_neuronsize256_Adagrad.txt', 'seed1234/batch50/256/seed1234_batch50_neuronsize256_Adagrad.txt')
last_b50_delta_256_acc_avg, last_b50_delta_256_acc_se, last_b50_delta_256_spar_avg, last_b50_delta_256_spar_se, last_b50_delta_256_selec_avg, last_b50_delta_256_selec_se = val_extractor_extract_last('seed1/batch50/256/seed1_batch50_neuronsize256_Adadelta.txt', 'seed100/batch50/256/seed100_batch50_neuronsize256_Adadelta.txt', 'seed1234/batch50/256/seed1234_batch50_neuronsize256_Adadelta.txt')
last_b50_adam_256_acc_avg, last_b50_adam_256_acc_se, last_b50_adam_256_spar_avg, last_b50_adam_256_spar_se, last_b50_adam_256_selec_avg, last_b50_adam_256_selec_se = val_extractor_extract_last('seed1/batch50/256/seed1_batch50_neuronsize256_Adam.txt', 'seed100/batch50/256/seed100_batch50_neuronsize256_Adam.txt', 'seed1234/batch50/256/seed1234_batch50_neuronsize256_Adam.txt')

# 384 
last_b50_sgd_384_acc_avg, last_b50_sgd_384_acc_se, last_b50_sgd_384_spar_avg, last_b50_sgd_384_spar_se, last_b50_sgd_384_selec_avg, last_b50_sgd_384_selec_se = val_extractor_extract_last('seed1/batch50/384/seed1_batch50_neuronsize384_SGD.txt', 'seed100/batch50/384/seed100_batch50_neuronsize384_SGD.txt', 'seed1234/batch50/384/seed1234_batch50_neuronsize384_SGD.txt')
last_b50_grad_384_acc_avg, last_b50_grad_384_acc_se, last_b50_grad_384_spar_avg, last_b50_grad_384_spar_se, last_b50_grad_384_selec_avg, last_b50_grad_384_selec_se = val_extractor_extract_last('seed1/batch50/384/seed1_batch50_neuronsize384_Adagrad.txt', 'seed100/batch50/384/seed100_batch50_neuronsize384_Adagrad.txt', 'seed1234/batch50/384/seed1234_batch50_neuronsize384_Adagrad.txt')
last_b50_delta_384_acc_avg, last_b50_delta_384_acc_se, last_b50_delta_384_spar_avg, last_b50_delta_384_spar_se, last_b50_delta_384_selec_avg, last_b50_delta_384_selec_se = val_extractor_extract_last('seed1/batch50/384/seed1_batch50_neuronsize384_Adadelta.txt', 'seed100/batch50/384/seed100_batch50_neuronsize384_Adadelta.txt', 'seed1234/batch50/384/seed1234_batch50_neuronsize384_Adadelta.txt')
last_b50_adam_384_acc_avg, last_b50_adam_384_acc_se, last_b50_adam_384_spar_avg, last_b50_adam_384_spar_se, last_b50_adam_384_selec_avg, last_b50_adam_384_selec_se = val_extractor_extract_last('seed1/batch50/384/seed1_batch50_neuronsize384_Adam.txt', 'seed100/batch50/384/seed100_batch50_neuronsize384_Adam.txt', 'seed1234/batch50/384/seed1234_batch50_neuronsize384_Adam.txt')

# 512
last_b50_sgd_512_acc_avg, last_b50_sgd_512_acc_se, last_b50_sgd_512_spar_avg, last_b50_sgd_512_spar_se, last_b50_sgd_512_selec_avg, last_b50_sgd_512_selec_se = val_extractor_extract_last('seed1/batch50/512/seed1_batch50_neuronsize512_SGD.txt', 'seed100/batch50/512/seed100_batch50_neuronsize512_SGD.txt', 'seed1234/batch50/512/seed1234_batch50_neuronsize512_SGD.txt')
last_b50_grad_512_acc_avg, last_b50_grad_512_acc_se, last_b50_grad_512_spar_avg, last_b50_grad_512_spar_se, last_b50_grad_512_selec_avg, last_b50_grad_512_selec_se = val_extractor_extract_last('seed1/batch50/512/seed1_batch50_neuronsize512_Adagrad.txt', 'seed100/batch50/512/seed100_batch50_neuronsize512_Adagrad.txt', 'seed1234/batch50/512/seed1234_batch50_neuronsize512_Adagrad.txt')
last_b50_delta_512_acc_avg, last_b50_delta_512_acc_se, last_b50_delta_512_spar_avg, last_b50_delta_512_spar_se, last_b50_delta_512_selec_avg, last_b50_delta_512_selec_se = val_extractor_extract_last('seed1/batch50/512/seed1_batch50_neuronsize512_Adadelta.txt', 'seed100/batch50/512/seed100_batch50_neuronsize512_Adadelta.txt', 'seed1234/batch50/512/seed1234_batch50_neuronsize512_Adadelta.txt')
last_b50_adam_512_acc_avg, last_b50_adam_512_acc_se, last_b50_adam_512_spar_avg, last_b50_adam_512_spar_se, last_b50_adam_512_selec_avg, last_b50_adam_512_selec_se = val_extractor_extract_last('seed1/batch50/512/seed1_batch50_neuronsize512_Adam.txt', 'seed100/batch50/512/seed100_batch50_neuronsize512_Adam.txt', 'seed1234/batch50/512/seed1234_batch50_neuronsize512_Adam.txt')

# 640 
last_b50_sgd_640_acc_avg, last_b50_sgd_640_acc_se, last_b50_sgd_640_spar_avg, last_b50_sgd_640_spar_se, last_b50_sgd_640_selec_avg, last_b50_sgd_640_selec_se = val_extractor_extract_last('seed1/batch50/640/seed1_batch50_neuronsize640_SGD.txt', 'seed100/batch50/640/seed100_batch50_neuronsize640_SGD.txt', 'seed1234/batch50/640/seed1234_batch50_neuronsize640_SGD.txt')
last_b50_grad_640_acc_avg, last_b50_grad_640_acc_se, last_b50_grad_640_spar_avg, last_b50_grad_640_spar_se, last_b50_grad_640_selec_avg, last_b50_grad_640_selec_se = val_extractor_extract_last('seed1/batch50/640/seed1_batch50_neuronsize640_Adagrad.txt', 'seed100/batch50/640/seed100_batch50_neuronsize640_Adagrad.txt', 'seed1234/batch50/640/seed1234_batch50_neuronsize640_Adagrad.txt')
last_b50_delta_640_acc_avg, last_b50_delta_640_acc_se, last_b50_delta_640_spar_avg, last_b50_delta_640_spar_se, last_b50_delta_640_selec_avg, last_b50_delta_640_selec_se = val_extractor_extract_last('seed1/batch50/640/seed1_batch50_neuronsize640_Adadelta.txt', 'seed100/batch50/640/seed100_batch50_neuronsize640_Adadelta.txt', 'seed1234/batch50/640/seed1234_batch50_neuronsize640_Adadelta.txt')
last_b50_adam_640_acc_avg, last_b50_adam_640_acc_se, last_b50_adam_640_spar_avg, last_b50_adam_640_spar_se, last_b50_adam_640_selec_avg, last_b50_adam_640_selec_se = val_extractor_extract_last('seed1/batch50/640/seed1_batch50_neuronsize640_Adam.txt', 'seed100/batch50/640/seed100_batch50_neuronsize640_Adam.txt', 'seed1234/batch50/640/seed1234_batch50_neuronsize640_Adam.txt')

# 768
last_b50_sgd_768_acc_avg, last_b50_sgd_768_acc_se, last_b50_sgd_768_spar_avg, last_b50_sgd_768_spar_se, last_b50_sgd_768_selec_avg, last_b50_sgd_768_selec_se = val_extractor_extract_last('seed1/batch50/768/seed1_batch50_neuronsize768_SGD.txt', 'seed100/batch50/768/seed100_batch50_neuronsize768_SGD.txt', 'seed1234/batch50/768/seed1234_batch50_neuronsize768_SGD.txt')
last_b50_grad_768_acc_avg, last_b50_grad_768_acc_se, last_b50_grad_768_spar_avg, last_b50_grad_768_spar_se, last_b50_grad_768_selec_avg, last_b50_grad_768_selec_se = val_extractor_extract_last('seed1/batch50/768/seed1_batch50_neuronsize768_Adagrad.txt', 'seed100/batch50/768/seed100_batch50_neuronsize768_Adagrad.txt', 'seed1234/batch50/768/seed1234_batch50_neuronsize768_Adagrad.txt')
last_b50_delta_768_acc_avg, last_b50_delta_768_acc_se, last_b50_delta_768_spar_avg, last_b50_delta_768_spar_se, last_b50_delta_768_selec_avg, last_b50_delta_768_selec_se = val_extractor_extract_last('seed1/batch50/768/seed1_batch50_neuronsize768_Adadelta.txt', 'seed100/batch50/768/seed100_batch50_neuronsize768_Adadelta.txt', 'seed1234/batch50/768/seed1234_batch50_neuronsize768_Adadelta.txt')
last_b50_adam_768_acc_avg, last_b50_adam_768_acc_se, last_b50_adam_768_spar_avg, last_b50_adam_768_spar_se, last_b50_adam_768_selec_avg, last_b50_adam_768_selec_se = val_extractor_extract_last('seed1/batch50/768/seed1_batch50_neuronsize768_Adam.txt', 'seed100/batch50/768/seed100_batch50_neuronsize768_Adam.txt', 'seed1234/batch50/768/seed1234_batch50_neuronsize768_Adam.txt')

# %%
# 64
last_b1_sgd_64_acc_avg, last_b1_sgd_64_acc_se, last_b1_sgd_64_spar_avg, last_b1_sgd_64_spar_se, last_b1_sgd_64_selec_avg, last_b1_sgd_64_selec_se = val_extractor_extract_last('seed1/batch1/64/seed1_batch1_neuronsize64_SGD.txt', 'seed100/batch1/64/seed100_batch1_neuronsize64_SGD.txt', 'seed1234/batch1/64/seed1234_batch1_neuronsize64_SGD.txt')
last_b1_grad_64_acc_avg, last_b1_grad_64_acc_se, last_b1_grad_64_spar_avg, last_b1_grad_64_spar_se, last_b1_grad_64_selec_avg, last_b1_grad_64_selec_se = val_extractor_extract_last('seed1/batch1/64/seed1_batch1_neuronsize64_Adagrad.txt', 'seed100/batch1/64/seed100_batch1_neuronsize64_Adagrad.txt', 'seed1234/batch1/64/seed1234_batch1_neuronsize64_Adagrad.txt')
last_b1_delta_64_acc_avg, last_b1_delta_64_acc_se, last_b1_delta_64_spar_avg, last_b1_delta_64_spar_se, last_b1_delta_64_selec_avg, last_b1_delta_64_selec_se = val_extractor_extract_last('seed1/batch1/64/seed1_batch1_neuronsize64_Adadelta.txt', 'seed100/batch1/64/seed100_batch1_neuronsize64_Adadelta.txt', 'seed1234/batch1/64/seed1234_batch1_neuronsize64_Adadelta.txt')
last_b1_adam_64_acc_avg, last_b1_adam_64_acc_se, last_b1_adam_64_spar_avg, last_b1_adam_64_spar_se, last_b1_adam_64_selec_avg, last_b1_adam_64_selec_se = val_extractor_extract_last('seed1/batch1/64/seed1_batch1_neuronsize64_Adam.txt', 'seed100/batch1/64/seed100_batch1_neuronsize64_Adam.txt', 'seed1234/batch1/64/seed1234_batch1_neuronsize64_Adam.txt')

# 128 
last_b1_sgd_128_acc_avg, last_b1_sgd_128_acc_se, last_b1_sgd_128_spar_avg, last_b1_sgd_128_spar_se, last_b1_sgd_128_selec_avg, last_b1_sgd_128_selec_se = val_extractor_extract_last('seed1/batch1/128/seed1_batch1_neuronsize128_SGD.txt', 'seed100/batch1/128/seed100_batch1_neuronsize128_SGD.txt', 'seed1234/batch1/128/seed1234_batch1_neuronsize128_SGD.txt')
last_b1_grad_128_acc_avg, last_b1_grad_128_acc_se, last_b1_grad_128_spar_avg, last_b1_grad_128_spar_se, last_b1_grad_128_selec_avg, last_b1_grad_128_selec_se = val_extractor_extract_last('seed1/batch1/128/seed1_batch1_neuronsize128_Adagrad.txt', 'seed100/batch1/128/seed100_batch1_neuronsize128_Adagrad.txt', 'seed1234/batch1/128/seed1234_batch1_neuronsize128_Adagrad.txt')
last_b1_delta_128_acc_avg, last_b1_delta_128_acc_se, last_b1_delta_128_spar_avg, last_b1_delta_128_spar_se, last_b1_delta_128_selec_avg, last_b1_delta_128_selec_se = val_extractor_extract_last('seed1/batch1/128/seed1_batch1_neuronsize128_Adadelta.txt', 'seed100/batch1/128/seed100_batch1_neuronsize128_Adadelta.txt', 'seed1234/batch1/128/seed1234_batch1_neuronsize128_Adadelta.txt')
last_b1_adam_128_acc_avg, last_b1_adam_128_acc_se, last_b1_adam_128_spar_avg, last_b1_adam_128_spar_se, last_b1_adam_128_selec_avg, last_b1_adam_128_selec_se = val_extractor_extract_last('seed1/batch1/128/seed1_batch1_neuronsize128_Adam.txt', 'seed100/batch1/128/seed100_batch1_neuronsize128_Adam.txt', 'seed1234/batch1/128/seed1234_batch1_neuronsize128_Adam.txt')

# 256
last_b1_sgd_256_acc_avg, last_b1_sgd_256_acc_se, last_b1_sgd_256_spar_avg, last_b1_sgd_256_spar_se, last_b1_sgd_256_selec_avg, last_b1_sgd_256_selec_se = val_extractor_extract_last('seed1/batch1/256/seed1_batch1_neuronsize256_SGD.txt', 'seed100/batch1/256/seed100_batch1_neuronsize256_SGD.txt', 'seed1234/batch1/256/seed1234_batch1_neuronsize256_SGD.txt')
last_b1_grad_256_acc_avg, last_b1_grad_256_acc_se, last_b1_grad_256_spar_avg, last_b1_grad_256_spar_se, last_b1_grad_256_selec_avg, last_b1_grad_256_selec_se = val_extractor_extract_last('seed1/batch1/256/seed1_batch1_neuronsize256_Adagrad.txt', 'seed100/batch1/256/seed100_batch1_neuronsize256_Adagrad.txt', 'seed1234/batch1/256/seed1234_batch1_neuronsize256_Adagrad.txt')
last_b1_delta_256_acc_avg, last_b1_delta_256_acc_se, last_b1_delta_256_spar_avg, last_b1_delta_256_spar_se, last_b1_delta_256_selec_avg, last_b1_delta_256_selec_se = val_extractor_extract_last('seed1/batch1/256/seed1_batch1_neuronsize256_Adadelta.txt', 'seed100/batch1/256/seed100_batch1_neuronsize256_Adadelta.txt', 'seed1234/batch1/256/seed1234_batch1_neuronsize256_Adadelta.txt')
last_b1_adam_256_acc_avg, last_b1_adam_256_acc_se, last_b1_adam_256_spar_avg, last_b1_adam_256_spar_se, last_b1_adam_256_selec_avg, last_b1_adam_256_selec_se = val_extractor_extract_last('seed1/batch1/256/seed1_batch1_neuronsize256_Adam.txt', 'seed100/batch1/256/seed100_batch1_neuronsize256_Adam.txt', 'seed1234/batch1/256/seed1234_batch1_neuronsize256_Adam.txt')

# 384 
last_b1_sgd_384_acc_avg, last_b1_sgd_384_acc_se, last_b1_sgd_384_spar_avg, last_b1_sgd_384_spar_se, last_b1_sgd_384_selec_avg, last_b1_sgd_384_selec_se = val_extractor_extract_last('seed1/batch1/384/seed1_batch1_neuronsize384_SGD.txt', 'seed100/batch1/384/seed100_batch1_neuronsize384_SGD.txt', 'seed1234/batch1/384/seed1234_batch1_neuronsize384_SGD.txt')
last_b1_grad_384_acc_avg, last_b1_grad_384_acc_se, last_b1_grad_384_spar_avg, last_b1_grad_384_spar_se, last_b1_grad_384_selec_avg, last_b1_grad_384_selec_se = val_extractor_extract_last('seed1/batch1/384/seed1_batch1_neuronsize384_Adagrad.txt', 'seed100/batch1/384/seed100_batch1_neuronsize384_Adagrad.txt', 'seed1234/batch1/384/seed1234_batch1_neuronsize384_Adagrad.txt')
last_b1_delta_384_acc_avg, last_b1_delta_384_acc_se, last_b1_delta_384_spar_avg, last_b1_delta_384_spar_se, last_b1_delta_384_selec_avg, last_b1_delta_384_selec_se = val_extractor_extract_last('seed1/batch1/384/seed1_batch1_neuronsize384_Adadelta.txt', 'seed100/batch1/384/seed100_batch1_neuronsize384_Adadelta.txt', 'seed1234/batch1/384/seed1234_batch1_neuronsize384_Adadelta.txt')
last_b1_adam_384_acc_avg, last_b1_adam_384_acc_se, last_b1_adam_384_spar_avg, last_b1_adam_384_spar_se, last_b1_adam_384_selec_avg, last_b1_adam_384_selec_se = val_extractor_extract_last('seed1/batch1/384/seed1_batch1_neuronsize384_Adam.txt', 'seed100/batch1/384/seed100_batch1_neuronsize384_Adam.txt', 'seed1234/batch1/384/seed1234_batch1_neuronsize384_Adam.txt')

# 512
last_b1_sgd_512_acc_avg, last_b1_sgd_512_acc_se, last_b1_sgd_512_spar_avg, last_b1_sgd_512_spar_se, last_b1_sgd_512_selec_avg, last_b1_sgd_512_selec_se = val_extractor_extract_last('seed1/batch1/512/seed1_batch1_neuronsize512_SGD.txt', 'seed100/batch1/512/seed100_batch1_neuronsize512_SGD.txt', 'seed1234/batch1/512/seed1234_batch1_neuronsize512_SGD.txt')
last_b1_grad_512_acc_avg, last_b1_grad_512_acc_se, last_b1_grad_512_spar_avg, last_b1_grad_512_spar_se, last_b1_grad_512_selec_avg, last_b1_grad_512_selec_se = val_extractor_extract_last('seed1/batch1/512/seed1_batch1_neuronsize512_Adagrad.txt', 'seed100/batch1/512/seed100_batch1_neuronsize512_Adagrad.txt', 'seed1234/batch1/512/seed1234_batch1_neuronsize512_Adagrad.txt')
last_b1_delta_512_acc_avg, last_b1_delta_512_acc_se, last_b1_delta_512_spar_avg, last_b1_delta_512_spar_se, last_b1_delta_512_selec_avg, last_b1_delta_512_selec_se = val_extractor_extract_last('seed1/batch1/512/seed1_batch1_neuronsize512_Adadelta.txt', 'seed100/batch1/512/seed100_batch1_neuronsize512_Adadelta.txt', 'seed1234/batch1/512/seed1234_batch1_neuronsize512_Adadelta.txt')
last_b1_adam_512_acc_avg, last_b1_adam_512_acc_se, last_b1_adam_512_spar_avg, last_b1_adam_512_spar_se, last_b1_adam_512_selec_avg, last_b1_adam_512_selec_se = val_extractor_extract_last('seed1/batch1/512/seed1_batch1_neuronsize512_Adam.txt', 'seed100/batch1/512/seed100_batch1_neuronsize512_Adam.txt', 'seed1234/batch1/512/seed1234_batch1_neuronsize512_Adam.txt')

# 640 
last_b1_sgd_640_acc_avg, last_b1_sgd_640_acc_se, last_b1_sgd_640_spar_avg, last_b1_sgd_640_spar_se, last_b1_sgd_640_selec_avg, last_b1_sgd_640_selec_se = val_extractor_extract_last('seed1/batch1/640/seed1_batch1_neuronsize640_SGD.txt', 'seed100/batch1/640/seed100_batch1_neuronsize640_SGD.txt', 'seed1234/batch1/640/seed1234_batch1_neuronsize640_SGD.txt')
last_b1_grad_640_acc_avg, last_b1_grad_640_acc_se, last_b1_grad_640_spar_avg, last_b1_grad_640_spar_se, last_b1_grad_640_selec_avg, last_b1_grad_640_selec_se = val_extractor_extract_last('seed1/batch1/640/seed1_batch1_neuronsize640_Adagrad.txt', 'seed100/batch1/640/seed100_batch1_neuronsize640_Adagrad.txt', 'seed1234/batch1/640/seed1234_batch1_neuronsize640_Adagrad.txt')
last_b1_delta_640_acc_avg, last_b1_delta_640_acc_se, last_b1_delta_640_spar_avg, last_b1_delta_640_spar_se, last_b1_delta_640_selec_avg, last_b1_delta_640_selec_se = val_extractor_extract_last('seed1/batch1/640/seed1_batch1_neuronsize640_Adadelta.txt', 'seed100/batch1/640/seed100_batch1_neuronsize640_Adadelta.txt', 'seed1234/batch1/640/seed1234_batch1_neuronsize640_Adadelta.txt')
last_b1_adam_640_acc_avg, last_b1_adam_640_acc_se, last_b1_adam_640_spar_avg, last_b1_adam_640_spar_se, last_b1_adam_640_selec_avg, last_b1_adam_640_selec_se = val_extractor_extract_last('seed1/batch1/640/seed1_batch1_neuronsize640_Adam.txt', 'seed100/batch1/640/seed100_batch1_neuronsize640_Adam.txt', 'seed1234/batch1/640/seed1234_batch1_neuronsize640_Adam.txt')

# 768
last_b1_sgd_768_acc_avg, last_b1_sgd_768_acc_se, last_b1_sgd_768_spar_avg, last_b1_sgd_768_spar_se, last_b1_sgd_768_selec_avg, last_b1_sgd_768_selec_se = val_extractor_extract_last('seed1/batch1/768/seed1_batch1_neuronsize768_SGD.txt', 'seed100/batch1/768/seed100_batch1_neuronsize768_SGD.txt', 'seed1234/batch1/768/seed1234_batch1_neuronsize768_SGD.txt')
last_b1_grad_768_acc_avg, last_b1_grad_768_acc_se, last_b1_grad_768_spar_avg, last_b1_grad_768_spar_se, last_b1_grad_768_selec_avg, last_b1_grad_768_selec_se = val_extractor_extract_last('seed1/batch1/768/seed1_batch1_neuronsize768_Adagrad.txt', 'seed100/batch1/768/seed100_batch1_neuronsize768_Adagrad.txt', 'seed1234/batch1/768/seed1234_batch1_neuronsize768_Adagrad.txt')
last_b1_delta_768_acc_avg, last_b1_delta_768_acc_se, last_b1_delta_768_spar_avg, last_b1_delta_768_spar_se, last_b1_delta_768_selec_avg, last_b1_delta_768_selec_se = val_extractor_extract_last('seed1/batch1/768/seed1_batch1_neuronsize768_Adadelta.txt', 'seed100/batch1/768/seed100_batch1_neuronsize768_Adadelta.txt', 'seed1234/batch1/768/seed1234_batch1_neuronsize768_Adadelta.txt')
last_b1_adam_768_acc_avg, last_b1_adam_768_acc_se, last_b1_adam_768_spar_avg, last_b1_adam_768_spar_se, last_b1_adam_768_selec_avg, last_b1_adam_768_selec_se = val_extractor_extract_last('seed1/batch1/768/seed1_batch1_neuronsize768_Adam.txt', 'seed100/batch1/768/seed100_batch1_neuronsize768_Adam.txt', 'seed1234/batch1/768/seed1234_batch1_neuronsize768_Adam.txt')

# %%
# batch50

# sgd 
b50_sgd_acc = [last_b50_sgd_64_acc_avg, last_b50_sgd_128_acc_avg, last_b50_sgd_256_acc_avg, last_b50_sgd_384_acc_avg, last_b50_sgd_512_acc_avg, last_b50_sgd_640_acc_avg, last_b50_sgd_768_acc_avg]
b50_sgd_acc_se = [last_b50_sgd_64_acc_se, last_b50_sgd_128_acc_se, last_b50_sgd_256_acc_se, last_b50_sgd_384_acc_se, last_b50_sgd_512_acc_se, last_b50_sgd_640_acc_se, last_b50_sgd_768_acc_se]
b50_sgd_spar = [last_b50_sgd_64_spar_avg, last_b50_sgd_128_spar_avg, last_b50_sgd_256_spar_avg, last_b50_sgd_384_spar_avg, last_b50_sgd_512_spar_avg, last_b50_sgd_640_spar_avg, last_b50_sgd_768_spar_avg]
b50_sgd_spar_se = [last_b50_sgd_64_spar_se, last_b50_sgd_128_spar_se, last_b50_sgd_256_spar_se, last_b50_sgd_384_spar_se, last_b50_sgd_512_spar_se, last_b50_sgd_640_spar_se, last_b50_sgd_768_spar_se]
b50_sgd_selec = [last_b50_sgd_64_selec_avg, last_b50_sgd_128_selec_avg, last_b50_sgd_256_selec_avg, last_b50_sgd_384_selec_avg, last_b50_sgd_512_selec_avg, last_b50_sgd_640_selec_avg, last_b50_sgd_768_selec_avg]
b50_sgd_selec_se = [last_b50_sgd_64_selec_se, last_b50_sgd_128_selec_se, last_b50_sgd_256_selec_se, last_b50_sgd_384_selec_se, last_b50_sgd_512_selec_se, last_b50_sgd_640_selec_se, last_b50_sgd_768_selec_se]

# adagrad
b50_grad_acc = [last_b50_grad_64_acc_avg, last_b50_grad_128_acc_avg, last_b50_grad_256_acc_avg, last_b50_grad_384_acc_avg, last_b50_grad_512_acc_avg, last_b50_grad_640_acc_avg, last_b50_grad_768_acc_avg]
b50_grad_acc_se = [last_b50_grad_64_acc_se, last_b50_grad_128_acc_se, last_b50_grad_256_acc_se, last_b50_grad_384_acc_se, last_b50_grad_512_acc_se, last_b50_grad_640_acc_se, last_b50_grad_768_acc_se]
b50_grad_spar = [last_b50_grad_64_spar_avg, last_b50_grad_128_spar_avg, last_b50_grad_256_spar_avg, last_b50_grad_384_spar_avg, last_b50_grad_512_spar_avg, last_b50_grad_640_spar_avg, last_b50_grad_768_spar_avg]
b50_grad_spar_se = [last_b50_grad_64_spar_se, last_b50_grad_128_spar_se, last_b50_grad_256_spar_se, last_b50_grad_384_spar_se, last_b50_grad_512_spar_se, last_b50_grad_640_spar_se, last_b50_grad_768_spar_se]
b50_grad_selec = [last_b50_grad_64_selec_avg, last_b50_grad_128_selec_avg, last_b50_grad_256_selec_avg, last_b50_grad_384_selec_avg, last_b50_grad_512_selec_avg, last_b50_grad_640_selec_avg, last_b50_grad_768_selec_avg]
b50_grad_selec_se = [last_b50_grad_64_selec_se, last_b50_grad_128_selec_se, last_b50_grad_256_selec_se, last_b50_grad_384_selec_se, last_b50_grad_512_selec_se, last_b50_grad_640_selec_se, last_b50_grad_768_selec_se]

# adadelta 
b50_delta_acc = [last_b50_delta_64_acc_avg, last_b50_delta_128_acc_avg, last_b50_delta_256_acc_avg, last_b50_delta_384_acc_avg, last_b50_delta_512_acc_avg, last_b50_delta_640_acc_avg, last_b50_delta_768_acc_avg]
b50_delta_acc_se = [last_b50_delta_64_acc_se, last_b50_delta_128_acc_se, last_b50_delta_256_acc_se, last_b50_delta_384_acc_se, last_b50_delta_512_acc_se, last_b50_delta_640_acc_se, last_b50_delta_768_acc_se]
b50_delta_spar = [last_b50_delta_64_spar_avg, last_b50_delta_128_spar_avg, last_b50_delta_256_spar_avg, last_b50_delta_384_spar_avg, last_b50_delta_512_spar_avg, last_b50_delta_640_spar_avg, last_b50_delta_768_spar_avg]
b50_delta_spar_se = [last_b50_delta_64_spar_se, last_b50_delta_128_spar_se, last_b50_delta_256_spar_se, last_b50_delta_384_spar_se, last_b50_delta_512_spar_se, last_b50_delta_640_spar_se, last_b50_delta_768_spar_se]
b50_delta_selec = [last_b50_delta_64_selec_avg, last_b50_delta_128_selec_avg, last_b50_delta_256_selec_avg, last_b50_delta_384_selec_avg, last_b50_delta_512_selec_avg, last_b50_delta_640_selec_avg, last_b50_delta_768_selec_avg]
b50_delta_selec_se = [last_b50_delta_64_selec_se, last_b50_delta_128_selec_se, last_b50_delta_256_selec_se, last_b50_delta_384_selec_se, last_b50_delta_512_selec_se, last_b50_delta_640_selec_se, last_b50_delta_768_selec_se]

# adam 
b50_adam_acc = [last_b50_adam_64_acc_avg, last_b50_adam_128_acc_avg, last_b50_adam_256_acc_avg, last_b50_adam_384_acc_avg, last_b50_adam_512_acc_avg, last_b50_adam_640_acc_avg, last_b50_adam_768_acc_avg]
b50_adam_acc_se = [last_b50_adam_64_acc_se, last_b50_adam_128_acc_se, last_b50_adam_256_acc_se, last_b50_adam_384_acc_se, last_b50_adam_512_acc_se, last_b50_adam_640_acc_se, last_b50_adam_768_acc_se]
b50_adam_spar = [last_b50_adam_64_spar_avg, last_b50_adam_128_spar_avg, last_b50_adam_256_spar_avg, last_b50_adam_384_spar_avg, last_b50_adam_512_spar_avg, last_b50_adam_640_spar_avg, last_b50_adam_768_spar_avg]
b50_adam_spar_se = [last_b50_adam_64_spar_se, last_b50_adam_128_spar_se, last_b50_adam_256_spar_se, last_b50_adam_384_spar_se, last_b50_adam_512_spar_se, last_b50_adam_640_spar_se, last_b50_adam_768_spar_se]
b50_adam_selec = [last_b50_adam_64_selec_avg, last_b50_adam_128_selec_avg, last_b50_adam_256_selec_avg, last_b50_adam_384_selec_avg, last_b50_adam_512_selec_avg, last_b50_adam_640_selec_avg, last_b50_adam_768_selec_avg]
b50_adam_selec_se = [last_b50_adam_64_selec_se, last_b50_adam_128_selec_se, last_b50_adam_256_selec_se, last_b50_adam_384_selec_se, last_b50_adam_512_selec_se, last_b50_adam_640_selec_se, last_b50_adam_768_selec_se]

# %%
# batch1

# sgd 
b1_sgd_acc = [last_b1_sgd_64_acc_avg, last_b1_sgd_128_acc_avg, last_b1_sgd_256_acc_avg, last_b1_sgd_384_acc_avg, last_b1_sgd_512_acc_avg, last_b1_sgd_640_acc_avg, last_b1_sgd_768_acc_avg]
b1_sgd_acc_se = [last_b1_sgd_64_acc_se, last_b1_sgd_128_acc_se, last_b1_sgd_256_acc_se, last_b1_sgd_384_acc_se, last_b1_sgd_512_acc_se, last_b1_sgd_640_acc_se, last_b1_sgd_768_acc_se]
b1_sgd_spar = [last_b1_sgd_64_spar_avg, last_b1_sgd_128_spar_avg, last_b1_sgd_256_spar_avg, last_b1_sgd_384_spar_avg, last_b1_sgd_512_spar_avg, last_b1_sgd_640_spar_avg, last_b1_sgd_768_spar_avg]
b1_sgd_spar_se = [last_b1_sgd_64_spar_se, last_b1_sgd_128_spar_se, last_b1_sgd_256_spar_se, last_b1_sgd_384_spar_se, last_b1_sgd_512_spar_se, last_b1_sgd_640_spar_se, last_b1_sgd_768_spar_se]
b1_sgd_selec = [last_b1_sgd_64_selec_avg, last_b1_sgd_128_selec_avg, last_b1_sgd_256_selec_avg, last_b1_sgd_384_selec_avg, last_b1_sgd_512_selec_avg, last_b1_sgd_640_selec_avg, last_b1_sgd_768_selec_avg]
b1_sgd_selec_se = [last_b1_sgd_64_selec_se, last_b1_sgd_128_selec_se, last_b1_sgd_256_selec_se, last_b1_sgd_384_selec_se, last_b1_sgd_512_selec_se, last_b1_sgd_640_selec_se, last_b1_sgd_768_selec_se]

# adagrad
b1_grad_acc = [last_b1_grad_64_acc_avg, last_b1_grad_128_acc_avg, last_b1_grad_256_acc_avg, last_b1_grad_384_acc_avg, last_b1_grad_512_acc_avg, last_b1_grad_640_acc_avg, last_b1_grad_768_acc_avg]
b1_grad_acc_se = [last_b1_grad_64_acc_se, last_b1_grad_128_acc_se, last_b1_grad_256_acc_se, last_b1_grad_384_acc_se, last_b1_grad_512_acc_se, last_b1_grad_640_acc_se, last_b1_grad_768_acc_se]
b1_grad_spar = [last_b1_grad_64_spar_avg, last_b1_grad_128_spar_avg, last_b1_grad_256_spar_avg, last_b1_grad_384_spar_avg, last_b1_grad_512_spar_avg, last_b1_grad_640_spar_avg, last_b1_grad_768_spar_avg]
b1_grad_spar_se = [last_b1_grad_64_spar_se, last_b1_grad_128_spar_se, last_b1_grad_256_spar_se, last_b1_grad_384_spar_se, last_b1_grad_512_spar_se, last_b1_grad_640_spar_se, last_b1_grad_768_spar_se]
b1_grad_selec = [last_b1_grad_64_selec_avg, last_b1_grad_128_selec_avg, last_b1_grad_256_selec_avg, last_b1_grad_384_selec_avg, last_b1_grad_512_selec_avg, last_b1_grad_640_selec_avg, last_b1_grad_768_selec_avg]
b1_grad_selec_se = [last_b1_grad_64_selec_se, last_b1_grad_128_selec_se, last_b1_grad_256_selec_se, last_b1_grad_384_selec_se, last_b1_grad_512_selec_se, last_b1_grad_640_selec_se, last_b1_grad_768_selec_se]

# adadelta 
b1_delta_acc = [last_b1_delta_64_acc_avg, last_b1_delta_128_acc_avg, last_b1_delta_256_acc_avg, last_b1_delta_384_acc_avg, last_b1_delta_512_acc_avg, last_b1_delta_640_acc_avg, last_b1_delta_768_acc_avg]
b1_delta_acc_se = [last_b1_delta_64_acc_se, last_b1_delta_128_acc_se, last_b1_delta_256_acc_se, last_b1_delta_384_acc_se, last_b1_delta_512_acc_se, last_b1_delta_640_acc_se, last_b1_delta_768_acc_se]
b1_delta_spar = [last_b1_delta_64_spar_avg, last_b1_delta_128_spar_avg, last_b1_delta_256_spar_avg, last_b1_delta_384_spar_avg, last_b1_delta_512_spar_avg, last_b1_delta_640_spar_avg, last_b1_delta_768_spar_avg]
b1_delta_spar_se = [last_b1_delta_64_spar_se, last_b1_delta_128_spar_se, last_b1_delta_256_spar_se, last_b1_delta_384_spar_se, last_b1_delta_512_spar_se, last_b1_delta_640_spar_se, last_b1_delta_768_spar_se]
b1_delta_selec = [last_b1_delta_64_selec_avg, last_b1_delta_128_selec_avg, last_b1_delta_256_selec_avg, last_b1_delta_384_selec_avg, last_b1_delta_512_selec_avg, last_b1_delta_640_selec_avg, last_b1_delta_768_selec_avg]
b1_delta_selec_se = [last_b1_delta_64_selec_se, last_b1_delta_128_selec_se, last_b1_delta_256_selec_se, last_b1_delta_384_selec_se, last_b1_delta_512_selec_se, last_b1_delta_640_selec_se, last_b1_delta_768_selec_se]

# adam 
b1_adam_acc = [last_b1_adam_64_acc_avg, last_b1_adam_128_acc_avg, last_b1_adam_256_acc_avg, last_b1_adam_384_acc_avg, last_b1_adam_512_acc_avg, last_b1_adam_640_acc_avg, last_b1_adam_768_acc_avg]
b1_adam_acc_se = [last_b1_adam_64_acc_se, last_b1_adam_128_acc_se, last_b1_adam_256_acc_se, last_b1_adam_384_acc_se, last_b1_adam_512_acc_se, last_b1_adam_640_acc_se, last_b1_adam_768_acc_se]
b1_adam_spar = [last_b1_adam_64_spar_avg, last_b1_adam_128_spar_avg, last_b1_adam_256_spar_avg, last_b1_adam_384_spar_avg, last_b1_adam_512_spar_avg, last_b1_adam_640_spar_avg, last_b1_adam_768_spar_avg]
b1_adam_spar_se = [last_b1_adam_64_spar_se, last_b1_adam_128_spar_se, last_b1_adam_256_spar_se, last_b1_adam_384_spar_se, last_b1_adam_512_spar_se, last_b1_adam_640_spar_se, last_b1_adam_768_spar_se]
b1_adam_selec = [last_b1_adam_64_selec_avg, last_b1_adam_128_selec_avg, last_b1_adam_256_selec_avg, last_b1_adam_384_selec_avg, last_b1_adam_512_selec_avg, last_b1_adam_640_selec_avg, last_b1_adam_768_selec_avg]
b1_adam_selec_se = [last_b1_adam_64_selec_se, last_b1_adam_128_selec_se, last_b1_adam_256_selec_se, last_b1_adam_384_selec_se, last_b1_adam_512_selec_se, last_b1_adam_640_selec_se, last_b1_adam_768_selec_se]

# %%
e7 = np.linspace(1, 7, 7)

fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(15, 5))

# default setting for grpahs 
hl_ticks = ['64', '128', '256', '384', '512', '640', '768']
ax1.set_xticks(np.linspace(1, 7, 7))
ax1.set_xticklabels(hl_ticks)

ax2.set_xticks(np.linspace(1, 7, 7))
ax2.set_xticklabels(hl_ticks)

ax3.set_xticks(np.linspace(1, 7, 7))
ax3.set_xticklabels(hl_ticks)

# batch 50 
# Accuracy 
# SGD
ax1.plot(e7, b50_sgd_acc, label='SGD', marker='o', c='darkred')
ax1.fill_between(e7, np.subtract(b50_sgd_acc, b50_sgd_acc_se), np.add(b50_sgd_acc, b50_sgd_acc_se), color='lightcoral', alpha=0.5)
# Adagrad
ax1.plot(e7, b50_grad_acc, label='Adagrad', marker='^', c='darkgreen')
ax1.fill_between(e7, np.subtract(b50_grad_acc, b50_grad_acc_se), np.add(b50_grad_acc, b50_grad_acc_se), color='lime', alpha=0.5)
# Adadelta
ax1.plot(e7, b50_delta_acc, label='Adadelta', marker='v', c='darkblue')
ax1.fill_between(e7, np.subtract(b50_delta_acc, b50_delta_acc_se), np.add(b50_delta_acc, b50_delta_acc_se), color='lightsteelblue', alpha=0.5)
# Adam
ax1.plot(e7, b50_adam_acc, label='Adam', marker='s', c='purple')
ax1.fill_between(e7, np.subtract(b50_adam_acc, b50_adam_acc_se), np.add(b50_adam_acc, b50_adam_acc_se), color='violet', alpha=0.5)


# Sparsity 
# SGD
ax2.plot(e7, b50_sgd_spar, label='SGD', marker='o', c='darkred')
ax2.fill_between(e7, np.subtract(b50_sgd_spar, b50_sgd_spar_se), np.add(b50_sgd_spar, b50_sgd_spar_se), color='lightcoral', alpha=0.5)
# Adagrad
ax2.plot(e7, b50_grad_spar, label='Adagrad', marker='^', c='darkgreen')
ax2.fill_between(e7, np.subtract(b50_grad_spar, b50_grad_spar_se), np.add(b50_grad_spar, b50_grad_spar_se), color='lime', alpha=0.5)
# Adadelta
ax2.plot(e7, b50_delta_spar, label='Adadelta', marker='v', c='darkblue')
ax2.fill_between(e7, np.subtract(b50_delta_spar, b50_delta_spar_se), np.add(b50_delta_spar, b50_delta_spar_se), color='lightsteelblue', alpha=0.5)
# Adam
ax2.plot(e7, b50_adam_spar, label='Adam', marker='s', c='purple')
ax2.fill_between(e7, np.subtract(b50_adam_spar, b50_adam_spar_se), np.add(b50_adam_spar, b50_adam_spar_se), color='violet', alpha=0.5)


# Selectivity
# SGD
ax3.plot(e7, b50_sgd_selec, label='SGD', marker='o', c='darkred')
ax3.fill_between(e7, np.subtract(b50_sgd_selec, b50_sgd_selec_se), np.add(b50_sgd_selec, b50_sgd_selec_se), color='lightcoral', alpha=0.5)
# Adagrad
ax3.plot(e7, b50_grad_selec, label='Adagrad', marker='^', c='darkgreen')
ax3.fill_between(e7, np.subtract(b50_grad_selec, b50_grad_selec_se), np.add(b50_grad_selec, b50_grad_selec_se), color='lime', alpha=0.5)
# Adadelta
ax3.plot(e7, b50_delta_selec, label='Adadelta', marker='v', c='darkblue')
ax3.fill_between(e7, np.subtract(b50_delta_selec, b50_delta_selec_se), np.add(b50_delta_selec, b50_delta_selec_se), color='lightsteelblue', alpha=0.5)
# Adam
ax3.plot(e7, b50_adam_selec, label='Adam', marker='s', c='purple')
ax3.fill_between(e7, np.subtract(b50_adam_selec, b50_adam_selec_se), np.add(b50_adam_selec, b50_adam_selec_se), color='violet', alpha=0.5)



# batch 1
# Accuracy 
# SGD
ax1.plot(e7, b1_sgd_acc, label='SGD', marker='o', c='saddlebrown')
ax1.fill_between(e7, np.subtract(b1_sgd_acc, b1_sgd_acc_se), np.add(b1_sgd_acc, b1_sgd_acc_se), color='sandybrown', alpha=0.5)
# Adagrad
ax1.plot(e7, b1_grad_acc, label='Adagrad', marker='^', c='teal')
ax1.fill_between(e7, np.subtract(b1_grad_acc, b1_grad_acc_se), np.add(b1_grad_acc, b1_grad_acc_se), color='aqua', alpha=0.5)
# Adadelta
ax1.plot(e7, b1_delta_acc, label='Adadelta', marker='v', c='darkslateblue')
ax1.fill_between(e7, np.subtract(b1_delta_acc, b1_delta_acc_se), np.add(b1_delta_acc, b1_delta_acc_se), color='slateblue', alpha=0.5)
# Adam
ax1.plot(e7, b1_adam_acc, label='Adam', marker='s', c='deeppink')
ax1.fill_between(e7, np.subtract(b1_adam_acc, b1_adam_acc_se), np.add(b1_adam_acc, b1_adam_acc_se), color='hotpink', alpha=0.5)


# Sparsity 
# SGD
ax2.plot(e7, b1_sgd_spar, label='SGD', marker='o', c='saddlebrown')
ax2.fill_between(e7, np.subtract(b1_sgd_spar, b1_sgd_spar_se), np.add(b1_sgd_spar, b1_sgd_spar_se), color='sandybrown', alpha=0.5)
# Adagrad
ax2.plot(e7, b1_grad_spar, label='Adagrad', marker='^', c='teal')
ax2.fill_between(e7, np.subtract(b1_grad_spar, b1_grad_spar_se), np.add(b1_grad_spar, b1_grad_spar_se), color='aqua', alpha=0.5)
# Adadelta
ax2.plot(e7, b1_delta_spar, label='Adadelta', marker='v', c='darkslateblue')
ax2.fill_between(e7, np.subtract(b1_delta_spar, b1_delta_spar_se), np.add(b1_delta_spar, b1_delta_spar_se), color='slateblue', alpha=0.5)
# Adam
ax2.plot(e7, b1_adam_spar, label='Adam', marker='s', c='deeppink')
ax2.fill_between(e7, np.subtract(b1_adam_spar, b1_adam_spar_se), np.add(b1_adam_spar, b1_adam_spar_se), color='hotpink', alpha=0.5)


# Selectivity
# SGD
ax3.plot(e7, b1_sgd_selec, label='SGD', marker='o', c='saddlebrown')
ax3.fill_between(e7, np.subtract(b1_sgd_selec, b1_sgd_selec_se), np.add(b1_sgd_selec, b1_sgd_selec_se), color='sandybrown', alpha=0.5)
# Adagrad
ax3.plot(e7, b1_grad_selec, label='Adagrad', marker='^', c='teal')
ax3.fill_between(e7, np.subtract(b1_grad_selec, b1_grad_selec_se), np.add(b1_grad_selec, b1_grad_selec_se), color='aqua', alpha=0.5)
# Adadelta
ax3.plot(e7, b1_delta_selec, label='Adadelta', marker='v', c='darkslateblue')
ax3.fill_between(e7, np.subtract(b1_delta_selec, b1_delta_selec_se), np.add(b1_delta_selec, b1_delta_selec_se), color='slateblue', alpha=0.5)
# Adam
ax3.plot(e7, b1_adam_selec, label='Adam', marker='s', c='deeppink')
ax3.fill_between(e7, np.subtract(b1_adam_selec, b1_adam_selec_se), np.add(b1_adam_selec, b1_adam_selec_se), color='hotpink', alpha=0.5)


ax1.grid()
ax2.grid()
ax3.grid()

ax1.set_title('Test-accuracy')
ax2.set_title('Sparsity')
ax3.set_title('Selectivity')

ax1.set_ylabel('Test-accuracy, Sparsity, and Selectivity')

ax1.axvline(x=3, color='black')
ax2.axvline(x=3, color='black')
ax3.axvline(x=3, color='black')

ax3.legend(loc='upper center', bbox_to_anchor=(-0.7, -0.1),
          fancybox=True, shadow=True, ncol=2)

# %% [markdown]
# # batch 50

# %%
e30 = np.linspace(1, 30, 30)

# ['64', '128', '256', '384', '512', '640', '768']

fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, figsize=(20, 5))

# ax1 == SGD 
# ax2 == Adagrad 
# ax3 == Adadelta 
# ax4 == Adam 

# SGD
# 64
ax1.plot(e30, b50_sgd_64_acc_avg, c='darkred', label='64')
ax1.fill_between(e30, np.subtract(b50_sgd_64_acc_avg, b50_sgd_64_acc_se), np.add(b50_sgd_64_acc_avg, b50_sgd_64_acc_se), color='lightcoral', alpha=0.5)
# 128
ax1.plot(e30, b50_sgd_128_acc_avg, c='darkorange', label='128')
ax1.fill_between(e30, np.subtract(b50_sgd_128_acc_avg, b50_sgd_128_acc_se), np.add(b50_sgd_128_acc_avg, b50_sgd_128_acc_se), color='moccasin', alpha=0.5)
# 256
ax1.plot(e30, b50_sgd_256_acc_avg, c='saddlebrown', label='256')
ax1.fill_between(e30, np.subtract(b50_sgd_256_acc_avg, b50_sgd_256_acc_se), np.add(b50_sgd_256_acc_avg, b50_sgd_256_acc_se), color='peru', alpha=0.5)
# 384
ax1.plot(e30, b50_sgd_384_acc_avg, c='darkgreen', label='384')
ax1.fill_between(e30, np.subtract(b50_sgd_384_acc_avg, b50_sgd_384_acc_se), np.add(b50_sgd_384_acc_avg, b50_sgd_384_acc_se), color='lime', alpha=0.5)
# 512 
ax1.plot(e30, b50_sgd_512_acc_avg, c='royalblue', label='512')
ax1.fill_between(e30, np.subtract(b50_sgd_512_acc_avg, b50_sgd_512_acc_se), np.add(b50_sgd_512_acc_avg, b50_sgd_512_acc_se), color='lightsteelblue', alpha=0.5)
# 640 
ax1.plot(e30, b50_sgd_640_acc_avg, c='purple', label='640')
ax1.fill_between(e30, np.subtract(b50_sgd_640_acc_avg, b50_sgd_640_acc_se), np.add(b50_sgd_640_acc_avg, b50_sgd_640_acc_se), color='violet', alpha=0.5)
# 768
ax1.plot(e30, b50_sgd_768_acc_avg, c='black', label='768')
ax1.fill_between(e30, np.subtract(b50_sgd_768_acc_avg, b50_sgd_768_acc_se), np.add(b50_sgd_768_acc_avg, b50_sgd_768_acc_se), color='lightgrey', alpha=0.5)


# Adagrad 
# 64
ax2.plot(e30, b50_grad_64_acc_avg, c='darkred', label='64')
ax2.fill_between(e30, np.subtract(b50_grad_64_acc_avg, b50_grad_64_acc_se), np.add(b50_grad_64_acc_avg, b50_grad_64_acc_se), color='lightcoral', alpha=0.5)
# 128
ax2.plot(e30, b50_grad_128_acc_avg, c='darkorange', label='128')
ax2.fill_between(e30, np.subtract(b50_grad_128_acc_avg, b50_grad_128_acc_se), np.add(b50_grad_128_acc_avg, b50_grad_128_acc_se), color='moccasin', alpha=0.5)
# 256
ax2.plot(e30, b50_grad_256_acc_avg, c='saddlebrown', label='256')
ax2.fill_between(e30, np.subtract(b50_grad_256_acc_avg, b50_grad_256_acc_se), np.add(b50_grad_256_acc_avg, b50_grad_256_acc_se), color='peru', alpha=0.5)
# 384
ax2.plot(e30, b50_grad_384_acc_avg, c='darkgreen', label='384')
ax2.fill_between(e30, np.subtract(b50_grad_384_acc_avg, b50_grad_384_acc_se), np.add(b50_grad_384_acc_avg, b50_grad_384_acc_se), color='lime', alpha=0.5)
# 512 
ax2.plot(e30, b50_grad_512_acc_avg, c='royalblue', label='512')
ax2.fill_between(e30, np.subtract(b50_grad_512_acc_avg, b50_grad_512_acc_se), np.add(b50_grad_512_acc_avg, b50_grad_512_acc_se), color='lightsteelblue', alpha=0.5)
# 640 
ax2.plot(e30, b50_grad_640_acc_avg, c='purple', label='640')
ax2.fill_between(e30, np.subtract(b50_grad_640_acc_avg, b50_grad_640_acc_se), np.add(b50_grad_640_acc_avg, b50_grad_640_acc_se), color='violet', alpha=0.5)
# 768
ax2.plot(e30, b50_grad_768_acc_avg, c='black', label='768')
ax2.fill_between(e30, np.subtract(b50_grad_768_acc_avg, b50_grad_768_acc_se), np.add(b50_grad_768_acc_avg, b50_grad_768_acc_se), color='lightgrey', alpha=0.5)

# Adadelta
# 64
ax3.plot(e30, b50_delta_64_acc_avg, c='darkred', label='64')
ax3.fill_between(e30, np.subtract(b50_delta_64_acc_avg, b50_delta_64_acc_se), np.add(b50_delta_64_acc_avg, b50_delta_64_acc_se), color='lightcoral', alpha=0.5)
# 128
ax3.plot(e30, b50_delta_128_acc_avg, c='darkorange', label='128')
ax3.fill_between(e30, np.subtract(b50_delta_128_acc_avg, b50_delta_128_acc_se), np.add(b50_delta_128_acc_avg, b50_delta_128_acc_se), color='moccasin', alpha=0.5)
# 256
ax3.plot(e30, b50_delta_256_acc_avg, c='saddlebrown', label='256')
ax3.fill_between(e30, np.subtract(b50_delta_256_acc_avg, b50_delta_256_acc_se), np.add(b50_delta_256_acc_avg, b50_delta_256_acc_se), color='peru', alpha=0.5)
# 384
ax3.plot(e30, b50_delta_384_acc_avg, c='darkgreen', label='384')
ax3.fill_between(e30, np.subtract(b50_delta_384_acc_avg, b50_delta_384_acc_se), np.add(b50_delta_384_acc_avg, b50_delta_384_acc_se), color='lime', alpha=0.5)
# 512 
ax3.plot(e30, b50_delta_512_acc_avg, c='royalblue', label='512')
ax3.fill_between(e30, np.subtract(b50_delta_512_acc_avg, b50_delta_512_acc_se), np.add(b50_delta_512_acc_avg, b50_delta_512_acc_se), color='lightsteelblue', alpha=0.5)
# 640 
ax3.plot(e30, b50_delta_640_acc_avg, c='purple', label='640')
ax3.fill_between(e30, np.subtract(b50_delta_640_acc_avg, b50_delta_640_acc_se), np.add(b50_delta_640_acc_avg, b50_delta_640_acc_se), color='violet', alpha=0.5)
# 768
ax3.plot(e30, b50_delta_768_acc_avg, c='black', label='768')
ax3.fill_between(e30, np.subtract(b50_delta_768_acc_avg, b50_delta_768_acc_se), np.add(b50_delta_768_acc_avg, b50_delta_768_acc_se), color='lightgrey', alpha=0.5)

# Adam 
# 64
ax4.plot(e30, b50_adam_64_acc_avg, c='darkred', label='64')
ax4.fill_between(e30, np.subtract(b50_adam_64_acc_avg, b50_adam_64_acc_se), np.add(b50_adam_64_acc_avg, b50_adam_64_acc_se), color='lightcoral', alpha=0.5)
# 128
ax4.plot(e30, b50_adam_128_acc_avg, c='darkorange', label='128')
ax4.fill_between(e30, np.subtract(b50_adam_128_acc_avg, b50_adam_128_acc_se), np.add(b50_adam_128_acc_avg, b50_adam_128_acc_se), color='moccasin', alpha=0.5)
# 256
ax4.plot(e30, b50_adam_256_acc_avg, c='saddlebrown', label='256')
ax4.fill_between(e30, np.subtract(b50_adam_256_acc_avg, b50_adam_256_acc_se), np.add(b50_adam_256_acc_avg, b50_adam_256_acc_se), color='peru', alpha=0.5)
# 384
ax4.plot(e30, b50_adam_384_acc_avg, c='darkgreen', label='384')
ax4.fill_between(e30, np.subtract(b50_adam_384_acc_avg, b50_adam_384_acc_se), np.add(b50_adam_384_acc_avg, b50_adam_384_acc_se), color='lime', alpha=0.5)
# 512 
ax4.plot(e30, b50_adam_512_acc_avg, c='royalblue', label='512')
ax4.fill_between(e30, np.subtract(b50_adam_512_acc_avg, b50_adam_512_acc_se), np.add(b50_adam_512_acc_avg, b50_adam_512_acc_se), color='lightsteelblue', alpha=0.5)
# 640 
ax4.plot(e30, b50_adam_640_acc_avg, c='purple', label='640')
ax4.fill_between(e30, np.subtract(b50_adam_640_acc_avg, b50_adam_640_acc_se), np.add(b50_adam_640_acc_avg, b50_adam_640_acc_se), color='violet', alpha=0.5)
# 768
ax4.plot(e30, b50_adam_768_acc_avg, c='black', label='768')
ax4.fill_between(e30, np.subtract(b50_adam_768_acc_avg, b50_adam_768_acc_se), np.add(b50_adam_768_acc_avg, b50_adam_768_acc_se), color='lightgrey', alpha=0.5)

ax4.set_xlabel('Epochs')

ax1.set_title('batch size=50 SGD')
ax2.set_title('batch size=50 Adagrad')
ax3.set_title('batch size=50 Adadelta')
ax4.set_title('batch size=50 Adam')

ax1.set_xlabel('Epochs')
ax2.set_xlabel('Epochs')
ax3.set_xlabel('Epochs')
ax4.set_xlabel('Epochs')

ax1.set_ylabel('Test Accuracy')

ax1.grid()
ax2.grid()
ax3.grid()
ax4.grid()

# %%
e30 = np.linspace(1, 30, 30)

# ['64', '128', '256', '384', '512', '640', '768']

fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, figsize=(20, 5))

# ax1 == SGD 
# ax2 == Adagrad 
# ax3 == Adadelta 
# ax4 == Adam 

# SGD
# 64
ax1.plot(e30, b50_sgd_64_acc_avg, c='darkred', label='64')
ax1.fill_between(e30, np.subtract(b50_sgd_64_acc_avg, b50_sgd_64_acc_se), np.add(b50_sgd_64_acc_avg, b50_sgd_64_acc_se), color='lightcoral', alpha=0.5)
# 128
ax1.plot(e30, b50_sgd_128_acc_avg, c='darkorange', label='128')
ax1.fill_between(e30, np.subtract(b50_sgd_128_acc_avg, b50_sgd_128_acc_se), np.add(b50_sgd_128_acc_avg, b50_sgd_128_acc_se), color='moccasin', alpha=0.5)
# 256
ax1.plot(e30, b50_sgd_256_acc_avg, c='saddlebrown', label='256')
ax1.fill_between(e30, np.subtract(b50_sgd_256_acc_avg, b50_sgd_256_acc_se), np.add(b50_sgd_256_acc_avg, b50_sgd_256_acc_se), color='peru', alpha=0.5)
# 384
ax1.plot(e30, b50_sgd_384_acc_avg, c='darkgreen', label='384')
ax1.fill_between(e30, np.subtract(b50_sgd_384_acc_avg, b50_sgd_384_acc_se), np.add(b50_sgd_384_acc_avg, b50_sgd_384_acc_se), color='lime', alpha=0.5)
# 512 
ax1.plot(e30, b50_sgd_512_acc_avg, c='royalblue', label='512')
ax1.fill_between(e30, np.subtract(b50_sgd_512_acc_avg, b50_sgd_512_acc_se), np.add(b50_sgd_512_acc_avg, b50_sgd_512_acc_se), color='lightsteelblue', alpha=0.5)
# 640 
ax1.plot(e30, b50_sgd_640_acc_avg, c='purple', label='640')
ax1.fill_between(e30, np.subtract(b50_sgd_640_acc_avg, b50_sgd_640_acc_se), np.add(b50_sgd_640_acc_avg, b50_sgd_640_acc_se), color='violet', alpha=0.5)
# 768
ax1.plot(e30, b50_sgd_768_acc_avg, c='black', label='768')
ax1.fill_between(e30, np.subtract(b50_sgd_768_acc_avg, b50_sgd_768_acc_se), np.add(b50_sgd_768_acc_avg, b50_sgd_768_acc_se), color='lightgrey', alpha=0.5)


# Adagrad 
# 64
ax2.plot(e30, b50_grad_64_acc_avg, c='darkred', label='64')
ax2.fill_between(e30, np.subtract(b50_grad_64_acc_avg, b50_grad_64_acc_se), np.add(b50_grad_64_acc_avg, b50_grad_64_acc_se), color='lightcoral', alpha=0.5)
# 128
ax2.plot(e30, b50_grad_128_acc_avg, c='darkorange', label='128')
ax2.fill_between(e30, np.subtract(b50_grad_128_acc_avg, b50_grad_128_acc_se), np.add(b50_grad_128_acc_avg, b50_grad_128_acc_se), color='moccasin', alpha=0.5)
# 256
ax2.plot(e30, b50_grad_256_acc_avg, c='saddlebrown', label='256')
ax2.fill_between(e30, np.subtract(b50_grad_256_acc_avg, b50_grad_256_acc_se), np.add(b50_grad_256_acc_avg, b50_grad_256_acc_se), color='peru', alpha=0.5)
# 384
ax2.plot(e30, b50_grad_384_acc_avg, c='darkgreen', label='384')
ax2.fill_between(e30, np.subtract(b50_grad_384_acc_avg, b50_grad_384_acc_se), np.add(b50_grad_384_acc_avg, b50_grad_384_acc_se), color='lime', alpha=0.5)
# 512 
ax2.plot(e30, b50_grad_512_acc_avg, c='royalblue', label='512')
ax2.fill_between(e30, np.subtract(b50_grad_512_acc_avg, b50_grad_512_acc_se), np.add(b50_grad_512_acc_avg, b50_grad_512_acc_se), color='lightsteelblue', alpha=0.5)
# 640 
ax2.plot(e30, b50_grad_640_acc_avg, c='purple', label='640')
ax2.fill_between(e30, np.subtract(b50_grad_640_acc_avg, b50_grad_640_acc_se), np.add(b50_grad_640_acc_avg, b50_grad_640_acc_se), color='violet', alpha=0.5)
# 768
ax2.plot(e30, b50_grad_768_acc_avg, c='black', label='768')
ax2.fill_between(e30, np.subtract(b50_grad_768_acc_avg, b50_grad_768_acc_se), np.add(b50_grad_768_acc_avg, b50_grad_768_acc_se), color='lightgrey', alpha=0.5)

# Adadelta
# 64
ax3.plot(e30, b50_delta_64_acc_avg, c='darkred', label='64')
ax3.fill_between(e30, np.subtract(b50_delta_64_acc_avg, b50_delta_64_acc_se), np.add(b50_delta_64_acc_avg, b50_delta_64_acc_se), color='lightcoral', alpha=0.5)
# 128
ax3.plot(e30, b50_delta_128_acc_avg, c='darkorange', label='128')
ax3.fill_between(e30, np.subtract(b50_delta_128_acc_avg, b50_delta_128_acc_se), np.add(b50_delta_128_acc_avg, b50_delta_128_acc_se), color='moccasin', alpha=0.5)
# 256
ax3.plot(e30, b50_delta_256_acc_avg, c='saddlebrown', label='256')
ax3.fill_between(e30, np.subtract(b50_delta_256_acc_avg, b50_delta_256_acc_se), np.add(b50_delta_256_acc_avg, b50_delta_256_acc_se), color='peru', alpha=0.5)
# 384
ax3.plot(e30, b50_delta_384_acc_avg, c='darkgreen', label='384')
ax3.fill_between(e30, np.subtract(b50_delta_384_acc_avg, b50_delta_384_acc_se), np.add(b50_delta_384_acc_avg, b50_delta_384_acc_se), color='lime', alpha=0.5)
# 512 
ax3.plot(e30, b50_delta_512_acc_avg, c='royalblue', label='512')
ax3.fill_between(e30, np.subtract(b50_delta_512_acc_avg, b50_delta_512_acc_se), np.add(b50_delta_512_acc_avg, b50_delta_512_acc_se), color='lightsteelblue', alpha=0.5)
# 640 
ax3.plot(e30, b50_delta_640_acc_avg, c='purple', label='640')
ax3.fill_between(e30, np.subtract(b50_delta_640_acc_avg, b50_delta_640_acc_se), np.add(b50_delta_640_acc_avg, b50_delta_640_acc_se), color='violet', alpha=0.5)
# 768
ax3.plot(e30, b50_delta_768_acc_avg, c='black', label='768')
ax3.fill_between(e30, np.subtract(b50_delta_768_acc_avg, b50_delta_768_acc_se), np.add(b50_delta_768_acc_avg, b50_delta_768_acc_se), color='lightgrey', alpha=0.5)

# Adam 
# 64
ax4.plot(e30, b50_adam_64_acc_avg, c='darkred', label='64')
ax4.fill_between(e30, np.subtract(b50_adam_64_acc_avg, b50_adam_64_acc_se), np.add(b50_adam_64_acc_avg, b50_adam_64_acc_se), color='lightcoral', alpha=0.5)
# 128
ax4.plot(e30, b50_adam_128_acc_avg, c='darkorange', label='128')
ax4.fill_between(e30, np.subtract(b50_adam_128_acc_avg, b50_adam_128_acc_se), np.add(b50_adam_128_acc_avg, b50_adam_128_acc_se), color='moccasin', alpha=0.5)
# 256
ax4.plot(e30, b50_adam_256_acc_avg, c='saddlebrown', label='256')
ax4.fill_between(e30, np.subtract(b50_adam_256_acc_avg, b50_adam_256_acc_se), np.add(b50_adam_256_acc_avg, b50_adam_256_acc_se), color='peru', alpha=0.5)
# 384
ax4.plot(e30, b50_adam_384_acc_avg, c='darkgreen', label='384')
ax4.fill_between(e30, np.subtract(b50_adam_384_acc_avg, b50_adam_384_acc_se), np.add(b50_adam_384_acc_avg, b50_adam_384_acc_se), color='lime', alpha=0.5)
# 512 
ax4.plot(e30, b50_adam_512_acc_avg, c='royalblue', label='512')
ax4.fill_between(e30, np.subtract(b50_adam_512_acc_avg, b50_adam_512_acc_se), np.add(b50_adam_512_acc_avg, b50_adam_512_acc_se), color='lightsteelblue', alpha=0.5)
# 640 
ax4.plot(e30, b50_adam_640_acc_avg, c='purple', label='640')
ax4.fill_between(e30, np.subtract(b50_adam_640_acc_avg, b50_adam_640_acc_se), np.add(b50_adam_640_acc_avg, b50_adam_640_acc_se), color='violet', alpha=0.5)
# 768
ax4.plot(e30, b50_adam_768_acc_avg, c='black', label='768')
ax4.fill_between(e30, np.subtract(b50_adam_768_acc_avg, b50_adam_768_acc_se), np.add(b50_adam_768_acc_avg, b50_adam_768_acc_se), color='lightgrey', alpha=0.5)

ax4.set_xlabel('Epochs')

ax1.set_title('batch size=50 SGD')
ax2.set_title('batch size=50 Adagrad')
ax3.set_title('batch size=50 Adadelta')
ax4.set_title('batch size=50 Adam')

ax1.set_xlabel('Epochs')
ax2.set_xlabel('Epochs')
ax3.set_xlabel('Epochs')
ax4.set_xlabel('Epochs')

ax1.set_ylabel('Test Accuracy Zoomed')

ax1.set_ylim([0.96, 0.984])
ax2.set_ylim([0.96, 0.984])
ax3.set_ylim([0.96, 0.984])
ax4.set_ylim([0.96, 0.984])


ax1.grid()
ax2.grid()
ax3.grid()
ax4.grid()

# %%
e30 = np.linspace(1, 30, 30)

# ['64', '128', '256', '384', '512', '640', '768']

fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, figsize=(20, 5))

# ax1 == SGD 
# ax2 == Adagrad 
# ax3 == Adadelta 
# ax4 == Adam 

# SGD
# 64
ax1.plot(e30, b50_sgd_64_spar_avg, c='darkred', label='64')
ax1.fill_between(e30, np.subtract(b50_sgd_64_spar_avg, b50_sgd_64_spar_se), np.add(b50_sgd_64_spar_avg, b50_sgd_64_spar_se), color='lightcoral', alpha=0.5)
# 128
ax1.plot(e30, b50_sgd_128_spar_avg, c='darkorange', label='128')
ax1.fill_between(e30, np.subtract(b50_sgd_128_spar_avg, b50_sgd_128_spar_se), np.add(b50_sgd_128_spar_avg, b50_sgd_128_spar_se), color='moccasin', alpha=0.5)
# 256
ax1.plot(e30, b50_sgd_256_spar_avg, c='saddlebrown', label='256')
ax1.fill_between(e30, np.subtract(b50_sgd_256_spar_avg, b50_sgd_256_spar_se), np.add(b50_sgd_256_spar_avg, b50_sgd_256_spar_se), color='peru', alpha=0.5)
# 384
ax1.plot(e30, b50_sgd_384_spar_avg, c='darkgreen', label='384')
ax1.fill_between(e30, np.subtract(b50_sgd_384_spar_avg, b50_sgd_384_spar_se), np.add(b50_sgd_384_spar_avg, b50_sgd_384_spar_se), color='lime', alpha=0.5)
# 512 
ax1.plot(e30, b50_sgd_512_spar_avg, c='royalblue', label='512')
ax1.fill_between(e30, np.subtract(b50_sgd_512_spar_avg, b50_sgd_512_spar_se), np.add(b50_sgd_512_spar_avg, b50_sgd_512_spar_se), color='lightsteelblue', alpha=0.5)
# 640 
ax1.plot(e30, b50_sgd_640_spar_avg, c='purple', label='640')
ax1.fill_between(e30, np.subtract(b50_sgd_640_spar_avg, b50_sgd_640_spar_se), np.add(b50_sgd_640_spar_avg, b50_sgd_640_spar_se), color='violet', alpha=0.5)
# 768
ax1.plot(e30, b50_sgd_768_spar_avg, c='black', label='768')
ax1.fill_between(e30, np.subtract(b50_sgd_768_spar_avg, b50_sgd_768_spar_se), np.add(b50_sgd_768_spar_avg, b50_sgd_768_spar_se), color='lightgrey', alpha=0.5)


# Adagrad 
# 64
ax2.plot(e30, b50_grad_64_spar_avg, c='darkred', label='64')
ax2.fill_between(e30, np.subtract(b50_grad_64_spar_avg, b50_grad_64_spar_se), np.add(b50_grad_64_spar_avg, b50_grad_64_spar_se), color='lightcoral', alpha=0.5)
# 128
ax2.plot(e30, b50_grad_128_spar_avg, c='darkorange', label='128')
ax2.fill_between(e30, np.subtract(b50_grad_128_spar_avg, b50_grad_128_spar_se), np.add(b50_grad_128_spar_avg, b50_grad_128_spar_se), color='moccasin', alpha=0.5)
# 256
ax2.plot(e30, b50_grad_256_spar_avg, c='saddlebrown', label='256')
ax2.fill_between(e30, np.subtract(b50_grad_256_spar_avg, b50_grad_256_spar_se), np.add(b50_grad_256_spar_avg, b50_grad_256_spar_se), color='peru', alpha=0.5)
# 384
ax2.plot(e30, b50_grad_384_spar_avg, c='darkgreen', label='384')
ax2.fill_between(e30, np.subtract(b50_grad_384_spar_avg, b50_grad_384_spar_se), np.add(b50_grad_384_spar_avg, b50_grad_384_spar_se), color='lime', alpha=0.5)
# 512 
ax2.plot(e30, b50_grad_512_spar_avg, c='royalblue', label='512')
ax2.fill_between(e30, np.subtract(b50_grad_512_spar_avg, b50_grad_512_spar_se), np.add(b50_grad_512_spar_avg, b50_grad_512_spar_se), color='lightsteelblue', alpha=0.5)
# 640 
ax2.plot(e30, b50_grad_640_spar_avg, c='purple', label='640')
ax2.fill_between(e30, np.subtract(b50_grad_640_spar_avg, b50_grad_640_spar_se), np.add(b50_grad_640_spar_avg, b50_grad_640_spar_se), color='violet', alpha=0.5)
# 768
ax2.plot(e30, b50_grad_768_spar_avg, c='black', label='768')
ax2.fill_between(e30, np.subtract(b50_grad_768_spar_avg, b50_grad_768_spar_se), np.add(b50_grad_768_spar_avg, b50_grad_768_spar_se), color='lightgrey', alpha=0.5)

# Adadelta
# 64
ax3.plot(e30, b50_delta_64_spar_avg, c='darkred', label='64')
ax3.fill_between(e30, np.subtract(b50_delta_64_spar_avg, b50_delta_64_spar_se), np.add(b50_delta_64_spar_avg, b50_delta_64_spar_se), color='lightcoral', alpha=0.5)
# 128
ax3.plot(e30, b50_delta_128_spar_avg, c='darkorange', label='128')
ax3.fill_between(e30, np.subtract(b50_delta_128_spar_avg, b50_delta_128_spar_se), np.add(b50_delta_128_spar_avg, b50_delta_128_spar_se), color='moccasin', alpha=0.5)
# 256
ax3.plot(e30, b50_delta_256_spar_avg, c='saddlebrown', label='256')
ax3.fill_between(e30, np.subtract(b50_delta_256_spar_avg, b50_delta_256_spar_se), np.add(b50_delta_256_spar_avg, b50_delta_256_spar_se), color='peru', alpha=0.5)
# 384
ax3.plot(e30, b50_delta_384_spar_avg, c='darkgreen', label='384')
ax3.fill_between(e30, np.subtract(b50_delta_384_spar_avg, b50_delta_384_spar_se), np.add(b50_delta_384_spar_avg, b50_delta_384_spar_se), color='lime', alpha=0.5)
# 512 
ax3.plot(e30, b50_delta_512_spar_avg, c='royalblue', label='512')
ax3.fill_between(e30, np.subtract(b50_delta_512_spar_avg, b50_delta_512_spar_se), np.add(b50_delta_512_spar_avg, b50_delta_512_spar_se), color='lightsteelblue', alpha=0.5)
# 640 
ax3.plot(e30, b50_delta_640_spar_avg, c='purple', label='640')
ax3.fill_between(e30, np.subtract(b50_delta_640_spar_avg, b50_delta_640_spar_se), np.add(b50_delta_640_spar_avg, b50_delta_640_spar_se), color='violet', alpha=0.5)
# 768
ax3.plot(e30, b50_delta_768_spar_avg, c='black', label='768')
ax3.fill_between(e30, np.subtract(b50_delta_768_spar_avg, b50_delta_768_spar_se), np.add(b50_delta_768_spar_avg, b50_delta_768_spar_se), color='lightgrey', alpha=0.5)

# Adam 
# 64
ax4.plot(e30, b50_adam_64_spar_avg, c='darkred', label='64')
ax4.fill_between(e30, np.subtract(b50_adam_64_spar_avg, b50_adam_64_spar_se), np.add(b50_adam_64_spar_avg, b50_adam_64_spar_se), color='lightcoral', alpha=0.5)
# 128
ax4.plot(e30, b50_adam_128_spar_avg, c='darkorange', label='128')
ax4.fill_between(e30, np.subtract(b50_adam_128_spar_avg, b50_adam_128_spar_se), np.add(b50_adam_128_spar_avg, b50_adam_128_spar_se), color='moccasin', alpha=0.5)
# 256
ax4.plot(e30, b50_adam_256_spar_avg, c='saddlebrown', label='256')
ax4.fill_between(e30, np.subtract(b50_adam_256_spar_avg, b50_adam_256_spar_se), np.add(b50_adam_256_spar_avg, b50_adam_256_spar_se), color='peru', alpha=0.5)
# 384
ax4.plot(e30, b50_adam_384_spar_avg, c='darkgreen', label='384')
ax4.fill_between(e30, np.subtract(b50_adam_384_spar_avg, b50_adam_384_spar_se), np.add(b50_adam_384_spar_avg, b50_adam_384_spar_se), color='lime', alpha=0.5)
# 512 
ax4.plot(e30, b50_adam_512_spar_avg, c='royalblue', label='512')
ax4.fill_between(e30, np.subtract(b50_adam_512_spar_avg, b50_adam_512_spar_se), np.add(b50_adam_512_spar_avg, b50_adam_512_spar_se), color='lightsteelblue', alpha=0.5)
# 640 
ax4.plot(e30, b50_adam_640_spar_avg, c='purple', label='640')
ax4.fill_between(e30, np.subtract(b50_adam_640_spar_avg, b50_adam_640_spar_se), np.add(b50_adam_640_spar_avg, b50_adam_640_spar_se), color='violet', alpha=0.5)
# 768
ax4.plot(e30, b50_adam_768_spar_avg, c='black', label='768')
ax4.fill_between(e30, np.subtract(b50_adam_768_spar_avg, b50_adam_768_spar_se), np.add(b50_adam_768_spar_avg, b50_adam_768_spar_se), color='lightgrey', alpha=0.5)

ax4.set_xlabel('Epochs')

ax1.set_title('batch size=50 SGD')
ax2.set_title('batch size=50 Adagrad')
ax3.set_title('batch size=50 Adadelta')
ax4.set_title('batch size=50 Adam')

ax1.set_xlabel('Epochs')
ax2.set_xlabel('Epochs')
ax3.set_xlabel('Epochs')
ax4.set_xlabel('Epochs')

ax1.set_ylabel('Sparsity')

ax1.grid()
ax2.grid()
ax3.grid()
ax4.grid()

# %%
e30 = np.linspace(1, 30, 30)

# ['64', '128', '256', '384', '512', '640', '768']

fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, figsize=(20, 5))

# ax1 == SGD 
# ax2 == Adagrad 
# ax3 == Adadelta 
# ax4 == Adam 

# SGD
# 64
ax1.plot(e30, b50_sgd_64_selec_avg, c='darkred', label='64')
ax1.fill_between(e30, np.subtract(b50_sgd_64_selec_avg, b50_sgd_64_selec_se), np.add(b50_sgd_64_selec_avg, b50_sgd_64_selec_se), color='lightcoral', alpha=0.5)
# 128
ax1.plot(e30, b50_sgd_128_selec_avg, c='darkorange', label='128')
ax1.fill_between(e30, np.subtract(b50_sgd_128_selec_avg, b50_sgd_128_selec_se), np.add(b50_sgd_128_selec_avg, b50_sgd_128_selec_se), color='moccasin', alpha=0.5)
# 256
ax1.plot(e30, b50_sgd_256_selec_avg, c='saddlebrown', label='256')
ax1.fill_between(e30, np.subtract(b50_sgd_256_selec_avg, b50_sgd_256_selec_se), np.add(b50_sgd_256_selec_avg, b50_sgd_256_selec_se), color='peru', alpha=0.5)
# 384
ax1.plot(e30, b50_sgd_384_selec_avg, c='darkgreen', label='384')
ax1.fill_between(e30, np.subtract(b50_sgd_384_selec_avg, b50_sgd_384_selec_se), np.add(b50_sgd_384_selec_avg, b50_sgd_384_selec_se), color='lime', alpha=0.5)
# 512 
ax1.plot(e30, b50_sgd_512_selec_avg, c='royalblue', label='512')
ax1.fill_between(e30, np.subtract(b50_sgd_512_selec_avg, b50_sgd_512_selec_se), np.add(b50_sgd_512_selec_avg, b50_sgd_512_selec_se), color='lightsteelblue', alpha=0.5)
# 640 
ax1.plot(e30, b50_sgd_640_selec_avg, c='purple', label='640')
ax1.fill_between(e30, np.subtract(b50_sgd_640_selec_avg, b50_sgd_640_selec_se), np.add(b50_sgd_640_selec_avg, b50_sgd_640_selec_se), color='violet', alpha=0.5)
# 768
ax1.plot(e30, b50_sgd_768_selec_avg, c='black', label='768')
ax1.fill_between(e30, np.subtract(b50_sgd_768_selec_avg, b50_sgd_768_selec_se), np.add(b50_sgd_768_selec_avg, b50_sgd_768_selec_se), color='lightgrey', alpha=0.5)


# Adagrad 
# 64
ax2.plot(e30, b50_grad_64_selec_avg, c='darkred', label='64')
ax2.fill_between(e30, np.subtract(b50_grad_64_selec_avg, b50_grad_64_selec_se), np.add(b50_grad_64_selec_avg, b50_grad_64_selec_se), color='lightcoral', alpha=0.5)
# 128
ax2.plot(e30, b50_grad_128_selec_avg, c='darkorange', label='128')
ax2.fill_between(e30, np.subtract(b50_grad_128_selec_avg, b50_grad_128_selec_se), np.add(b50_grad_128_selec_avg, b50_grad_128_selec_se), color='moccasin', alpha=0.5)
# 256
ax2.plot(e30, b50_grad_256_selec_avg, c='saddlebrown', label='256')
ax2.fill_between(e30, np.subtract(b50_grad_256_selec_avg, b50_grad_256_selec_se), np.add(b50_grad_256_selec_avg, b50_grad_256_selec_se), color='peru', alpha=0.5)
# 384
ax2.plot(e30, b50_grad_384_selec_avg, c='darkgreen', label='384')
ax2.fill_between(e30, np.subtract(b50_grad_384_selec_avg, b50_grad_384_selec_se), np.add(b50_grad_384_selec_avg, b50_grad_384_selec_se), color='lime', alpha=0.5)
# 512 
ax2.plot(e30, b50_grad_512_selec_avg, c='royalblue', label='512')
ax2.fill_between(e30, np.subtract(b50_grad_512_selec_avg, b50_grad_512_selec_se), np.add(b50_grad_512_selec_avg, b50_grad_512_selec_se), color='lightsteelblue', alpha=0.5)
# 640 
ax2.plot(e30, b50_grad_640_selec_avg, c='purple', label='640')
ax2.fill_between(e30, np.subtract(b50_grad_640_selec_avg, b50_grad_640_selec_se), np.add(b50_grad_640_selec_avg, b50_grad_640_selec_se), color='violet', alpha=0.5)
# 768
ax2.plot(e30, b50_grad_768_selec_avg, c='black', label='768')
ax2.fill_between(e30, np.subtract(b50_grad_768_selec_avg, b50_grad_768_selec_se), np.add(b50_grad_768_selec_avg, b50_grad_768_selec_se), color='lightgrey', alpha=0.5)

# Adadelta
# 64
ax3.plot(e30, b50_delta_64_selec_avg, c='darkred', label='64')
ax3.fill_between(e30, np.subtract(b50_delta_64_selec_avg, b50_delta_64_selec_se), np.add(b50_delta_64_selec_avg, b50_delta_64_selec_se), color='lightcoral', alpha=0.5)
# 128
ax3.plot(e30, b50_delta_128_selec_avg, c='darkorange', label='128')
ax3.fill_between(e30, np.subtract(b50_delta_128_selec_avg, b50_delta_128_selec_se), np.add(b50_delta_128_selec_avg, b50_delta_128_selec_se), color='moccasin', alpha=0.5)
# 256
ax3.plot(e30, b50_delta_256_selec_avg, c='saddlebrown', label='256')
ax3.fill_between(e30, np.subtract(b50_delta_256_selec_avg, b50_delta_256_selec_se), np.add(b50_delta_256_selec_avg, b50_delta_256_selec_se), color='peru', alpha=0.5)
# 384
ax3.plot(e30, b50_delta_384_selec_avg, c='darkgreen', label='384')
ax3.fill_between(e30, np.subtract(b50_delta_384_selec_avg, b50_delta_384_selec_se), np.add(b50_delta_384_selec_avg, b50_delta_384_selec_se), color='lime', alpha=0.5)
# 512 
ax3.plot(e30, b50_delta_512_selec_avg, c='royalblue', label='512')
ax3.fill_between(e30, np.subtract(b50_delta_512_selec_avg, b50_delta_512_selec_se), np.add(b50_delta_512_selec_avg, b50_delta_512_selec_se), color='lightsteelblue', alpha=0.5)
# 640 
ax3.plot(e30, b50_delta_640_selec_avg, c='purple', label='640')
ax3.fill_between(e30, np.subtract(b50_delta_640_selec_avg, b50_delta_640_selec_se), np.add(b50_delta_640_selec_avg, b50_delta_640_selec_se), color='violet', alpha=0.5)
# 768
ax3.plot(e30, b50_delta_768_selec_avg, c='black', label='768')
ax3.fill_between(e30, np.subtract(b50_delta_768_selec_avg, b50_delta_768_selec_se), np.add(b50_delta_768_selec_avg, b50_delta_768_selec_se), color='lightgrey', alpha=0.5)

# Adam 
# 64
ax4.plot(e30, b50_adam_64_selec_avg, c='darkred', label='64')
ax4.fill_between(e30, np.subtract(b50_adam_64_selec_avg, b50_adam_64_selec_se), np.add(b50_adam_64_selec_avg, b50_adam_64_selec_se), color='lightcoral', alpha=0.5)
# 128
ax4.plot(e30, b50_adam_128_selec_avg, c='darkorange', label='128')
ax4.fill_between(e30, np.subtract(b50_adam_128_selec_avg, b50_adam_128_selec_se), np.add(b50_adam_128_selec_avg, b50_adam_128_selec_se), color='moccasin', alpha=0.5)
# 256
ax4.plot(e30, b50_adam_256_selec_avg, c='saddlebrown', label='256')
ax4.fill_between(e30, np.subtract(b50_adam_256_selec_avg, b50_adam_256_selec_se), np.add(b50_adam_256_selec_avg, b50_adam_256_selec_se), color='peru', alpha=0.5)
# 384
ax4.plot(e30, b50_adam_384_selec_avg, c='darkgreen', label='384')
ax4.fill_between(e30, np.subtract(b50_adam_384_selec_avg, b50_adam_384_selec_se), np.add(b50_adam_384_selec_avg, b50_adam_384_selec_se), color='lime', alpha=0.5)
# 512 
ax4.plot(e30, b50_adam_512_selec_avg, c='royalblue', label='512')
ax4.fill_between(e30, np.subtract(b50_adam_512_selec_avg, b50_adam_512_selec_se), np.add(b50_adam_512_selec_avg, b50_adam_512_selec_se), color='lightsteelblue', alpha=0.5)
# 640 
ax4.plot(e30, b50_adam_640_selec_avg, c='purple', label='640')
ax4.fill_between(e30, np.subtract(b50_adam_640_selec_avg, b50_adam_640_selec_se), np.add(b50_adam_640_selec_avg, b50_adam_640_selec_se), color='violet', alpha=0.5)
# 768
ax4.plot(e30, b50_adam_768_selec_avg, c='black', label='768')
ax4.fill_between(e30, np.subtract(b50_adam_768_selec_avg, b50_adam_768_selec_se), np.add(b50_adam_768_selec_avg, b50_adam_768_selec_se), color='lightgrey', alpha=0.5)

ax4.set_xlabel('Epochs')
ax4.legend(loc='upper center', bbox_to_anchor=(-1.3, -0.15),
          fancybox=True, shadow=True, ncol=7)

ax1.set_title('batch size=50 SGD')
ax2.set_title('batch size=50 Adagrad')
ax3.set_title('batch size=50 Adadelta')
ax4.set_title('batch size=50 Adam')

ax1.set_xlabel('Epochs')
ax2.set_xlabel('Epochs')
ax3.set_xlabel('Epochs')
ax4.set_xlabel('Epochs')

ax1.set_ylabel('Selectivity')

ax1.grid()
ax2.grid()
ax3.grid()
ax4.grid()

# %%
# batch 1

# %%
e30 = np.linspace(1, 30, 30)

# ['64', '128', '256', '384', '512', '640', '768']

fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, figsize=(20, 5))

# ax1 == SGD 
# ax2 == Adagrad 
# ax3 == Adadelta 
# ax4 == Adam 

# SGD
# 64
ax1.plot(e30, b1_sgd_64_acc_avg, c='darkred', label='64')
ax1.fill_between(e30, np.subtract(b1_sgd_64_acc_avg, b1_sgd_64_acc_se), np.add(b1_sgd_64_acc_avg, b1_sgd_64_acc_se), color='lightcoral', alpha=0.5)
# 128
ax1.plot(e30, b1_sgd_128_acc_avg, c='darkorange', label='128')
ax1.fill_between(e30, np.subtract(b1_sgd_128_acc_avg, b1_sgd_128_acc_se), np.add(b1_sgd_128_acc_avg, b1_sgd_128_acc_se), color='moccasin', alpha=0.5)
# 256
ax1.plot(e30, b1_sgd_256_acc_avg, c='saddlebrown', label='256')
ax1.fill_between(e30, np.subtract(b1_sgd_256_acc_avg, b1_sgd_256_acc_se), np.add(b1_sgd_256_acc_avg, b1_sgd_256_acc_se), color='peru', alpha=0.5)
# 384
ax1.plot(e30, b1_sgd_384_acc_avg, c='darkgreen', label='384')
ax1.fill_between(e30, np.subtract(b1_sgd_384_acc_avg, b1_sgd_384_acc_se), np.add(b1_sgd_384_acc_avg, b1_sgd_384_acc_se), color='lime', alpha=0.5)
# 512 
ax1.plot(e30, b1_sgd_512_acc_avg, c='royalblue', label='512')
ax1.fill_between(e30, np.subtract(b1_sgd_512_acc_avg, b1_sgd_512_acc_se), np.add(b1_sgd_512_acc_avg, b1_sgd_512_acc_se), color='lightsteelblue', alpha=0.5)
# 640 
ax1.plot(e30, b1_sgd_640_acc_avg, c='purple', label='640')
ax1.fill_between(e30, np.subtract(b1_sgd_640_acc_avg, b1_sgd_640_acc_se), np.add(b1_sgd_640_acc_avg, b1_sgd_640_acc_se), color='violet', alpha=0.5)
# 768
ax1.plot(e30, b1_sgd_768_acc_avg, c='black', label='768')
ax1.fill_between(e30, np.subtract(b1_sgd_768_acc_avg, b1_sgd_768_acc_se), np.add(b1_sgd_768_acc_avg, b1_sgd_768_acc_se), color='lightgrey', alpha=0.5)


# Adagrad 
# 64
ax2.plot(e30, b1_grad_64_acc_avg, c='darkred', label='64')
ax2.fill_between(e30, np.subtract(b1_grad_64_acc_avg, b1_grad_64_acc_se), np.add(b1_grad_64_acc_avg, b1_grad_64_acc_se), color='lightcoral', alpha=0.5)
# 128
ax2.plot(e30, b1_grad_128_acc_avg, c='darkorange', label='128')
ax2.fill_between(e30, np.subtract(b1_grad_128_acc_avg, b1_grad_128_acc_se), np.add(b1_grad_128_acc_avg, b1_grad_128_acc_se), color='moccasin', alpha=0.5)
# 256
ax2.plot(e30, b1_grad_256_acc_avg, c='saddlebrown', label='256')
ax2.fill_between(e30, np.subtract(b1_grad_256_acc_avg, b1_grad_256_acc_se), np.add(b1_grad_256_acc_avg, b1_grad_256_acc_se), color='peru', alpha=0.5)
# 384
ax2.plot(e30, b1_grad_384_acc_avg, c='darkgreen', label='384')
ax2.fill_between(e30, np.subtract(b1_grad_384_acc_avg, b1_grad_384_acc_se), np.add(b1_grad_384_acc_avg, b1_grad_384_acc_se), color='lime', alpha=0.5)
# 512 
ax2.plot(e30, b1_grad_512_acc_avg, c='royalblue', label='512')
ax2.fill_between(e30, np.subtract(b1_grad_512_acc_avg, b1_grad_512_acc_se), np.add(b1_grad_512_acc_avg, b1_grad_512_acc_se), color='lightsteelblue', alpha=0.5)
# 640 
ax2.plot(e30, b1_grad_640_acc_avg, c='purple', label='640')
ax2.fill_between(e30, np.subtract(b1_grad_640_acc_avg, b1_grad_640_acc_se), np.add(b1_grad_640_acc_avg, b1_grad_640_acc_se), color='violet', alpha=0.5)
# 768
ax2.plot(e30, b1_grad_768_acc_avg, c='black', label='768')
ax2.fill_between(e30, np.subtract(b1_grad_768_acc_avg, b1_grad_768_acc_se), np.add(b1_grad_768_acc_avg, b1_grad_768_acc_se), color='lightgrey', alpha=0.5)

# Adadelta
# 64
ax3.plot(e30, b1_delta_64_acc_avg, c='darkred', label='64')
ax3.fill_between(e30, np.subtract(b1_delta_64_acc_avg, b1_delta_64_acc_se), np.add(b1_delta_64_acc_avg, b1_delta_64_acc_se), color='lightcoral', alpha=0.5)
# 128
ax3.plot(e30, b1_delta_128_acc_avg, c='darkorange', label='128')
ax3.fill_between(e30, np.subtract(b1_delta_128_acc_avg, b1_delta_128_acc_se), np.add(b1_delta_128_acc_avg, b1_delta_128_acc_se), color='moccasin', alpha=0.5)
# 256
ax3.plot(e30, b1_delta_256_acc_avg, c='saddlebrown', label='256')
ax3.fill_between(e30, np.subtract(b1_delta_256_acc_avg, b1_delta_256_acc_se), np.add(b1_delta_256_acc_avg, b1_delta_256_acc_se), color='peru', alpha=0.5)
# 384
ax3.plot(e30, b1_delta_384_acc_avg, c='darkgreen', label='384')
ax3.fill_between(e30, np.subtract(b1_delta_384_acc_avg, b1_delta_384_acc_se), np.add(b1_delta_384_acc_avg, b1_delta_384_acc_se), color='lime', alpha=0.5)
# 512 
ax3.plot(e30, b1_delta_512_acc_avg, c='royalblue', label='512')
ax3.fill_between(e30, np.subtract(b1_delta_512_acc_avg, b1_delta_512_acc_se), np.add(b1_delta_512_acc_avg, b1_delta_512_acc_se), color='lightsteelblue', alpha=0.5)
# 640 
ax3.plot(e30, b1_delta_640_acc_avg, c='purple', label='640')
ax3.fill_between(e30, np.subtract(b1_delta_640_acc_avg, b1_delta_640_acc_se), np.add(b1_delta_640_acc_avg, b1_delta_640_acc_se), color='violet', alpha=0.5)
# 768
ax3.plot(e30, b1_delta_768_acc_avg, c='black', label='768')
ax3.fill_between(e30, np.subtract(b1_delta_768_acc_avg, b1_delta_768_acc_se), np.add(b1_delta_768_acc_avg, b1_delta_768_acc_se), color='lightgrey', alpha=0.5)

# Adam 
# 64
ax4.plot(e30, b1_adam_64_acc_avg, c='darkred', label='64')
ax4.fill_between(e30, np.subtract(b1_adam_64_acc_avg, b1_adam_64_acc_se), np.add(b1_adam_64_acc_avg, b1_adam_64_acc_se), color='lightcoral', alpha=0.5)
# 128
ax4.plot(e30, b1_adam_128_acc_avg, c='darkorange', label='128')
ax4.fill_between(e30, np.subtract(b1_adam_128_acc_avg, b1_adam_128_acc_se), np.add(b1_adam_128_acc_avg, b1_adam_128_acc_se), color='moccasin', alpha=0.5)
# 256
ax4.plot(e30, b1_adam_256_acc_avg, c='saddlebrown', label='256')
ax4.fill_between(e30, np.subtract(b1_adam_256_acc_avg, b1_adam_256_acc_se), np.add(b1_adam_256_acc_avg, b1_adam_256_acc_se), color='peru', alpha=0.5)
# 384
ax4.plot(e30, b1_adam_384_acc_avg, c='darkgreen', label='384')
ax4.fill_between(e30, np.subtract(b1_adam_384_acc_avg, b1_adam_384_acc_se), np.add(b1_adam_384_acc_avg, b1_adam_384_acc_se), color='lime', alpha=0.5)
# 512 
ax4.plot(e30, b1_adam_512_acc_avg, c='royalblue', label='512')
ax4.fill_between(e30, np.subtract(b1_adam_512_acc_avg, b1_adam_512_acc_se), np.add(b1_adam_512_acc_avg, b1_adam_512_acc_se), color='lightsteelblue', alpha=0.5)
# 640 
ax4.plot(e30, b1_adam_640_acc_avg, c='purple', label='640')
ax4.fill_between(e30, np.subtract(b1_adam_640_acc_avg, b1_adam_640_acc_se), np.add(b1_adam_640_acc_avg, b1_adam_640_acc_se), color='violet', alpha=0.5)
# 768
ax4.plot(e30, b1_adam_768_acc_avg, c='black', label='768')
ax4.fill_between(e30, np.subtract(b1_adam_768_acc_avg, b1_adam_768_acc_se), np.add(b1_adam_768_acc_avg, b1_adam_768_acc_se), color='lightgrey', alpha=0.5)

ax4.set_xlabel('Epochs')

ax1.set_title('batch size=1 SGD')
ax2.set_title('batch size=1 Adagrad')
ax3.set_title('batch size=1 Adadelta')
ax4.set_title('batch size=1 Adam')

ax1.set_xlabel('Epochs')
ax2.set_xlabel('Epochs')
ax3.set_xlabel('Epochs')
ax4.set_xlabel('Epochs')

ax1.set_ylabel('Test Accuracy')

ax1.grid()
ax2.grid()
ax3.grid()
ax4.grid()

# %%
e30 = np.linspace(1, 30, 30)

# ['64', '128', '256', '384', '512', '640', '768']

fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, figsize=(20, 5))

# ax1 == SGD 
# ax2 == Adagrad 
# ax3 == Adadelta 
# ax4 == Adam 

# SGD
# 64
ax1.plot(e30, b1_sgd_64_spar_avg, c='darkred', label='64')
ax1.fill_between(e30, np.subtract(b1_sgd_64_spar_avg, b1_sgd_64_spar_se), np.add(b1_sgd_64_spar_avg, b1_sgd_64_spar_se), color='lightcoral', alpha=0.5)
# 128
ax1.plot(e30, b1_sgd_128_spar_avg, c='darkorange', label='128')
ax1.fill_between(e30, np.subtract(b1_sgd_128_spar_avg, b1_sgd_128_spar_se), np.add(b1_sgd_128_spar_avg, b1_sgd_128_spar_se), color='moccasin', alpha=0.5)
# 256
ax1.plot(e30, b1_sgd_256_spar_avg, c='saddlebrown', label='256')
ax1.fill_between(e30, np.subtract(b1_sgd_256_spar_avg, b1_sgd_256_spar_se), np.add(b1_sgd_256_spar_avg, b1_sgd_256_spar_se), color='peru', alpha=0.5)
# 384
ax1.plot(e30, b1_sgd_384_spar_avg, c='darkgreen', label='384')
ax1.fill_between(e30, np.subtract(b1_sgd_384_spar_avg, b1_sgd_384_spar_se), np.add(b1_sgd_384_spar_avg, b1_sgd_384_spar_se), color='lime', alpha=0.5)
# 512 
ax1.plot(e30, b1_sgd_512_spar_avg, c='royalblue', label='512')
ax1.fill_between(e30, np.subtract(b1_sgd_512_spar_avg, b1_sgd_512_spar_se), np.add(b1_sgd_512_spar_avg, b1_sgd_512_spar_se), color='lightsteelblue', alpha=0.5)
# 640 
ax1.plot(e30, b1_sgd_640_spar_avg, c='purple', label='640')
ax1.fill_between(e30, np.subtract(b1_sgd_640_spar_avg, b1_sgd_640_spar_se), np.add(b1_sgd_640_spar_avg, b1_sgd_640_spar_se), color='violet', alpha=0.5)
# 768
ax1.plot(e30, b1_sgd_768_spar_avg, c='black', label='768')
ax1.fill_between(e30, np.subtract(b1_sgd_768_spar_avg, b1_sgd_768_spar_se), np.add(b1_sgd_768_spar_avg, b1_sgd_768_spar_se), color='lightgrey', alpha=0.5)


# Adagrad 
# 64
ax2.plot(e30, b1_grad_64_spar_avg, c='darkred', label='64')
ax2.fill_between(e30, np.subtract(b1_grad_64_spar_avg, b1_grad_64_spar_se), np.add(b1_grad_64_spar_avg, b1_grad_64_spar_se), color='lightcoral', alpha=0.5)
# 128
ax2.plot(e30, b1_grad_128_spar_avg, c='darkorange', label='128')
ax2.fill_between(e30, np.subtract(b1_grad_128_spar_avg, b1_grad_128_spar_se), np.add(b1_grad_128_spar_avg, b1_grad_128_spar_se), color='moccasin', alpha=0.5)
# 256
ax2.plot(e30, b1_grad_256_spar_avg, c='saddlebrown', label='256')
ax2.fill_between(e30, np.subtract(b1_grad_256_spar_avg, b1_grad_256_spar_se), np.add(b1_grad_256_spar_avg, b1_grad_256_spar_se), color='peru', alpha=0.5)
# 384
ax2.plot(e30, b1_grad_384_spar_avg, c='darkgreen', label='384')
ax2.fill_between(e30, np.subtract(b1_grad_384_spar_avg, b1_grad_384_spar_se), np.add(b1_grad_384_spar_avg, b1_grad_384_spar_se), color='lime', alpha=0.5)
# 512 
ax2.plot(e30, b1_grad_512_spar_avg, c='royalblue', label='512')
ax2.fill_between(e30, np.subtract(b1_grad_512_spar_avg, b1_grad_512_spar_se), np.add(b1_grad_512_spar_avg, b1_grad_512_spar_se), color='lightsteelblue', alpha=0.5)
# 640 
ax2.plot(e30, b1_grad_640_spar_avg, c='purple', label='640')
ax2.fill_between(e30, np.subtract(b1_grad_640_spar_avg, b1_grad_640_spar_se), np.add(b1_grad_640_spar_avg, b1_grad_640_spar_se), color='violet', alpha=0.5)
# 768
ax2.plot(e30, b1_grad_768_spar_avg, c='black', label='768')
ax2.fill_between(e30, np.subtract(b1_grad_768_spar_avg, b1_grad_768_spar_se), np.add(b1_grad_768_spar_avg, b1_grad_768_spar_se), color='lightgrey', alpha=0.5)

# Adadelta
# 64
ax3.plot(e30, b1_delta_64_spar_avg, c='darkred', label='64')
ax3.fill_between(e30, np.subtract(b1_delta_64_spar_avg, b1_delta_64_spar_se), np.add(b1_delta_64_spar_avg, b1_delta_64_spar_se), color='lightcoral', alpha=0.5)
# 128
ax3.plot(e30, b1_delta_128_spar_avg, c='darkorange', label='128')
ax3.fill_between(e30, np.subtract(b1_delta_128_spar_avg, b1_delta_128_spar_se), np.add(b1_delta_128_spar_avg, b1_delta_128_spar_se), color='moccasin', alpha=0.5)
# 256
ax3.plot(e30, b1_delta_256_spar_avg, c='saddlebrown', label='256')
ax3.fill_between(e30, np.subtract(b1_delta_256_spar_avg, b1_delta_256_spar_se), np.add(b1_delta_256_spar_avg, b1_delta_256_spar_se), color='peru', alpha=0.5)
# 384
ax3.plot(e30, b1_delta_384_spar_avg, c='darkgreen', label='384')
ax3.fill_between(e30, np.subtract(b1_delta_384_spar_avg, b1_delta_384_spar_se), np.add(b1_delta_384_spar_avg, b1_delta_384_spar_se), color='lime', alpha=0.5)
# 512 
ax3.plot(e30, b1_delta_512_spar_avg, c='royalblue', label='512')
ax3.fill_between(e30, np.subtract(b1_delta_512_spar_avg, b1_delta_512_spar_se), np.add(b1_delta_512_spar_avg, b1_delta_512_spar_se), color='lightsteelblue', alpha=0.5)
# 640 
ax3.plot(e30, b1_delta_640_spar_avg, c='purple', label='640')
ax3.fill_between(e30, np.subtract(b1_delta_640_spar_avg, b1_delta_640_spar_se), np.add(b1_delta_640_spar_avg, b1_delta_640_spar_se), color='violet', alpha=0.5)
# 768
ax3.plot(e30, b1_delta_768_spar_avg, c='black', label='768')
ax3.fill_between(e30, np.subtract(b1_delta_768_spar_avg, b1_delta_768_spar_se), np.add(b1_delta_768_spar_avg, b1_delta_768_spar_se), color='lightgrey', alpha=0.5)

# Adam 
# 64
ax4.plot(e30, b1_adam_64_spar_avg, c='darkred', label='64')
ax4.fill_between(e30, np.subtract(b1_adam_64_spar_avg, b1_adam_64_spar_se), np.add(b1_adam_64_spar_avg, b1_adam_64_spar_se), color='lightcoral', alpha=0.5)
# 128
ax4.plot(e30, b1_adam_128_spar_avg, c='darkorange', label='128')
ax4.fill_between(e30, np.subtract(b1_adam_128_spar_avg, b1_adam_128_spar_se), np.add(b1_adam_128_spar_avg, b1_adam_128_spar_se), color='moccasin', alpha=0.5)
# 256
ax4.plot(e30, b1_adam_256_spar_avg, c='saddlebrown', label='256')
ax4.fill_between(e30, np.subtract(b1_adam_256_spar_avg, b1_adam_256_spar_se), np.add(b1_adam_256_spar_avg, b1_adam_256_spar_se), color='peru', alpha=0.5)
# 384
ax4.plot(e30, b1_adam_384_spar_avg, c='darkgreen', label='384')
ax4.fill_between(e30, np.subtract(b1_adam_384_spar_avg, b1_adam_384_spar_se), np.add(b1_adam_384_spar_avg, b1_adam_384_spar_se), color='lime', alpha=0.5)
# 512 
ax4.plot(e30, b1_adam_512_spar_avg, c='royalblue', label='512')
ax4.fill_between(e30, np.subtract(b1_adam_512_spar_avg, b1_adam_512_spar_se), np.add(b1_adam_512_spar_avg, b1_adam_512_spar_se), color='lightsteelblue', alpha=0.5)
# 640 
ax4.plot(e30, b1_adam_640_spar_avg, c='purple', label='640')
ax4.fill_between(e30, np.subtract(b1_adam_640_spar_avg, b1_adam_640_spar_se), np.add(b1_adam_640_spar_avg, b1_adam_640_spar_se), color='violet', alpha=0.5)
# 768
ax4.plot(e30, b1_adam_768_spar_avg, c='black', label='768')
ax4.fill_between(e30, np.subtract(b1_adam_768_spar_avg, b1_adam_768_spar_se), np.add(b1_adam_768_spar_avg, b1_adam_768_spar_se), color='lightgrey', alpha=0.5)

ax4.set_xlabel('Epochs')

ax1.set_title('batch size=1 SGD')
ax2.set_title('batch size=1 Adagrad')
ax3.set_title('batch size=1 Adadelta')
ax4.set_title('batch size=1 Adam')

ax1.set_xlabel('Epochs')
ax2.set_xlabel('Epochs')
ax3.set_xlabel('Epochs')
ax4.set_xlabel('Epochs')

ax1.set_ylabel('Sparsity')

ax1.grid()
ax2.grid()
ax3.grid()
ax4.grid()

# %%
e30 = np.linspace(1, 30, 30)

# ['64', '128', '256', '384', '512', '640', '768']

fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, figsize=(20, 5))

# ax1 == SGD 
# ax2 == Adagrad 
# ax3 == Adadelta 
# ax4 == Adam 

# SGD
# 64
ax1.plot(e30, b1_sgd_64_selec_avg, c='darkred', label='64')
ax1.fill_between(e30, np.subtract(b1_sgd_64_selec_avg, b1_sgd_64_selec_se), np.add(b1_sgd_64_selec_avg, b1_sgd_64_selec_se), color='lightcoral', alpha=0.5)
# 128
ax1.plot(e30, b1_sgd_128_selec_avg, c='darkorange', label='128')
ax1.fill_between(e30, np.subtract(b1_sgd_128_selec_avg, b1_sgd_128_selec_se), np.add(b1_sgd_128_selec_avg, b1_sgd_128_selec_se), color='moccasin', alpha=0.5)
# 256
ax1.plot(e30, b1_sgd_256_selec_avg, c='saddlebrown', label='256')
ax1.fill_between(e30, np.subtract(b1_sgd_256_selec_avg, b1_sgd_256_selec_se), np.add(b1_sgd_256_selec_avg, b1_sgd_256_selec_se), color='peru', alpha=0.5)
# 384
ax1.plot(e30, b1_sgd_384_selec_avg, c='darkgreen', label='384')
ax1.fill_between(e30, np.subtract(b1_sgd_384_selec_avg, b1_sgd_384_selec_se), np.add(b1_sgd_384_selec_avg, b1_sgd_384_selec_se), color='lime', alpha=0.5)
# 512 
ax1.plot(e30, b1_sgd_512_selec_avg, c='royalblue', label='512')
ax1.fill_between(e30, np.subtract(b1_sgd_512_selec_avg, b1_sgd_512_selec_se), np.add(b1_sgd_512_selec_avg, b1_sgd_512_selec_se), color='lightsteelblue', alpha=0.5)
# 640 
ax1.plot(e30, b1_sgd_640_selec_avg, c='purple', label='640')
ax1.fill_between(e30, np.subtract(b1_sgd_640_selec_avg, b1_sgd_640_selec_se), np.add(b1_sgd_640_selec_avg, b1_sgd_640_selec_se), color='violet', alpha=0.5)
# 768
ax1.plot(e30, b1_sgd_768_selec_avg, c='black', label='768')
ax1.fill_between(e30, np.subtract(b1_sgd_768_selec_avg, b1_sgd_768_selec_se), np.add(b1_sgd_768_selec_avg, b1_sgd_768_selec_se), color='lightgrey', alpha=0.5)


# Adagrad 
# 64
ax2.plot(e30, b1_grad_64_selec_avg, c='darkred', label='64')
ax2.fill_between(e30, np.subtract(b1_grad_64_selec_avg, b1_grad_64_selec_se), np.add(b1_grad_64_selec_avg, b1_grad_64_selec_se), color='lightcoral', alpha=0.5)
# 128
ax2.plot(e30, b1_grad_128_selec_avg, c='darkorange', label='128')
ax2.fill_between(e30, np.subtract(b1_grad_128_selec_avg, b1_grad_128_selec_se), np.add(b1_grad_128_selec_avg, b1_grad_128_selec_se), color='moccasin', alpha=0.5)
# 256
ax2.plot(e30, b1_grad_256_selec_avg, c='saddlebrown', label='256')
ax2.fill_between(e30, np.subtract(b1_grad_256_selec_avg, b1_grad_256_selec_se), np.add(b1_grad_256_selec_avg, b1_grad_256_selec_se), color='peru', alpha=0.5)
# 384
ax2.plot(e30, b1_grad_384_selec_avg, c='darkgreen', label='384')
ax2.fill_between(e30, np.subtract(b1_grad_384_selec_avg, b1_grad_384_selec_se), np.add(b1_grad_384_selec_avg, b1_grad_384_selec_se), color='lime', alpha=0.5)
# 512 
ax2.plot(e30, b1_grad_512_selec_avg, c='royalblue', label='512')
ax2.fill_between(e30, np.subtract(b1_grad_512_selec_avg, b1_grad_512_selec_se), np.add(b1_grad_512_selec_avg, b1_grad_512_selec_se), color='lightsteelblue', alpha=0.5)
# 640 
ax2.plot(e30, b1_grad_640_selec_avg, c='purple', label='640')
ax2.fill_between(e30, np.subtract(b1_grad_640_selec_avg, b1_grad_640_selec_se), np.add(b1_grad_640_selec_avg, b1_grad_640_selec_se), color='violet', alpha=0.5)
# 768
ax2.plot(e30, b1_grad_768_selec_avg, c='black', label='768')
ax2.fill_between(e30, np.subtract(b1_grad_768_selec_avg, b1_grad_768_selec_se), np.add(b1_grad_768_selec_avg, b1_grad_768_selec_se), color='lightgrey', alpha=0.5)

# Adadelta
# 64
ax3.plot(e30, b1_delta_64_selec_avg, c='darkred', label='64')
ax3.fill_between(e30, np.subtract(b1_delta_64_selec_avg, b1_delta_64_selec_se), np.add(b1_delta_64_selec_avg, b1_delta_64_selec_se), color='lightcoral', alpha=0.5)
# 128
ax3.plot(e30, b1_delta_128_selec_avg, c='darkorange', label='128')
ax3.fill_between(e30, np.subtract(b1_delta_128_selec_avg, b1_delta_128_selec_se), np.add(b1_delta_128_selec_avg, b1_delta_128_selec_se), color='moccasin', alpha=0.5)
# 256
ax3.plot(e30, b1_delta_256_selec_avg, c='saddlebrown', label='256')
ax3.fill_between(e30, np.subtract(b1_delta_256_selec_avg, b1_delta_256_selec_se), np.add(b1_delta_256_selec_avg, b1_delta_256_selec_se), color='peru', alpha=0.5)
# 384
ax3.plot(e30, b1_delta_384_selec_avg, c='darkgreen', label='384')
ax3.fill_between(e30, np.subtract(b1_delta_384_selec_avg, b1_delta_384_selec_se), np.add(b1_delta_384_selec_avg, b1_delta_384_selec_se), color='lime', alpha=0.5)
# 512 
ax3.plot(e30, b1_delta_512_selec_avg, c='royalblue', label='512')
ax3.fill_between(e30, np.subtract(b1_delta_512_selec_avg, b1_delta_512_selec_se), np.add(b1_delta_512_selec_avg, b1_delta_512_selec_se), color='lightsteelblue', alpha=0.5)
# 640 
ax3.plot(e30, b1_delta_640_selec_avg, c='purple', label='640')
ax3.fill_between(e30, np.subtract(b1_delta_640_selec_avg, b1_delta_640_selec_se), np.add(b1_delta_640_selec_avg, b1_delta_640_selec_se), color='violet', alpha=0.5)
# 768
ax3.plot(e30, b1_delta_768_selec_avg, c='black', label='768')
ax3.fill_between(e30, np.subtract(b1_delta_768_selec_avg, b1_delta_768_selec_se), np.add(b1_delta_768_selec_avg, b1_delta_768_selec_se), color='lightgrey', alpha=0.5)

# Adam 
# 64
ax4.plot(e30, b1_adam_64_selec_avg, c='darkred', label='64')
ax4.fill_between(e30, np.subtract(b1_adam_64_selec_avg, b1_adam_64_selec_se), np.add(b1_adam_64_selec_avg, b1_adam_64_selec_se), color='lightcoral', alpha=0.5)
# 128
ax4.plot(e30, b1_adam_128_selec_avg, c='darkorange', label='128')
ax4.fill_between(e30, np.subtract(b1_adam_128_selec_avg, b1_adam_128_selec_se), np.add(b1_adam_128_selec_avg, b1_adam_128_selec_se), color='moccasin', alpha=0.5)
# 256
ax4.plot(e30, b1_adam_256_selec_avg, c='saddlebrown', label='256')
ax4.fill_between(e30, np.subtract(b1_adam_256_selec_avg, b1_adam_256_selec_se), np.add(b1_adam_256_selec_avg, b1_adam_256_selec_se), color='peru', alpha=0.5)
# 384
ax4.plot(e30, b1_adam_384_selec_avg, c='darkgreen', label='384')
ax4.fill_between(e30, np.subtract(b1_adam_384_selec_avg, b1_adam_384_selec_se), np.add(b1_adam_384_selec_avg, b1_adam_384_selec_se), color='lime', alpha=0.5)
# 512 
ax4.plot(e30, b1_adam_512_selec_avg, c='royalblue', label='512')
ax4.fill_between(e30, np.subtract(b1_adam_512_selec_avg, b1_adam_512_selec_se), np.add(b1_adam_512_selec_avg, b1_adam_512_selec_se), color='lightsteelblue', alpha=0.5)
# 640 
ax4.plot(e30, b1_adam_640_selec_avg, c='purple', label='640')
ax4.fill_between(e30, np.subtract(b1_adam_640_selec_avg, b1_adam_640_selec_se), np.add(b1_adam_640_selec_avg, b1_adam_640_selec_se), color='violet', alpha=0.5)
# 768
ax4.plot(e30, b1_adam_768_selec_avg, c='black', label='768')
ax4.fill_between(e30, np.subtract(b1_adam_768_selec_avg, b1_adam_768_selec_se), np.add(b1_adam_768_selec_avg, b1_adam_768_selec_se), color='lightgrey', alpha=0.5)

ax4.set_xlabel('Epochs')
ax4.legend(loc='upper center', bbox_to_anchor=(-1.3, -0.15),
          fancybox=True, shadow=True, ncol=7)

ax1.set_title('batch size=1 SGD')
ax2.set_title('batch size=1 Adagrad')
ax3.set_title('batch size=1 Adadelta')
ax4.set_title('batch size=1 Adam')

ax1.set_xlabel('Epochs')
ax2.set_xlabel('Epochs')
ax3.set_xlabel('Epochs')
ax4.set_xlabel('Epochs')

ax1.set_ylabel('Selectivity')

ax1.grid()
ax2.grid()
ax3.grid()
ax4.grid()
