# %%
import matplotlib.pyplot as plt
import numpy as np
import re
import ast 
import torch

# %%
def val_extractor(file_name1, file_name2, file_name3):    
    
    test_accuracy_seed1 = 0
    sparsity_average_seed1 = 0
    selectivity_average_seed1 = 0
    
    test_accuracy_seed2 = 0
    sparsity_average_seed2 = 0
    selectivity_average_seed2 = 0
    
    test_accuracy_seed3 = 0
    sparsity_average_seed3 = 0
    selectivity_average_seed3 = 0
    
    # index 0 --> test acc (list)
    # index 1 --> sparsity (list) 
    # index 3 --> selectivity (value)
    
    with open(file_name1) as fi:
        for i, line in enumerate(fi):
            if i == 0:
                test_accuracy_seed1 = ast.literal_eval(line)     
            if i == 1:
                sparsity_average_seed1 = ast.literal_eval(line)
            if i == 3:
                selectivity_average_seed1 = ast.literal_eval(line)
                
    with open(file_name2) as fi:
        for i, line in enumerate(fi):
            if i == 0:
                test_accuracy_seed2 = ast.literal_eval(line)     
            if i == 1:
                sparsity_average_seed2 = ast.literal_eval(line)
            if i == 3:
                selectivity_average_seed2 = ast.literal_eval(line)
                
    with open(file_name3) as fi:
        for i, line in enumerate(fi):
            if i == 0:
                test_accuracy_seed3 = ast.literal_eval(line)     
            if i == 1:
                sparsity_average_seed3 = ast.literal_eval(line)
            if i == 3:
                selectivity_average_seed3 = ast.literal_eval(line)
    
    acc_avg = list()
    acc_se  = list()

    spar_avg = list()
    spar_se  = list()

    selec_avg = list()
    selec_se  = list()

    for i in range(len(test_accuracy_seed1)):
        acc_avg.append(np.mean([test_accuracy_seed1[i], test_accuracy_seed2[i], test_accuracy_seed3[i]]))
        acc_se .append(np.std ([test_accuracy_seed1[i], test_accuracy_seed2[i], test_accuracy_seed3[i]]) / np.sqrt(3))

        spar_avg.append(np.mean([sparsity_average_seed1[i], sparsity_average_seed2[i], sparsity_average_seed3[i]]))
        spar_se .append(np.std ([sparsity_average_seed1[i], sparsity_average_seed2[i], sparsity_average_seed3[i]]) / np.sqrt(3))

        selec_avg.append(np.mean([selectivity_average_seed1[i], selectivity_average_seed2[i], selectivity_average_seed3[i]]))
        selec_se .append(np.std ([selectivity_average_seed1[i], selectivity_average_seed2[i], selectivity_average_seed3[i]]) / np.sqrt(3))
    
                
    return acc_avg, acc_se, spar_avg, spar_se, selec_avg, selec_se

# %%
def last_val_extractor(file_name1, file_name2, file_name3):    
    
    test_accuracy_seed1 = 0
    sparsity_average_seed1 = 0
    selectivity_average_seed1 = 0
    
    test_accuracy_seed2 = 0
    sparsity_average_seed2 = 0
    selectivity_average_seed2 = 0
    
    test_accuracy_seed3 = 0
    sparsity_average_seed3 = 0
    selectivity_average_seed3 = 0
    
    # index 0 --> test acc (list)
    # index 1 --> sparsity (list) 
    # index 3 --> selectivity (value)
    
    with open(file_name1) as fi:
        for i, line in enumerate(fi):
            if i == 0:
                test_accuracy_seed1 = ast.literal_eval(line)     
            if i == 1:
                sparsity_average_seed1 = ast.literal_eval(line)
            if i == 3:
                selectivity_average_seed1 = ast.literal_eval(line)
                
    with open(file_name2) as fi:
        for i, line in enumerate(fi):
            if i == 0:
                test_accuracy_seed2 = ast.literal_eval(line)     
            if i == 1:
                sparsity_average_seed2 = ast.literal_eval(line)
            if i == 3:
                selectivity_average_seed2 = ast.literal_eval(line)
                
    with open(file_name3) as fi:
        for i, line in enumerate(fi):
            if i == 0:
                test_accuracy_seed3 = ast.literal_eval(line)     
            if i == 1:
                sparsity_average_seed3 = ast.literal_eval(line)
            if i == 3:
                selectivity_average_seed3 = ast.literal_eval(line)
    
    acc_avg = list()
    acc_se  = list()

    spar_avg = list()
    spar_se  = list()

    selec_avg = list()
    selec_se  = list()

    for i in range(len(test_accuracy_seed1)):
        acc_avg.append(np.mean([test_accuracy_seed1[i], test_accuracy_seed2[i], test_accuracy_seed3[i]]))
        acc_se .append(np.std ([test_accuracy_seed1[i], test_accuracy_seed2[i], test_accuracy_seed3[i]]) / np.sqrt(3))

        spar_avg.append(np.mean([sparsity_average_seed1[i], sparsity_average_seed2[i], sparsity_average_seed3[i]]))
        spar_se .append(np.std ([sparsity_average_seed1[i], sparsity_average_seed2[i], sparsity_average_seed3[i]]) / np.sqrt(3))

        selec_avg.append(np.mean([selectivity_average_seed1[i], selectivity_average_seed2[i], selectivity_average_seed3[i]]))
        selec_se .append(np.std ([selectivity_average_seed1[i], selectivity_average_seed2[i], selectivity_average_seed3[i]]) / np.sqrt(3))
    
                
    return acc_avg[-1], acc_se[-1], spar_avg[-1], spar_se[-1], selec_avg[-1], selec_se[-1]

# %%
# All

# ori 
ori_sgd_acc_avg, ori_sgd_acc_se, ori_sgd_spar_avg, ori_sgd_spar_se, ori_sgd_selec_avg, ori_sgd_selec_se = val_extractor            ('seed1/ori/seed_1_batchsize_50_50_SGD.txt',      'seed100/ori/seed_100_batchsize_50_50_SGD.txt',       'seed1234/ori/seed_1234_batchsize_50_50_SGD.txt')
ori_grad_acc_avg, ori_grad_acc_se, ori_grad_spar_avg, ori_grad_spar_se, ori_grad_selec_avg, ori_grad_selec_se = val_extractor      ('seed1/ori/seed_1_batchsize_50_50_Adagrad.txt',  'seed100/ori/seed_100_batchsize_50_50_Adagrad.txt',   'seed1234/ori/seed_1234_batchsize_50_50_Adagrad.txt')
ori_delta_acc_avg, ori_delta_acc_se, ori_delta_spar_avg, ori_delta_spar_se, ori_delta_selec_avg, ori_delta_selec_se = val_extractor('seed1/ori/seed_1_batchsize_50_50_Adadelta.txt', 'seed100/ori/seed_100_batchsize_50_50_Adadelta.txt',  'seed1234/ori/seed_1234_batchsize_50_50_Adadelta.txt')
ori_adam_acc_avg, ori_adam_acc_se, ori_adam_spar_avg, ori_adam_spar_se, ori_adam_selec_avg, ori_adam_selec_se = val_extractor      ('seed1/ori/seed_1_batchsize_50_50_Adam.txt',     'seed100/ori/seed_100_batchsize_50_50_Adam.txt',      'seed1234/ori/seed_1234_batchsize_50_50_Adam.txt')

# sub 1
sub1_sgd_acc_avg, sub1_sgd_acc_se, sub1_sgd_spar_avg, sub1_sgd_spar_se, sub1_sgd_selec_avg, sub1_sgd_selec_se = val_extractor('seed1/sub1/seed1_1subsebatch1_sparsity_selectivity_SGD.txt', 'seed100/sub1/seed100_1subsebatch1_sparsity_selectivity_SGD.txt', 'seed1234/sub1/seed1234_1subsebatch1_sparsity_selectivity_SGD.txt')
sub1_grad_acc_avg, sub1_grad_acc_se, sub1_grad_spar_avg, sub1_grad_spar_se, sub1_grad_selec_avg, sub1_grad_selec_se = val_extractor('seed1/sub1/seed1_1subsebatch1_sparsity_selectivity_Adagrad.txt', 'seed100/sub1/seed100_1subsebatch1_sparsity_selectivity_Adagrad.txt', 'seed1234/sub1/seed1234_1subsebatch1_sparsity_selectivity_Adagrad.txt')
sub1_delta_acc_avg, sub1_delta_acc_se, sub1_delta_spar_avg, sub1_delta_spar_se, sub1_delta_selec_avg, sub1_delta_selec_se = val_extractor('seed1/sub1/seed1_1subsebatch1_sparsity_selectivity_Adadelta.txt', 'seed100/sub1/seed100_1subsebatch1_sparsity_selectivity_Adadelta.txt', 'seed1234/sub1/seed1234_1subsebatch1_sparsity_selectivity_Adadelta.txt')
sub1_adam_acc_avg, sub1_adam_acc_se, sub1_adam_spar_avg, sub1_adam_spar_se, sub1_adam_selec_avg, sub1_adam_selec_se = val_extractor('seed1/sub1/seed1_1subsebatch1_sparsity_selectivity_Adam.txt', 'seed100/sub1/seed100_1subsebatch1_sparsity_selectivity_Adam.txt', 'seed1234/sub1/seed1234_1subsebatch1_sparsity_selectivity_Adam.txt')

# sub 5 
sub5_sgd_acc_avg, sub5_sgd_acc_se, sub5_sgd_spar_avg, sub5_sgd_spar_se, sub5_sgd_selec_avg, sub5_sgd_selec_se = val_extractor('seed1/sub5/seed1_5subsebatch1_sparsity_selectivity_SGD.txt', 'seed100/sub5/seed100_5subsebatch1_sparsity_selectivity_SGD.txt', 'seed1234/sub5/seed1234_5subsebatch1_sparsity_selectivity_SGD.txt')
sub5_grad_acc_avg, sub5_grad_acc_se, sub5_grad_spar_avg, sub5_grad_spar_se, sub5_grad_selec_avg, sub5_grad_selec_se = val_extractor('seed1/sub5/seed1_5subsebatch1_sparsity_selectivity_Adagrad.txt', 'seed100/sub5/seed100_5subsebatch1_sparsity_selectivity_Adagrad.txt', 'seed1234/sub5/seed1234_5subsebatch1_sparsity_selectivity_Adagrad.txt')
sub5_delta_acc_avg, sub5_delta_acc_se, sub5_delta_spar_avg, sub5_delta_spar_se, sub5_delta_selec_avg, sub5_delta_selec_se = val_extractor('seed1/sub5/seed1_5subsebatch1_sparsity_selectivity_Adadelta.txt', 'seed100/sub5/seed100_5subsebatch1_sparsity_selectivity_Adadelta.txt', 'seed1234/sub5/seed1234_5subsebatch1_sparsity_selectivity_Adadelta.txt')
sub5_adam_acc_avg, sub5_adam_acc_se, sub5_adam_spar_avg, sub5_adam_spar_se, sub5_adam_selec_avg, sub5_adam_selec_se = val_extractor('seed1/sub5/seed1_5subsebatch1_sparsity_selectivity_Adam.txt', 'seed100/sub5/seed100_5subsebatch1_sparsity_selectivity_Adam.txt', 'seed1234/sub5/seed1234_5subsebatch1_sparsity_selectivity_Adam.txt')

# sub 10 
sub10_sgd_acc_avg, sub10_sgd_acc_se, sub10_sgd_spar_avg, sub10_sgd_spar_se, sub10_sgd_selec_avg, sub10_sgd_selec_se = val_extractor('seed1/sub10/seed1_10subsebatch1_sparsity_selectivity_SGD.txt', 'seed100/sub10/seed100_10subsebatch1_sparsity_selectivity_SGD.txt', 'seed1234/sub10/seed1234_10subsebatch1_sparsity_selectivity_SGD.txt')
sub10_grad_acc_avg, sub10_grad_acc_se, sub10_grad_spar_avg, sub10_grad_spar_se, sub10_grad_selec_avg, sub10_grad_selec_se = val_extractor('seed1/sub10/seed1_10subsebatch1_sparsity_selectivity_Adagrad.txt', 'seed100/sub10/seed100_10subsebatch1_sparsity_selectivity_Adagrad.txt', 'seed1234/sub10/seed1234_10subsebatch1_sparsity_selectivity_Adagrad.txt')
sub10_delta_acc_avg, sub10_delta_acc_se, sub10_delta_spar_avg, sub10_delta_spar_se, sub10_delta_selec_avg, sub10_delta_selec_se = val_extractor('seed1/sub10/seed1_10subsebatch1_sparsity_selectivity_Adadelta.txt', 'seed100/sub10/seed100_10subsebatch1_sparsity_selectivity_Adadelta.txt', 'seed1234/sub10/seed1234_10subsebatch1_sparsity_selectivity_Adadelta.txt')
sub10_adam_acc_avg, sub10_adam_acc_se, sub10_adam_spar_avg, sub10_adam_spar_se, sub10_adam_selec_avg, sub10_adam_selec_se = val_extractor('seed1/sub10/seed1_10subsebatch1_sparsity_selectivity_Adam.txt', 'seed100/sub10/seed100_10subsebatch1_sparsity_selectivity_Adam.txt', 'seed1234/sub10/seed1234_10subsebatch1_sparsity_selectivity_Adam.txt')

# %%
e30 = np.linspace(1, 30, 30)

fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, figsize=(20, 5))

# SGD
# sub 1
ax1.plot(e30, sub1_sgd_acc_avg, c='darkred', label='sub 1')
ax1.fill_between(e30, np.subtract(sub1_sgd_acc_avg, sub1_sgd_acc_se), np.add(sub1_sgd_acc_avg, sub1_sgd_acc_se), color='lightcoral', alpha=0.5)
# sub 5 
ax1.plot(e30, sub5_sgd_acc_avg, c='darkorange', label='sub 5')
ax1.fill_between(e30, np.subtract(sub5_sgd_acc_avg, sub5_sgd_acc_se), np.add(sub5_sgd_acc_avg, sub5_sgd_acc_se), color='moccasin', alpha=0.5)
# sub 10
ax1.plot(e30, sub10_sgd_acc_avg, c='saddlebrown', label='sub 10')
ax1.fill_between(e30, np.subtract(sub10_sgd_acc_avg, sub10_sgd_acc_se), np.add(sub10_sgd_acc_avg, sub10_sgd_acc_se), color='peru', alpha=0.5)
# ori 
ax1.plot(e30, ori_sgd_acc_avg, c='darkgreen', label='baseline')
ax1.fill_between(e30, np.subtract(ori_sgd_acc_avg, ori_sgd_acc_se), np.add(ori_sgd_acc_avg, ori_sgd_acc_se), color='lime', alpha=0.5)

# Adagrad
# sub 1
ax2.plot(e30, sub1_grad_acc_avg, c='darkred', label='sub 1')
ax2.fill_between(e30, np.subtract(sub1_grad_acc_avg, sub1_grad_acc_se), np.add(sub1_grad_acc_avg, sub1_grad_acc_se), color='lightcoral', alpha=0.5)
# sub 5 
ax2.plot(e30, sub5_grad_acc_avg, c='darkorange', label='sub 5')
ax2.fill_between(e30, np.subtract(sub5_grad_acc_avg, sub5_grad_acc_se), np.add(sub5_grad_acc_avg, sub5_grad_acc_se), color='moccasin', alpha=0.5)
# sub 10
ax2.plot(e30, sub10_grad_acc_avg, c='saddlebrown', label='sub 10')
ax2.fill_between(e30, np.subtract(sub10_grad_acc_avg, sub10_grad_acc_se), np.add(sub10_grad_acc_avg, sub10_grad_acc_se), color='peru', alpha=0.5)
# ori 
ax2.plot(e30, ori_grad_acc_avg, c='darkgreen', label='baseline')
ax2.fill_between(e30, np.subtract(ori_grad_acc_avg, ori_grad_acc_se), np.add(ori_grad_acc_avg, ori_grad_acc_se), color='lime', alpha=0.5)

# Adadelta 
# SGD
# sub 1
ax3.plot(e30, sub1_delta_acc_avg, c='darkred', label='sub 1')
ax3.fill_between(e30, np.subtract(sub1_delta_acc_avg, sub1_delta_acc_se), np.add(sub1_delta_acc_avg, sub1_delta_acc_se), color='lightcoral', alpha=0.5)
# sub 5 
ax3.plot(e30, sub5_delta_acc_avg, c='darkorange', label='sub 5')
ax3.fill_between(e30, np.subtract(sub5_delta_acc_avg, sub5_delta_acc_se), np.add(sub5_delta_acc_avg, sub5_delta_acc_se), color='moccasin', alpha=0.5)
# sub 10
ax3.plot(e30, sub10_delta_acc_avg, c='saddlebrown', label='sub 10')
ax3.fill_between(e30, np.subtract(sub10_delta_acc_avg, sub10_delta_acc_se), np.add(sub10_delta_acc_avg, sub10_delta_acc_se), color='peru', alpha=0.5)
# ori 
ax3.plot(e30, ori_delta_acc_avg, c='darkgreen', label='baseline')
ax3.fill_between(e30, np.subtract(ori_delta_acc_avg, ori_delta_acc_se), np.add(ori_delta_acc_avg, ori_delta_acc_se), color='lime', alpha=0.5)

# Adam
# sub 1
ax4.plot(e30, sub1_adam_acc_avg, c='darkred', label='sub 1')
ax4.fill_between(e30, np.subtract(sub1_adam_acc_avg, sub1_adam_acc_se), np.add(sub1_adam_acc_avg, sub1_adam_acc_se), color='lightcoral', alpha=0.5)
# sub 5 
ax4.plot(e30, sub5_adam_acc_avg, c='darkorange', label='sub 5')
ax4.fill_between(e30, np.subtract(sub5_adam_acc_avg, sub5_adam_acc_se), np.add(sub5_adam_acc_avg, sub5_adam_acc_se), color='moccasin', alpha=0.5)
# sub 10
ax4.plot(e30, sub10_adam_acc_avg, c='saddlebrown', label='sub 10')
ax4.fill_between(e30, np.subtract(sub10_adam_acc_avg, sub10_adam_acc_se), np.add(sub10_adam_acc_avg, sub10_adam_acc_se), color='peru', alpha=0.5)
# ori 
ax4.plot(e30, ori_adam_acc_avg, c='darkgreen', label='baseline')
ax4.fill_between(e30, np.subtract(ori_adam_acc_avg, ori_adam_acc_se), np.add(ori_adam_acc_avg, ori_adam_acc_se), color='lime', alpha=0.5)


ax1.grid()
ax2.grid()
ax3.grid()
ax4.grid()

ax1.set_title('SGD')
ax2.set_title('Adagrad')
ax3.set_title('Adadelta')
ax4.set_title('Adam')

ax1.set_xlabel('Epochs')
ax2.set_xlabel('Epochs')
ax3.set_xlabel('Epochs')
ax4.set_xlabel('Epochs')

ax1.set_ylabel('Test-accuracy')



plt.plot()
# Out:
# []

# %%
e30 = np.linspace(1, 30, 30)

fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, figsize=(20, 5))

# SGD
# sub 1
ax1.plot(e30, sub1_sgd_acc_avg, c='darkred', label='sub 1')
ax1.fill_between(e30, np.subtract(sub1_sgd_acc_avg, sub1_sgd_acc_se), np.add(sub1_sgd_acc_avg, sub1_sgd_acc_se), color='lightcoral', alpha=0.5)
# sub 5 
ax1.plot(e30, sub5_sgd_acc_avg, c='darkorange', label='sub 5')
ax1.fill_between(e30, np.subtract(sub5_sgd_acc_avg, sub5_sgd_acc_se), np.add(sub5_sgd_acc_avg, sub5_sgd_acc_se), color='moccasin', alpha=0.5)
# sub 10
ax1.plot(e30, sub10_sgd_acc_avg, c='saddlebrown', label='sub 10')
ax1.fill_between(e30, np.subtract(sub10_sgd_acc_avg, sub10_sgd_acc_se), np.add(sub10_sgd_acc_avg, sub10_sgd_acc_se), color='peru', alpha=0.5)
# ori 
ax1.plot(e30, ori_sgd_acc_avg, c='darkgreen', label='baseline')
ax1.fill_between(e30, np.subtract(ori_sgd_acc_avg, ori_sgd_acc_se), np.add(ori_sgd_acc_avg, ori_sgd_acc_se), color='lime', alpha=0.5)

# Adagrad
# sub 1
ax2.plot(e30, sub1_grad_acc_avg, c='darkred', label='sub 1')
ax2.fill_between(e30, np.subtract(sub1_grad_acc_avg, sub1_grad_acc_se), np.add(sub1_grad_acc_avg, sub1_grad_acc_se), color='lightcoral', alpha=0.5)
# sub 5 
ax2.plot(e30, sub5_grad_acc_avg, c='darkorange', label='sub 5')
ax2.fill_between(e30, np.subtract(sub5_grad_acc_avg, sub5_grad_acc_se), np.add(sub5_grad_acc_avg, sub5_grad_acc_se), color='moccasin', alpha=0.5)
# sub 10
ax2.plot(e30, sub10_grad_acc_avg, c='saddlebrown', label='sub 10')
ax2.fill_between(e30, np.subtract(sub10_grad_acc_avg, sub10_grad_acc_se), np.add(sub10_grad_acc_avg, sub10_grad_acc_se), color='peru', alpha=0.5)
# ori 
ax2.plot(e30, ori_grad_acc_avg, c='darkgreen', label='baseline')
ax2.fill_between(e30, np.subtract(ori_grad_acc_avg, ori_grad_acc_se), np.add(ori_grad_acc_avg, ori_grad_acc_se), color='lime', alpha=0.5)

# Adadelta 
# SGD
# sub 1
ax3.plot(e30, sub1_delta_acc_avg, c='darkred', label='sub 1')
ax3.fill_between(e30, np.subtract(sub1_delta_acc_avg, sub1_delta_acc_se), np.add(sub1_delta_acc_avg, sub1_delta_acc_se), color='lightcoral', alpha=0.5)
# sub 5 
ax3.plot(e30, sub5_delta_acc_avg, c='darkorange', label='sub 5')
ax3.fill_between(e30, np.subtract(sub5_delta_acc_avg, sub5_delta_acc_se), np.add(sub5_delta_acc_avg, sub5_delta_acc_se), color='moccasin', alpha=0.5)
# sub 10
ax3.plot(e30, sub10_delta_acc_avg, c='saddlebrown', label='sub 10')
ax3.fill_between(e30, np.subtract(sub10_delta_acc_avg, sub10_delta_acc_se), np.add(sub10_delta_acc_avg, sub10_delta_acc_se), color='peru', alpha=0.5)
# ori 
ax3.plot(e30, ori_delta_acc_avg, c='darkgreen', label='baseline')
ax3.fill_between(e30, np.subtract(ori_delta_acc_avg, ori_delta_acc_se), np.add(ori_delta_acc_avg, ori_delta_acc_se), color='lime', alpha=0.5)

# Adam
# sub 1
ax4.plot(e30, sub1_adam_acc_avg, c='darkred', label='sub 1')
ax4.fill_between(e30, np.subtract(sub1_adam_acc_avg, sub1_adam_acc_se), np.add(sub1_adam_acc_avg, sub1_adam_acc_se), color='lightcoral', alpha=0.5)
# sub 5 
ax4.plot(e30, sub5_adam_acc_avg, c='darkorange', label='sub 5')
ax4.fill_between(e30, np.subtract(sub5_adam_acc_avg, sub5_adam_acc_se), np.add(sub5_adam_acc_avg, sub5_adam_acc_se), color='moccasin', alpha=0.5)
# sub 10
ax4.plot(e30, sub10_adam_acc_avg, c='saddlebrown', label='sub 10')
ax4.fill_between(e30, np.subtract(sub10_adam_acc_avg, sub10_adam_acc_se), np.add(sub10_adam_acc_avg, sub10_adam_acc_se), color='peru', alpha=0.5)
# ori 
ax4.plot(e30, ori_adam_acc_avg, c='darkgreen', label='baseline')
ax4.fill_between(e30, np.subtract(ori_adam_acc_avg, ori_adam_acc_se), np.add(ori_adam_acc_avg, ori_adam_acc_se), color='lime', alpha=0.5)


ax1.grid()
ax2.grid()
ax3.grid()
ax4.grid()

ax1.set_title('SGD')
ax2.set_title('Adagrad')
ax3.set_title('Adadelta')
ax4.set_title('Adam')

ax1.set_xlabel('Epochs')
ax2.set_xlabel('Epochs')
ax3.set_xlabel('Epochs')
ax4.set_xlabel('Epochs')

ax1.set_ylabel('Test-accuracy Zoomed')


ax1.set_ylim([0.975, 0.985])
ax2.set_ylim([0.975, 0.985])
ax3.set_ylim([0.975, 0.985])
ax4.set_ylim([0.975, 0.985])


plt.plot()
# Out:
# []

# %%
e30 = np.linspace(1, 30, 30)

fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, figsize=(20, 5))

# SGD
# sub 1
ax1.plot(e30, sub1_sgd_spar_avg, c='darkred', label='sub 1')
ax1.fill_between(e30, np.subtract(sub1_sgd_spar_avg, sub1_sgd_spar_se), np.add(sub1_sgd_spar_avg, sub1_sgd_spar_se), color='lightcoral', alpha=0.5)
# sub 5 
ax1.plot(e30, sub5_sgd_spar_avg, c='darkorange', label='sub 5')
ax1.fill_between(e30, np.subtract(sub5_sgd_spar_avg, sub5_sgd_spar_se), np.add(sub5_sgd_spar_avg, sub5_sgd_spar_se), color='moccasin', alpha=0.5)
# sub 10
ax1.plot(e30, sub10_sgd_spar_avg, c='saddlebrown', label='sub 10')
ax1.fill_between(e30, np.subtract(sub10_sgd_spar_avg, sub10_sgd_spar_se), np.add(sub10_sgd_spar_avg, sub10_sgd_spar_se), color='peru', alpha=0.5)
# ori 
ax1.plot(e30, ori_sgd_spar_avg, c='darkgreen', label='baseline')
ax1.fill_between(e30, np.subtract(ori_sgd_spar_avg, ori_sgd_spar_se), np.add(ori_sgd_spar_avg, ori_sgd_spar_se), color='lime', alpha=0.5)

# Adagrad
# sub 1
ax2.plot(e30, sub1_grad_spar_avg, c='darkred', label='sub 1')
ax2.fill_between(e30, np.subtract(sub1_grad_spar_avg, sub1_grad_spar_se), np.add(sub1_grad_spar_avg, sub1_grad_spar_se), color='lightcoral', alpha=0.5)
# sub 5 
ax2.plot(e30, sub5_grad_spar_avg, c='darkorange', label='sub 5')
ax2.fill_between(e30, np.subtract(sub5_grad_spar_avg, sub5_grad_spar_se), np.add(sub5_grad_spar_avg, sub5_grad_spar_se), color='moccasin', alpha=0.5)
# sub 10
ax2.plot(e30, sub10_grad_spar_avg, c='saddlebrown', label='sub 10')
ax2.fill_between(e30, np.subtract(sub10_grad_spar_avg, sub10_grad_spar_se), np.add(sub10_grad_spar_avg, sub10_grad_spar_se), color='peru', alpha=0.5)
# ori 
ax2.plot(e30, ori_grad_spar_avg, c='darkgreen', label='baseline')
ax2.fill_between(e30, np.subtract(ori_grad_spar_avg, ori_grad_spar_se), np.add(ori_grad_spar_avg, ori_grad_spar_se), color='lime', alpha=0.5)

# Adadelta 
# SGD
# sub 1
ax3.plot(e30, sub1_delta_spar_avg, c='darkred', label='sub 1')
ax3.fill_between(e30, np.subtract(sub1_delta_spar_avg, sub1_delta_spar_se), np.add(sub1_delta_spar_avg, sub1_delta_spar_se), color='lightcoral', alpha=0.5)
# sub 5 
ax3.plot(e30, sub5_delta_spar_avg, c='darkorange', label='sub 5')
ax3.fill_between(e30, np.subtract(sub5_delta_spar_avg, sub5_delta_spar_se), np.add(sub5_delta_spar_avg, sub5_delta_spar_se), color='moccasin', alpha=0.5)
# sub 10
ax3.plot(e30, sub10_delta_spar_avg, c='saddlebrown', label='sub 10')
ax3.fill_between(e30, np.subtract(sub10_delta_spar_avg, sub10_delta_spar_se), np.add(sub10_delta_spar_avg, sub10_delta_spar_se), color='peru', alpha=0.5)
# ori 
ax3.plot(e30, ori_delta_spar_avg, c='darkgreen', label='baseline')
ax3.fill_between(e30, np.subtract(ori_delta_spar_avg, ori_delta_spar_se), np.add(ori_delta_spar_avg, ori_delta_spar_se), color='lime', alpha=0.5)

# Adam
# sub 1
ax4.plot(e30, sub1_adam_spar_avg, c='darkred', label='sub 1')
ax4.fill_between(e30, np.subtract(sub1_adam_spar_avg, sub1_adam_spar_se), np.add(sub1_adam_spar_avg, sub1_adam_spar_se), color='lightcoral', alpha=0.5)
# sub 5 
ax4.plot(e30, sub5_adam_spar_avg, c='darkorange', label='sub 5')
ax4.fill_between(e30, np.subtract(sub5_adam_spar_avg, sub5_adam_spar_se), np.add(sub5_adam_spar_avg, sub5_adam_spar_se), color='moccasin', alpha=0.5)
# sub 10
ax4.plot(e30, sub10_adam_spar_avg, c='saddlebrown', label='sub 10')
ax4.fill_between(e30, np.subtract(sub10_adam_spar_avg, sub10_adam_spar_se), np.add(sub10_adam_spar_avg, sub10_adam_spar_se), color='peru', alpha=0.5)
# ori 
ax4.plot(e30, ori_adam_spar_avg, c='darkgreen', label='baseline')
ax4.fill_between(e30, np.subtract(ori_adam_spar_avg, ori_adam_spar_se), np.add(ori_adam_spar_avg, ori_adam_spar_se), color='lime', alpha=0.5)


ax1.grid()
ax2.grid()
ax3.grid()
ax4.grid()

ax1.set_title('SGD')
ax2.set_title('Adagrad')
ax3.set_title('Adadelta')
ax4.set_title('Adam')

ax1.set_xlabel('Epochs')
ax2.set_xlabel('Epochs')
ax3.set_xlabel('Epochs')
ax4.set_xlabel('Epochs')

ax1.set_ylabel('Sparsity')

plt.plot()
# Out:
# []

# %%
e30 = np.linspace(1, 30, 30)

fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, figsize=(20, 5))

# SGD
# sub 1
ax1.plot(e30, sub1_sgd_selec_avg, c='darkred', label='sub 1')
ax1.fill_between(e30, np.subtract(sub1_sgd_selec_avg, sub1_sgd_selec_se), np.add(sub1_sgd_selec_avg, sub1_sgd_selec_se), color='lightcoral', alpha=0.5)
# sub 5 
ax1.plot(e30, sub5_sgd_selec_avg, c='darkorange', label='sub 5')
ax1.fill_between(e30, np.subtract(sub5_sgd_selec_avg, sub5_sgd_selec_se), np.add(sub5_sgd_selec_avg, sub5_sgd_selec_se), color='moccasin', alpha=0.5)
# sub 10
ax1.plot(e30, sub10_sgd_selec_avg, c='saddlebrown', label='sub 10')
ax1.fill_between(e30, np.subtract(sub10_sgd_selec_avg, sub10_sgd_selec_se), np.add(sub10_sgd_selec_avg, sub10_sgd_selec_se), color='peru', alpha=0.5)
# ori 
ax1.plot(e30, ori_sgd_selec_avg, c='darkgreen', label='baseline')
ax1.fill_between(e30, np.subtract(ori_sgd_selec_avg, ori_sgd_selec_se), np.add(ori_sgd_selec_avg, ori_sgd_selec_se), color='lime', alpha=0.5)

# Adagrad
# sub 1
ax2.plot(e30, sub1_grad_selec_avg, c='darkred', label='sub 1')
ax2.fill_between(e30, np.subtract(sub1_grad_selec_avg, sub1_grad_selec_se), np.add(sub1_grad_selec_avg, sub1_grad_selec_se), color='lightcoral', alpha=0.5)
# sub 5 
ax2.plot(e30, sub5_grad_selec_avg, c='darkorange', label='sub 5')
ax2.fill_between(e30, np.subtract(sub5_grad_selec_avg, sub5_grad_selec_se), np.add(sub5_grad_selec_avg, sub5_grad_selec_se), color='moccasin', alpha=0.5)
# sub 10
ax2.plot(e30, sub10_grad_selec_avg, c='saddlebrown', label='sub 10')
ax2.fill_between(e30, np.subtract(sub10_grad_selec_avg, sub10_grad_selec_se), np.add(sub10_grad_selec_avg, sub10_grad_selec_se), color='peru', alpha=0.5)
# ori 
ax2.plot(e30, ori_grad_selec_avg, c='darkgreen', label='baseline')
ax2.fill_between(e30, np.subtract(ori_grad_selec_avg, ori_grad_selec_se), np.add(ori_grad_selec_avg, ori_grad_selec_se), color='lime', alpha=0.5)

# Adadelta 
# SGD
# sub 1
ax3.plot(e30, sub1_delta_selec_avg, c='darkred', label='sub 1')
ax3.fill_between(e30, np.subtract(sub1_delta_selec_avg, sub1_delta_selec_se), np.add(sub1_delta_selec_avg, sub1_delta_selec_se), color='lightcoral', alpha=0.5)
# sub 5 
ax3.plot(e30, sub5_delta_selec_avg, c='darkorange', label='sub 5')
ax3.fill_between(e30, np.subtract(sub5_delta_selec_avg, sub5_delta_selec_se), np.add(sub5_delta_selec_avg, sub5_delta_selec_se), color='moccasin', alpha=0.5)
# sub 10
ax3.plot(e30, sub10_delta_selec_avg, c='saddlebrown', label='sub 10')
ax3.fill_between(e30, np.subtract(sub10_delta_selec_avg, sub10_delta_selec_se), np.add(sub10_delta_selec_avg, sub10_delta_selec_se), color='peru', alpha=0.5)
# ori 
ax3.plot(e30, ori_delta_selec_avg, c='darkgreen', label='baseline')
ax3.fill_between(e30, np.subtract(ori_delta_selec_avg, ori_delta_selec_se), np.add(ori_delta_selec_avg, ori_delta_selec_se), color='lime', alpha=0.5)

# Adam
# sub 1
ax4.plot(e30, sub1_adam_selec_avg, c='darkred', label='con 1')
ax4.fill_between(e30, np.subtract(sub1_adam_selec_avg, sub1_adam_selec_se), np.add(sub1_adam_selec_avg, sub1_adam_selec_se), color='lightcoral', alpha=0.5)
# sub 5 
ax4.plot(e30, sub5_adam_selec_avg, c='darkorange', label='con 5')
ax4.fill_between(e30, np.subtract(sub5_adam_selec_avg, sub5_adam_selec_se), np.add(sub5_adam_selec_avg, sub5_adam_selec_se), color='moccasin', alpha=0.5)
# sub 10
ax4.plot(e30, sub10_adam_selec_avg, c='saddlebrown', label='con 10')
ax4.fill_between(e30, np.subtract(sub10_adam_selec_avg, sub10_adam_selec_se), np.add(sub10_adam_selec_avg, sub10_adam_selec_se), color='peru', alpha=0.5)
# ori 
ax4.plot(e30, ori_adam_selec_avg, c='darkgreen', label='baseline')
ax4.fill_between(e30, np.subtract(ori_adam_selec_avg, ori_adam_selec_se), np.add(ori_adam_selec_avg, ori_adam_selec_se), color='lime', alpha=0.5)


ax1.grid()
ax2.grid()
ax3.grid()
ax4.grid()

ax1.set_title('SGD')
ax2.set_title('Adagrad')
ax3.set_title('Adadelta')
ax4.set_title('Adam')

ax1.set_xlabel('Epochs')
ax2.set_xlabel('Epochs')
ax3.set_xlabel('Epochs')
ax4.set_xlabel('Epochs')

ax1.set_ylabel('Selectivity')

ax4.legend(loc='upper center', bbox_to_anchor=(-1.3, -0.15),
          fancybox=True, shadow=True, ncol=4)

plt.plot()
# Out:
# []

# %%
# Last

# sub 1
sub1_sgd_acc_avg_last, sub1_sgd_acc_se_last, sub1_sgd_spar_avg_last, sub1_sgd_spar_se_last, sub1_sgd_selec_avg_last, sub1_sgd_selec_se_last = last_val_extractor('seed1/sub1/seed1_1subsebatch1_sparsity_selectivity_SGD.txt', 'seed100/sub1/seed100_1subsebatch1_sparsity_selectivity_SGD.txt', 'seed1234/sub1/seed1234_1subsebatch1_sparsity_selectivity_SGD.txt')
sub1_grad_acc_avg_last, sub1_grad_acc_se_last, sub1_grad_spar_avg_last, sub1_grad_spar_se_last, sub1_grad_selec_avg_last, sub1_grad_selec_se_last = last_val_extractor('seed1/sub1/seed1_1subsebatch1_sparsity_selectivity_Adagrad.txt', 'seed100/sub1/seed100_1subsebatch1_sparsity_selectivity_Adagrad.txt', 'seed1234/sub1/seed1234_1subsebatch1_sparsity_selectivity_Adagrad.txt')
sub1_delta_acc_avg_last, sub1_delta_acc_se_last, sub1_delta_spar_avg_last, sub1_delta_spar_se_last, sub1_delta_selec_avg_last, sub1_delta_selec_se_last = last_val_extractor('seed1/sub1/seed1_1subsebatch1_sparsity_selectivity_Adadelta.txt', 'seed100/sub1/seed100_1subsebatch1_sparsity_selectivity_Adadelta.txt', 'seed1234/sub1/seed1234_1subsebatch1_sparsity_selectivity_Adadelta.txt')
sub1_adam_acc_avg_last, sub1_adam_acc_se_last, sub1_adam_spar_avg_last, sub1_adam_spar_se_last, sub1_adam_selec_avg_last, sub1_adam_selec_se_last = last_val_extractor('seed1/sub1/seed1_1subsebatch1_sparsity_selectivity_Adam.txt', 'seed100/sub1/seed100_1subsebatch1_sparsity_selectivity_Adam.txt', 'seed1234/sub1/seed1234_1subsebatch1_sparsity_selectivity_Adam.txt')

# sub 5 
sub5_sgd_acc_avg_last, sub5_sgd_acc_se_last, sub5_sgd_spar_avg_last, sub5_sgd_spar_se_last, sub5_sgd_selec_avg_last, sub5_sgd_selec_se_last = last_val_extractor('seed1/sub5/seed1_5subsebatch1_sparsity_selectivity_SGD.txt', 'seed100/sub5/seed100_5subsebatch1_sparsity_selectivity_SGD.txt', 'seed1234/sub5/seed1234_5subsebatch1_sparsity_selectivity_SGD.txt')
sub5_grad_acc_avg_last, sub5_grad_acc_se_last, sub5_grad_spar_avg_last, sub5_grad_spar_se_last, sub5_grad_selec_avg_last, sub5_grad_selec_se_last = last_val_extractor('seed1/sub5/seed1_5subsebatch1_sparsity_selectivity_Adagrad.txt', 'seed100/sub5/seed100_5subsebatch1_sparsity_selectivity_Adagrad.txt', 'seed1234/sub5/seed1234_5subsebatch1_sparsity_selectivity_Adagrad.txt')
sub5_delta_acc_avg_last, sub5_delta_acc_se_last, sub5_delta_spar_avg_last, sub5_delta_spar_se_last, sub5_delta_selec_avg_last, sub5_delta_selec_se_last = last_val_extractor('seed1/sub5/seed1_5subsebatch1_sparsity_selectivity_Adadelta.txt', 'seed100/sub5/seed100_5subsebatch1_sparsity_selectivity_Adadelta.txt', 'seed1234/sub5/seed1234_5subsebatch1_sparsity_selectivity_Adadelta.txt')
sub5_adam_acc_avg_last, sub5_adam_acc_se_last, sub5_adam_spar_avg_last, sub5_adam_spar_se_last, sub5_adam_selec_avg_last, sub5_adam_selec_se_last = last_val_extractor('seed1/sub5/seed1_5subsebatch1_sparsity_selectivity_Adam.txt', 'seed100/sub5/seed100_5subsebatch1_sparsity_selectivity_Adam.txt', 'seed1234/sub5/seed1234_5subsebatch1_sparsity_selectivity_Adam.txt')

# sub 10 
sub10_sgd_acc_avg_last, sub10_sgd_acc_se_last, sub10_sgd_spar_avg_last, sub10_sgd_spar_se_last, sub10_sgd_selec_avg_last, sub10_sgd_selec_se_last = last_val_extractor('seed1/sub10/seed1_10subsebatch1_sparsity_selectivity_SGD.txt', 'seed100/sub10/seed100_10subsebatch1_sparsity_selectivity_SGD.txt', 'seed1234/sub10/seed1234_10subsebatch1_sparsity_selectivity_SGD.txt')
sub10_grad_acc_avg_last, sub10_grad_acc_se_last, sub10_grad_spar_avg_last, sub10_grad_spar_se_last, sub10_grad_selec_avg_last, sub10_grad_selec_se_last = last_val_extractor('seed1/sub10/seed1_10subsebatch1_sparsity_selectivity_Adagrad.txt', 'seed100/sub10/seed100_10subsebatch1_sparsity_selectivity_Adagrad.txt', 'seed1234/sub10/seed1234_10subsebatch1_sparsity_selectivity_Adagrad.txt')
sub10_delta_acc_avg_last, sub10_delta_acc_se_last, sub10_delta_spar_avg_last, sub10_delta_spar_se_last, sub10_delta_selec_avg_last, sub10_delta_selec_se_last = last_val_extractor('seed1/sub10/seed1_10subsebatch1_sparsity_selectivity_Adadelta.txt', 'seed100/sub10/seed100_10subsebatch1_sparsity_selectivity_Adadelta.txt', 'seed1234/sub10/seed1234_10subsebatch1_sparsity_selectivity_Adadelta.txt')
sub10_adam_acc_avg_last, sub10_adam_acc_se_last, sub10_adam_spar_avg_last, sub10_adam_spar_se_last, sub10_adam_selec_avg_last, sub10_adam_selec_se_last = last_val_extractor('seed1/sub10/seed1_10subsebatch1_sparsity_selectivity_Adam.txt', 'seed100/sub10/seed100_10subsebatch1_sparsity_selectivity_Adam.txt', 'seed1234/sub10/seed1234_10subsebatch1_sparsity_selectivity_Adam.txt')

# %%
sgd_acc = [sub1_sgd_acc_avg_last, sub5_sgd_acc_avg_last, sub10_sgd_acc_avg_last]
sgd_acc_se  = [sub1_sgd_acc_se_last, sub5_sgd_acc_se_last, sub10_sgd_acc_se_last]

grad_acc = [sub1_grad_acc_avg_last, sub5_grad_acc_avg_last, sub10_grad_acc_avg_last]
grad_acc_se  = [sub1_grad_acc_se_last, sub5_grad_acc_se_last, sub10_grad_acc_se_last]

delta_acc = [sub1_delta_acc_avg_last, sub5_delta_acc_avg_last, sub10_delta_acc_avg_last]
delta_acc_se  = [sub1_delta_acc_se_last, sub5_delta_acc_se_last, sub10_delta_acc_se_last]

adam_acc = [sub1_adam_acc_avg_last, sub5_adam_acc_avg_last, sub10_adam_acc_avg_last]
adam_acc_se  = [sub1_adam_acc_se_last, sub5_adam_acc_se_last, sub10_adam_acc_se_last]

sgd_spar = [sub1_sgd_spar_avg_last, sub5_sgd_spar_avg_last, sub10_sgd_spar_avg_last]
sgd_spar_se  = [sub1_sgd_spar_se_last, sub5_sgd_spar_se_last, sub10_sgd_spar_se_last]

grad_spar = [sub1_grad_spar_avg_last, sub5_grad_spar_avg_last, sub10_grad_spar_avg_last]
grad_spar_se  = [sub1_grad_spar_se_last, sub5_grad_spar_se_last, sub10_grad_spar_se_last]

delta_spar = [sub1_delta_spar_avg_last, sub5_delta_spar_avg_last, sub10_delta_spar_avg_last]
delta_spar_se  = [sub1_delta_spar_se_last, sub5_delta_spar_se_last, sub10_delta_spar_se_last]

adam_spar = [sub1_adam_spar_avg_last, sub5_adam_spar_avg_last, sub10_adam_spar_avg_last]
adam_spar_se  = [sub1_adam_spar_se_last, sub5_adam_spar_se_last, sub10_adam_spar_se_last]

sgd_selec = [sub1_sgd_selec_avg_last, sub5_sgd_selec_avg_last, sub10_sgd_selec_avg_last]
sgd_selec_se  = [sub1_sgd_selec_se_last, sub5_sgd_selec_se_last, sub10_sgd_selec_se_last]

grad_selec = [sub1_grad_selec_avg_last, sub5_grad_selec_avg_last, sub10_grad_selec_avg_last]
grad_selec_se  = [sub1_grad_selec_se_last, sub5_grad_selec_se_last, sub10_grad_selec_se_last]

delta_selec = [sub1_delta_selec_avg_last, sub5_delta_selec_avg_last, sub10_delta_selec_avg_last]
delta_selec_se  = [sub1_delta_selec_se_last, sub5_delta_selec_se_last, sub10_delta_selec_se_last]

adam_selec = [sub1_adam_selec_avg_last, sub5_adam_selec_avg_last, sub10_adam_selec_avg_last]
adam_selec_se  = [sub1_adam_selec_se_last, sub5_adam_selec_se_last, sub10_adam_selec_se_last]

# %%
e4 = np.linspace(1, 3, 3)

fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(15, 5))

# default setting for grpahs 
hl_ticks = ['con 1', 'con 5', 'con 10']
ax1.set_xticks(np.linspace(1, 3, 3))
ax1.set_xticklabels(hl_ticks)

ax2.set_xticks(np.linspace(1, 3, 3))
ax2.set_xticklabels(hl_ticks)

ax3.set_xticks(np.linspace(1, 3, 3))
ax3.set_xticklabels(hl_ticks)

# Accuracy 
# SGD
ax1.plot(e4, sgd_acc, label='SGD', marker='o', c='darkred')
ax1.fill_between(e4, np.subtract(sgd_acc, sgd_acc_se), np.add(sgd_acc, sgd_acc_se), color='lightcoral', alpha=0.5)
# Adagrad
ax1.plot(e4, grad_acc, label='Adagrad', marker='^', c='darkgreen')
ax1.fill_between(e4, np.subtract(grad_acc, grad_acc_se), np.add(grad_acc, grad_acc_se), color='lime', alpha=0.5)
# Adadelta
ax1.plot(e4, delta_acc, label='Adadelta', marker='v', c='darkblue')
ax1.fill_between(e4, np.subtract(delta_acc, delta_acc_se), np.add(delta_acc, delta_acc_se), color='lightsteelblue', alpha=0.5)
# Adam
ax1.plot(e4, adam_acc, label='Adam', marker='s', c='purple')
ax1.fill_between(e4, np.subtract(adam_acc, adam_acc_se), np.add(adam_acc, adam_acc_se), color='violet', alpha=0.5)


# Sparsity 
# SGD
ax2.plot(e4, sgd_spar, label='SGD', marker='o', c='darkred')
ax2.fill_between(e4, np.subtract(sgd_spar, sgd_spar_se), np.add(sgd_spar, sgd_spar_se), color='lightcoral', alpha=0.5)
# Adagrad
ax2.plot(e4, grad_spar, label='Adagrad', marker='^', c='darkgreen')
ax2.fill_between(e4, np.subtract(grad_spar, grad_spar_se), np.add(grad_spar, grad_spar_se), color='lime', alpha=0.5)
# Adadelta
ax2.plot(e4, delta_spar, label='Adadelta', marker='v', c='darkblue')
ax2.fill_between(e4, np.subtract(delta_spar, delta_spar_se), np.add(delta_spar, delta_spar_se), color='lightsteelblue', alpha=0.5)
# Adam
ax2.plot(e4, adam_spar, label='Adam', marker='s', c='purple')
ax2.fill_between(e4, np.subtract(adam_spar, adam_spar_se), np.add(adam_spar, adam_spar_se), color='violet', alpha=0.5)


# Selectivity
# SGD
ax3.plot(e4, sgd_selec, label='SGD', marker='o', c='darkred')
ax3.fill_between(e4, np.subtract(sgd_selec, sgd_selec_se), np.add(sgd_selec, sgd_selec_se), color='lightcoral', alpha=0.5)
# Adagrad
ax3.plot(e4, grad_selec, label='Adagrad', marker='^', c='darkgreen')
ax3.fill_between(e4, np.subtract(grad_selec, grad_selec_se), np.add(grad_selec, grad_selec_se), color='lime', alpha=0.5)
# Adadelta
ax3.plot(e4, delta_selec, label='Adadelta', marker='v', c='darkblue')
ax3.fill_between(e4, np.subtract(delta_selec, delta_selec_se), np.add(delta_selec, delta_selec_se), color='lightsteelblue', alpha=0.5)
# Adam
ax3.plot(e4, adam_selec, label='Adam', marker='s', c='purple')
ax3.fill_between(e4, np.subtract(adam_selec, adam_selec_se), np.add(adam_selec, adam_selec_se), color='violet', alpha=0.5)


ax1.grid()
ax2.grid()
ax3.grid()

ax1.set_title('Test-accuracy')
ax2.set_title('Sparsity')
ax3.set_title('Selectivity')

ax1.set_ylabel('Test-accuracy, Sparsity, and Selectivity')

ax2.set_ylim([0.2, 0.8])
ax3.set_ylim([0.2, 0.8])

ax1.axhline(0.97, ls='-', label='baseline SGD', color='red')
ax2.axhline(0.226, ls='-', label='baseline SGD', color='red')
ax3.axhline(0.325, ls='-', label='baseline SGD', color='red')

ax1.axhline(0.981, ls='--', label='baseline Adagrad', color='green')
ax2.axhline(0.611, ls='--', label='baseline Adagrad', color='green')
ax3.axhline(0.662, ls='--', label='baseline Adagrad', color='green')

ax1.axhline(0.982, ls='-.', label='baseline Adadelta', color='blue')
ax2.axhline(0.33, ls='-.', label='baseline Adadelta', color='blue')
ax3.axhline(0.409, ls='-.', label='baseline Adadelta', color='blue')

ax1.axhline(0.98, ls=':', label='baseline Adam', color='purple')
ax2.axhline(0.293, ls=':', label='baseline Adam', color='purple')
ax3.axhline(0.372, ls=':', label='baseline Adam', color='purple')


ax3.legend(loc='upper center', bbox_to_anchor=(-0.7, -0.1),
          fancybox=True, shadow=True, ncol=2)
