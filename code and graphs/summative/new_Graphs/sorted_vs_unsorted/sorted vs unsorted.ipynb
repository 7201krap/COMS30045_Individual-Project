# %%
import matplotlib.pyplot as plt
import numpy as np
import re
import ast 
import torch

# %%
def val_extractor(file_name1, file_name2, file_name3):    
    
    test_accuracy_seed1 = 0
    sparsity_average_seed1 = 0
    selectivity_average_seed1 = 0
    
    test_accuracy_seed2 = 0
    sparsity_average_seed2 = 0
    selectivity_average_seed2 = 0
    
    test_accuracy_seed3 = 0
    sparsity_average_seed3 = 0
    selectivity_average_seed3 = 0
    
    # index 0 --> test acc (list)
    # index 1 --> sparsity (list) 
    # index 2 --> selectivity (value)
    
    with open(file_name1) as fi:
        for i, line in enumerate(fi):
            if i == 0:
                test_accuracy_seed1 = ast.literal_eval(line)     
            if i == 1:
                sparsity_average_seed1 = ast.literal_eval(line)
            if i == 2:
                selectivity_average_seed1 = ast.literal_eval(line)
                
    with open(file_name2) as fi:
        for i, line in enumerate(fi):
            if i == 0:
                test_accuracy_seed2 = ast.literal_eval(line)     
            if i == 1:
                sparsity_average_seed2 = ast.literal_eval(line)
            if i == 2:
                selectivity_average_seed2 = ast.literal_eval(line)
                
    with open(file_name3) as fi:
        for i, line in enumerate(fi):
            if i == 0:
                test_accuracy_seed3 = ast.literal_eval(line)     
            if i == 1:
                sparsity_average_seed3 = ast.literal_eval(line)
            if i == 2:
                selectivity_average_seed3 = ast.literal_eval(line)
                
    acc_avg = list()
    acc_se  = list()

    spar_avg = list()
    spar_se  = list()

    selec_avg = list()
    selec_se  = list()

    for i in range(len(test_accuracy_seed1)):
        acc_avg.append(np.mean([test_accuracy_seed1[i], test_accuracy_seed2[i], test_accuracy_seed3[i]]))
        acc_se .append(np.std ([test_accuracy_seed1[i], test_accuracy_seed2[i], test_accuracy_seed3[i]]) / np.sqrt(3))

        spar_avg.append(np.mean([sparsity_average_seed1[i], sparsity_average_seed2[i], sparsity_average_seed3[i]]))
        spar_se .append(np.std ([sparsity_average_seed1[i], sparsity_average_seed2[i], sparsity_average_seed3[i]]) / np.sqrt(3))

        selec_avg.append(np.mean([selectivity_average_seed1[i], selectivity_average_seed2[i], selectivity_average_seed3[i]]))
        selec_se .append(np.std ([selectivity_average_seed1[i], selectivity_average_seed2[i], selectivity_average_seed3[i]]) / np.sqrt(3))
    
                
    return acc_avg, acc_se, spar_avg, spar_se, selec_avg, selec_se

# %%
def last_val_extractor(file_name1, file_name2, file_name3):    
    
    test_accuracy_seed1 = 0
    sparsity_average_seed1 = 0
    selectivity_average_seed1 = 0
    
    test_accuracy_seed2 = 0
    sparsity_average_seed2 = 0
    selectivity_average_seed2 = 0
    
    test_accuracy_seed3 = 0
    sparsity_average_seed3 = 0
    selectivity_average_seed3 = 0
    
    # index 0 --> test acc (list)
    # index 1 --> sparsity (list) 
    # index 2 --> selectivity (value)
    
    with open(file_name1) as fi:
        for i, line in enumerate(fi):
            if i == 0:
                test_accuracy_seed1 = ast.literal_eval(line)     
            if i == 1:
                sparsity_average_seed1 = ast.literal_eval(line)
            if i == 2:
                selectivity_average_seed1 = ast.literal_eval(line)
                
    with open(file_name2) as fi:
        for i, line in enumerate(fi):
            if i == 0:
                test_accuracy_seed2 = ast.literal_eval(line)     
            if i == 1:
                sparsity_average_seed2 = ast.literal_eval(line)
            if i == 2:
                selectivity_average_seed2 = ast.literal_eval(line)
                
    with open(file_name3) as fi:
        for i, line in enumerate(fi):
            if i == 0:
                test_accuracy_seed3 = ast.literal_eval(line)     
            if i == 1:
                sparsity_average_seed3 = ast.literal_eval(line)
            if i == 2:
                selectivity_average_seed3 = ast.literal_eval(line)
                
    acc_avg = list()
    acc_se  = list()

    spar_avg = list()
    spar_se  = list()

    selec_avg = list()
    selec_se  = list()

    for i in range(len(test_accuracy_seed1)):
        acc_avg.append(np.mean([test_accuracy_seed1[i], test_accuracy_seed2[i], test_accuracy_seed3[i]]))
        acc_se .append(np.std ([test_accuracy_seed1[i], test_accuracy_seed2[i], test_accuracy_seed3[i]]) / np.sqrt(3))

        spar_avg.append(np.mean([sparsity_average_seed1[i], sparsity_average_seed2[i], sparsity_average_seed3[i]]))
        spar_se .append(np.std ([sparsity_average_seed1[i], sparsity_average_seed2[i], sparsity_average_seed3[i]]) / np.sqrt(3))

        selec_avg.append(np.mean([selectivity_average_seed1[i], selectivity_average_seed2[i], selectivity_average_seed3[i]]))
        selec_se .append(np.std ([selectivity_average_seed1[i], selectivity_average_seed2[i], selectivity_average_seed3[i]]) / np.sqrt(3))
    
                
    return acc_avg[-1], acc_se[-1], spar_avg[-1], spar_se[-1], selec_avg[-1], selec_se[-1]

# %%
# sorted 
sor_sgd_acc_avg,   sor_sgd_acc_se,   sor_sgd_spar_avg,   sor_sgd_spar_se,   sor_sgd_selec_avg,   sor_sgd_selec_se   = val_extractor('sorted_vs_unsorted/seed1/sorted/seed1_sorted_batch_50_SGD.txt',      'sorted_vs_unsorted/seed100/sorted/seed100_sorted_batch_50_SGD.txt',      'sorted_vs_unsorted/seed1234/sorted/seed1234_sorted_batch_50_SGD.txt')
sor_grad_acc_avg,  sor_grad_acc_se,  sor_grad_spar_avg,  sor_grad_spar_se,  sor_grad_selec_avg,  sor_grad_selec_se  = val_extractor('sorted_vs_unsorted/seed1/sorted/seed1_sorted_batch_50_Adagrad.txt',  'sorted_vs_unsorted/seed100/sorted/seed100_sorted_batch_50_Adagrad.txt',  'sorted_vs_unsorted/seed1234/sorted/seed1234_sorted_batch_50_Adagrad.txt')
sor_delta_acc_avg, sor_delta_acc_se, sor_delta_spar_avg, sor_delta_spar_se, sor_delta_selec_avg, sor_delta_selec_se = val_extractor('sorted_vs_unsorted/seed1/sorted/seed1_sorted_batch_50_Adadelta.txt', 'sorted_vs_unsorted/seed100/sorted/seed100_sorted_batch_50_Adadelta.txt', 'sorted_vs_unsorted/seed1234/sorted/seed1234_sorted_batch_50_Adadelta.txt')
sor_adam_acc_avg,  sor_adam_acc_se,  sor_adam_spar_avg,  sor_adam_spar_se,  sor_adam_selec_avg,  sor_adam_selec_se  = val_extractor('sorted_vs_unsorted/seed1/sorted/seed1_sorted_batch_50_Adam.txt',     'sorted_vs_unsorted/seed100/sorted/seed100_sorted_batch_50_Adam.txt',     'sorted_vs_unsorted/seed1234/sorted/seed1234_sorted_batch_50_Adam.txt')

# unsorted
unsor_sgd_acc_avg,   unsor_sgd_acc_se,   unsor_sgd_spar_avg,   unsor_sgd_spar_se,   unsor_sgd_selec_avg,   unsor_sgd_selec_se   = val_extractor('sorted_vs_unsorted/seed1/unsorted/seed1_unsorted_batch_50_SGD.txt',      'sorted_vs_unsorted/seed100/unsorted/seed100_unsorted_batch_50_SGD.txt',      'sorted_vs_unsorted/seed1234/unsorted/seed1234_unsorted_batch_50_SGD.txt')
unsor_grad_acc_avg,  unsor_grad_acc_se,  unsor_grad_spar_avg,  unsor_grad_spar_se,  unsor_grad_selec_avg,  unsor_grad_selec_se  = val_extractor('sorted_vs_unsorted/seed1/unsorted/seed1_unsorted_batch_50_Adagrad.txt',  'sorted_vs_unsorted/seed100/unsorted/seed100_unsorted_batch_50_Adagrad.txt',  'sorted_vs_unsorted/seed1234/unsorted/seed1234_unsorted_batch_50_Adagrad.txt')
unsor_delta_acc_avg, unsor_delta_acc_se, unsor_delta_spar_avg, unsor_delta_spar_se, unsor_delta_selec_avg, unsor_delta_selec_se = val_extractor('sorted_vs_unsorted/seed1/unsorted/seed1_unsorted_batch_50_Adadelta.txt', 'sorted_vs_unsorted/seed100/unsorted/seed100_unsorted_batch_50_Adadelta.txt', 'sorted_vs_unsorted/seed1234/unsorted/seed1234_unsorted_batch_50_Adadelta.txt')
unsor_adam_acc_avg,  unsor_adam_acc_se,  unsor_adam_spar_avg,  unsor_adam_spar_se,  unsor_adam_selec_avg,  unsor_adam_selec_se  = val_extractor('sorted_vs_unsorted/seed1/unsorted/seed1_unsorted_batch_50_Adam.txt',     'sorted_vs_unsorted/seed100/unsorted/seed100_unsorted_batch_50_Adam.txt',     'sorted_vs_unsorted/seed1234/unsorted/seed1234_unsorted_batch_50_Adam.txt')

# %%
# sorted 
last_sor_sgd_acc_avg,   last_sor_sgd_acc_se,   last_sor_sgd_spar_avg,   last_sor_sgd_spar_se,   last_sor_sgd_selec_avg,   last_sor_sgd_selec_se   = last_val_extractor('sorted_vs_unsorted/seed1/sorted/seed1_sorted_batch_50_SGD.txt',      'sorted_vs_unsorted/seed100/sorted/seed100_sorted_batch_50_SGD.txt',      'sorted_vs_unsorted/seed1234/sorted/seed1234_sorted_batch_50_SGD.txt')
last_sor_grad_acc_avg,  last_sor_grad_acc_se,  last_sor_grad_spar_avg,  last_sor_grad_spar_se,  last_sor_grad_selec_avg,  last_sor_grad_selec_se  = last_val_extractor('sorted_vs_unsorted/seed1/sorted/seed1_sorted_batch_50_Adagrad.txt',  'sorted_vs_unsorted/seed100/sorted/seed100_sorted_batch_50_Adagrad.txt',  'sorted_vs_unsorted/seed1234/sorted/seed1234_sorted_batch_50_Adagrad.txt')
last_sor_delta_acc_avg, last_sor_delta_acc_se, last_sor_delta_spar_avg, last_sor_delta_spar_se, last_sor_delta_selec_avg, last_sor_delta_selec_se = last_val_extractor('sorted_vs_unsorted/seed1/sorted/seed1_sorted_batch_50_Adadelta.txt', 'sorted_vs_unsorted/seed100/sorted/seed100_sorted_batch_50_Adadelta.txt', 'sorted_vs_unsorted/seed1234/sorted/seed1234_sorted_batch_50_Adadelta.txt')
last_sor_adam_acc_avg,  last_sor_adam_acc_se,  last_sor_adam_spar_avg,  last_sor_adam_spar_se,  last_sor_adam_selec_avg,  last_sor_adam_selec_se  = last_val_extractor('sorted_vs_unsorted/seed1/sorted/seed1_sorted_batch_50_Adam.txt',     'sorted_vs_unsorted/seed100/sorted/seed100_sorted_batch_50_Adam.txt',     'sorted_vs_unsorted/seed1234/sorted/seed1234_sorted_batch_50_Adam.txt')

# unsorted
last_unsor_sgd_acc_avg,   last_unsor_sgd_acc_se,   last_unsor_sgd_spar_avg,   last_unsor_sgd_spar_se,   last_unsor_sgd_selec_avg,   last_unsor_sgd_selec_se   = last_val_extractor('sorted_vs_unsorted/seed1/unsorted/seed1_unsorted_batch_50_SGD.txt',      'sorted_vs_unsorted/seed100/unsorted/seed100_unsorted_batch_50_SGD.txt',      'sorted_vs_unsorted/seed1234/unsorted/seed1234_unsorted_batch_50_SGD.txt')
last_unsor_grad_acc_avg,  last_unsor_grad_acc_se,  last_unsor_grad_spar_avg,  last_unsor_grad_spar_se,  last_unsor_grad_selec_avg,  last_unsor_grad_selec_se  = last_val_extractor('sorted_vs_unsorted/seed1/unsorted/seed1_unsorted_batch_50_Adagrad.txt',  'sorted_vs_unsorted/seed100/unsorted/seed100_unsorted_batch_50_Adagrad.txt',  'sorted_vs_unsorted/seed1234/unsorted/seed1234_unsorted_batch_50_Adagrad.txt')
last_unsor_delta_acc_avg, last_unsor_delta_acc_se, last_unsor_delta_spar_avg, last_unsor_delta_spar_se, last_unsor_delta_selec_avg, last_unsor_delta_selec_se = last_val_extractor('sorted_vs_unsorted/seed1/unsorted/seed1_unsorted_batch_50_Adadelta.txt', 'sorted_vs_unsorted/seed100/unsorted/seed100_unsorted_batch_50_Adadelta.txt', 'sorted_vs_unsorted/seed1234/unsorted/seed1234_unsorted_batch_50_Adadelta.txt')
last_unsor_adam_acc_avg,  last_unsor_adam_acc_se,  last_unsor_adam_spar_avg,  last_unsor_adam_spar_se,  last_unsor_adam_selec_avg,  last_unsor_adam_selec_se  = last_val_extractor('sorted_vs_unsorted/seed1/unsorted/seed1_unsorted_batch_50_Adam.txt',     'sorted_vs_unsorted/seed100/unsorted/seed100_unsorted_batch_50_Adam.txt',     'sorted_vs_unsorted/seed1234/unsorted/seed1234_unsorted_batch_50_Adam.txt')

# %%
e100 = np.linspace(1, 100, 100)

fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, figsize=(20, 5))

# SGD
ax1.plot(e100, sor_sgd_acc_avg, c='darkred', label='sorted SGD')
ax1.fill_between(e100, np.subtract(sor_sgd_acc_avg, sor_sgd_acc_se), np.add(sor_sgd_acc_avg, sor_sgd_acc_se), color='lightcoral')
ax1.plot(e100, unsor_sgd_acc_avg, c='darkgreen', label='baseline SGD')
ax1.fill_between(e100, np.subtract(unsor_sgd_acc_avg, unsor_sgd_acc_se), np.add(unsor_sgd_acc_avg, unsor_sgd_acc_se), color='lime')

# Adagrad
ax2.plot(e100, sor_grad_acc_avg, c='darkred', label='sorted Adagrad')
ax2.fill_between(e100, np.subtract(sor_grad_acc_avg, sor_grad_acc_se), np.add(sor_grad_acc_avg, sor_grad_acc_se), color='lightcoral')
ax2.plot(e100, unsor_grad_acc_avg, c='darkgreen', label='baseline Adagrad')
ax2.fill_between(e100, np.subtract(unsor_grad_acc_avg, unsor_grad_acc_se), np.add(unsor_grad_acc_avg, unsor_grad_acc_se), color='lime')

# Adadelta
ax3.plot(e100, sor_delta_acc_avg, c='darkred', label='sorted SGD')
ax3.fill_between(e100, np.subtract(sor_delta_acc_avg, sor_delta_acc_se), np.add(sor_delta_acc_avg, sor_delta_acc_se), color='lightcoral')
ax3.plot(e100, unsor_delta_acc_avg, c='darkgreen', label='baseline SGD')
ax3.fill_between(e100, np.subtract(unsor_delta_acc_avg, unsor_delta_acc_se), np.add(unsor_delta_acc_avg, unsor_delta_acc_se), color='lime')

# Adam 
# SGD
ax4.plot(e100, sor_adam_acc_avg, c='darkred', label='sorted SGD')
ax4.fill_between(e100, np.subtract(sor_adam_acc_avg, sor_adam_acc_se), np.add(sor_adam_acc_avg, sor_adam_acc_se), color='lightcoral')
ax4.plot(e100, unsor_adam_acc_avg, c='darkgreen', label='baseline SGD')
ax4.fill_between(e100, np.subtract(unsor_adam_acc_avg, unsor_adam_acc_se), np.add(unsor_adam_acc_avg, unsor_adam_acc_se), color='lime')


ax1.set_title('SGD')
ax2.set_title('Adagrad')
ax3.set_title('Adadelta')
ax4.set_title('Adam')

ax1.set_xlabel('Epochs')
ax2.set_xlabel('Epochs')
ax3.set_xlabel('Epochs')
ax4.set_xlabel('Epochs')

ax1.set_ylabel('Test-accuracy')

ax1.grid()
ax2.grid()
ax3.grid()
ax4.grid()

plt.plot()
# Out:
# []

# %%
e100 = np.linspace(1, 100, 100)

fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, figsize=(20, 5))

# SGD
ax1.plot(e100, sor_sgd_spar_avg, c='darkred', label='sorted SGD')
ax1.fill_between(e100, np.subtract(sor_sgd_spar_avg, sor_sgd_spar_se), np.add(sor_sgd_spar_avg, sor_sgd_spar_se), color='lightcoral')
ax1.plot(e100, unsor_sgd_spar_avg, c='darkgreen', label='baseline SGD')
ax1.fill_between(e100, np.subtract(unsor_sgd_spar_avg, unsor_sgd_spar_se), np.add(unsor_sgd_spar_avg, unsor_sgd_spar_se), color='lime')

# Adagrad
ax2.plot(e100, sor_grad_spar_avg, c='darkred', label='sorted Adagrad')
ax2.fill_between(e100, np.subtract(sor_grad_spar_avg, sor_grad_spar_se), np.add(sor_grad_spar_avg, sor_grad_spar_se), color='lightcoral')
ax2.plot(e100, unsor_grad_spar_avg, c='darkgreen', label='baseline Adagrad')
ax2.fill_between(e100, np.subtract(unsor_grad_spar_avg, unsor_grad_spar_se), np.add(unsor_grad_spar_avg, unsor_grad_spar_se), color='lime')

# Adadelta
ax3.plot(e100, sor_delta_spar_avg, c='darkred', label='sorted SGD')
ax3.fill_between(e100, np.subtract(sor_delta_spar_avg, sor_delta_spar_se), np.add(sor_delta_spar_avg, sor_delta_spar_se), color='lightcoral')
ax3.plot(e100, unsor_delta_spar_avg, c='darkgreen', label='baseline SGD')
ax3.fill_between(e100, np.subtract(unsor_delta_spar_avg, unsor_delta_spar_se), np.add(unsor_delta_spar_avg, unsor_delta_spar_se), color='lime')

# Adam 
# SGD
ax4.plot(e100, sor_adam_spar_avg, c='darkred', label='sorted SGD')
ax4.fill_between(e100, np.subtract(sor_adam_spar_avg, sor_adam_spar_se), np.add(sor_adam_spar_avg, sor_adam_spar_se), color='lightcoral')
ax4.plot(e100, unsor_adam_spar_avg, c='darkgreen', label='baseline SGD')
ax4.fill_between(e100, np.subtract(unsor_adam_spar_avg, unsor_adam_spar_se), np.add(unsor_adam_spar_avg, unsor_adam_spar_se), color='lime')

ax1.set_title('SGD')
ax2.set_title('Adagrad')
ax3.set_title('Adadelta')
ax4.set_title('Adam')

ax1.set_xlabel('Epochs')
ax2.set_xlabel('Epochs')
ax3.set_xlabel('Epochs')
ax4.set_xlabel('Epochs')

ax1.set_ylabel('Sparsity')

ax1.grid()
ax2.grid()
ax3.grid()
ax4.grid()

plt.plot()
# Out:
# []

# %%
e100 = np.linspace(1, 100, 100)

fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, figsize=(20, 5))

# SGD
ax1.plot(e100, sor_sgd_selec_avg, c='darkred', label='sorted SGD')
ax1.fill_between(e100, np.subtract(sor_sgd_selec_avg, sor_sgd_selec_se), np.add(sor_sgd_selec_avg, sor_sgd_selec_se), color='lightcoral')
ax1.plot(e100, unsor_sgd_selec_avg, c='darkgreen', label='baseline SGD')
ax1.fill_between(e100, np.subtract(unsor_sgd_selec_avg, unsor_sgd_selec_se), np.add(unsor_sgd_selec_avg, unsor_sgd_selec_se), color='lime')

# Adagrad
ax2.plot(e100, sor_grad_selec_avg, c='darkred', label='sorted Adagrad')
ax2.fill_between(e100, np.subtract(sor_grad_selec_avg, sor_grad_selec_se), np.add(sor_grad_selec_avg, sor_grad_selec_se), color='lightcoral')
ax2.plot(e100, unsor_grad_selec_avg, c='darkgreen', label='baseline Adagrad')
ax2.fill_between(e100, np.subtract(unsor_grad_selec_avg, unsor_grad_selec_se), np.add(unsor_grad_selec_avg, unsor_grad_selec_se), color='lime')

# Adadelta
ax3.plot(e100, sor_delta_selec_avg, c='darkred', label='sorted SGD')
ax3.fill_between(e100, np.subtract(sor_delta_selec_avg, sor_delta_selec_se), np.add(sor_delta_selec_avg, sor_delta_selec_se), color='lightcoral')
ax3.plot(e100, unsor_delta_selec_avg, c='darkgreen', label='baseline SGD')
ax3.fill_between(e100, np.subtract(unsor_delta_selec_avg, unsor_delta_selec_se), np.add(unsor_delta_selec_avg, unsor_delta_selec_se), color='lime')

# Adam 
# SGD
ax4.plot(e100, sor_adam_selec_avg, c='darkred', label='sorted SGD')
ax4.fill_between(e100, np.subtract(sor_adam_selec_avg, sor_adam_selec_se), np.add(sor_adam_selec_avg, sor_adam_selec_se), color='lightcoral')
ax4.plot(e100, unsor_adam_selec_avg, c='darkgreen', label='baseline SGD')
ax4.fill_between(e100, np.subtract(unsor_adam_selec_avg, unsor_adam_selec_se), np.add(unsor_adam_selec_avg, unsor_adam_selec_se), color='lime')

ax1.set_title('SGD')
ax2.set_title('Adagrad')
ax3.set_title('Adadelta')
ax4.set_title('Adam')

ax1.set_xlabel('Epochs')
ax2.set_xlabel('Epochs')
ax3.set_xlabel('Epochs')
ax4.set_xlabel('Epochs')

ax1.set_ylabel('Selectivity')

ax1.grid()
ax2.grid()
ax3.grid()
ax4.grid()

plt.plot()

ax4.legend(loc='upper center', bbox_to_anchor=(-1.3, -0.15),
          fancybox=True, shadow=True, ncol=2)

plt.plot()
# Out:
# []

# %%
# baseline -> sorted 
sgd = [last_unsor_sgd_acc_avg, last_sor_sgd_acc_avg]
sgd_se = [last_unsor_sgd_acc_se, last_sor_sgd_acc_se]

grad = [last_unsor_grad_acc_avg, last_sor_grad_acc_avg]
grad_se = [last_unsor_grad_acc_se, last_sor_grad_acc_se]

delta = [last_unsor_delta_acc_avg, last_sor_delta_acc_avg]
delta_se = [last_unsor_delta_acc_se, last_sor_delta_acc_se]

adam = [last_unsor_adam_acc_avg, last_sor_adam_acc_avg]
adam_se = [last_unsor_adam_acc_se, last_sor_adam_acc_se]

# baseline -> sorted 
sgd_spar = [last_unsor_sgd_spar_avg, last_sor_sgd_spar_avg]
sgd_se_spar = [last_unsor_sgd_spar_se, last_sor_sgd_spar_se]

grad_spar = [last_unsor_grad_spar_avg, last_sor_grad_spar_avg]
grad_se_spar = [last_unsor_grad_spar_se, last_sor_grad_spar_se]

delta_spar = [last_unsor_delta_spar_avg, last_sor_delta_spar_avg]
delta_se_spar = [last_unsor_delta_spar_se, last_sor_delta_spar_se]

adam_spar = [last_unsor_adam_spar_avg, last_sor_adam_spar_avg]
adam_se_spar = [last_unsor_adam_spar_se, last_sor_adam_spar_se]

# baseline -> sorted 
sgd_selec = [last_unsor_sgd_selec_avg, last_sor_sgd_selec_avg]
sgd_se_selec = [last_unsor_sgd_selec_se, last_sor_sgd_selec_se]

grad_selec = [last_unsor_grad_selec_avg, last_sor_grad_selec_avg]
grad_se_selec = [last_unsor_grad_selec_se, last_sor_grad_selec_se]

delta_selec = [last_unsor_delta_selec_avg, last_sor_delta_selec_avg]
delta_se_selec = [last_unsor_delta_selec_se, last_sor_delta_selec_se]

adam_selec = [last_unsor_adam_selec_avg, last_sor_adam_selec_avg]
adam_se_selec = [last_unsor_adam_selec_se, last_sor_adam_selec_se]

# %%
e2 = np.linspace(1,2,2)

fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(15, 5))

# default setting for grpahs 
hl_ticks = ['baseline', 'sorted']
ax1.set_xticks(np.linspace(1, 2, 2))
ax1.set_xticklabels(hl_ticks)

ax2.set_xticks(np.linspace(1, 2, 2))
ax2.set_xticklabels(hl_ticks)

ax3.set_xticks(np.linspace(1, 2, 2))
ax3.set_xticklabels(hl_ticks)

ax1.plot(e2 , sgd, label='SGD', c='darkred', marker='o')
ax1.fill_between(e2, np.subtract(sgd, sgd_se), np.add(sgd, sgd_se), color='lightcoral', alpha=0.5)
ax1.plot(e2 , grad, label='Adagrad', c='darkgreen', marker='^')
ax1.fill_between(e2, np.subtract(grad, grad_se), np.add(grad, grad_se), color='lime', alpha=0.5)
ax1.plot(e2 , delta, label='Adadelta', c='darkblue', marker='v')
ax1.fill_between(e2, np.subtract(delta, delta_se), np.add(delta, delta_se), color='lightsteelblue', alpha=0.5)
ax1.plot(e2 , adam, label='Adam', c='purple', marker='s')
ax1.fill_between(e2, np.subtract(adam, adam_se), np.add(adam, adam_se), color='violet', alpha=0.5)

ax2.plot(e2 , sgd_spar, label='SGD', c='darkred', marker='o')
ax2.fill_between(e2, np.subtract(sgd_spar, sgd_se_spar), np.add(sgd_spar, sgd_se_spar), color='lightcoral', alpha=0.5)
ax2.plot(e2 , grad_spar, label='Adagrad', c='darkgreen', marker='^')
ax2.fill_between(e2, np.subtract(grad_spar, grad_se_spar), np.add(grad_spar, grad_se_spar), color='lime', alpha=0.5)
ax2.plot(e2 , delta_spar, label='Adadelta', c='darkblue', marker='v')
ax2.fill_between(e2, np.subtract(delta_spar, delta_se_spar), np.add(delta_spar, delta_se_spar), color='lightsteelblue', alpha=0.5)
ax2.plot(e2 , adam_spar, label='Adam', c='purple', marker='s')
ax2.fill_between(e2, np.subtract(adam_spar, adam_se_spar), np.add(adam_spar, adam_se_spar), color='violet', alpha=0.5)

ax3.plot(e2 , sgd_selec, label='SGD', c='darkred', marker='o')
ax3.fill_between(e2, np.subtract(sgd_selec, sgd_se_selec), np.add(sgd_selec, sgd_se_selec), color='lightcoral', alpha=0.5)
ax3.plot(e2 , grad_selec, label='Adagrad', c='darkgreen', marker='^')
ax3.fill_between(e2, np.subtract(grad_selec, grad_se_selec), np.add(grad_selec, grad_se_selec), color='lime', alpha=0.5)
ax3.plot(e2 , delta_selec, label='Adadelta', c='darkblue', marker='v')
ax3.fill_between(e2, np.subtract(delta_selec, delta_se_selec), np.add(delta_selec, delta_se_selec), color='lightsteelblue', alpha=0.5)
ax3.plot(e2 , adam_selec, label='Adam', c='purple', marker='s')
ax3.fill_between(e2, np.subtract(adam_selec, adam_se_selec), np.add(adam_selec, adam_se_selec), color='violet', alpha=0.5)

ax1.set_title('Test Accuracy')
ax2.set_title('Sparsity')
ax3.set_title('Selectivity')

ax1.set_ylabel('Test Accruacy, Sparsity, and Selectivity')

ax1.grid()
ax2.grid()
ax3.grid()

ax3.legend(loc='upper center', bbox_to_anchor=(-0.7, -0.1),
          fancybox=True, shadow=True, ncol=4)

plt.plot()
# Out:
# []
