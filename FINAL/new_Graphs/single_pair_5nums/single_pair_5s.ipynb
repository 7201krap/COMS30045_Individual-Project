# %%
import matplotlib.pyplot as plt
import numpy as np
import re
import ast 
import torch

# %%
def val_extractor(file_name1, file_name2, file_name3):    
    
    test_accuracy_seed1 = 0
    sparsity_average_seed1 = 0
    selectivity_average_seed1 = 0
    
    test_accuracy_seed2 = 0
    sparsity_average_seed2 = 0
    selectivity_average_seed2 = 0
    
    test_accuracy_seed3 = 0
    sparsity_average_seed3 = 0
    selectivity_average_seed3 = 0
    
    # index 0 --> test acc (list)
    # index 1 --> sparsity (list) 
    # index 3 --> selectivity (list)
    
    with open(file_name1) as fi:
        for i, line in enumerate(fi):
            if i == 0:
                test_accuracy_seed1 = ast.literal_eval(line)     
            if i == 1:
                sparsity_average_seed1 = ast.literal_eval(line)
            if i == 2:
                selectivity_average_seed1 = ast.literal_eval(line)
                
    with open(file_name2) as fi:
        for i, line in enumerate(fi):
            if i == 0:
                test_accuracy_seed2 = ast.literal_eval(line)     
            if i == 1:
                sparsity_average_seed2 = ast.literal_eval(line)
            if i == 2:
                selectivity_average_seed2 = ast.literal_eval(line)
                
    with open(file_name3) as fi:
        for i, line in enumerate(fi):
            if i == 0:
                test_accuracy_seed3 = ast.literal_eval(line)     
            if i == 1:
                sparsity_average_seed3 = ast.literal_eval(line)
            if i == 2:
                selectivity_average_seed3 = ast.literal_eval(line)
    
    acc_avg = list()
    acc_se  = list()

    spar_avg = list()
    spar_se  = list()

    selec_avg = list()
    selec_se  = list()

    for i in range(len(test_accuracy_seed1)):
        acc_avg.append(np.mean([test_accuracy_seed1[i], test_accuracy_seed2[i], test_accuracy_seed3[i]]))
        acc_se .append(np.std ([test_accuracy_seed1[i], test_accuracy_seed2[i], test_accuracy_seed3[i]]) / np.sqrt(3))

        spar_avg.append(np.mean([sparsity_average_seed1[i], sparsity_average_seed2[i], sparsity_average_seed3[i]]))
        spar_se .append(np.std ([sparsity_average_seed1[i], sparsity_average_seed2[i], sparsity_average_seed3[i]]) / np.sqrt(3))

        selec_avg.append(np.mean([selectivity_average_seed1[i], selectivity_average_seed2[i], selectivity_average_seed3[i]]))
        selec_se .append(np.std ([selectivity_average_seed1[i], selectivity_average_seed2[i], selectivity_average_seed3[i]]) / np.sqrt(3))
    
                
    return acc_avg, acc_se, spar_avg, spar_se, selec_avg, selec_se

# %%
def extract_last_val_extractor(file_name1, file_name2, file_name3):    
    
    test_accuracy_seed1 = 0
    sparsity_average_seed1 = 0
    selectivity_average_seed1 = 0
    
    test_accuracy_seed2 = 0
    sparsity_average_seed2 = 0
    selectivity_average_seed2 = 0
    
    test_accuracy_seed3 = 0
    sparsity_average_seed3 = 0
    selectivity_average_seed3 = 0
    
    # index 0 --> test acc (list)
    # index 1 --> sparsity (list) 
    # index 2 --> selectivity (list)
    
    with open(file_name1) as fi:
        for i, line in enumerate(fi):
            if i == 0:
                test_accuracy_seed1 = ast.literal_eval(line)     
            if i == 1:
                sparsity_average_seed1 = ast.literal_eval(line)
            if i == 2:
                selectivity_average_seed1 = ast.literal_eval(line)
                
    with open(file_name2) as fi:
        for i, line in enumerate(fi):
            if i == 0:
                test_accuracy_seed2 = ast.literal_eval(line)     
            if i == 1:
                sparsity_average_seed2 = ast.literal_eval(line)
            if i == 2:
                selectivity_average_seed2 = ast.literal_eval(line)
                
    with open(file_name3) as fi:
        for i, line in enumerate(fi):
            if i == 0:
                test_accuracy_seed3 = ast.literal_eval(line)     
            if i == 1:
                sparsity_average_seed3 = ast.literal_eval(line)
            if i == 2:
                selectivity_average_seed3 = ast.literal_eval(line)
    
    acc_avg = list()
    acc_se  = list()

    spar_avg = list()
    spar_se  = list()

    selec_avg = list()
    selec_se  = list()

    for i in range(len(test_accuracy_seed1)):
        acc_avg.append(np.mean([test_accuracy_seed1[i], test_accuracy_seed2[i], test_accuracy_seed3[i]]))
        acc_se .append(np.std ([test_accuracy_seed1[i], test_accuracy_seed2[i], test_accuracy_seed3[i]]) / np.sqrt(3))

        spar_avg.append(np.mean([sparsity_average_seed1[i], sparsity_average_seed2[i], sparsity_average_seed3[i]]))
        spar_se .append(np.std ([sparsity_average_seed1[i], sparsity_average_seed2[i], sparsity_average_seed3[i]]) / np.sqrt(3))

        selec_avg.append(np.mean([selectivity_average_seed1[i], selectivity_average_seed2[i], selectivity_average_seed3[i]]))
        selec_se .append(np.std ([selectivity_average_seed1[i], selectivity_average_seed2[i], selectivity_average_seed3[i]]) / np.sqrt(3))
    
                
    return acc_avg[-1], acc_se[-1], spar_avg[-1], spar_se[-1], selec_avg[-1], selec_se[-1]

# %%
# extract all

# original
ori_sgd_acc_avg, ori_sgd_acc_se, ori_sgd_spar_avg, ori_sgd_spar_se, ori_sgd_selec_avg, ori_sgd_selec_se = val_extractor('training/seed1/seed_1_sparsity_selectivity_4_optim_training_SGD.txt', 'training/seed100/seed_100_sparsity_selectivity_4_optim_training_SGD.txt', 'training/seed1234/seed_1234_sparsity_selectivity_4_optim_training_SGD.txt')
ori_grad_acc_avg, ori_grad_acc_se, ori_grad_spar_avg, ori_grad_spar_se, ori_grad_selec_avg, ori_grad_selec_se = val_extractor('training/seed1/seed_1_sparsity_selectivity_4_optim_training_Adagrad.txt', 'training/seed100/seed_100_sparsity_selectivity_4_optim_training_Adagrad.txt', 'training/seed1234/seed_1234_sparsity_selectivity_4_optim_training_Adagrad.txt')
ori_delta_acc_avg, ori_delta_acc_se, ori_delta_spar_avg, ori_delta_spar_se, ori_delta_selec_avg, ori_delta_selec_se = val_extractor('training/seed1/seed_1_sparsity_selectivity_4_optim_training_Adadelta.txt', 'training/seed100/seed_100_sparsity_selectivity_4_optim_training_Adadelta.txt', 'training/seed1234/seed_1234_sparsity_selectivity_4_optim_training_Adadelta.txt')
ori_adam_acc_avg, ori_adam_acc_se, ori_adam_spar_avg, ori_adam_spar_se, ori_adam_selec_avg, ori_adam_selec_se = val_extractor('training/seed1/seed_1_sparsity_selectivity_4_optim_training_Adam.txt', 'training/seed100/seed_100_sparsity_selectivity_4_optim_training_Adam.txt', 'training/seed1234/seed_1234_sparsity_selectivity_4_optim_training_Adam.txt')

# 5nums 
num5_sgd_acc_avg, num5_sgd_acc_se, num5_sgd_spar_avg, num5_sgd_spar_se, num5_sgd_selec_avg, num5_sgd_selec_se = val_extractor('seed1/5nums/seed_1_5nums_SGD.txt', 'seed100/5nums/seed_100_5nums_SGD.txt', 'seed1234/5nums/seed_1234_5nums_SGD.txt')
num5_grad_acc_avg, num5_grad_acc_se, num5_grad_spar_avg, num5_grad_spar_se, num5_grad_selec_avg, num5_grad_selec_se = val_extractor('seed1/5nums/seed_1_5nums_Adagrad.txt', 'seed100/5nums/seed_100_5nums_Adagrad.txt', 'seed1234/5nums/seed_1234_5nums_Adagrad.txt') 
num5_delta_acc_avg, num5_delta_acc_se, num5_delta_spar_avg, num5_delta_spar_se, num5_delta_selec_avg, num5_delta_selec_se = val_extractor('seed1/5nums/seed_1_5nums_Adadelta.txt', 'seed100/5nums/seed_100_5nums_Adadelta.txt', 'seed1234/5nums/seed_1234_5nums_Adadelta.txt') 
num5_adam_acc_avg, num5_adam_acc_se, num5_adam_spar_avg, num5_adam_spar_se, num5_adam_selec_avg, num5_adam_selec_se = val_extractor('seed1/5nums/seed_1_5nums_Adam.txt', 'seed100/5nums/seed_100_5nums_Adam.txt', 'seed1234/5nums/seed_1234_5nums_Adam.txt') 

# pair 
pair_sgd_acc_avg, pair_sgd_acc_se, pair_sgd_spar_avg, pair_sgd_spar_se, pair_sgd_selec_avg, pair_sgd_selec_se = val_extractor('seed1/pair/seed_1_pair_SGD.txt', 'seed100/pair/seed_100_pair_SGD.txt', 'seed1234/pair/seed_1234_pair_SGD.txt')
pair_grad_acc_avg, pair_grad_acc_se, pair_grad_spar_avg, pair_grad_spar_se, pair_grad_selec_avg, pair_grad_selec_se = val_extractor('seed1/pair/seed_1_pair_Adagrad.txt', 'seed100/pair/seed_100_pair_Adagrad.txt', 'seed1234/pair/seed_1234_pair_Adagrad.txt') 
pair_delta_acc_avg, pair_delta_acc_se, pair_delta_spar_avg, pair_delta_spar_se, pair_delta_selec_avg, pair_delta_selec_se = val_extractor('seed1/pair/seed_1_pair_Adadelta.txt', 'seed100/pair/seed_100_pair_Adadelta.txt', 'seed1234/pair/seed_1234_pair_Adadelta.txt') 
pair_adam_acc_avg, pair_adam_acc_se, pair_adam_spar_avg, pair_adam_spar_se, pair_adam_selec_avg, pair_adam_selec_se = val_extractor('seed1/pair/seed_1_pair_Adam.txt', 'seed100/pair/seed_100_pair_Adam.txt', 'seed1234/pair/seed_1234_pair_Adam.txt') 

# single 
single_sgd_acc_avg, single_sgd_acc_se, single_sgd_spar_avg, single_sgd_spar_se, single_sgd_selec_avg, single_sgd_selec_se = val_extractor('seed1/single/seed_1_single_SGD.txt', 'seed100/single/seed_100_single_SGD.txt', 'seed1234/single/seed_1234_single_SGD.txt')
single_grad_acc_avg, single_grad_acc_se, single_grad_spar_avg, single_grad_spar_se, single_grad_selec_avg, single_grad_selec_se = val_extractor('seed1/single/seed_1_single_Adagrad.txt', 'seed100/single/seed_100_single_Adagrad.txt', 'seed1234/single/seed_1234_single_Adagrad.txt') 
single_delta_acc_avg, single_delta_acc_se, single_delta_spar_avg, single_delta_spar_se, single_delta_selec_avg, single_delta_selec_se = val_extractor('seed1/single/seed_1_single_Adadelta.txt', 'seed100/single/seed_100_single_Adadelta.txt', 'seed1234/single/seed_1234_single_Adadelta.txt') 
single_adam_acc_avg, single_adam_acc_se, single_adam_spar_avg, single_adam_spar_se, single_adam_selec_avg, single_adam_selec_se = val_extractor('seed1/single/seed_1_single_Adam.txt', 'seed100/single/seed_100_single_Adam.txt', 'seed1234/single/seed_1234_single_Adam.txt')

# %%
# extract last 

# original
ori_sgd_acc_avg_last, ori_sgd_acc_se_last, ori_sgd_spar_avg_last, ori_sgd_spar_se_last, ori_sgd_selec_avg_last, ori_sgd_selec_se_last = extract_last_val_extractor('training/seed1/seed_1_sparsity_selectivity_4_optim_training_SGD.txt', 'training/seed100/seed_100_sparsity_selectivity_4_optim_training_SGD.txt', 'training/seed1234/seed_1234_sparsity_selectivity_4_optim_training_SGD.txt')
ori_grad_acc_avg_last, ori_grad_acc_se_last, ori_grad_spar_avg_last, ori_grad_spar_se_last, ori_grad_selec_avg_last, ori_grad_selec_se_last = extract_last_val_extractor('training/seed1/seed_1_sparsity_selectivity_4_optim_training_Adagrad.txt', 'training/seed100/seed_100_sparsity_selectivity_4_optim_training_Adagrad.txt', 'training/seed1234/seed_1234_sparsity_selectivity_4_optim_training_Adagrad.txt')
ori_delta_acc_avg_last, ori_delta_acc_se_last, ori_delta_spar_avg_last, ori_delta_spar_se_last, ori_delta_selec_avg_last, ori_delta_selec_se_last = extract_last_val_extractor('training/seed1/seed_1_sparsity_selectivity_4_optim_training_Adadelta.txt', 'training/seed100/seed_100_sparsity_selectivity_4_optim_training_Adadelta.txt', 'training/seed1234/seed_1234_sparsity_selectivity_4_optim_training_Adadelta.txt')
ori_adam_acc_avg_last, ori_adam_acc_se_last, ori_adam_spar_avg_last, ori_adam_spar_se_last, ori_adam_selec_avg_last, ori_adam_selec_se_last = extract_last_val_extractor('training/seed1/seed_1_sparsity_selectivity_4_optim_training_Adam.txt', 'training/seed100/seed_100_sparsity_selectivity_4_optim_training_Adam.txt', 'training/seed1234/seed_1234_sparsity_selectivity_4_optim_training_Adam.txt')

# 5nums 
num5_sgd_acc_avg_last, num5_sgd_acc_se_last, num5_sgd_spar_avg_last, num5_sgd_spar_se_last, num5_sgd_selec_avg_last, num5_sgd_selec_se_last = extract_last_val_extractor('seed1/5nums/seed_1_5nums_SGD.txt', 'seed100/5nums/seed_100_5nums_SGD.txt', 'seed1234/5nums/seed_1234_5nums_SGD.txt')
num5_grad_acc_avg_last, num5_grad_acc_se_last, num5_grad_spar_avg_last, num5_grad_spar_se_last, num5_grad_selec_avg_last, num5_grad_selec_se_last = extract_last_val_extractor('seed1/5nums/seed_1_5nums_Adagrad.txt', 'seed100/5nums/seed_100_5nums_Adagrad.txt', 'seed1234/5nums/seed_1234_5nums_Adagrad.txt') 
num5_delta_acc_avg_last, num5_delta_acc_se_last, num5_delta_spar_avg_last, num5_delta_spar_se_last, num5_delta_selec_avg_last, num5_delta_selec_se_last = extract_last_val_extractor('seed1/5nums/seed_1_5nums_Adadelta.txt', 'seed100/5nums/seed_100_5nums_Adadelta.txt', 'seed1234/5nums/seed_1234_5nums_Adadelta.txt') 
num5_adam_acc_avg_last, num5_adam_acc_se_last, num5_adam_spar_avg_last, num5_adam_spar_se_last, num5_adam_selec_avg_last, num5_adam_selec_se_last = extract_last_val_extractor('seed1/5nums/seed_1_5nums_Adam.txt', 'seed100/5nums/seed_100_5nums_Adam.txt', 'seed1234/5nums/seed_1234_5nums_Adam.txt') 

# pair 
pair_sgd_acc_avg_last, pair_sgd_acc_se_last, pair_sgd_spar_avg_last, pair_sgd_spar_se_last, pair_sgd_selec_avg_last, pair_sgd_selec_se_last = extract_last_val_extractor('seed1/pair/seed_1_pair_SGD.txt', 'seed100/pair/seed_100_pair_SGD.txt', 'seed1234/pair/seed_1234_pair_SGD.txt')
pair_grad_acc_avg_last, pair_grad_acc_se_last, pair_grad_spar_avg_last, pair_grad_spar_se_last, pair_grad_selec_avg_last, pair_grad_selec_se_last = extract_last_val_extractor('seed1/pair/seed_1_pair_Adagrad.txt', 'seed100/pair/seed_100_pair_Adagrad.txt', 'seed1234/pair/seed_1234_pair_Adagrad.txt') 
pair_delta_acc_avg_last, pair_delta_acc_se_last, pair_delta_spar_avg_last, pair_delta_spar_se_last, pair_delta_selec_avg_last, pair_delta_selec_se_last = extract_last_val_extractor('seed1/pair/seed_1_pair_Adadelta.txt', 'seed100/pair/seed_100_pair_Adadelta.txt', 'seed1234/pair/seed_1234_pair_Adadelta.txt') 
pair_adam_acc_avg_last, pair_adam_acc_se_last, pair_adam_spar_avg_last, pair_adam_spar_se_last, pair_adam_selec_avg_last, pair_adam_selec_se_last = extract_last_val_extractor('seed1/pair/seed_1_pair_Adam.txt', 'seed100/pair/seed_100_pair_Adam.txt', 'seed1234/pair/seed_1234_pair_Adam.txt') 

# single 
single_sgd_acc_avg_last, single_sgd_acc_se_last, single_sgd_spar_avg_last, single_sgd_spar_se_last, single_sgd_selec_avg_last, single_sgd_selec_se_last = extract_last_val_extractor('seed1/single/seed_1_single_SGD.txt', 'seed100/single/seed_100_single_SGD.txt', 'seed1234/single/seed_1234_single_SGD.txt')
single_grad_acc_avg_last, single_grad_acc_se_last, single_grad_spar_avg_last, single_grad_spar_se_last, single_grad_selec_avg_last, single_grad_selec_se_last = extract_last_val_extractor('seed1/single/seed_1_single_Adagrad.txt', 'seed100/single/seed_100_single_Adagrad.txt', 'seed1234/single/seed_1234_single_Adagrad.txt') 
single_delta_acc_avg_last, single_delta_acc_se_last, single_delta_spar_avg_last, single_delta_spar_se_last, single_delta_selec_avg_last, single_delta_selec_se_last = extract_last_val_extractor('seed1/single/seed_1_single_Adadelta.txt', 'seed100/single/seed_100_single_Adadelta.txt', 'seed1234/single/seed_1234_single_Adadelta.txt') 
single_adam_acc_avg_last, single_adam_acc_se_last, single_adam_spar_avg_last, single_adam_spar_se_last, single_adam_selec_avg_last, single_adam_selec_se_last = extract_last_val_extractor('seed1/single/seed_1_single_Adam.txt', 'seed100/single/seed_100_single_Adam.txt', 'seed1234/single/seed_1234_single_Adam.txt')

# %%
# accuracy
sgd_acc = [ori_sgd_acc_avg_last, num5_sgd_acc_avg_last, pair_sgd_acc_avg_last, single_sgd_acc_avg_last]
sgd_acc_se = [ori_sgd_acc_se_last, num5_sgd_acc_se_last, pair_sgd_acc_se_last, single_sgd_acc_se_last]

grad_acc = [ori_grad_acc_avg_last, num5_grad_acc_avg_last, pair_grad_acc_avg_last, single_grad_acc_avg_last]
grad_acc_se = [ori_grad_acc_se_last, num5_grad_acc_se_last, pair_grad_acc_se_last, single_grad_acc_se_last]

delta_acc = [ori_delta_acc_avg_last, num5_delta_acc_avg_last, pair_delta_acc_avg_last, single_delta_acc_avg_last]
delta_acc_se = [ori_delta_acc_se_last, num5_delta_acc_se_last, pair_delta_acc_se_last, single_delta_acc_se_last]

adam_acc = [ori_adam_acc_avg_last, num5_adam_acc_avg_last, pair_adam_acc_avg_last, single_adam_acc_avg_last]
adam_acc_se = [ori_adam_acc_se_last, num5_adam_acc_se_last, pair_adam_acc_se_last, single_adam_acc_se_last]

# sparsity 
sgd_spar = [ori_sgd_spar_avg_last, num5_sgd_spar_avg_last, pair_sgd_spar_avg_last, single_sgd_spar_avg_last]
sgd_spar_se = [ori_sgd_spar_se_last, num5_sgd_spar_se_last, pair_sgd_spar_se_last, single_sgd_spar_se_last]

grad_spar = [ori_grad_spar_avg_last, num5_grad_spar_avg_last, pair_grad_spar_avg_last, single_grad_spar_avg_last]
grad_spar_se = [ori_grad_spar_se_last, num5_grad_spar_se_last, pair_grad_spar_se_last, single_grad_spar_se_last]

delta_spar = [ori_delta_spar_avg_last, num5_delta_spar_avg_last, pair_delta_spar_avg_last, single_delta_spar_avg_last]
delta_spar_se = [ori_delta_spar_se_last, num5_delta_spar_se_last, pair_delta_spar_se_last, single_delta_spar_se_last]

adam_spar = [ori_adam_spar_avg_last, num5_adam_spar_avg_last, pair_adam_spar_avg_last, single_adam_spar_avg_last]
adam_spar_se = [ori_adam_spar_se_last, num5_adam_spar_se_last, pair_adam_spar_se_last, single_adam_spar_se_last]

# selectivity 
sgd_selec = [ori_sgd_selec_avg_last, num5_sgd_selec_avg_last, pair_sgd_selec_avg_last, single_sgd_selec_avg_last]
sgd_selec_se = [ori_sgd_selec_se_last, num5_sgd_selec_se_last, pair_sgd_selec_se_last, single_sgd_selec_se_last]

grad_selec = [ori_grad_selec_avg_last, num5_grad_selec_avg_last, pair_grad_selec_avg_last, single_grad_selec_avg_last]
grad_selec_se = [ori_grad_selec_se_last, num5_grad_selec_se_last, pair_grad_selec_se_last, single_grad_selec_se_last]

delta_selec = [ori_delta_selec_avg_last, num5_delta_selec_avg_last, pair_delta_selec_avg_last, single_delta_selec_avg_last]
delta_selec_se = [ori_delta_selec_se_last, num5_delta_selec_se_last, pair_delta_selec_se_last, single_delta_selec_se_last]

adam_selec = [ori_adam_selec_avg_last, num5_adam_selec_avg_last, pair_adam_selec_avg_last, single_adam_selec_avg_last]
adam_selec_se = [ori_adam_selec_se_last, num5_adam_selec_se_last, pair_adam_selec_se_last, single_adam_selec_se_last]

# %%
e4 = np.linspace(1, 4, 4)

fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(21, 7))

# default setting for grpahs 
hl_ticks = ['original', '5nums', 'pair', 'single']
ax1.set_xticks(np.linspace(1, 4, 4))
ax1.set_xticklabels(hl_ticks)

ax2.set_xticks(np.linspace(1, 4, 4))
ax2.set_xticklabels(hl_ticks)

ax3.set_xticks(np.linspace(1, 4, 4))
ax3.set_xticklabels(hl_ticks)

# Accuracy 
# SGD
ax1.plot(e4, sgd_acc, label='SGD', marker='o', c='darkred')
ax1.fill_between(e4, np.subtract(sgd_acc, sgd_acc_se), np.add(sgd_acc, sgd_acc_se), color='lightcoral', alpha=0.5)
# Adagrad
ax1.plot(e4, grad_acc, label='Adagrad', marker='^', c='darkgreen')
ax1.fill_between(e4, np.subtract(grad_acc, grad_acc_se), np.add(grad_acc, grad_acc_se), color='lime', alpha=0.5)
# Adadelta
ax1.plot(e4, delta_acc, label='Adadelta', marker='v', c='darkblue')
ax1.fill_between(e4, np.subtract(delta_acc, delta_acc_se), np.add(delta_acc, delta_acc_se), color='lightsteelblue', alpha=0.5)
# Adam
ax1.plot(e4, adam_acc, label='Adam', marker='s', c='purple')
ax1.fill_between(e4, np.subtract(adam_acc, adam_acc_se), np.add(adam_acc, adam_acc_se), color='violet', alpha=0.5)


# Sparsity 
# SGD
ax2.plot(e4, sgd_spar, label='SGD', marker='o', c='darkred')
ax2.fill_between(e4, np.subtract(sgd_spar, sgd_spar_se), np.add(sgd_spar, sgd_spar_se), color='lightcoral', alpha=0.5)
# Adagrad
ax2.plot(e4, grad_spar, label='Adagrad', marker='^', c='darkgreen')
ax2.fill_between(e4, np.subtract(grad_spar, grad_spar_se), np.add(grad_spar, grad_spar_se), color='lime', alpha=0.5)
# Adadelta
ax2.plot(e4, delta_spar, label='Adadelta', marker='v', c='darkblue')
ax2.fill_between(e4, np.subtract(delta_spar, delta_spar_se), np.add(delta_spar, delta_spar_se), color='lightsteelblue', alpha=0.5)
# Adam
ax2.plot(e4, adam_spar, label='Adam', marker='s', c='purple')
ax2.fill_between(e4, np.subtract(adam_spar, adam_spar_se), np.add(adam_spar, adam_spar_se), color='violet', alpha=0.5)


# Selectivity
# SGD
ax3.plot(e4, sgd_selec, label='SGD', marker='o', c='darkred')
ax3.fill_between(e4, np.subtract(sgd_selec, sgd_selec_se), np.add(sgd_selec, sgd_selec_se), color='lightcoral', alpha=0.5)
# Adagrad
ax3.plot(e4, grad_selec, label='Adagrad', marker='^', c='darkgreen')
ax3.fill_between(e4, np.subtract(grad_selec, grad_selec_se), np.add(grad_selec, grad_selec_se), color='lime', alpha=0.5)
# Adadelta
ax3.plot(e4, delta_selec, label='Adadelta', marker='v', c='darkblue')
ax3.fill_between(e4, np.subtract(delta_selec, delta_selec_se), np.add(delta_selec, delta_selec_se), color='lightsteelblue', alpha=0.5)
# Adam
ax3.plot(e4, adam_selec, label='Adam', marker='s', c='purple')
ax3.fill_between(e4, np.subtract(adam_selec, adam_selec_se), np.add(adam_selec, adam_selec_se), color='violet', alpha=0.5)


ax1.grid()
ax2.grid()
ax3.grid()

ax1.set_title('Accuracy')
ax2.set_title('Sparsity')
ax3.set_title('Selectivity')

ax1.set_ylabel('Accuracy')
ax2.set_ylabel('Sparsity')
ax3.set_ylabel('Selectivity')
# Out:
# Text(0, 0.5, 'Selectivity')

# %%
# accuracy

e30 = np.linspace(1, 30, 30)

fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, figsize=(28, 7))

# SGD
ax1.plot(e30, ori_sgd_acc_avg, c='darkred', label='original')
ax1.fill_between(e30, np.subtract(ori_sgd_acc_avg, ori_sgd_acc_se), np.add(ori_sgd_acc_avg, ori_sgd_acc_se), color='lightcoral', alpha=0.5)

ax1.plot(e30, num5_sgd_acc_avg, c='darkorange', label='5nums')
ax1.fill_between(e30, np.subtract(num5_sgd_acc_avg, num5_sgd_acc_se), np.add(num5_sgd_acc_avg, num5_sgd_acc_se), color='moccasin', alpha=0.5)

ax1.plot(e30, pair_sgd_acc_avg, c='saddlebrown', label='pair')
ax1.fill_between(e30, np.subtract(pair_sgd_acc_avg, pair_sgd_acc_se), np.add(pair_sgd_acc_avg, pair_sgd_acc_se), color='peru', alpha=0.5)

ax1.plot(e30, single_sgd_acc_avg, c='darkgreen', label='single')
ax1.fill_between(e30, np.subtract(single_sgd_acc_avg, single_sgd_acc_se), np.add(single_sgd_acc_avg, single_sgd_acc_se), color='lime', alpha=0.5)


# Adagrad
ax2.plot(e30, ori_grad_acc_avg, c='darkred', label='original')
ax2.fill_between(e30, np.subtract(ori_grad_acc_avg, ori_grad_acc_se), np.add(ori_grad_acc_avg, ori_grad_acc_se), color='lightcoral', alpha=0.5)

ax2.plot(e30, num5_grad_acc_avg, c='darkorange', label='5nums')
ax2.fill_between(e30, np.subtract(num5_grad_acc_avg, num5_grad_acc_se), np.add(num5_grad_acc_avg, num5_grad_acc_se), color='moccasin', alpha=0.5)

ax2.plot(e30, pair_grad_acc_avg, c='saddlebrown', label='pair')
ax2.fill_between(e30, np.subtract(pair_grad_acc_avg, pair_grad_acc_se), np.add(pair_grad_acc_avg, pair_grad_acc_se), color='peru', alpha=0.5)

ax2.plot(e30, single_grad_acc_avg, c='darkgreen', label='single')
ax2.fill_between(e30, np.subtract(single_grad_acc_avg, single_grad_acc_se), np.add(single_grad_acc_avg, single_grad_acc_se), color='lime', alpha=0.5)

# Adadelta 
ax3.plot(e30, ori_delta_acc_avg, c='darkred', label='original')
ax3.fill_between(e30, np.subtract(ori_delta_acc_avg, ori_delta_acc_se), np.add(ori_delta_acc_avg, ori_delta_acc_se), color='lightcoral', alpha=0.5)

ax3.plot(e30, num5_delta_acc_avg, c='darkorange', label='5nums')
ax3.fill_between(e30, np.subtract(num5_delta_acc_avg, num5_delta_acc_se), np.add(num5_delta_acc_avg, num5_delta_acc_se), color='moccasin', alpha=0.5)

ax3.plot(e30, pair_delta_acc_avg, c='saddlebrown', label='pair')
ax3.fill_between(e30, np.subtract(pair_delta_acc_avg, pair_delta_acc_se), np.add(pair_delta_acc_avg, pair_delta_acc_se), color='peru', alpha=0.5)

ax3.plot(e30, single_delta_acc_avg, c='darkgreen', label='single')
ax3.fill_between(e30, np.subtract(single_delta_acc_avg, single_delta_acc_se), np.add(single_delta_acc_avg, single_delta_acc_se), color='lime', alpha=0.5)

# Adam
ax4.plot(e30, ori_adam_acc_avg, c='darkred', label='original')
ax4.fill_between(e30, np.subtract(ori_adam_acc_avg, ori_adam_acc_se), np.add(ori_adam_acc_avg, ori_adam_acc_se), color='lightcoral', alpha=0.5)

ax4.plot(e30, num5_adam_acc_avg, c='darkorange', label='5nums')
ax4.fill_between(e30, np.subtract(num5_adam_acc_avg, num5_adam_acc_se), np.add(num5_adam_acc_avg, num5_adam_acc_se), color='moccasin', alpha=0.5)

ax4.plot(e30, pair_adam_acc_avg, c='saddlebrown', label='pair')
ax4.fill_between(e30, np.subtract(pair_adam_acc_avg, pair_adam_acc_se), np.add(pair_adam_acc_avg, pair_adam_acc_se), color='peru', alpha=0.5)

ax4.plot(e30, single_adam_acc_avg, c='darkgreen', label='single')
ax4.fill_between(e30, np.subtract(single_adam_acc_avg, single_adam_acc_se), np.add(single_adam_acc_avg, single_adam_acc_se), color='lime', alpha=0.5)
ax4.legend(loc='upper center', bbox_to_anchor=(-1.3, -0.1),
          fancybox=True, shadow=True, ncol=4)

ax1.set_title('SGD')
ax2.set_title('Adagrad')
ax3.set_title('Adadelta')
ax4.set_title('Adam')

ax1.grid()
ax2.grid()
ax3.grid()
ax4.grid()

ax1.set_xlabel('Epochs')
ax2.set_xlabel('Epochs')
ax3.set_xlabel('Epochs')
ax4.set_xlabel('Epochs')

ax1.set_ylabel('Accuracy')
ax2.set_ylabel('Accuracy')
ax3.set_ylabel('Accuracy')
ax4.set_ylabel('Accuracy')

plt.plot()
# Out:
# []

# %%
# accuracy

e30 = np.linspace(1, 30, 30)

fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, figsize=(28, 7))

# SGD
ax1.plot(e30, ori_sgd_acc_avg, c='darkred', label='original')
ax1.fill_between(e30, np.subtract(ori_sgd_acc_avg, ori_sgd_acc_se), np.add(ori_sgd_acc_avg, ori_sgd_acc_se), color='lightcoral', alpha=0.5)

ax1.plot(e30, num5_sgd_acc_avg, c='darkorange', label='5nums')
ax1.fill_between(e30, np.subtract(num5_sgd_acc_avg, num5_sgd_acc_se), np.add(num5_sgd_acc_avg, num5_sgd_acc_se), color='moccasin', alpha=0.5)

ax1.plot(e30, pair_sgd_acc_avg, c='saddlebrown', label='pair')
ax1.fill_between(e30, np.subtract(pair_sgd_acc_avg, pair_sgd_acc_se), np.add(pair_sgd_acc_avg, pair_sgd_acc_se), color='peru', alpha=0.5)

ax1.plot(e30, single_sgd_acc_avg, c='darkgreen', label='single')
ax1.fill_between(e30, np.subtract(single_sgd_acc_avg, single_sgd_acc_se), np.add(single_sgd_acc_avg, single_sgd_acc_se), color='lime', alpha=0.5)


# Adagrad
ax2.plot(e30, ori_grad_acc_avg, c='darkred', label='original')
ax2.fill_between(e30, np.subtract(ori_grad_acc_avg, ori_grad_acc_se), np.add(ori_grad_acc_avg, ori_grad_acc_se), color='lightcoral', alpha=0.5)

ax2.plot(e30, num5_grad_acc_avg, c='darkorange', label='5nums')
ax2.fill_between(e30, np.subtract(num5_grad_acc_avg, num5_grad_acc_se), np.add(num5_grad_acc_avg, num5_grad_acc_se), color='moccasin', alpha=0.5)

ax2.plot(e30, pair_grad_acc_avg, c='saddlebrown', label='pair')
ax2.fill_between(e30, np.subtract(pair_grad_acc_avg, pair_grad_acc_se), np.add(pair_grad_acc_avg, pair_grad_acc_se), color='peru', alpha=0.5)

ax2.plot(e30, single_grad_acc_avg, c='darkgreen', label='single')
ax2.fill_between(e30, np.subtract(single_grad_acc_avg, single_grad_acc_se), np.add(single_grad_acc_avg, single_grad_acc_se), color='lime', alpha=0.5)

# Adadelta 
ax3.plot(e30, ori_delta_acc_avg, c='darkred', label='original')
ax3.fill_between(e30, np.subtract(ori_delta_acc_avg, ori_delta_acc_se), np.add(ori_delta_acc_avg, ori_delta_acc_se), color='lightcoral', alpha=0.5)

ax3.plot(e30, num5_delta_acc_avg, c='darkorange', label='5nums')
ax3.fill_between(e30, np.subtract(num5_delta_acc_avg, num5_delta_acc_se), np.add(num5_delta_acc_avg, num5_delta_acc_se), color='moccasin', alpha=0.5)

ax3.plot(e30, pair_delta_acc_avg, c='saddlebrown', label='pair')
ax3.fill_between(e30, np.subtract(pair_delta_acc_avg, pair_delta_acc_se), np.add(pair_delta_acc_avg, pair_delta_acc_se), color='peru', alpha=0.5)

ax3.plot(e30, single_delta_acc_avg, c='darkgreen', label='single')
ax3.fill_between(e30, np.subtract(single_delta_acc_avg, single_delta_acc_se), np.add(single_delta_acc_avg, single_delta_acc_se), color='lime', alpha=0.5)

# Adam
ax4.plot(e30, ori_adam_acc_avg, c='darkred', label='original')
ax4.fill_between(e30, np.subtract(ori_adam_acc_avg, ori_adam_acc_se), np.add(ori_adam_acc_avg, ori_adam_acc_se), color='lightcoral', alpha=0.5)

ax4.plot(e30, num5_adam_acc_avg, c='darkorange', label='5nums')
ax4.fill_between(e30, np.subtract(num5_adam_acc_avg, num5_adam_acc_se), np.add(num5_adam_acc_avg, num5_adam_acc_se), color='moccasin', alpha=0.5)

ax4.plot(e30, pair_adam_acc_avg, c='saddlebrown', label='pair')
ax4.fill_between(e30, np.subtract(pair_adam_acc_avg, pair_adam_acc_se), np.add(pair_adam_acc_avg, pair_adam_acc_se), color='peru', alpha=0.5)

ax4.plot(e30, single_adam_acc_avg, c='darkgreen', label='single')
ax4.fill_between(e30, np.subtract(single_adam_acc_avg, single_adam_acc_se), np.add(single_adam_acc_avg, single_adam_acc_se), color='lime', alpha=0.5)
ax4.legend(loc='upper center', bbox_to_anchor=(-1.3, -0.1),
          fancybox=True, shadow=True, ncol=4)

ax1.set_title('SGD')
ax2.set_title('Adagrad')
ax3.set_title('Adadelta')
ax4.set_title('Adam')

ax1.grid()
ax2.grid()
ax3.grid()
ax4.grid()

ax1.set_xlabel('Epochs')
ax2.set_xlabel('Epochs')
ax3.set_xlabel('Epochs')
ax4.set_xlabel('Epochs')

ax1.set_ylabel('Zoomed Accuracy')
ax2.set_ylabel('Zoomed Accuracy')
ax3.set_ylabel('Zoomed Accuracy')
ax4.set_ylabel('Zoomed Accuracy')

ax1.set_ylim([0.90, 1])
ax2.set_ylim([0.90, 1])
ax3.set_ylim([0.90, 1])
ax4.set_ylim([0.90, 1])

plt.plot()
# Out:
# []

# %%
# Sparsity

e30 = np.linspace(1, 30, 30)

fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, figsize=(28, 7))

# SGD
ax1.plot(e30, ori_sgd_spar_avg, c='darkred', label='original')
ax1.fill_between(e30, np.subtract(ori_sgd_spar_avg, ori_sgd_spar_se), np.add(ori_sgd_spar_avg, ori_sgd_spar_se), color='lightcoral', alpha=0.5)

ax1.plot(e30, num5_sgd_spar_avg, c='darkorange', label='5nums')
ax1.fill_between(e30, np.subtract(num5_sgd_spar_avg, num5_sgd_spar_se), np.add(num5_sgd_spar_avg, num5_sgd_spar_se), color='moccasin', alpha=0.5)

ax1.plot(e30, pair_sgd_spar_avg, c='saddlebrown', label='pair')
ax1.fill_between(e30, np.subtract(pair_sgd_spar_avg, pair_sgd_spar_se), np.add(pair_sgd_spar_avg, pair_sgd_spar_se), color='peru', alpha=0.5)

ax1.plot(e30, single_sgd_spar_avg, c='darkgreen', label='single')
ax1.fill_between(e30, np.subtract(single_sgd_spar_avg, single_sgd_spar_se), np.add(single_sgd_spar_avg, single_sgd_spar_se), color='lime', alpha=0.5)


# Adagrad
ax2.plot(e30, ori_grad_spar_avg, c='darkred', label='original')
ax2.fill_between(e30, np.subtract(ori_grad_spar_avg, ori_grad_spar_se), np.add(ori_grad_spar_avg, ori_grad_spar_se), color='lightcoral', alpha=0.5)

ax2.plot(e30, num5_grad_spar_avg, c='darkorange', label='5nums')
ax2.fill_between(e30, np.subtract(num5_grad_spar_avg, num5_grad_spar_se), np.add(num5_grad_spar_avg, num5_grad_spar_se), color='moccasin', alpha=0.5)

ax2.plot(e30, pair_grad_spar_avg, c='saddlebrown', label='pair')
ax2.fill_between(e30, np.subtract(pair_grad_spar_avg, pair_grad_spar_se), np.add(pair_grad_spar_avg, pair_grad_spar_se), color='peru', alpha=0.5)

ax2.plot(e30, single_grad_spar_avg, c='darkgreen', label='single')
ax2.fill_between(e30, np.subtract(single_grad_spar_avg, single_grad_spar_se), np.add(single_grad_spar_avg, single_grad_spar_se), color='lime', alpha=0.5)

# Adadelta 
ax3.plot(e30, ori_delta_spar_avg, c='darkred', label='original')
ax3.fill_between(e30, np.subtract(ori_delta_spar_avg, ori_delta_spar_se), np.add(ori_delta_spar_avg, ori_delta_spar_se), color='lightcoral', alpha=0.5)

ax3.plot(e30, num5_delta_spar_avg, c='darkorange', label='5nums')
ax3.fill_between(e30, np.subtract(num5_delta_spar_avg, num5_delta_spar_se), np.add(num5_delta_spar_avg, num5_delta_spar_se), color='moccasin', alpha=0.5)

ax3.plot(e30, pair_delta_spar_avg, c='saddlebrown', label='pair')
ax3.fill_between(e30, np.subtract(pair_delta_spar_avg, pair_delta_spar_se), np.add(pair_delta_spar_avg, pair_delta_spar_se), color='peru', alpha=0.5)

ax3.plot(e30, single_delta_spar_avg, c='darkgreen', label='single')
ax3.fill_between(e30, np.subtract(single_delta_spar_avg, single_delta_spar_se), np.add(single_delta_spar_avg, single_delta_spar_se), color='lime', alpha=0.5)

# Adam
ax4.plot(e30, ori_adam_spar_avg, c='darkred', label='original')
ax4.fill_between(e30, np.subtract(ori_adam_spar_avg, ori_adam_spar_se), np.add(ori_adam_spar_avg, ori_adam_spar_se), color='lightcoral', alpha=0.5)

ax4.plot(e30, num5_adam_spar_avg, c='darkorange', label='5nums')
ax4.fill_between(e30, np.subtract(num5_adam_spar_avg, num5_adam_spar_se), np.add(num5_adam_spar_avg, num5_adam_spar_se), color='moccasin', alpha=0.5)

ax4.plot(e30, pair_adam_spar_avg, c='saddlebrown', label='pair')
ax4.fill_between(e30, np.subtract(pair_adam_spar_avg, pair_adam_spar_se), np.add(pair_adam_spar_avg, pair_adam_spar_se), color='peru', alpha=0.5)

ax4.plot(e30, single_adam_spar_avg, c='darkgreen', label='single')
ax4.fill_between(e30, np.subtract(single_adam_spar_avg, single_adam_spar_se), np.add(single_adam_spar_avg, single_adam_spar_se), color='lime', alpha=0.5)
ax4.legend(loc='upper center', bbox_to_anchor=(-1.3, -0.1),
          fancybox=True, shadow=True, ncol=4)

ax1.set_title('SGD')
ax2.set_title('Adagrad')
ax3.set_title('Adadelta')
ax4.set_title('Adam')

ax1.grid()
ax2.grid()
ax3.grid()
ax4.grid()

ax1.set_xlabel('Epochs')
ax2.set_xlabel('Epochs')
ax3.set_xlabel('Epochs')
ax4.set_xlabel('Epochs')

ax1.set_ylabel('Sparsity')
ax2.set_ylabel('Sparsity')
ax3.set_ylabel('Sparsity')
ax4.set_ylabel('Sparsity')

plt.plot()
# Out:
# []

# %%
# Selectivity

e30 = np.linspace(1, 30, 30)

fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, figsize=(28, 7))

# SGD
ax1.plot(e30, ori_sgd_selec_avg, c='darkred', label='original')
ax1.fill_between(e30, np.subtract(ori_sgd_selec_avg, ori_sgd_selec_se), np.add(ori_sgd_selec_avg, ori_sgd_selec_se), color='lightcoral', alpha=0.5)

ax1.plot(e30, num5_sgd_selec_avg, c='darkorange', label='5nums')
ax1.fill_between(e30, np.subtract(num5_sgd_selec_avg, num5_sgd_selec_se), np.add(num5_sgd_selec_avg, num5_sgd_selec_se), color='moccasin', alpha=0.5)

ax1.plot(e30, pair_sgd_selec_avg, c='saddlebrown', label='pair')
ax1.fill_between(e30, np.subtract(pair_sgd_selec_avg, pair_sgd_selec_se), np.add(pair_sgd_selec_avg, pair_sgd_selec_se), color='peru', alpha=0.5)

ax1.plot(e30, single_sgd_selec_avg, c='darkgreen', label='single')
ax1.fill_between(e30, np.subtract(single_sgd_selec_avg, single_sgd_selec_se), np.add(single_sgd_selec_avg, single_sgd_selec_se), color='lime', alpha=0.5)


# Adagrad
ax2.plot(e30, ori_grad_selec_avg, c='darkred', label='original')
ax2.fill_between(e30, np.subtract(ori_grad_selec_avg, ori_grad_selec_se), np.add(ori_grad_selec_avg, ori_grad_selec_se), color='lightcoral', alpha=0.5)

ax2.plot(e30, num5_grad_selec_avg, c='darkorange', label='5nums')
ax2.fill_between(e30, np.subtract(num5_grad_selec_avg, num5_grad_selec_se), np.add(num5_grad_selec_avg, num5_grad_selec_se), color='moccasin', alpha=0.5)

ax2.plot(e30, pair_grad_selec_avg, c='saddlebrown', label='pair')
ax2.fill_between(e30, np.subtract(pair_grad_selec_avg, pair_grad_selec_se), np.add(pair_grad_selec_avg, pair_grad_selec_se), color='peru', alpha=0.5)

ax2.plot(e30, single_grad_selec_avg, c='darkgreen', label='single')
ax2.fill_between(e30, np.subtract(single_grad_selec_avg, single_grad_selec_se), np.add(single_grad_selec_avg, single_grad_selec_se), color='lime', alpha=0.5)

# Adadelta 
ax3.plot(e30, ori_delta_selec_avg, c='darkred', label='original')
ax3.fill_between(e30, np.subtract(ori_delta_selec_avg, ori_delta_selec_se), np.add(ori_delta_selec_avg, ori_delta_selec_se), color='lightcoral', alpha=0.5)

ax3.plot(e30, num5_delta_selec_avg, c='darkorange', label='5nums')
ax3.fill_between(e30, np.subtract(num5_delta_selec_avg, num5_delta_selec_se), np.add(num5_delta_selec_avg, num5_delta_selec_se), color='moccasin', alpha=0.5)

ax3.plot(e30, pair_delta_selec_avg, c='saddlebrown', label='pair')
ax3.fill_between(e30, np.subtract(pair_delta_selec_avg, pair_delta_selec_se), np.add(pair_delta_selec_avg, pair_delta_selec_se), color='peru', alpha=0.5)

ax3.plot(e30, single_delta_selec_avg, c='darkgreen', label='single')
ax3.fill_between(e30, np.subtract(single_delta_selec_avg, single_delta_selec_se), np.add(single_delta_selec_avg, single_delta_selec_se), color='lime', alpha=0.5)

# Adam
ax4.plot(e30, ori_adam_selec_avg, c='darkred', label='original')
ax4.fill_between(e30, np.subtract(ori_adam_selec_avg, ori_adam_selec_se), np.add(ori_adam_selec_avg, ori_adam_selec_se), color='lightcoral', alpha=0.5)

ax4.plot(e30, num5_adam_selec_avg, c='darkorange', label='5nums')
ax4.fill_between(e30, np.subtract(num5_adam_selec_avg, num5_adam_selec_se), np.add(num5_adam_selec_avg, num5_adam_selec_se), color='moccasin', alpha=0.5)

ax4.plot(e30, pair_adam_selec_avg, c='saddlebrown', label='pair')
ax4.fill_between(e30, np.subtract(pair_adam_selec_avg, pair_adam_selec_se), np.add(pair_adam_selec_avg, pair_adam_selec_se), color='peru', alpha=0.5)

ax4.plot(e30, single_adam_selec_avg, c='darkgreen', label='single')
ax4.fill_between(e30, np.subtract(single_adam_selec_avg, single_adam_selec_se), np.add(single_adam_selec_avg, single_adam_selec_se), color='lime', alpha=0.5)
ax4.legend(loc='upper center', bbox_to_anchor=(-1.3, -0.1),
          fancybox=True, shadow=True, ncol=4)

ax1.set_title('SGD')
ax2.set_title('Adagrad')
ax3.set_title('Adadelta')
ax4.set_title('Adam')

ax1.grid()
ax2.grid()
ax3.grid()
ax4.grid()

ax1.set_xlabel('Epochs')
ax2.set_xlabel('Epochs')
ax3.set_xlabel('Epochs')
ax4.set_xlabel('Epochs')

ax1.set_ylabel('Selectivity')
ax2.set_ylabel('Selectivity')
ax3.set_ylabel('Selectivity')
ax4.set_ylabel('Selectivity')

plt.plot()
# Out:
# []

# %% [markdown]
# # 10sub + batch 1
# # single + batch 10

# %%
# 10sub + batch 1 
sub10_b1_sgd_acc_avg, sub10_b1_sgd_acc_se, sub10_b1_sgd_spar_avg, sub10_b1_sgd_spar_se, sub10_b1_sgd_selec_avg, sub10_b1_sgd_selec_se = val_extractor('10sub_batch1/seed1/seed1_10subsebatch1_sparsity_selectivity_SGD.txt', '10sub_batch1/seed100/seed100_10subsebatch1_sparsity_selectivity_SGD.txt', '10sub_batch1/seed1234/seed1234_10subsebatch1_sparsity_selectivity_SGD.txt')
sub10_b1_grad_acc_avg, sub10_b1_grad_acc_se, sub10_b1_grad_spar_avg, sub10_b1_grad_spar_se, sub10_b1_grad_selec_avg, sub10_b1_grad_selec_se = val_extractor('10sub_batch1/seed1/seed1_10subsebatch1_sparsity_selectivity_Adagrad.txt', '10sub_batch1/seed100/seed100_10subsebatch1_sparsity_selectivity_Adagrad.txt', '10sub_batch1/seed1234/seed1234_10subsebatch1_sparsity_selectivity_Adagrad.txt')
sub10_b1_delta_acc_avg, sub10_b1_delta_acc_se, sub10_b1_delta_spar_avg, sub10_b1_delta_spar_se, sub10_b1_delta_selec_avg, sub10_b1_delta_selec_se = val_extractor('10sub_batch1/seed1/seed1_10subsebatch1_sparsity_selectivity_Adadelta.txt', '10sub_batch1/seed100/seed100_10subsebatch1_sparsity_selectivity_Adadelta.txt', '10sub_batch1/seed1234/seed1234_10subsebatch1_sparsity_selectivity_Adadelta.txt')
sub10_b1_adam_acc_avg, sub10_b1_adam_acc_se, sub10_b1_adam_spar_avg, sub10_b1_adam_spar_se, sub10_b1_adam_selec_avg, sub10_b1_adam_selec_se = val_extractor('10sub_batch1/seed1/seed1_10subsebatch1_sparsity_selectivity_Adam.txt', '10sub_batch1/seed100/seed100_10subsebatch1_sparsity_selectivity_Adam.txt', '10sub_batch1/seed1234/seed1234_10subsebatch1_sparsity_selectivity_Adam.txt')

# single + batch 10 
single_b10_sgd_acc_avg, single_b10_sgd_acc_se, single_b10_sgd_spar_avg, single_b10_sgd_spar_se, single_b10_sgd_selec_avg, single_b10_sgd_selec_se = val_extractor('single_batch10/seed1/seed1_single_batchsize10_SGD.txt', 'single_batch10/seed100/seed100_single_batchsize10_SGD.txt', 'single_batch10/seed1234/seed1234_single_batchsize10_SGD.txt')
single_b10_grad_acc_avg, single_b10_grad_acc_se, single_b10_grad_spar_avg, single_b10_grad_spar_se, single_b10_grad_selec_avg, single_b10_grad_selec_se = val_extractor('single_batch10/seed1/seed1_single_batchsize10_Adagrad.txt', 'single_batch10/seed100/seed100_single_batchsize10_Adagrad.txt', 'single_batch10/seed1234/seed1234_single_batchsize10_Adagrad.txt')
single_b10_delta_acc_avg, single_b10_delta_acc_se, single_b10_delta_spar_avg, single_b10_delta_spar_se, single_b10_delta_selec_avg, single_b10_delta_selec_se = val_extractor('single_batch10/seed1/seed1_single_batchsize10_Adadelta.txt', 'single_batch10/seed100/seed100_single_batchsize10_Adadelta.txt', 'single_batch10/seed1234/seed1234_single_batchsize10_Adadelta.txt')
single_b10_adam_acc_avg, single_b10_adam_acc_se, single_b10_adam_spar_avg, single_b10_adam_spar_se, single_b10_adam_selec_avg, single_b10_adam_selec_se = val_extractor('single_batch10/seed1/seed1_single_batchsize10_Adam.txt', 'single_batch10/seed100/seed100_single_batchsize10_Adam.txt', 'single_batch10/seed1234/seed1234_single_batchsize10_Adam.txt')

# %%
e30 = np.linspace(1, 30, 30)

fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, figsize=(28, 7))

# SGD
ax1.plot(e30, sub10_b1_sgd_acc_avg, color='darkred', label='SGD sub10 batch=1')
ax1.fill_between(e30, np.subtract(sub10_b1_sgd_acc_avg, sub10_b1_sgd_acc_se), np.add(sub10_b1_sgd_acc_avg, sub10_b1_sgd_acc_se), color='lightcoral', alpha=0.5)

ax1.plot(e30, single_b10_sgd_acc_avg, color='darkgreen', label='SGD single batch=10')
ax1.fill_between(e30, np.subtract(single_b10_sgd_acc_avg, single_b10_sgd_acc_se), np.add(single_b10_sgd_acc_avg, single_b10_sgd_acc_se), color='lime', alpha=0.5)

# Adagrad
ax2.plot(e30, sub10_b1_grad_acc_avg, color='darkred', label='Adagrad sub10 batch=1')
ax2.fill_between(e30, np.subtract(sub10_b1_grad_acc_avg, sub10_b1_grad_acc_se), np.add(sub10_b1_grad_acc_avg, sub10_b1_grad_acc_se), color='lightcoral', alpha=0.5)

ax2.plot(e30, single_b10_grad_acc_avg, color='darkgreen', label='Adagrad single batch=10')
ax2.fill_between(e30, np.subtract(single_b10_grad_acc_avg, single_b10_grad_acc_se), np.add(single_b10_grad_acc_avg, single_b10_grad_acc_se), color='lime', alpha=0.5)

# Adadelta 
ax3.plot(e30, sub10_b1_delta_acc_avg, color='darkred', label='Adadelta sub10 batch=1')
ax3.fill_between(e30, np.subtract(sub10_b1_delta_acc_avg, sub10_b1_delta_acc_se), np.add(sub10_b1_delta_acc_avg, sub10_b1_delta_acc_se), color='lightcoral', alpha=0.5)

ax3.plot(e30, single_b10_delta_acc_avg, color='darkgreen', label='Adadelta single batch=10')
ax3.fill_between(e30, np.subtract(single_b10_delta_acc_avg, single_b10_delta_acc_se), np.add(single_b10_delta_acc_avg, single_b10_delta_acc_se), color='lime', alpha=0.5)

# Adam
ax4.plot(e30, sub10_b1_adam_acc_avg, color='darkred', label='sub10 + batch=1')
ax4.fill_between(e30, np.subtract(sub10_b1_adam_acc_avg, sub10_b1_adam_acc_se), np.add(sub10_b1_adam_acc_avg, sub10_b1_adam_acc_se), color='lightcoral', alpha=0.5)

ax4.plot(e30, single_b10_adam_acc_avg, color='darkgreen', label='single + batch=10')
ax4.fill_between(e30, np.subtract(single_b10_adam_acc_avg, single_b10_adam_acc_se), np.add(single_b10_adam_acc_avg, single_b10_adam_acc_se), color='lime', alpha=0.5)

ax4.legend(loc='upper center', bbox_to_anchor=(-1.3, -0.1),
          fancybox=True, shadow=True, ncol=2)

ax1.set_xlabel('Epochs')
ax2.set_xlabel('Epochs')
ax3.set_xlabel('Epochs')
ax4.set_xlabel('Epochs')

ax1.set_title('SGD Test Accuracy')
ax2.set_title('Adagrad Test Accuracy')
ax3.set_title('Adadelta Test Accuracy')
ax4.set_title('Adam Test Accuracy')

ax1.grid()
ax2.grid()
ax3.grid()
ax4.grid()

plt.plot()
# Out:
# []

# %%
e30 = np.linspace(1, 30, 30)

fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, figsize=(28, 7))

# SGD
ax1.plot(e30, sub10_b1_sgd_spar_avg, color='darkred', label='SGD sub10 batch=1')
ax1.fill_between(e30, np.subtract(sub10_b1_sgd_spar_avg, sub10_b1_sgd_spar_se), np.add(sub10_b1_sgd_spar_avg, sub10_b1_sgd_spar_se), color='lightcoral', alpha=0.5)

ax1.plot(e30, single_b10_sgd_spar_avg, color='darkgreen', label='SGD single batch=10')
ax1.fill_between(e30, np.subtract(single_b10_sgd_spar_avg, single_b10_sgd_spar_se), np.add(single_b10_sgd_spar_avg, single_b10_sgd_spar_se), color='lime', alpha=0.5)

# Adagrad
ax2.plot(e30, sub10_b1_grad_spar_avg, color='darkred', label='Adagrad sub10 batch=1')
ax2.fill_between(e30, np.subtract(sub10_b1_grad_spar_avg, sub10_b1_grad_spar_se), np.add(sub10_b1_grad_spar_avg, sub10_b1_grad_spar_se), color='lightcoral', alpha=0.5)

ax2.plot(e30, single_b10_grad_spar_avg, color='darkgreen', label='Adagrad single batch=10')
ax2.fill_between(e30, np.subtract(single_b10_grad_spar_avg, single_b10_grad_spar_se), np.add(single_b10_grad_spar_avg, single_b10_grad_spar_se), color='lime', alpha=0.5)

# Adadelta 
ax3.plot(e30, sub10_b1_delta_spar_avg, color='darkred', label='Adadelta sub10 batch=1')
ax3.fill_between(e30, np.subtract(sub10_b1_delta_spar_avg, sub10_b1_delta_spar_se), np.add(sub10_b1_delta_spar_avg, sub10_b1_delta_spar_se), color='lightcoral', alpha=0.5)

ax3.plot(e30, single_b10_delta_spar_avg, color='darkgreen', label='Adadelta single batch=10')
ax3.fill_between(e30, np.subtract(single_b10_delta_spar_avg, single_b10_delta_spar_se), np.add(single_b10_delta_spar_avg, single_b10_delta_spar_se), color='lime', alpha=0.5)

# Adam
ax4.plot(e30, sub10_b1_adam_spar_avg, color='darkred', label='sub10 + batch=1')
ax4.fill_between(e30, np.subtract(sub10_b1_adam_spar_avg, sub10_b1_adam_spar_se), np.add(sub10_b1_adam_spar_avg, sub10_b1_adam_spar_se), color='lightcoral', alpha=0.5)

ax4.plot(e30, single_b10_adam_spar_avg, color='darkgreen', label='single + batch=10')
ax4.fill_between(e30, np.subtract(single_b10_adam_spar_avg, single_b10_adam_spar_se), np.add(single_b10_adam_spar_avg, single_b10_adam_spar_se), color='lime', alpha=0.5)

ax4.legend(loc='upper center', bbox_to_anchor=(-1.3, -0.1),
          fancybox=True, shadow=True, ncol=2)

ax1.set_xlabel('Epochs')
ax2.set_xlabel('Epochs')
ax3.set_xlabel('Epochs')
ax4.set_xlabel('Epochs')

ax1.set_title('SGD Sparsity')
ax2.set_title('Adagrad Sparsity')
ax3.set_title('Adadelta Sparsity')
ax4.set_title('Adam Sparsity')

ax1.grid()
ax2.grid()
ax3.grid()
ax4.grid()

plt.plot()
# Out:
# []

# %%
e30 = np.linspace(1, 30, 30)

fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, figsize=(28, 7))

# SGD
ax1.plot(e30, sub10_b1_sgd_selec_avg, color='darkred', label='SGD sub10 batch=1')
ax1.fill_between(e30, np.subtract(sub10_b1_sgd_selec_avg, sub10_b1_sgd_selec_se), np.add(sub10_b1_sgd_selec_avg, sub10_b1_sgd_selec_se), color='lightcoral', alpha=0.5)

ax1.plot(e30, single_b10_sgd_selec_avg, color='darkgreen', label='SGD single batch=10')
ax1.fill_between(e30, np.subtract(single_b10_sgd_selec_avg, single_b10_sgd_selec_se), np.add(single_b10_sgd_selec_avg, single_b10_sgd_selec_se), color='lime', alpha=0.5)

# Adagrad
ax2.plot(e30, sub10_b1_grad_selec_avg, color='darkred', label='Adagrad sub10 batch=1')
ax2.fill_between(e30, np.subtract(sub10_b1_grad_selec_avg, sub10_b1_grad_selec_se), np.add(sub10_b1_grad_selec_avg, sub10_b1_grad_selec_se), color='lightcoral', alpha=0.5)

ax2.plot(e30, single_b10_grad_selec_avg, color='darkgreen', label='Adagrad single batch=10')
ax2.fill_between(e30, np.subtract(single_b10_grad_selec_avg, single_b10_grad_selec_se), np.add(single_b10_grad_selec_avg, single_b10_grad_selec_se), color='lime', alpha=0.5)

# Adadelta 
ax3.plot(e30, sub10_b1_delta_selec_avg, color='darkred', label='Adadelta sub10 batch=1')
ax3.fill_between(e30, np.subtract(sub10_b1_delta_selec_avg, sub10_b1_delta_selec_se), np.add(sub10_b1_delta_selec_avg, sub10_b1_delta_selec_se), color='lightcoral', alpha=0.5)

ax3.plot(e30, single_b10_delta_selec_avg, color='darkgreen', label='Adadelta single batch=10')
ax3.fill_between(e30, np.subtract(single_b10_delta_selec_avg, single_b10_delta_selec_se), np.add(single_b10_delta_selec_avg, single_b10_delta_selec_se), color='lime', alpha=0.5)

# Adam
ax4.plot(e30, sub10_b1_adam_selec_avg, color='darkred', label='sub10 + batch=1')
ax4.fill_between(e30, np.subtract(sub10_b1_adam_selec_avg, sub10_b1_adam_selec_se), np.add(sub10_b1_adam_selec_avg, sub10_b1_adam_selec_se), color='lightcoral', alpha=0.5)

ax4.plot(e30, single_b10_adam_selec_avg, color='darkgreen', label='single + batch=10')
ax4.fill_between(e30, np.subtract(single_b10_adam_selec_avg, single_b10_adam_selec_se), np.add(single_b10_adam_selec_avg, single_b10_adam_selec_se), color='lime', alpha=0.5)

ax4.legend(loc='upper center', bbox_to_anchor=(-1.3, -0.1),
          fancybox=True, shadow=True, ncol=2)

ax1.set_xlabel('Epochs')
ax2.set_xlabel('Epochs')
ax3.set_xlabel('Epochs')
ax4.set_xlabel('Epochs')

ax1.set_title('SGD Selectivity')
ax2.set_title('Adagrad Selectivity')
ax3.set_title('Adadelta Selectivity')
ax4.set_title('Adam Selectivity')

ax1.grid()
ax2.grid()
ax3.grid()
ax4.grid()

plt.plot()
# Out:
# []

# %%
# 10sub + batch 1 
last_sub10_b1_sgd_acc_avg, last_sub10_b1_sgd_acc_se, last_sub10_b1_sgd_spar_avg, last_sub10_b1_sgd_spar_se, last_sub10_b1_sgd_selec_avg, last_sub10_b1_sgd_selec_se = extract_last_val_extractor('10sub_batch1/seed1/seed1_10subsebatch1_sparsity_selectivity_SGD.txt', '10sub_batch1/seed100/seed100_10subsebatch1_sparsity_selectivity_SGD.txt', '10sub_batch1/seed1234/seed1234_10subsebatch1_sparsity_selectivity_SGD.txt')
last_sub10_b1_grad_acc_avg, last_sub10_b1_grad_acc_se, last_sub10_b1_grad_spar_avg, last_sub10_b1_grad_spar_se, last_sub10_b1_grad_selec_avg, last_sub10_b1_grad_selec_se = extract_last_val_extractor('10sub_batch1/seed1/seed1_10subsebatch1_sparsity_selectivity_Adagrad.txt', '10sub_batch1/seed100/seed100_10subsebatch1_sparsity_selectivity_Adagrad.txt', '10sub_batch1/seed1234/seed1234_10subsebatch1_sparsity_selectivity_Adagrad.txt')
last_sub10_b1_delta_acc_avg, last_sub10_b1_delta_acc_se, last_sub10_b1_delta_spar_avg, last_sub10_b1_delta_spar_se, last_sub10_b1_delta_selec_avg, last_sub10_b1_delta_selec_se = extract_last_val_extractor('10sub_batch1/seed1/seed1_10subsebatch1_sparsity_selectivity_Adadelta.txt', '10sub_batch1/seed100/seed100_10subsebatch1_sparsity_selectivity_Adadelta.txt', '10sub_batch1/seed1234/seed1234_10subsebatch1_sparsity_selectivity_Adadelta.txt')
last_sub10_b1_adam_acc_avg, last_sub10_b1_adam_acc_se, last_sub10_b1_adam_spar_avg, last_sub10_b1_adam_spar_se, last_sub10_b1_adam_selec_avg, last_sub10_b1_adam_selec_se = extract_last_val_extractor('10sub_batch1/seed1/seed1_10subsebatch1_sparsity_selectivity_Adam.txt', '10sub_batch1/seed100/seed100_10subsebatch1_sparsity_selectivity_Adam.txt', '10sub_batch1/seed1234/seed1234_10subsebatch1_sparsity_selectivity_Adam.txt')

# single + batch 10 
last_single_b10_sgd_acc_avg, last_single_b10_sgd_acc_se, last_single_b10_sgd_spar_avg, last_single_b10_sgd_spar_se, last_single_b10_sgd_selec_avg, last_single_b10_sgd_selec_se = extract_last_val_extractor('single_batch10/seed1/seed1_single_batchsize10_SGD.txt', 'single_batch10/seed100/seed100_single_batchsize10_SGD.txt', 'single_batch10/seed1234/seed1234_single_batchsize10_SGD.txt')
last_single_b10_grad_acc_avg, last_single_b10_grad_acc_se, last_single_b10_grad_spar_avg, last_single_b10_grad_spar_se, last_single_b10_grad_selec_avg, last_single_b10_grad_selec_se = extract_last_val_extractor('single_batch10/seed1/seed1_single_batchsize10_Adagrad.txt', 'single_batch10/seed100/seed100_single_batchsize10_Adagrad.txt', 'single_batch10/seed1234/seed1234_single_batchsize10_Adagrad.txt')
last_single_b10_delta_acc_avg, last_single_b10_delta_acc_se, last_single_b10_delta_spar_avg, last_single_b10_delta_spar_se, last_single_b10_delta_selec_avg, last_single_b10_delta_selec_se = extract_last_val_extractor('single_batch10/seed1/seed1_single_batchsize10_Adadelta.txt', 'single_batch10/seed100/seed100_single_batchsize10_Adadelta.txt', 'single_batch10/seed1234/seed1234_single_batchsize10_Adadelta.txt')
last_single_b10_adam_acc_avg, last_single_b10_adam_acc_se, last_single_b10_adam_spar_avg, last_single_b10_adam_spar_se, last_single_b10_adam_selec_avg, last_single_b10_adam_selec_se = extract_last_val_extractor('single_batch10/seed1/seed1_single_batchsize10_Adam.txt', 'single_batch10/seed100/seed100_single_batchsize10_Adam.txt', 'single_batch10/seed1234/seed1234_single_batchsize10_Adam.txt')

# %%
# single -> batch 1
sgd_acc    = [last_single_b10_sgd_acc_avg, last_sub10_b1_sgd_acc_avg]
sgd_acc_se = [last_single_b10_sgd_acc_se, last_sub10_b1_sgd_acc_se]

grad_acc    = [last_single_b10_grad_acc_avg, last_sub10_b1_grad_acc_avg]
grad_acc_se = [last_single_b10_grad_acc_se, last_sub10_b1_grad_acc_se]

delta_acc    = [last_single_b10_delta_acc_avg, last_sub10_b1_delta_acc_avg]
delta_acc_se = [last_single_b10_delta_acc_se, last_sub10_b1_delta_acc_se]

adam_acc    = [last_single_b10_adam_acc_avg, last_sub10_b1_adam_acc_avg]
adam_acc_se = [last_single_b10_adam_acc_se, last_sub10_b1_adam_acc_se]

# sparsity 
sgd_spar    = [last_single_b10_sgd_spar_avg, last_sub10_b1_sgd_spar_avg]
sgd_spar_se = [last_single_b10_sgd_spar_se, last_sub10_b1_sgd_spar_se]

grad_spar    = [last_single_b10_grad_spar_avg, last_sub10_b1_grad_spar_avg]
grad_spar_se = [last_single_b10_grad_spar_se, last_sub10_b1_grad_spar_se]

delta_spar    = [last_single_b10_delta_spar_avg, last_sub10_b1_delta_spar_avg]
delta_spar_se = [last_single_b10_delta_spar_se, last_sub10_b1_delta_spar_se]

adam_spar    = [last_single_b10_adam_spar_avg, last_sub10_b1_adam_spar_avg]
adam_spar_se = [last_single_b10_adam_spar_se, last_sub10_b1_adam_spar_se]

# selectivity 
sgd_selec    = [last_single_b10_sgd_selec_avg, last_sub10_b1_sgd_selec_avg]
sgd_selec_se = [last_single_b10_sgd_selec_se, last_sub10_b1_sgd_selec_se]

grad_selec    = [last_single_b10_grad_selec_avg, last_sub10_b1_grad_selec_avg]
grad_selec_se = [last_single_b10_grad_selec_se, last_sub10_b1_grad_selec_se]

delta_selec    = [last_single_b10_delta_selec_avg, last_sub10_b1_delta_selec_avg]
delta_selec_se = [last_single_b10_delta_selec_se, last_sub10_b1_delta_selec_se]

adam_selec    = [last_single_b10_adam_selec_avg, last_sub10_b1_adam_selec_avg]
adam_selec_se = [last_single_b10_adam_selec_se, last_sub10_b1_adam_selec_se]

# %%
e2 = np.linspace(1,2,2)

fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(21, 7))

# default setting for grpahs 
hl_ticks = ['single + bs=10', 'sub 10 + bs=1']
ax1.set_xticks(np.linspace(1, 2, 2))
ax1.set_xticklabels(hl_ticks)

ax2.set_xticks(np.linspace(1, 2, 2))
ax2.set_xticklabels(hl_ticks)

ax3.set_xticks(np.linspace(1, 2, 2))
ax3.set_xticklabels(hl_ticks)

# Accuracy 
ax1.plot(e2, sgd_acc, c='darkred', label='SGD')
ax1.fill_between(e2, np.subtract(sgd_acc, sgd_acc_se), np.add(sgd_acc, sgd_acc_se), color='lightcoral', alpha=0.5)

ax1.plot(e2, grad_acc, c='darkgreen', label='Adagrad')
ax1.fill_between(e2, np.subtract(grad_acc, grad_acc_se), np.add(grad_acc, grad_acc_se), color='lime', alpha=0.5)

ax1.plot(e2, delta_acc, c='darkblue', label='Adadelta')
ax1.fill_between(e2, np.subtract(delta_acc, delta_acc_se), np.add(delta_acc, delta_acc_se), color='lightsteelblue', alpha=0.5)

ax1.plot(e2, adam_acc, c='purple', label='Adam')
ax1.fill_between(e2, np.subtract(adam_acc, adam_acc_se), np.add(adam_acc, adam_acc_se), color='violet', alpha=0.5)

# Sparsity 
ax2.plot(e2, sgd_spar, c='darkred', label='SGD')
ax2.fill_between(e2, np.subtract(sgd_spar, sgd_spar_se), np.add(sgd_spar, sgd_spar_se), color='lightcoral', alpha=0.5)

ax2.plot(e2, grad_spar, c='darkgreen', label='Adagrad')
ax2.fill_between(e2, np.subtract(grad_spar, grad_spar_se), np.add(grad_spar, grad_spar_se), color='lime', alpha=0.5)

ax2.plot(e2, delta_spar, c='darkblue', label='Adadelta')
ax2.fill_between(e2, np.subtract(delta_spar, delta_spar_se), np.add(delta_spar, delta_spar_se), color='lightsteelblue', alpha=0.5)

ax2.plot(e2, adam_spar, c='purple', label='Adam')
ax2.fill_between(e2, np.subtract(adam_spar, adam_spar_se), np.add(adam_spar, adam_spar_se), color='violet', alpha=0.5)

# Selectivity
ax3.plot(e2, sgd_selec, c='darkred', label='SGD')
ax3.fill_between(e2, np.subtract(sgd_selec, sgd_selec_se), np.add(sgd_selec, sgd_selec_se), color='lightcoral', alpha=0.5)

ax3.plot(e2, grad_selec, c='darkgreen', label='Adagrad')
ax3.fill_between(e2, np.subtract(grad_selec, grad_selec_se), np.add(grad_selec, grad_selec_se), color='lime', alpha=0.5)

ax3.plot(e2, delta_selec, c='darkblue', label='Adadelta')
ax3.fill_between(e2, np.subtract(delta_selec, delta_selec_se), np.add(delta_selec, delta_selec_se), color='lightsteelblue', alpha=0.5)

ax3.plot(e2, adam_selec, c='purple', label='Adam')
ax3.fill_between(e2, np.subtract(adam_selec, adam_selec_se), np.add(adam_selec, adam_selec_se), color='violet', alpha=0.5)

ax1.grid()
ax2.grid()
ax3.grid()

ax1.set_title('Test Accruacy')
ax2.set_title('Sparsity')
ax3.set_title('Selectivity')

ax3.legend(loc='upper center', bbox_to_anchor=(-0.7, -0.1),
          fancybox=True, shadow=True, ncol=4)
