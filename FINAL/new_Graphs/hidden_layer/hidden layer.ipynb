# %%
import matplotlib.pyplot as plt
import numpy as np
import re
import ast 
import torch
import scipy.stats as ss

# %%
def val_extractor(file_name):    
    
    test_accuracy = 0
    sparsity_average = 0
    selectivity_average = 0
    
    with open(file_name) as fi:
        for i, line in enumerate(fi):
            if i == 0:
                test_accuracy = ast.literal_eval(line)     
            if i == 1:
                sparsity_average = ast.literal_eval(line)
            if i == 3:
                selectivity_average = ast.literal_eval(line)
                
    return test_accuracy, sparsity_average, selectivity_average

# %%
acc_sgd_seed1 = [0,0,0,0,0,0]
spar_sgd_seed1 = [0,0,0,0,0,0]
selec_sgd_seed1 = [0,0,0,0,0,0]

acc_grad_seed1 = [0,0,0,0,0,0]
spar_grad_seed1 = [0,0,0,0,0,0]
selec_grad_seed1 = [0,0,0,0,0,0]

acc_delta_seed1 = [0,0,0,0,0,0]
spar_delta_seed1 = [0,0,0,0,0,0]
selec_delta_seed1 = [0,0,0,0,0,0]

acc_adam_seed1 = [0,0,0,0,0,0]
spar_adam_seed1 = [0,0,0,0,0,0]
selec_adam_seed1 = [0,0,0,0,0,0]

# SGD
for i in range(1, 6):
    acc_sgd_seed1[i], spar_sgd_seed1[i], selec_sgd_seed1[i] = val_extractor(f'seed1/{i}HL/seed_1_{i}HL_SGD.txt')
    
# Adagrad
for i in range(1, 6):
    acc_grad_seed1[i], spar_grad_seed1[i], selec_grad_seed1[i] = val_extractor(f'seed1/{i}HL/seed_1_{i}HL_Adagrad.txt')    
    
# Adadelta
for i in range(1, 6):
    acc_delta_seed1[i], spar_delta_seed1[i], selec_delta_seed1[i] = val_extractor(f'seed1/{i}HL/seed_1_{i}HL_Adadelta.txt')  

# Adam
for i in range(1, 6):
    acc_adam_seed1[i], spar_adam_seed1[i], selec_adam_seed1[i] = val_extractor(f'seed1/{i}HL/seed_1_{i}HL_Adam.txt')

# %%
acc_sgd_seed2 = [0,0,0,0,0,0]
spar_sgd_seed2 = [0,0,0,0,0,0]
selec_sgd_seed2 = [0,0,0,0,0,0]

acc_grad_seed2 = [0,0,0,0,0,0]
spar_grad_seed2 = [0,0,0,0,0,0]
selec_grad_seed2 = [0,0,0,0,0,0]

acc_delta_seed2 = [0,0,0,0,0,0]
spar_delta_seed2 = [0,0,0,0,0,0]
selec_delta_seed2 = [0,0,0,0,0,0]

acc_adam_seed2 = [0,0,0,0,0,0]
spar_adam_seed2 = [0,0,0,0,0,0]
selec_adam_seed2 = [0,0,0,0,0,0]

# SGD
for i in range(1, 6):
    acc_sgd_seed2[i], spar_sgd_seed2[i], selec_sgd_seed2[i] = val_extractor(f'seed100/{i}HL/seed_100_{i}HL_SGD.txt')
    
# Adagrad
for i in range(1, 6):
    acc_grad_seed2[i], spar_grad_seed2[i], selec_grad_seed2[i] = val_extractor(f'seed100/{i}HL/seed_100_{i}HL_Adagrad.txt')    
    
# Adadelta
for i in range(1, 6):
    acc_delta_seed2[i], spar_delta_seed2[i], selec_delta_seed2[i] = val_extractor(f'seed100/{i}HL/seed_100_{i}HL_Adadelta.txt')  

# Adam
for i in range(1, 6):
    acc_adam_seed2[i], spar_adam_seed2[i], selec_adam_seed2[i] = val_extractor(f'seed100/{i}HL/seed_100_{i}HL_Adam.txt')

# %%
acc_sgd_seed3 = [0,0,0,0,0,0]
spar_sgd_seed3 = [0,0,0,0,0,0]
selec_sgd_seed3 = [0,0,0,0,0,0]

acc_grad_seed3 = [0,0,0,0,0,0]
spar_grad_seed3 = [0,0,0,0,0,0]
selec_grad_seed3 = [0,0,0,0,0,0]

acc_delta_seed3 = [0,0,0,0,0,0]
spar_delta_seed3 = [0,0,0,0,0,0]
selec_delta_seed3 = [0,0,0,0,0,0]

acc_adam_seed3 = [0,0,0,0,0,0]
spar_adam_seed3 = [0,0,0,0,0,0]
selec_adam_seed3 = [0,0,0,0,0,0]

# SGD
for i in range(1, 6):
    acc_sgd_seed3[i], spar_sgd_seed3[i], selec_sgd_seed3[i] = val_extractor(f'seed1234/{i}HL/seed_1234_{i}HL_SGD.txt')
    
# Adagrad
for i in range(1, 6):
    acc_grad_seed3[i], spar_grad_seed3[i], selec_grad_seed3[i] = val_extractor(f'seed1234/{i}HL/seed_1234_{i}HL_Adagrad.txt')    
    
# Adadelta
for i in range(1, 6):
    acc_delta_seed3[i], spar_delta_seed3[i], selec_delta_seed3[i] = val_extractor(f'seed1234/{i}HL/seed_1234_{i}HL_Adadelta.txt')  

# Adam
for i in range(1, 6):
    acc_adam_seed3[i], spar_adam_seed3[i], selec_adam_seed3[i] = val_extractor(f'seed1234/{i}HL/seed_1234_{i}HL_Adam.txt')

# %%
# acc_sgd_seed1[i] 이거는 HL1 부터 HL5 까지 값을 가지고 있다. 
# 에를 들어서 acc_sgd_seed1[1] == HL1  
# 에를 들어서 acc_sgd_seed1[2] == HL2 
# 에를 들어서 acc_sgd_seed1[3] == HL3  
# 에를 들어서 acc_sgd_seed1[4] == HL4  
# 에를 들어서 acc_sgd_seed1[5] == HL5

# %%
def mean_and_se(acc_seed1, acc_seed2, acc_seed3, 
                spar_seed1, spar_seed2, spar_seed3, 
                selec_seed1, selec_seed2, selec_seed3):

    acc_avg = list()
    acc_se  = list()

    spar_avg = list()
    spar_se  = list()

    selec_avg = list()
    selec_se  = list()

    for i in range(len(acc_seed1)):
        acc_avg.append(np.mean([acc_seed1[i], acc_seed2[i], acc_seed3[i]]))
        acc_se .append(np.std ([acc_seed1[i], acc_seed2[i], acc_seed3[i]]) / np.sqrt(3))

        spar_avg.append(np.mean([spar_seed1[i], spar_seed2[i], spar_seed3[i]]))
        spar_se .append(np.std ([spar_seed1[i], spar_seed2[i], spar_seed3[i]]) / np.sqrt(3))

        selec_avg.append(np.mean([selec_seed1[i], selec_seed2[i], selec_seed3[i]]))
        selec_se .append(np.std ([selec_seed1[i], selec_seed2[i], selec_seed3[i]]) / np.sqrt(3))
        
    return acc_avg, acc_se, spar_avg, spar_se, selec_avg, selec_se

# %%
sgd_acc_avg = [0,0,0,0,0,0]
sgd_acc_se = [0,0,0,0,0,0]
sgd_spar_avg = [0,0,0,0,0,0]
sgd_spar_se = [0,0,0,0,0,0]
sgd_selec_avg = [0,0,0,0,0,0]
sgd_selec_se = [0,0,0,0,0,0]

grad_acc_avg = [0,0,0,0,0,0]
grad_acc_se = [0,0,0,0,0,0]
grad_spar_avg = [0,0,0,0,0,0]
grad_spar_se = [0,0,0,0,0,0]
grad_selec_avg = [0,0,0,0,0,0]
grad_selec_se = [0,0,0,0,0,0]

delta_acc_avg = [0,0,0,0,0,0]
delta_acc_se = [0,0,0,0,0,0]
delta_spar_avg = [0,0,0,0,0,0]
delta_spar_se = [0,0,0,0,0,0]
delta_selec_avg = [0,0,0,0,0,0]
delta_selec_se = [0,0,0,0,0,0]

adam_acc_avg = [0,0,0,0,0,0]
adam_acc_se = [0,0,0,0,0,0]
adam_spar_avg = [0,0,0,0,0,0]
adam_spar_se = [0,0,0,0,0,0]
adam_selec_avg = [0,0,0,0,0,0]
adam_selec_se = [0,0,0,0,0,0]

for i in range(1, 6):
    sgd_acc_avg[i], sgd_acc_se[i], sgd_spar_avg[i], sgd_spar_se[i], sgd_selec_avg[i], sgd_selec_se[i] = mean_and_se(acc_sgd_seed1[i], acc_sgd_seed2[i], acc_sgd_seed3[i],
                                                                                                                    spar_sgd_seed1[i], spar_sgd_seed2[i], spar_sgd_seed3[i],
                                                                                                                    selec_sgd_seed1[i], selec_sgd_seed2[i], selec_sgd_seed3[i])
    
    grad_acc_avg[i], grad_acc_se[i], grad_spar_avg[i], grad_spar_se[i], grad_selec_avg[i], grad_selec_se[i] = mean_and_se(acc_grad_seed1[i], acc_grad_seed2[i], acc_grad_seed3[i],
                                                                                                                    spar_grad_seed1[i], spar_grad_seed2[i], spar_grad_seed3[i],
                                                                                                                    selec_grad_seed1[i], selec_grad_seed2[i], selec_grad_seed3[i])
    
    delta_acc_avg[i], delta_acc_se[i], delta_spar_avg[i], delta_spar_se[i], delta_selec_avg[i], delta_selec_se[i] = mean_and_se(acc_delta_seed1[i], acc_delta_seed2[i], acc_delta_seed3[i],
                                                                                                                    spar_delta_seed1[i], spar_delta_seed2[i], spar_delta_seed3[i],
                                                                                                                    selec_delta_seed1[i], selec_delta_seed2[i], selec_delta_seed3[i])
    
    adam_acc_avg[i], adam_acc_se[i], adam_spar_avg[i], adam_spar_se[i], adam_selec_avg[i], adam_selec_se[i] = mean_and_se(acc_adam_seed1[i], acc_adam_seed2[i], acc_adam_seed3[i],
                                                                                                                    spar_adam_seed1[i], spar_adam_seed2[i], spar_adam_seed3[i],
                                                                                                                    selec_adam_seed1[i], selec_adam_seed2[i], selec_adam_seed3[i])

# %%
epoch50 = np.linspace(1,50,50)

# %%
# Accuracy Plot

# %%
fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, figsize=(20, 5))

# SGD
ax1.plot(epoch50, sgd_acc_avg[1], c='darkred', label='HL1')
ax1.fill_between(epoch50, np.subtract(sgd_acc_avg[1], sgd_acc_se[1]), np.add(sgd_acc_avg[1], sgd_acc_se[1]), color='lightcoral')

ax1.plot(epoch50, sgd_acc_avg[2], c='darkorange', label='HL2')
ax1.fill_between(epoch50, np.subtract(sgd_acc_avg[2], sgd_acc_se[2]), np.add(sgd_acc_avg[2], sgd_acc_se[2]), color='moccasin')

ax1.plot(epoch50, sgd_acc_avg[3], c='saddlebrown', label='HL3')
ax1.fill_between(epoch50, np.subtract(sgd_acc_avg[3], sgd_acc_se[3]), np.add(sgd_acc_avg[3], sgd_acc_se[3]), color='peru')

ax1.plot(epoch50, sgd_acc_avg[4], c='darkgreen', label='HL4')
ax1.fill_between(epoch50, np.subtract(sgd_acc_avg[4], sgd_acc_se[4]), np.add(sgd_acc_avg[4], sgd_acc_se[4]), color='lime')

ax1.plot(epoch50, sgd_acc_avg[5], c='royalblue', label='HL5')
ax1.fill_between(epoch50, np.subtract(sgd_acc_avg[5], sgd_acc_se[5]), np.add(sgd_acc_avg[5], sgd_acc_se[5]), color='lightsteelblue')

ax1.grid()
ax1.set_title('SGD')
ax1.set_xlabel('Epochs')

# Adagrad
ax2.plot(epoch50, grad_acc_avg[1], c='darkred', label='HL1')
ax2.fill_between(epoch50, np.subtract(grad_acc_avg[1], grad_acc_se[1]), np.add(grad_acc_avg[1], grad_acc_se[1]), color='lightcoral')

ax2.plot(epoch50, grad_acc_avg[2], c='darkorange', label='HL2')
ax2.fill_between(epoch50, np.subtract(grad_acc_avg[2], grad_acc_se[2]), np.add(grad_acc_avg[2], grad_acc_se[2]), color='moccasin')

ax2.plot(epoch50, grad_acc_avg[3], c='saddlebrown', label='HL3')
ax2.fill_between(epoch50, np.subtract(grad_acc_avg[3], grad_acc_se[3]), np.add(grad_acc_avg[3], grad_acc_se[3]), color='peru')

ax2.plot(epoch50, grad_acc_avg[4], c='darkgreen', label='HL4')
ax2.fill_between(epoch50, np.subtract(grad_acc_avg[4], grad_acc_se[4]), np.add(grad_acc_avg[4], grad_acc_se[4]), color='lime')

ax2.plot(epoch50, grad_acc_avg[5], c='royalblue', label='HL5')
ax2.fill_between(epoch50, np.subtract(grad_acc_avg[5], grad_acc_se[5]), np.add(grad_acc_avg[5], grad_acc_se[5]), color='lightsteelblue')

ax2.grid()
ax2.set_title('Adagrad')
ax2.set_xlabel('Epochs')

# Adadelta
ax3.plot(epoch50, delta_acc_avg[1], c='darkred', label='HL1')
ax3.fill_between(epoch50, np.subtract(delta_acc_avg[1], delta_acc_se[1]), np.add(delta_acc_avg[1], delta_acc_se[1]), color='lightcoral')

ax3.plot(epoch50, delta_acc_avg[2], c='darkorange', label='HL2')
ax3.fill_between(epoch50, np.subtract(delta_acc_avg[2], delta_acc_se[2]), np.add(delta_acc_avg[2], delta_acc_se[2]), color='moccasin')

ax3.plot(epoch50, delta_acc_avg[3], c='saddlebrown', label='HL3')
ax3.fill_between(epoch50, np.subtract(delta_acc_avg[3], delta_acc_se[3]), np.add(delta_acc_avg[3], delta_acc_se[3]), color='peru')

ax3.plot(epoch50, delta_acc_avg[4], c='darkgreen', label='HL4')
ax3.fill_between(epoch50, np.subtract(delta_acc_avg[4], delta_acc_se[4]), np.add(delta_acc_avg[4], delta_acc_se[4]), color='lime')

ax3.plot(epoch50, delta_acc_avg[5], c='royalblue', label='HL5')
ax3.fill_between(epoch50, np.subtract(delta_acc_avg[5], delta_acc_se[5]), np.add(delta_acc_avg[5], delta_acc_se[5]), color='lightsteelblue')

ax3.grid()
ax3.set_title('Adadelta')
ax3.set_xlabel('Epochs')

# Adam
ax4.plot(epoch50, adam_acc_avg[1], c='darkred', label='HL1')
ax4.fill_between(epoch50, np.subtract(adam_acc_avg[1], adam_acc_se[1]), np.add(adam_acc_avg[1], adam_acc_se[1]), color='lightcoral')

ax4.plot(epoch50, adam_acc_avg[2], c='darkorange', label='HL2')
ax4.fill_between(epoch50, np.subtract(adam_acc_avg[2], adam_acc_se[2]), np.add(adam_acc_avg[2], adam_acc_se[2]), color='moccasin')

ax4.plot(epoch50, adam_acc_avg[3], c='saddlebrown', label='HL3')
ax4.fill_between(epoch50, np.subtract(adam_acc_avg[3], adam_acc_se[3]), np.add(adam_acc_avg[3], adam_acc_se[3]), color='peru')

ax4.plot(epoch50, adam_acc_avg[4], c='darkgreen', label='HL4')
ax4.fill_between(epoch50, np.subtract(adam_acc_avg[4], adam_acc_se[4]), np.add(adam_acc_avg[4], adam_acc_se[4]), color='lime')

ax4.plot(epoch50, adam_acc_avg[5], c='royalblue', label='HL5')
ax4.fill_between(epoch50, np.subtract(adam_acc_avg[5], adam_acc_se[5]), np.add(adam_acc_avg[5], adam_acc_se[5]), color='lightsteelblue')

ax4.grid()
ax4.set_title('Adam')
ax4.set_xlabel('Epochs')
ax1.set_ylabel('Test-accuracy')
# Out:
# Text(0, 0.5, 'Test-accuracy')

# %%
fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, figsize=(20, 5))

# SGD
ax1.plot(epoch50, sgd_acc_avg[1], c='darkred', label='HL1')
ax1.fill_between(epoch50, np.subtract(sgd_acc_avg[1], sgd_acc_se[1]), np.add(sgd_acc_avg[1], sgd_acc_se[1]), color='lightcoral')

ax1.plot(epoch50, sgd_acc_avg[2], c='darkorange', label='HL2')
ax1.fill_between(epoch50, np.subtract(sgd_acc_avg[2], sgd_acc_se[2]), np.add(sgd_acc_avg[2], sgd_acc_se[2]), color='moccasin')

ax1.plot(epoch50, sgd_acc_avg[3], c='saddlebrown', label='HL3')
ax1.fill_between(epoch50, np.subtract(sgd_acc_avg[3], sgd_acc_se[3]), np.add(sgd_acc_avg[3], sgd_acc_se[3]), color='peru')

ax1.plot(epoch50, sgd_acc_avg[4], c='darkgreen', label='HL4')
ax1.fill_between(epoch50, np.subtract(sgd_acc_avg[4], sgd_acc_se[4]), np.add(sgd_acc_avg[4], sgd_acc_se[4]), color='lime')

ax1.plot(epoch50, sgd_acc_avg[5], c='royalblue', label='HL5')
ax1.fill_between(epoch50, np.subtract(sgd_acc_avg[5], sgd_acc_se[5]), np.add(sgd_acc_avg[5], sgd_acc_se[5]), color='lightsteelblue')

ax1.grid()
ax1.set_title('SGD')
ax1.set_xlabel('Epochs')

# Adagrad
ax2.plot(epoch50, grad_acc_avg[1], c='darkred', label='HL1')
ax2.fill_between(epoch50, np.subtract(grad_acc_avg[1], grad_acc_se[1]), np.add(grad_acc_avg[1], grad_acc_se[1]), color='lightcoral')

ax2.plot(epoch50, grad_acc_avg[2], c='darkorange', label='HL2')
ax2.fill_between(epoch50, np.subtract(grad_acc_avg[2], grad_acc_se[2]), np.add(grad_acc_avg[2], grad_acc_se[2]), color='moccasin')

ax2.plot(epoch50, grad_acc_avg[3], c='saddlebrown', label='HL3')
ax2.fill_between(epoch50, np.subtract(grad_acc_avg[3], grad_acc_se[3]), np.add(grad_acc_avg[3], grad_acc_se[3]), color='peru')

ax2.plot(epoch50, grad_acc_avg[4], c='darkgreen', label='HL4')
ax2.fill_between(epoch50, np.subtract(grad_acc_avg[4], grad_acc_se[4]), np.add(grad_acc_avg[4], grad_acc_se[4]), color='lime')

ax2.plot(epoch50, grad_acc_avg[5], c='royalblue', label='HL5')
ax2.fill_between(epoch50, np.subtract(grad_acc_avg[5], grad_acc_se[5]), np.add(grad_acc_avg[5], grad_acc_se[5]), color='lightsteelblue')

ax2.grid()
ax2.set_title('Adagrad')
ax2.set_xlabel('Epochs')

# Adadelta
ax3.plot(epoch50, delta_acc_avg[1], c='darkred', label='HL1')
ax3.fill_between(epoch50, np.subtract(delta_acc_avg[1], delta_acc_se[1]), np.add(delta_acc_avg[1], delta_acc_se[1]), color='lightcoral')

ax3.plot(epoch50, delta_acc_avg[2], c='darkorange', label='HL2')
ax3.fill_between(epoch50, np.subtract(delta_acc_avg[2], delta_acc_se[2]), np.add(delta_acc_avg[2], delta_acc_se[2]), color='moccasin')

ax3.plot(epoch50, delta_acc_avg[3], c='saddlebrown', label='HL3')
ax3.fill_between(epoch50, np.subtract(delta_acc_avg[3], delta_acc_se[3]), np.add(delta_acc_avg[3], delta_acc_se[3]), color='peru')

ax3.plot(epoch50, delta_acc_avg[4], c='darkgreen', label='HL4')
ax3.fill_between(epoch50, np.subtract(delta_acc_avg[4], delta_acc_se[4]), np.add(delta_acc_avg[4], delta_acc_se[4]), color='lime')

ax3.plot(epoch50, delta_acc_avg[5], c='royalblue', label='HL5')
ax3.fill_between(epoch50, np.subtract(delta_acc_avg[5], delta_acc_se[5]), np.add(delta_acc_avg[5], delta_acc_se[5]), color='lightsteelblue')

ax3.grid()
ax3.set_title('Adadelta')
ax3.set_xlabel('Epochs')

# Adam
ax4.plot(epoch50, adam_acc_avg[1], c='darkred', label='HL1')
ax4.fill_between(epoch50, np.subtract(adam_acc_avg[1], adam_acc_se[1]), np.add(adam_acc_avg[1], adam_acc_se[1]), color='lightcoral')

ax4.plot(epoch50, adam_acc_avg[2], c='darkorange', label='HL2')
ax4.fill_between(epoch50, np.subtract(adam_acc_avg[2], adam_acc_se[2]), np.add(adam_acc_avg[2], adam_acc_se[2]), color='moccasin')

ax4.plot(epoch50, adam_acc_avg[3], c='saddlebrown', label='HL3')
ax4.fill_between(epoch50, np.subtract(adam_acc_avg[3], adam_acc_se[3]), np.add(adam_acc_avg[3], adam_acc_se[3]), color='peru')

ax4.plot(epoch50, adam_acc_avg[4], c='darkgreen', label='HL4')
ax4.fill_between(epoch50, np.subtract(adam_acc_avg[4], adam_acc_se[4]), np.add(adam_acc_avg[4], adam_acc_se[4]), color='lime')

ax4.plot(epoch50, adam_acc_avg[5], c='royalblue', label='HL5')
ax4.fill_between(epoch50, np.subtract(adam_acc_avg[5], adam_acc_se[5]), np.add(adam_acc_avg[5], adam_acc_se[5]), color='lightsteelblue')

ax4.grid()
ax4.set_title('Adam')
ax4.set_xlabel('Epochs')
ax1.set_ylabel('Zoomed Test-accuracy')

ax1.set_ylim([0.96, 0.985])
ax2.set_ylim([0.96, 0.985])
ax3.set_ylim([0.96, 0.985])
ax4.set_ylim([0.96, 0.985])
# Out:
# (0.96, 0.985)

# %%
# Sparsity

# %%
fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, figsize=(20, 5))

# SGD
ax1.plot(epoch50, sgd_spar_avg[1], c='darkred', label='HL1')
ax1.fill_between(epoch50, np.subtract(sgd_spar_avg[1], sgd_spar_se[1]), np.add(sgd_spar_avg[1], sgd_spar_se[1]), color='lightcoral')

ax1.plot(epoch50, sgd_spar_avg[2], c='darkorange', label='HL2')
ax1.fill_between(epoch50, np.subtract(sgd_spar_avg[2], sgd_spar_se[2]), np.add(sgd_spar_avg[2], sgd_spar_se[2]), color='moccasin')

ax1.plot(epoch50, sgd_spar_avg[3], c='saddlebrown', label='HL3')
ax1.fill_between(epoch50, np.subtract(sgd_spar_avg[3], sgd_spar_se[3]), np.add(sgd_spar_avg[3], sgd_spar_se[3]), color='peru')

ax1.plot(epoch50, sgd_spar_avg[4], c='darkgreen', label='HL4')
ax1.fill_between(epoch50, np.subtract(sgd_spar_avg[4], sgd_spar_se[4]), np.add(sgd_spar_avg[4], sgd_spar_se[4]), color='lime')

ax1.plot(epoch50, sgd_spar_avg[5], c='royalblue', label='HL5')
ax1.fill_between(epoch50, np.subtract(sgd_spar_avg[5], sgd_spar_se[5]), np.add(sgd_spar_avg[5], sgd_spar_se[5]), color='lightsteelblue')

ax1.grid()
ax1.set_title('SGD')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Sparsity')

# Adagrad
ax2.plot(epoch50, grad_spar_avg[1], c='darkred', label='HL1')
ax2.fill_between(epoch50, np.subtract(grad_spar_avg[1], grad_spar_se[1]), np.add(grad_spar_avg[1], grad_spar_se[1]), color='lightcoral')

ax2.plot(epoch50, grad_spar_avg[2], c='darkorange', label='HL2')
ax2.fill_between(epoch50, np.subtract(grad_spar_avg[2], grad_spar_se[2]), np.add(grad_spar_avg[2], grad_spar_se[2]), color='moccasin')

ax2.plot(epoch50, grad_spar_avg[3], c='saddlebrown', label='HL3')
ax2.fill_between(epoch50, np.subtract(grad_spar_avg[3], grad_spar_se[3]), np.add(grad_spar_avg[3], grad_spar_se[3]), color='peru')

ax2.plot(epoch50, grad_spar_avg[4], c='darkgreen', label='HL4')
ax2.fill_between(epoch50, np.subtract(grad_spar_avg[4], grad_spar_se[4]), np.add(grad_spar_avg[4], grad_spar_se[4]), color='lime')

ax2.plot(epoch50, grad_spar_avg[5], c='royalblue', label='HL5')
ax2.fill_between(epoch50, np.subtract(grad_spar_avg[5], grad_spar_se[5]), np.add(grad_spar_avg[5], grad_spar_se[5]), color='lightsteelblue')

ax2.grid()
ax2.set_title('Adagrad')
ax2.set_xlabel('Epochs')

# Adadelta
ax3.plot(epoch50, delta_spar_avg[1], c='darkred', label='HL1')
ax3.fill_between(epoch50, np.subtract(delta_spar_avg[1], delta_spar_se[1]), np.add(delta_spar_avg[1], delta_spar_se[1]), color='lightcoral')

ax3.plot(epoch50, delta_spar_avg[2], c='darkorange', label='HL2')
ax3.fill_between(epoch50, np.subtract(delta_spar_avg[2], delta_spar_se[2]), np.add(delta_spar_avg[2], delta_spar_se[2]), color='moccasin')

ax3.plot(epoch50, delta_spar_avg[3], c='saddlebrown', label='HL3')
ax3.fill_between(epoch50, np.subtract(delta_spar_avg[3], delta_spar_se[3]), np.add(delta_spar_avg[3], delta_spar_se[3]), color='peru')

ax3.plot(epoch50, delta_spar_avg[4], c='darkgreen', label='HL4')
ax3.fill_between(epoch50, np.subtract(delta_spar_avg[4], delta_spar_se[4]), np.add(delta_spar_avg[4], delta_spar_se[4]), color='lime')

ax3.plot(epoch50, delta_spar_avg[5], c='royalblue', label='HL5')
ax3.fill_between(epoch50, np.subtract(delta_spar_avg[5], delta_spar_se[5]), np.add(delta_spar_avg[5], delta_spar_se[5]), color='lightsteelblue')

ax3.grid()
ax3.set_title('Adadelta')
ax3.set_xlabel('Epochs')

# Adam
ax4.plot(epoch50, adam_spar_avg[1], c='darkred', label='HL1')
ax4.fill_between(epoch50, np.subtract(adam_spar_avg[1], adam_spar_se[1]), np.add(adam_spar_avg[1], adam_spar_se[1]), color='lightcoral')

ax4.plot(epoch50, adam_spar_avg[2], c='darkorange', label='HL2')
ax4.fill_between(epoch50, np.subtract(adam_spar_avg[2], adam_spar_se[2]), np.add(adam_spar_avg[2], adam_spar_se[2]), color='moccasin')

ax4.plot(epoch50, adam_spar_avg[3], c='saddlebrown', label='HL3')
ax4.fill_between(epoch50, np.subtract(adam_spar_avg[3], adam_spar_se[3]), np.add(adam_spar_avg[3], adam_spar_se[3]), color='peru')

ax4.plot(epoch50, adam_spar_avg[4], c='darkgreen', label='HL4')
ax4.fill_between(epoch50, np.subtract(adam_spar_avg[4], adam_spar_se[4]), np.add(adam_spar_avg[4], adam_spar_se[4]), color='lime')

ax4.plot(epoch50, adam_spar_avg[5], c='royalblue', label='HL5')
ax4.fill_between(epoch50, np.subtract(adam_spar_avg[5], adam_spar_se[5]), np.add(adam_spar_avg[5], adam_spar_se[5]), color='lightsteelblue')

ax4.grid()
ax4.set_title('Adam')
ax4.set_xlabel('Epochs')
# Out:
# Text(0.5, 0, 'Epochs')

# %%
# Selectivity

# %%
fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, figsize=(20, 5))

# SGD
ax1.plot(epoch50, sgd_selec_avg[1], c='darkred', label='HL1')
ax1.fill_between(epoch50, np.subtract(sgd_selec_avg[1], sgd_selec_se[1]), np.add(sgd_selec_avg[1], sgd_selec_se[1]), color='lightcoral')

ax1.plot(epoch50, sgd_selec_avg[2], c='darkorange', label='HL2')
ax1.fill_between(epoch50, np.subtract(sgd_selec_avg[2], sgd_selec_se[2]), np.add(sgd_selec_avg[2], sgd_selec_se[2]), color='moccasin')

ax1.plot(epoch50, sgd_selec_avg[3], c='saddlebrown', label='HL3')
ax1.fill_between(epoch50, np.subtract(sgd_selec_avg[3], sgd_selec_se[3]), np.add(sgd_selec_avg[3], sgd_selec_se[3]), color='peru')

ax1.plot(epoch50, sgd_selec_avg[4], c='darkgreen', label='HL4')
ax1.fill_between(epoch50, np.subtract(sgd_selec_avg[4], sgd_selec_se[4]), np.add(sgd_selec_avg[4], sgd_selec_se[4]), color='lime')

ax1.plot(epoch50, sgd_selec_avg[5], c='royalblue', label='HL5')
ax1.fill_between(epoch50, np.subtract(sgd_selec_avg[5], sgd_selec_se[5]), np.add(sgd_selec_avg[5], sgd_selec_se[5]), color='lightsteelblue')

ax1.grid()
ax1.set_title('SGD')
ax1.set_xlabel('Epochs')

# Adagrad
ax2.plot(epoch50, grad_selec_avg[1], c='darkred', label='HL1')
ax2.fill_between(epoch50, np.subtract(grad_selec_avg[1], grad_selec_se[1]), np.add(grad_selec_avg[1], grad_selec_se[1]), color='lightcoral')

ax2.plot(epoch50, grad_selec_avg[2], c='darkorange', label='HL2')
ax2.fill_between(epoch50, np.subtract(grad_selec_avg[2], grad_selec_se[2]), np.add(grad_selec_avg[2], grad_selec_se[2]), color='moccasin')

ax2.plot(epoch50, grad_selec_avg[3], c='saddlebrown', label='HL3')
ax2.fill_between(epoch50, np.subtract(grad_selec_avg[3], grad_selec_se[3]), np.add(grad_selec_avg[3], grad_selec_se[3]), color='peru')

ax2.plot(epoch50, grad_selec_avg[4], c='darkgreen', label='HL4')
ax2.fill_between(epoch50, np.subtract(grad_selec_avg[4], grad_selec_se[4]), np.add(grad_selec_avg[4], grad_selec_se[4]), color='lime')

ax2.plot(epoch50, grad_selec_avg[5], c='royalblue', label='HL5')
ax2.fill_between(epoch50, np.subtract(grad_selec_avg[5], grad_selec_se[5]), np.add(grad_selec_avg[5], grad_selec_se[5]), color='lightsteelblue')

ax2.grid()
ax2.set_title('Adagrad')
ax2.set_xlabel('Epochs')

# Adadelta
ax3.plot(epoch50, delta_selec_avg[1], c='darkred', label='HL1')
ax3.fill_between(epoch50, np.subtract(delta_selec_avg[1], delta_selec_se[1]), np.add(delta_selec_avg[1], delta_selec_se[1]), color='lightcoral')

ax3.plot(epoch50, delta_selec_avg[2], c='darkorange', label='HL2')
ax3.fill_between(epoch50, np.subtract(delta_selec_avg[2], delta_selec_se[2]), np.add(delta_selec_avg[2], delta_selec_se[2]), color='moccasin')

ax3.plot(epoch50, delta_selec_avg[3], c='saddlebrown', label='HL3')
ax3.fill_between(epoch50, np.subtract(delta_selec_avg[3], delta_selec_se[3]), np.add(delta_selec_avg[3], delta_selec_se[3]), color='peru')

ax3.plot(epoch50, delta_selec_avg[4], c='darkgreen', label='HL4')
ax3.fill_between(epoch50, np.subtract(delta_selec_avg[4], delta_selec_se[4]), np.add(delta_selec_avg[4], delta_selec_se[4]), color='lime')

ax3.plot(epoch50, delta_selec_avg[5], c='royalblue', label='HL5')
ax3.fill_between(epoch50, np.subtract(delta_selec_avg[5], delta_selec_se[5]), np.add(delta_selec_avg[5], delta_selec_se[5]), color='lightsteelblue')

ax3.grid()
ax3.set_title('Adadelta')
ax3.set_xlabel('Epochs')

# Adam
ax4.plot(epoch50, adam_selec_avg[1], c='darkred', label='HL1')
ax4.fill_between(epoch50, np.subtract(adam_selec_avg[1], adam_selec_se[1]), np.add(adam_selec_avg[1], adam_selec_se[1]), color='lightcoral')

ax4.plot(epoch50, adam_selec_avg[2], c='darkorange', label='HL2')
ax4.fill_between(epoch50, np.subtract(adam_selec_avg[2], adam_selec_se[2]), np.add(adam_selec_avg[2], adam_selec_se[2]), color='moccasin')

ax4.plot(epoch50, adam_selec_avg[3], c='saddlebrown', label='HL3')
ax4.fill_between(epoch50, np.subtract(adam_selec_avg[3], adam_selec_se[3]), np.add(adam_selec_avg[3], adam_selec_se[3]), color='peru')

ax4.plot(epoch50, adam_selec_avg[4], c='darkgreen', label='HL4')
ax4.fill_between(epoch50, np.subtract(adam_selec_avg[4], adam_selec_se[4]), np.add(adam_selec_avg[4], adam_selec_se[4]), color='lime')

ax4.plot(epoch50, adam_selec_avg[5], c='royalblue', label='HL5')
ax4.fill_between(epoch50, np.subtract(adam_selec_avg[5], adam_selec_se[5]), np.add(adam_selec_avg[5], adam_selec_se[5]), color='lightsteelblue')

ax4.grid()
ax4.set_title('Adam')
ax4.set_xlabel('Epochs')
ax1.set_ylabel('Selectivity')

ax4.legend(loc='upper center', bbox_to_anchor=(-1.3, -0.15),
          fancybox=True, shadow=True, ncol=5)

# %% [markdown]
# # Sparsity vs Selectivity

# %%
fig, ((ax1, ax2, ax3, ax4)) = plt.subplots(1, 4, figsize=(20,5))

# now plot both limits against eachother
ax1.scatter(sgd_spar_avg[1], sgd_selec_avg[1], c='red', label='HL1', alpha=0.5)
ax1.scatter(sgd_spar_avg[2], sgd_selec_avg[2], c='orange', label='HL2', alpha=0.5)
ax1.scatter(sgd_spar_avg[3], sgd_selec_avg[3], c='chocolate', label='HL3', alpha=0.5)
ax1.scatter(sgd_spar_avg[4], sgd_selec_avg[4], c='green', label='HL4', alpha=0.5)
ax1.scatter(sgd_spar_avg[5], sgd_selec_avg[5], c='cornflowerblue', label='HL5', alpha=0.5)
ax1.set_title('SGD')
ax1.set_xlabel('Sparsity')
ax1.set_ylabel('Selectivity')
ax1.grid()

ax2.scatter(grad_spar_avg[1], grad_selec_avg[1], c='red', label='HL1', alpha=0.5)
ax2.scatter(grad_spar_avg[2], grad_selec_avg[2], c='orange', label='HL2', alpha=0.5)
ax2.scatter(grad_spar_avg[3], grad_selec_avg[3], c='chocolate', label='HL3', alpha=0.5)
ax2.scatter(grad_spar_avg[4], grad_selec_avg[4], c='green', label='HL4', alpha=0.5)
ax2.scatter(grad_spar_avg[5], grad_selec_avg[5], c='cornflowerblue', label='HL5', alpha=0.5)
ax2.set_title('Adagrad')
ax2.set_xlabel('Sparsity')
ax2.grid()

ax3.scatter(delta_spar_avg[1], delta_selec_avg[1], c='red', label='HL1', alpha=0.5)
ax3.scatter(delta_spar_avg[2], delta_selec_avg[2], c='orange', label='HL2', alpha=0.5)
ax3.scatter(delta_spar_avg[3], delta_selec_avg[3], c='chocolate', label='HL3', alpha=0.5)
ax3.scatter(delta_spar_avg[4], delta_selec_avg[4], c='green', label='HL4', alpha=0.5)
ax3.scatter(delta_spar_avg[5], delta_selec_avg[5], c='cornflowerblue', label='HL5', alpha=0.5)
ax3.set_title('Adadelta')
ax3.set_xlabel('Sparsity')
ax3.grid()

ax4.scatter(adam_spar_avg[1], adam_selec_avg[1], c='red', label='HL1', alpha=0.5)
ax4.scatter(adam_spar_avg[2], adam_selec_avg[2], c='orange', label='HL2', alpha=0.5)
ax4.scatter(adam_spar_avg[3], adam_selec_avg[3], c='chocolate', label='HL3', alpha=0.5)
ax4.scatter(adam_spar_avg[4], adam_selec_avg[4], c='green', label='HL4', alpha=0.5)
ax4.scatter(adam_spar_avg[5], adam_selec_avg[5], c='cornflowerblue', label='HL5', alpha=0.5)
ax4.set_title('Adam')
ax4.set_xlabel('Sparsity')
ax4.grid()
ax4.legend(loc='upper center', bbox_to_anchor=(-1.3, -0.15),
          fancybox=True, shadow=True, ncol=5)


plt.plot()
# Out:
# []

# %% [markdown]
# # Accuracy vs Sparsity/Selectivity

# %%
fig, ((ax1, ax2, ax3, ax4)) = plt.subplots(1, 4, figsize=(20,5))

# now plot both limits against eachother
ax1.scatter(sgd_acc_avg[1], sgd_spar_avg[1], c='red', label='HL1 sparsity', alpha=0.5)
ax1.scatter(sgd_acc_avg[2], sgd_spar_avg[2], c='gold', label='HL2 sparsity', alpha=0.5)
ax1.scatter(sgd_acc_avg[3], sgd_spar_avg[3], c='grey', label='HL3 sparsity', alpha=0.5)
ax1.scatter(sgd_acc_avg[4], sgd_spar_avg[4], c='lime', label='HL4 sparsity', alpha=0.5)
ax1.scatter(sgd_acc_avg[5], sgd_spar_avg[5], c='cornflowerblue', label='HL5 sparsity', alpha=0.5)

ax1.scatter(sgd_acc_avg[1], sgd_selec_avg[1], c='maroon', label='HL1 selectivity', alpha=0.5)
ax1.scatter(sgd_acc_avg[2], sgd_selec_avg[2], c='darkgoldenrod', label='HL2 selectivity', alpha=0.5)
ax1.scatter(sgd_acc_avg[3], sgd_selec_avg[3], c='black', label='HL3 selectivity', alpha=0.5)
ax1.scatter(sgd_acc_avg[4], sgd_selec_avg[4], c='darkgreen', label='HL4 selectivity', alpha=0.5)
ax1.scatter(sgd_acc_avg[5], sgd_selec_avg[5], c='blue', label='HL5 selectivity', alpha=0.5)

ax1.set_title('SGD')
ax1.set_xlabel('Test-accuracy')
ax1.grid()

# now plot both limits against eachother
ax2.scatter(grad_acc_avg[1], grad_spar_avg[1], c='red', label='HL1', alpha=0.5)
ax2.scatter(grad_acc_avg[2], grad_spar_avg[2], c='gold', label='HL2', alpha=0.5)
ax2.scatter(grad_acc_avg[3], grad_spar_avg[3], c='grey', label='HL3', alpha=0.5)
ax2.scatter(grad_acc_avg[4], grad_spar_avg[4], c='lime', label='HL4', alpha=0.5)
ax2.scatter(grad_acc_avg[5], grad_spar_avg[5], c='cornflowerblue', label='HL5', alpha=0.5)

ax2.scatter(grad_acc_avg[1], grad_selec_avg[1], c='maroon', label='HL1', alpha=0.5)
ax2.scatter(grad_acc_avg[2], grad_selec_avg[2], c='darkgoldenrod', label='HL2', alpha=0.5)
ax2.scatter(grad_acc_avg[3], grad_selec_avg[3], c='black', label='HL3', alpha=0.5)
ax2.scatter(grad_acc_avg[4], grad_selec_avg[4], c='darkgreen', label='HL4', alpha=0.5)
ax2.scatter(grad_acc_avg[5], grad_selec_avg[5], c='blue', label='HL5', alpha=0.5)

ax2.set_title('Adagrad')
ax2.set_xlabel('Test-accuracy')
ax2.grid()

# now plot both limits against eachother
ax3.scatter(delta_acc_avg[1], delta_spar_avg[1], c='red', label='HL1', alpha=0.5)
ax3.scatter(delta_acc_avg[2], delta_spar_avg[2], c='gold', label='HL2', alpha=0.5)
ax3.scatter(delta_acc_avg[3], delta_spar_avg[3], c='grey', label='HL3', alpha=0.5)
ax3.scatter(delta_acc_avg[4], delta_spar_avg[4], c='lime', label='HL4', alpha=0.5)
ax3.scatter(delta_acc_avg[5], delta_spar_avg[5], c='cornflowerblue', label='HL5', alpha=0.5)

ax3.scatter(delta_acc_avg[1], delta_selec_avg[1], c='maroon', label='HL1', alpha=0.5)
ax3.scatter(delta_acc_avg[2], delta_selec_avg[2], c='darkgoldenrod', label='HL2', alpha=0.5)
ax3.scatter(delta_acc_avg[3], delta_selec_avg[3], c='black', label='HL3', alpha=0.5)
ax3.scatter(delta_acc_avg[4], delta_selec_avg[4], c='darkgreen', label='HL4', alpha=0.5)
ax3.scatter(delta_acc_avg[5], delta_selec_avg[5], c='blue', label='HL5', alpha=0.5)

ax3.set_title('Adadelta')
ax3.set_xlabel('Test-accuracy')
ax3.grid()

# now plot both limits against eachother
ax4.scatter(adam_acc_avg[1], adam_spar_avg[1], c='red', label='HL1 sparsity', alpha=0.5)
ax4.scatter(adam_acc_avg[2], adam_spar_avg[2], c='gold', label='HL2 sparsity', alpha=0.5)
ax4.scatter(adam_acc_avg[3], adam_spar_avg[3], c='grey', label='HL3 sparsity', alpha=0.5)
ax4.scatter(adam_acc_avg[4], adam_spar_avg[4], c='lime', label='HL4 sparsity', alpha=0.5)
ax4.scatter(adam_acc_avg[5], adam_spar_avg[5], c='cornflowerblue', label='HL5 sparsity', alpha=0.5)

ax4.scatter(adam_acc_avg[1], adam_selec_avg[1], c='maroon', label='HL1 selectivity', alpha=0.5)
ax4.scatter(adam_acc_avg[2], adam_selec_avg[2], c='darkgoldenrod', label='HL2 selectivity', alpha=0.5)
ax4.scatter(adam_acc_avg[3], adam_selec_avg[3], c='black', label='HL3 selectivity', alpha=0.5)
ax4.scatter(adam_acc_avg[4], adam_selec_avg[4], c='darkgreen', label='HL4 selectivity', alpha=0.5)
ax4.scatter(adam_acc_avg[5], adam_selec_avg[5], c='blue', label='HL5 selectivity', alpha=0.5)

ax4.set_title('Adam')
ax4.set_xlabel('Test-accuracy')
ax1.set_ylabel('Sparsity and Selectivity')
ax4.grid()

plt.plot()
# Out:
# []

# %%
fig, ((ax1, ax2, ax3, ax4)) = plt.subplots(1, 4, figsize=(20,5))

# now plot both limits against eachother
ax1.scatter(sgd_acc_avg[1], sgd_spar_avg[1], c='red', label='HL1 sparsity', alpha=0.5)
ax1.scatter(sgd_acc_avg[2], sgd_spar_avg[2], c='gold', label='HL2 sparsity', alpha=0.5)
ax1.scatter(sgd_acc_avg[3], sgd_spar_avg[3], c='grey', label='HL3 sparsity', alpha=0.5)
ax1.scatter(sgd_acc_avg[4], sgd_spar_avg[4], c='lime', label='HL4 sparsity', alpha=0.5)
ax1.scatter(sgd_acc_avg[5], sgd_spar_avg[5], c='cornflowerblue', label='HL5 sparsity', alpha=0.5)

ax1.scatter(sgd_acc_avg[1], sgd_selec_avg[1], c='maroon', label='HL1 selectivity', alpha=0.5)
ax1.scatter(sgd_acc_avg[2], sgd_selec_avg[2], c='darkgoldenrod', label='HL2 selectivity', alpha=0.5)
ax1.scatter(sgd_acc_avg[3], sgd_selec_avg[3], c='black', label='HL3 selectivity', alpha=0.5)
ax1.scatter(sgd_acc_avg[4], sgd_selec_avg[4], c='darkgreen', label='HL4 selectivity', alpha=0.5)
ax1.scatter(sgd_acc_avg[5], sgd_selec_avg[5], c='blue', label='HL5 selectivity', alpha=0.5)

ax1.set_title('SGD')
ax1.set_xlabel('Test-accuracy')
ax1.grid()
ax1.set_xlim([0.96, 0.98])
ax1.set_ylim([0.1, 0.8])

# now plot both limits against eachother
ax2.scatter(grad_acc_avg[1], grad_spar_avg[1], c='red', label='HL1', alpha=0.5)
ax2.scatter(grad_acc_avg[2], grad_spar_avg[2], c='gold', label='HL2', alpha=0.5)
ax2.scatter(grad_acc_avg[3], grad_spar_avg[3], c='grey', label='HL3', alpha=0.5)
ax2.scatter(grad_acc_avg[4], grad_spar_avg[4], c='lime', label='HL4', alpha=0.5)
ax2.scatter(grad_acc_avg[5], grad_spar_avg[5], c='cornflowerblue', label='HL5', alpha=0.5)

ax2.scatter(grad_acc_avg[1], grad_selec_avg[1], c='maroon', label='HL1', alpha=0.5)
ax2.scatter(grad_acc_avg[2], grad_selec_avg[2], c='darkgoldenrod', label='HL2', alpha=0.5)
ax2.scatter(grad_acc_avg[3], grad_selec_avg[3], c='black', label='HL3', alpha=0.5)
ax2.scatter(grad_acc_avg[4], grad_selec_avg[4], c='darkgreen', label='HL4', alpha=0.5)
ax2.scatter(grad_acc_avg[5], grad_selec_avg[5], c='blue', label='HL5', alpha=0.5)

ax2.set_title('Adagrad')
ax2.set_xlabel('Test-accuracy')
ax2.grid()
ax2.set_xlim([0.96, 0.985])
ax2.set_ylim([0.1, 0.8])

# now plot both limits against eachother
ax3.scatter(delta_acc_avg[1], delta_spar_avg[1], c='red', label='HL1', alpha=0.5)
ax3.scatter(delta_acc_avg[2], delta_spar_avg[2], c='gold', label='HL2', alpha=0.5)
ax3.scatter(delta_acc_avg[3], delta_spar_avg[3], c='grey', label='HL3', alpha=0.5)
ax3.scatter(delta_acc_avg[4], delta_spar_avg[4], c='lime', label='HL4', alpha=0.5)
ax3.scatter(delta_acc_avg[5], delta_spar_avg[5], c='cornflowerblue', label='HL5', alpha=0.5)

ax3.scatter(delta_acc_avg[1], delta_selec_avg[1], c='maroon', label='HL1', alpha=0.5)
ax3.scatter(delta_acc_avg[2], delta_selec_avg[2], c='darkgoldenrod', label='HL2', alpha=0.5)
ax3.scatter(delta_acc_avg[3], delta_selec_avg[3], c='black', label='HL3', alpha=0.5)
ax3.scatter(delta_acc_avg[4], delta_selec_avg[4], c='darkgreen', label='HL4', alpha=0.5)
ax3.scatter(delta_acc_avg[5], delta_selec_avg[5], c='blue', label='HL5', alpha=0.5)

ax3.set_title('Adadelta')
ax3.set_xlabel('Test-accuracy')
ax3.grid()
ax3.set_xlim([0.97, 0.985])
ax3.set_ylim([0.1, 0.8])

# now plot both limits against eachother
ax4.scatter(adam_acc_avg[1], adam_spar_avg[1], c='red', label='HL1 sparsity', alpha=0.5)
ax4.scatter(adam_acc_avg[2], adam_spar_avg[2], c='gold', label='HL2 sparsity', alpha=0.5)
ax4.scatter(adam_acc_avg[3], adam_spar_avg[3], c='grey', label='HL3 sparsity', alpha=0.5)
ax4.scatter(adam_acc_avg[4], adam_spar_avg[4], c='lime', label='HL4 sparsity', alpha=0.5)
ax4.scatter(adam_acc_avg[5], adam_spar_avg[5], c='cornflowerblue', label='HL5 sparsity', alpha=0.5)

ax4.scatter(adam_acc_avg[1], adam_selec_avg[1], c='maroon', label='HL1 selectivity', alpha=0.5)
ax4.scatter(adam_acc_avg[2], adam_selec_avg[2], c='darkgoldenrod', label='HL2 selectivity', alpha=0.5)
ax4.scatter(adam_acc_avg[3], adam_selec_avg[3], c='black', label='HL3 selectivity', alpha=0.5)
ax4.scatter(adam_acc_avg[4], adam_selec_avg[4], c='darkgreen', label='HL4 selectivity', alpha=0.5)
ax4.scatter(adam_acc_avg[5], adam_selec_avg[5], c='blue', label='HL5 selectivity', alpha=0.5)

ax4.set_title('Adam')
ax4.set_xlabel('Test-accuracy')
ax1.set_ylabel('Sparsity and Selectivity')
ax4.grid()
ax4.set_xlim([0.97, 0.985])
ax4.set_ylim([0.1, 0.8])
ax4.legend(loc='upper center', bbox_to_anchor=(-1.3, -0.15),
          fancybox=True, shadow=True, ncol=2)

plt.plot()
# Out:
# []

# %% [markdown]
# # Varying Hidden Layer

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(15, 5))

# default setting for grpahs 
hl_ticks = ['1HL', '2HLs', '3HLs', '4HLs', '5HLs']
ax1.set_xticks(np.linspace(1, 5, 5))
ax1.set_xticklabels(hl_ticks)

ax2.set_xticks(np.linspace(1, 5, 5))
ax2.set_xticklabels(hl_ticks)

ax3.set_xticks(np.linspace(1, 5, 5))
ax3.set_xticklabels(hl_ticks)

# Accuracy 
sgd =   [sgd_acc_avg[1][-1],   sgd_acc_avg[2][-1],   sgd_acc_avg[3][-1],   sgd_acc_avg[4][-1]]
sgd_se = [sgd_acc_se[1][-1],   sgd_acc_se[2][-1],   sgd_acc_se[3][-1],   sgd_acc_se[4][-1]]

grad =  [grad_acc_avg[1][-1],  grad_acc_avg[2][-1],  grad_acc_avg[3][-1],  grad_acc_avg[4][-1]]
grad_se = [grad_acc_se[1][-1],  grad_acc_se[2][-1],  grad_acc_se[3][-1],  grad_acc_se[4][-1]]

delta = [delta_acc_avg[1][-1], delta_acc_avg[2][-1], delta_acc_avg[3][-1], delta_acc_avg[4][-1], delta_acc_avg[5][-1]]
delta_se = [delta_acc_se[1][-1], delta_acc_se[2][-1], delta_acc_se[3][-1], delta_acc_se[4][-1], delta_acc_se[5][-1]]

adam =  [adam_acc_avg[1][-1],  adam_acc_avg[2][-1],  adam_acc_avg[3][-1],  adam_acc_avg[4][-1],  adam_acc_avg[5][-1]]
adam_se = [adam_acc_se[1][-1],  adam_acc_se[2][-1],  adam_acc_se[3][-1],  adam_acc_se[4][-1],  adam_acc_se[5][-1]]

# accuracy
ax1.plot(np.linspace(1, 5, 5)[:4], sgd, label='SGD', marker='o', c='darkred')
ax1.fill_between(np.linspace(1, 5, 5)[:4], np.subtract(sgd, sgd_se), np.add(sgd, sgd_se), color='lightcoral')

ax1.plot(np.linspace(1, 5, 5)[:4], grad, label='Adagrad', marker='^', c='darkgreen')
ax1.fill_between(np.linspace(1, 5, 5)[:4], np.subtract(grad, grad_se), np.add(grad, grad_se), color='lime')

ax1.plot(np.linspace(1, 5, 5), delta, label='Adadelta', marker='v', c='darkblue')
ax1.fill_between(np.linspace(1, 5, 5), np.subtract(delta, delta_se), np.add(delta, delta_se), color='lightsteelblue')

ax1.plot(np.linspace(1, 5, 5), adam, label='Adam', marker='s', c='purple')
ax1.fill_between(np.linspace(1, 5, 5), np.subtract(adam, adam_se), np.add(adam, adam_se), color='violet')
ax1.grid()
ax1.set_title('Test-accuracy Plot')
ax1.set_ylabel('Test-accuracy, Sparsity, and Selectivity')


# Sparsity
sgd =   [sgd_spar_avg[1][-1],   sgd_spar_avg[2][-1],   sgd_spar_avg[3][-1],   sgd_spar_avg[4][-1]]
sgd_se = [sgd_spar_se[1][-1],   sgd_spar_se[2][-1],   sgd_spar_se[3][-1],   sgd_spar_se[4][-1]]

grad =  [grad_spar_avg[1][-1],  grad_spar_avg[2][-1],  grad_spar_avg[3][-1],  grad_spar_avg[4][-1]]
grad_se = [grad_spar_se[1][-1],  grad_spar_se[2][-1],  grad_spar_se[3][-1],  grad_spar_se[4][-1]]

delta = [delta_spar_avg[1][-1], delta_spar_avg[2][-1], delta_spar_avg[3][-1], delta_spar_avg[4][-1], delta_spar_avg[5][-1]]
delta_se = [delta_spar_se[1][-1], delta_spar_se[2][-1], delta_spar_se[3][-1], delta_spar_se[4][-1], delta_spar_se[5][-1]]

adam =  [adam_spar_avg[1][-1],  adam_spar_avg[2][-1],  adam_spar_avg[3][-1],  adam_spar_avg[4][-1],  adam_spar_avg[5][-1]]
adam_se = [adam_spar_se[1][-1],  adam_spar_se[2][-1],  adam_spar_se[3][-1],  adam_spar_se[4][-1],  adam_spar_se[5][-1]]

ax2.plot(np.linspace(1, 5, 5)[:4], sgd, label='SGD', marker='o', c='darkred')
ax2.fill_between(np.linspace(1, 5, 5)[:4], np.subtract(sgd, sgd_se), np.add(sgd, sgd_se), color='lightcoral')

ax2.plot(np.linspace(1, 5, 5)[:4], grad, label='Adagrad', marker='^', c='darkgreen')
ax2.fill_between(np.linspace(1, 5, 5)[:4], np.subtract(grad, grad_se), np.add(grad, grad_se), color='lime')

ax2.plot(np.linspace(1, 5, 5), delta, label='Adadelta', marker='v', c='darkblue')
ax2.fill_between(np.linspace(1, 5, 5), np.subtract(delta, delta_se), np.add(delta, delta_se), color='lightsteelblue')

ax2.plot(np.linspace(1, 5, 5), adam, label='Adam', marker='s', c='purple')
ax2.fill_between(np.linspace(1, 5, 5), np.subtract(adam, adam_se), np.add(adam, adam_se), color='violet')
ax2.set_ylim([0, 0.8])
ax2.grid()
ax2.set_title('Sparsity Plot')


# Selectivity
sgd =   [sgd_selec_avg[1][-1],   sgd_selec_avg[2][-1],   sgd_selec_avg[3][-1],   sgd_selec_avg[4][-1]]
sgd_se = [sgd_selec_se[1][-1],   sgd_selec_se[2][-1],   sgd_selec_se[3][-1],   sgd_selec_se[4][-1]]

grad =  [grad_selec_avg[1][-1],  grad_selec_avg[2][-1],  grad_selec_avg[3][-1],  grad_selec_avg[4][-1]]
grad_se = [grad_selec_se[1][-1],  grad_selec_se[2][-1],  grad_selec_se[3][-1],  grad_selec_se[4][-1]]

delta = [delta_selec_avg[1][-1], delta_selec_avg[2][-1], delta_selec_avg[3][-1], delta_selec_avg[4][-1], delta_selec_avg[5][-1]]
delta_se = [delta_selec_se[1][-1], delta_selec_se[2][-1], delta_selec_se[3][-1], delta_selec_se[4][-1], delta_selec_se[5][-1]]

adam =  [adam_selec_avg[1][-1],  adam_selec_avg[2][-1],  adam_selec_avg[3][-1],  adam_selec_avg[4][-1],  adam_selec_avg[5][-1]]
adam_se = [adam_selec_se[1][-1],  adam_selec_se[2][-1],  adam_selec_se[3][-1],  adam_selec_se[4][-1],  adam_selec_se[5][-1]]

ax3.plot(np.linspace(1, 5, 5)[:4], sgd, label='SGD', marker='o', c='darkred')
ax3.fill_between(np.linspace(1, 5, 5)[:4], np.subtract(sgd, sgd_se), np.add(sgd, sgd_se), color='lightcoral')

ax3.plot(np.linspace(1, 5, 5)[:4], grad, label='Adagrad', marker='^', c='darkgreen')
ax3.fill_between(np.linspace(1, 5, 5)[:4], np.subtract(grad, grad_se), np.add(grad, grad_se), color='lime')

ax3.plot(np.linspace(1, 5, 5), delta, label='Adadelta', marker='v', c='darkblue')
ax3.fill_between(np.linspace(1, 5, 5), np.subtract(delta, delta_se), np.add(delta, delta_se), color='lightsteelblue')

ax3.plot(np.linspace(1, 5, 5), adam, label='Adam', marker='s', c='purple')
ax3.fill_between(np.linspace(1, 5, 5), np.subtract(adam, adam_se), np.add(adam, adam_se), color='violet')
ax3.set_ylim([0, 0.8])
ax3.grid()
ax3.set_title('Selectivity Plot')


ax3.legend(loc='upper center', bbox_to_anchor=(-0.73, -0.1),
          fancybox=True, shadow=True, ncol=4)

# %%
sgd =   [sgd_acc_avg[1][-1],   sgd_acc_avg[2][-1],   sgd_acc_avg[3][-1],   sgd_acc_avg[4][-1]]
sgd_se = [sgd_acc_se[1][-1],   sgd_acc_se[2][-1],   sgd_acc_se[3][-1],   sgd_acc_se[4][-1]]

grad =  [grad_acc_avg[1][-1],  grad_acc_avg[2][-1],  grad_acc_avg[3][-1],  grad_acc_avg[4][-1]]
grad_se = [grad_acc_se[1][-1],  grad_acc_se[2][-1],  grad_acc_se[3][-1],  grad_acc_se[4][-1]]

delta = [delta_acc_avg[1][-1], delta_acc_avg[2][-1], delta_acc_avg[3][-1], delta_acc_avg[4][-1], delta_acc_avg[5][-1]]
delta_se = [delta_acc_se[1][-1], delta_acc_se[2][-1], delta_acc_se[3][-1], delta_acc_se[4][-1], delta_acc_se[5][-1]]

adam =  [adam_acc_avg[1][-1],  adam_acc_avg[2][-1],  adam_acc_avg[3][-1],  adam_acc_avg[4][-1],  adam_acc_avg[5][-1]]
adam_se = [adam_acc_se[1][-1],  adam_acc_se[2][-1],  adam_acc_se[3][-1],  adam_acc_se[4][-1],  adam_acc_se[5][-1]]

print('accuracy')
print('sgd', sgd)
print('grad', grad)
print('delta', delta) 
print('adam', adam) 

sgd =   [sgd_spar_avg[1][-1],   sgd_spar_avg[2][-1],   sgd_spar_avg[3][-1],   sgd_spar_avg[4][-1]]
sgd_se = [sgd_spar_se[1][-1],   sgd_spar_se[2][-1],   sgd_spar_se[3][-1],   sgd_spar_se[4][-1]]

grad =  [grad_spar_avg[1][-1],  grad_spar_avg[2][-1],  grad_spar_avg[3][-1],  grad_spar_avg[4][-1]]
grad_se = [grad_spar_se[1][-1],  grad_spar_se[2][-1],  grad_spar_se[3][-1],  grad_spar_se[4][-1]]

delta = [delta_spar_avg[1][-1], delta_spar_avg[2][-1], delta_spar_avg[3][-1], delta_spar_avg[4][-1], delta_spar_avg[5][-1]]
delta_se = [delta_spar_se[1][-1], delta_spar_se[2][-1], delta_spar_se[3][-1], delta_spar_se[4][-1], delta_spar_se[5][-1]]

adam =  [adam_spar_avg[1][-1],  adam_spar_avg[2][-1],  adam_spar_avg[3][-1],  adam_spar_avg[4][-1],  adam_spar_avg[5][-1]]
adam_se = [adam_spar_se[1][-1],  adam_spar_se[2][-1],  adam_spar_se[3][-1],  adam_spar_se[4][-1],  adam_spar_se[5][-1]]

print('sparsity')
print(sgd)
print(grad)
print(delta) 
print(adam) 


sgd =   [sgd_selec_avg[1][-1],   sgd_selec_avg[2][-1],   sgd_selec_avg[3][-1],   sgd_selec_avg[4][-1]]
sgd_se = [sgd_selec_se[1][-1],   sgd_selec_se[2][-1],   sgd_selec_se[3][-1],   sgd_selec_se[4][-1]]

grad =  [grad_selec_avg[1][-1],  grad_selec_avg[2][-1],  grad_selec_avg[3][-1],  grad_selec_avg[4][-1]]
grad_se = [grad_selec_se[1][-1],  grad_selec_se[2][-1],  grad_selec_se[3][-1],  grad_selec_se[4][-1]]

delta = [delta_selec_avg[1][-1], delta_selec_avg[2][-1], delta_selec_avg[3][-1], delta_selec_avg[4][-1], delta_selec_avg[5][-1]]
delta_se = [delta_selec_se[1][-1], delta_selec_se[2][-1], delta_selec_se[3][-1], delta_selec_se[4][-1], delta_selec_se[5][-1]]

adam =  [adam_selec_avg[1][-1],  adam_selec_avg[2][-1],  adam_selec_avg[3][-1],  adam_selec_avg[4][-1],  adam_selec_avg[5][-1]]
adam_se = [adam_selec_se[1][-1],  adam_selec_se[2][-1],  adam_selec_se[3][-1],  adam_selec_se[4][-1],  adam_selec_se[5][-1]]

print('selectivity')
print(sgd)
print(grad)
print(delta) 
print(adam)
# Out:
# accuracy
# sgd [0.9765, 0.9776666666666666, 0.9741666666666666, 0.9431333333333334]
# grad [0.9809666666666667, 0.9808666666666667, 0.9778333333333333, 0.6812333333333335]
# delta [0.9822000000000001, 0.9826666666666667, 0.9806666666666667, 0.9788, 0.9721666666666667]
# adam [0.9812333333333333, 0.9812666666666666, 0.9817, 0.9795333333333334, 0.9804666666666666]
# sparsity
# [0.23802719016869864, 0.15272832289338112, 0.13709811452362275, 0.21925771671036878]
# [0.6077317794164022, 0.45443516969680786, 0.4300392236974504, 0.4158516153693199]
# [0.33128176132837933, 0.26889123022556305, 0.3291494796673457, 0.3867641016840935, 0.4059029410282771]
# [0.3149465123812358, 0.33605895439783734, 0.3903885881106059, 0.4298166558146477, 0.45131186445554095]
# selectivity
# [0.32797224164211114, 0.26528425786207094, 0.24956499293689646, 0.3439066111307721]
# [0.6542860693736374, 0.5842035180680063, 0.5216083587784329, 0.42689807307506306]
# ...
