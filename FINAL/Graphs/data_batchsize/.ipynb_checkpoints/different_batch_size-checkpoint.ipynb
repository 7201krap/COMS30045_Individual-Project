# %%
import matplotlib.pyplot as plt
import numpy as np
import re
import ast 
import torch

# %%
def test_val_extractor(file_name):    
    # get accuracy from sparsity.txt
    test_val_accumulator = list()
    with open(file_name) as fi:
        for i, line in enumerate(fi):
            if i == 0:
                line = ast.literal_eval(line)
                test_val_accumulator = line
                
    # return list of test accuracy 
    return test_val_accumulator[:30]

# %%
def selectivity_val_extractor(file_name):
    selectivity_average = 0
    selectivity_std = 0
    with open(file_name) as fi:
        for i, line in enumerate(fi):
            if i == 1:
                selectivity_average = ast.literal_eval(line)
            if i == 2:
                selectivity_std = ast.literal_eval(line)
    return selectivity_average[:30], selectivity_std[:30]

# %%
def sparsity_val_extractor(file_name):
    sparsity_average = 0
    with open(file_name) as fi:
        for i, line in enumerate(fi):
            if i == 1:
                sparsity_average = ast.literal_eval(line)
    return sparsity_average[:30]

# %%
def all_plotter(test_b1, sparsity_b1, selectivity_b1, test_b50, sparsity_b50, selectivity_b50, location='best'):
    fig, ax = plt.subplots(figsize=(12, 10))
    
    ax.plot(np.linspace(0.0, 30.0, num=30), test_b1, label='batch_size 1', c='royalblue')
    ax.plot(np.linspace(0.0, 30.0, num=30), sparsity_b1, label='batch_size 1 sparsity', c='cornflowerblue')
    ax.plot(np.linspace(0.0, 30.0, num=30), selectivity_b1, label='batch_size 1 selectivity', c='lightsteelblue')
    
    ax.plot(np.linspace(0.0, 30.0, num=30), test_b50, label='batch_size 50', c='indigo')
    ax.plot(np.linspace(0.0, 30.0, num=30), sparsity_b50, label='batch_size 50 sparsity', c='darkorchid')
    ax.plot(np.linspace(0.0, 30.0, num=30), selectivity_b50, label='batch_size 50 selectivity', c='violet')
    
    ax.set_ylim([-0.2,1.2])
    ax.legend(loc=location, bbox_to_anchor=(1, 0.5))
    plt.show()

# %% [markdown]
# # Adadelta

# %%
sparsity_b1 = sparsity_val_extractor('sparsity_batchsize_1_Adadelta.txt')
sparsity_b50 = sparsity_val_extractor('sparsity_batchsize_50_Adadelta.txt')

selectivity_b1, selectivity_b1 = selectivity_val_extractor('selectivity_batchsize_1_Adadelta.txt')
selectivity_b50, selectivity_b50 = selectivity_val_extractor('selectivity_batchsize_50_Adadelta.txt')

test_b1 = test_val_extractor('sparsity_batchsize_1_Adadelta.txt')
test_b50 = test_val_extractor('sparsity_batchsize_50_Adadelta.txt')

all_plotter(test_b1, sparsity_b1, selectivity_b1, test_b50, sparsity_b50, selectivity_b50)

# %% [markdown]
# # Adagrad

# %%
sparsity_b1 = sparsity_val_extractor('sparsity_batchsize_1_Adagrad.txt')
sparsity_b50 = sparsity_val_extractor('sparsity_batchsize_50_Adagrad.txt')

selectivity_b1, selectivity_b1 = selectivity_val_extractor('selectivity_batchsize_1_Adagrad.txt')
selectivity_b50, selectivity_b50 = selectivity_val_extractor('selectivity_batchsize_50_Adagrad.txt')

test_b1 = test_val_extractor('sparsity_batchsize_1_Adagrad.txt')
test_b50 = test_val_extractor('sparsity_batchsize_50_Adagrad.txt')

all_plotter(test_b1, sparsity_b1, selectivity_b1, test_b50, sparsity_b50, selectivity_b50)

# %% [markdown]
# # SGD

# %%
sparsity_b1 = sparsity_val_extractor('sparsity_batchsize_1_SGD.txt')
sparsity_b50 = sparsity_val_extractor('sparsity_batchsize_50_SGD.txt')

selectivity_b1, selectivity_b1 = selectivity_val_extractor('selectivity_batchsize_1_SGD.txt')
selectivity_b50, selectivity_b50 = selectivity_val_extractor('selectivity_batchsize_50_SGD.txt')

test_b1 = test_val_extractor('sparsity_batchsize_1_SGD.txt')
test_b50 = test_val_extractor('sparsity_batchsize_50_SGD.txt')

all_plotter(test_b1, sparsity_b1, selectivity_b1, test_b50, sparsity_b50, selectivity_b50)

# %% [markdown]
# # Adam

# %%
sparsity_b1 = sparsity_val_extractor('sparsity_batchsize_1_Adam.txt')
sparsity_b50 = sparsity_val_extractor('sparsity_batchsize_50_Adam.txt')

selectivity_b1, selectivity_b1 = selectivity_val_extractor('selectivity_batchsize_1_Adam.txt')
selectivity_b50, selectivity_b50 = selectivity_val_extractor('selectivity_batchsize_50_Adam.txt')

test_b1 = test_val_extractor('sparsity_batchsize_1_Adam.txt')
test_b50 = test_val_extractor('sparsity_batchsize_50_Adam.txt')

all_plotter(test_b1, sparsity_b1, selectivity_b1, test_b50, sparsity_b50, selectivity_b50)
