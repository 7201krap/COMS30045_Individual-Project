# %%
import matplotlib.pyplot as plt
import numpy as np
import re
import ast 
import torch

# %%
def test_val_extractor(file_name):    
    test_val_accumulator = list()
    with open(file_name) as fi:
        for i, line in enumerate(fi):
            if i == 0:
                line = ast.literal_eval(line)
                test_val_accumulator.append(line)
    
#     print("\ntest_val_accumulator: ", test_val_accumulator)
    return test_val_accumulator

# %%
def sparsity_val_extractor(file_name):
    sparsity_accumulator = list()
    with open(file_name) as fi:
        for i, line in enumerate(fi):
            if i == 1:
                line = ast.literal_eval(line)
                sparsity_accumulator.append(line)
    
    return sparsity_accumulator

# %%
def selectivity_val_extractor(file_name):
    selectivity_average_accumulator = list()
    selectivity_std_accumulator = list()
    with open(file_name) as fi:
        for i, line in enumerate(fi):
            if i == 2:
                line = ast.literal_eval(line)
                selectivity_average_accumulator.append(line)
            if i == 3:
                line = ast.literal_eval(line)
                selectivity_std_accumulator.append(line)
            
    return selectivity_average_accumulator, selectivity_std_accumulator

# %%
def all_plotter(__list__, test_acc_list, sparsity_list, selectivity_average_list, selectivity_std_list, location='best'):
    fig, ax = plt.subplots(figsize=(7, 7))
    ax.plot(__list__, test_acc_list, marker='s', label='test accuracy', c='r')
    ax.plot(__list__, sparsity_list, marker='v', label='sparsity', c='g')
    ax.errorbar(__list__, selectivity_average_list, selectivity_std_list, marker='^', label='selectivity', c='b')
    ax.set_ylim([-0.2,1.2])
    ax.legend(loc=location)
    ax.grid()
    plt.show()

# %%
hidden_layer_neurons = [64, 128, 256, 384, 512, 768, 1024]

# %% [markdown]
# # Graph

# %%
def plotter(optimizer_name, flag=False):
    test_vals  = test_val_extractor(f'{optimizer_name}_50_50.txt')
    sparsities = sparsity_val_extractor(f'{optimizer_name}_50_50.txt')
    selectivity_average, selectivity_std = selectivity_val_extractor(f"{optimizer_name}_50_50.txt")
    
    if flag==False:
        all_plotter(hidden_layer_neurons, test_vals, sparsities, selectivity_average, selectivity_std, 'lower right')
    
    if flag==True:
        return test_vals, sparsities, selectivity_average, selectivity_std

# %%
test_acc_sgd,      spar_sgd,      selec_avg_sgd,      selec_std_sgd      = plotter('sgd', flag=True)
test_acc_Adadelta, spar_Adadelta, selec_avg_Adadelta, selec_std_Adadelta = plotter('adadelta', flag=True)
test_acc_Adagrad,  spar_Adagrad,  selec_avg_Adagrad,  selec_std_Adagrad  = plotter('adagrad', flag=True)
test_acc_Adam    , spar_Adam    , selec_avg_Adam    , selec_std_Adam     = plotter('adam', flag=True)

# %%
test_acc_sgd
# Out:
# [[0.9696, 0.9713, 0.9711, 0.9683, 0.9676, 0.968, 0.9664]]

# %% [markdown]
# # Plot all in one

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(21,7))

# Test accuracy 
ax1.plot(hidden_layer_neurons, test_acc_sgd[0], marker='o', label='sgd accuracy', c='red')
ax1.plot(hidden_layer_neurons, test_acc_Adadelta[0], marker='o', label='adadelta accuracy', c='blue')
ax1.plot(hidden_layer_neurons, test_acc_Adagrad[0], marker='o', label='adagrad accuracy', c='green')
ax1.plot(hidden_layer_neurons, test_acc_Adam[0], marker='o', label='adam accuracy', c='violet')

# Sparsity 
ax2.plot(hidden_layer_neurons, spar_sgd[0], marker='o', label='sgd sparsity', c='red')
ax2.plot(hidden_layer_neurons, spar_Adadelta[0], marker='o', label='adadelta sparsity', c='blue')
ax2.plot(hidden_layer_neurons, spar_Adagrad[0], marker='o', label='adagrad sparsity', c='green')
ax2.plot(hidden_layer_neurons, spar_Adam[0], marker='o', label='adam sparsity', c='violet')

# Selectivity
ax3.plot(hidden_layer_neurons, selec_avg_sgd[0], marker='o', label='sgd selectivity', c='red')
ax3.plot(hidden_layer_neurons, selec_avg_Adadelta[0], marker='o', label='adadelta selectivity', c='blue')
ax3.plot(hidden_layer_neurons, selec_avg_Adagrad[0], marker='o', label='adagrad selectivity', c='green')
ax3.plot(hidden_layer_neurons, selec_avg_Adam[0], marker='o', label='adam selectivity', c='violet')

ax1.set_ylim([0.85,1.0])
ax2.set_ylim([0,1.0])
ax3.set_ylim([0,1.0])

ax1.legend(loc='best')
ax2.legend(loc='best')
ax3.legend(loc='best')

ax1.set_title('Accuracy')
ax2.set_title('Sparsity')
ax3.set_title('Selectivity')

ax1.grid()
ax2.grid()
ax3.grid()

plt.show()

# %% [markdown]
# # Accuracy x Sparsity (or Selectivity)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14,7))

# Accuracy x Sparsity 
ax1.plot(hidden_layer_neurons, [a * b for a, b in zip(test_acc_sgd[0], spar_sgd[0])], 
         label='SGD', marker='o', c='red')
ax1.plot(hidden_layer_neurons, [a * b for a, b in zip(test_acc_Adadelta[0], spar_Adadelta[0])], 
         label='Adadelta', marker='o',c='blue')
ax1.plot(hidden_layer_neurons, [a * b for a, b in zip(test_acc_Adagrad[0], spar_Adagrad[0])], 
         label='Adagrad', marker='o',c='green')
ax1.plot(hidden_layer_neurons, [a * b for a, b in zip(test_acc_Adam[0], spar_Adam[0])], 
         label='Adam', marker='o',c='violet')
ax1.set_ylim([0, 1.0])

ax1.set_title('Accuracy x Sparsity')
ax1.grid()
ax1.legend(loc='lower left')

# Accuracy x Selectivity   
ax2.plot(hidden_layer_neurons, [a * b for a, b in zip(test_acc_sgd[0], selec_avg_sgd[0])], 
         label='SGD', marker='o',c='red')
ax2.plot(hidden_layer_neurons, [a * b for a, b in zip(test_acc_Adadelta[0], selec_avg_Adadelta[0])], 
         label='Adadelta', marker='o',c='blue')
ax2.plot(hidden_layer_neurons, [a * b for a, b in zip(test_acc_Adagrad[0], selec_avg_Adagrad[0])], 
         label='Adagrad', marker='o',c='green')
ax2.plot(hidden_layer_neurons, [a * b for a, b in zip(test_acc_Adam[0], selec_avg_Adam[0])], 
         label='Adam', marker='o',c='violet')
ax2.set_ylim([0, 1])

ax2.set_title('Accuracy x Selectivity')
ax2.grid()
ax2.legend(loc='lower left')

plt.show()

# %% [markdown]
# # Compare

# %%
def compare(optimizer_name):
    print(f'\n==============={optimizer_name}===============')
    test_vals, sparsities, selectivity_average, selectivity_std = plotter(optimizer_name, flag=True)
    print(f"{optimizer_name} first (64): Test acc={test_vals[0]:.3f}, Spar={sparsities[0]:.3f}, Selec avg={selectivity_average[0]:.3f}, Selec std={selectivity_std[0]:.3f}")
    print(f"{optimizer_name} last(1024): Test acc={test_vals[-1]:.3f}, Spar={sparsities[-1]:.3f}, Selec avg={selectivity_average[-1]:.3f}, Selec std={selectivity_std[-1]:.3f}")
    print()
    print("test deviation: 1024 - 64(original):", test_vals[-1] - test_vals[0])
    print("sparsity deviation: 1024 - 64(original):", sparsities[-1] - sparsities[0])
    print("selectivity deviation: 1024 - 64(original):", selectivity_average[-1] - selectivity_average[0])
    print()
    print("test % difference: 1024 / 64(original):", (test_vals[-1] / test_vals[0]) * 100)
    print("sparsity % difference: 1024 / 64(original):", (sparsities[-1] / sparsities[0]) * 100)
    print("selectivity % difference: 1024 / 64(original):", (selectivity_average[-1] / selectivity_average[0]) * 100)

# %%
compare('SGD')
compare('Adadelta')
compare('Adagrad')
compare('Adam')

# %% [markdown]
# # SGD

# %%
plotter('SGD')

# %% [markdown]
# # Adadelta

# %%
plotter('Adadelta')

# %% [markdown]
# # Adagrad

# %%
plotter('Adagrad')

# %% [markdown]
# # Adam

# %%
plotter('Adam')
