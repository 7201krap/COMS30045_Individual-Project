# %% [markdown]
# <a href="https://colab.research.google.com/github/7201krap/PYTORCH_project/blob/main/FINAL/Code/base_model_4_opti/sparsity_testing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
from torchvision import transforms
import torchvision.datasets as datasets
import matplotlib.pyplot as plt
import numpy as np

# %%
torch.manual_seed(1234)
np.random.seed(1234)

# %%
mnist_trainset = datasets.MNIST(root='./data', train=True, 
                                download=True, 
                                transform=transforms.Compose([transforms.ToTensor()]))

mnist_testset  = datasets.MNIST(root='./data', 
                                train=False, 
                                download=True, 
                                transform=transforms.Compose([transforms.ToTensor()]))

train_dataloader = torch.utils.data.DataLoader(mnist_trainset, 
                                               batch_size=50, 
                                               shuffle=True)

test_dataloader  = torch.utils.data.DataLoader(mnist_testset, 
                                               batch_size=50, 
                                               shuffle=False)

print("Training dataset size: ", len(mnist_trainset))
print("Testing dataset size: ",  len(mnist_testset))
# Out:
# Training dataset size:  60000
# Testing dataset size:  10000

# %%
# Define the model 
class Model(torch.nn.Module):
    def __init__(self):
        super(Model, self).__init__()
        self.linear_1 = torch.nn.Linear(784, 256)
        self.linear_2 = torch.nn.Linear(256, 10)
        self.sigmoid  = torch.nn.Sigmoid()

    def forward(self, x):
        x = x.reshape(x.size(0), -1)
        x = self.linear_1(x)
        x = self.sigmoid(x)
        pred = self.linear_2(x)

        return pred

# %%
def get_activation(model):    
    def hook(module, input, output):
        model.layer_activations = output
    return hook

# %%
# adagrad 
model_adagrad = Model()
model_adagrad.sigmoid.register_forward_hook(get_activation(model_adagrad))
optimizer_adagrad  = torch.optim.Adagrad(model_adagrad.parameters(), lr=0.1)

# adadelta
model_adadelta = Model()
model_adadelta.sigmoid.register_forward_hook(get_activation(model_adadelta))
optimizer_adadelta = torch.optim.Adadelta(model_adadelta.parameters(), lr=1)

# adam
model_adam = Model()
model_adam.sigmoid.register_forward_hook(get_activation(model_adam))
optimizer_adam = torch.optim.Adam(model_adam.parameters(), lr=0.001)


# SGD 
model_sgd = Model()
model_sgd.sigmoid.register_forward_hook(get_activation(model_sgd))
optimizer_sgd      = torch.optim.SGD(model_sgd.parameters(), lr=0.1)

# %%
no_epochs = 30
def sparsity_trainer(optimizer, model):

    # reset the model 

    criterion = torch.nn.CrossEntropyLoss()
    train_loss = list()
    test_loss  = list()
    test_acc   = list()
    final_spareness = list()

    # define activation list 

    best_test_loss = 1

    for epoch in range(no_epochs):
        total_train_loss = 0
        total_test_loss = 0

        hidden_layer_activation_list = list()

        # training
        # set up training mode 
        model.train()

        for itr, (image, label) in enumerate(train_dataloader):

            optimizer.zero_grad()

            pred = model(image)

            loss = criterion(pred, label)
            total_train_loss += loss.item()

            loss.backward()
            optimizer.step()

        total_train_loss = total_train_loss / (itr + 1)
        train_loss.append(total_train_loss)

        # testing 
        # change to evaluation mode 
        model.eval()
        total = 0
        for itr, (image, label) in enumerate(test_dataloader):

            pred = model(image)

            loss = criterion(pred, label)
            total_test_loss += loss.item()

            # we now need softmax because we are testing.
            pred = torch.nn.functional.softmax(pred, dim=1)
            for i, p in enumerate(pred):
                if label[i] == torch.max(p.data, 0)[1]:
                    total = total + 1

            # Print/Append activation of the hidden layer 
            # print(model.layer_activations.shape)
            hidden_layer_activation_list.append(model.layer_activations)
        
        # this conains activations for all epochs 
        final_spareness.append(hidden_layer_activation_list)

        # caculate accuracy 
        accuracy = total / len(mnist_testset)

        # append accuracy here
        test_acc.append(accuracy)

        # append test loss here 
        total_test_loss = total_test_loss / (itr + 1)
        test_loss.append(total_test_loss)

        print('\nEpoch: {}/{}, Train Loss: {:.8f}, Test Loss: {:.8f}, Test Accuracy: {:.8f}'.format(epoch + 1, no_epochs, total_train_loss, total_test_loss, accuracy))

        if total_test_loss < best_test_loss:
            best_test_loss = total_test_loss
            print("Saving the model state dictionary for Epoch: {} with Test loss: {:.8f}".format(epoch + 1, total_test_loss))
            torch.save(model.state_dict(), "model.dth")

    sparseness_list = list()

    for single_epoch_spareness in final_spareness:

        hidden_layer_activation_list = single_epoch_spareness
        hidden_layer_activation_list = torch.stack(hidden_layer_activation_list)
        layer_activations_list = torch.reshape(hidden_layer_activation_list, (10000, 256))

        layer_activations_list = torch.abs(layer_activations_list)  # modified 
        num_neurons = layer_activations_list.shape[1]
        population_sparseness = (np.sqrt(num_neurons) - (torch.sum(layer_activations_list, dim=1) / torch.sqrt(torch.sum(layer_activations_list ** 2, dim=1)))) / (np.sqrt(num_neurons) - 1)
        mean_sparseness_per_epoch = torch.mean(population_sparseness)

        sparseness_list.append(mean_sparseness_per_epoch)

    return test_acc, sparseness_list

# %%
print("\n===== Entering SGD optimizer =====\n")
sgd_test_acc, sgd_sparseness_list           = sparsity_trainer(optimizer=optimizer_sgd,
                                                               model=model_sgd)

print("\n===== Entering Adagrad optimizer =====\n")
adagrad_test_acc, adagrad_sparseness_list   = sparsity_trainer(optimizer=optimizer_adagrad,
                                                               model=model_adagrad)

print("\n===== Entering Adadelta optimizer =====\n")
adadelta_test_acc, adadelta_sparseness_list = sparsity_trainer(optimizer=optimizer_adadelta,
                                                               model=model_adadelta)

print("\n===== Entering Adam optimizer =====\n")
adam_test_acc, adam_sparseness_list = sparsity_trainer(optimizer=optimizer_adam,
                                                               model=model_adam)
# Out:
# ===== Entering SGD optimizer =====
#
#
# Epoch: 1/30, Train Loss: 0.77014264, Test Loss: 0.36701960, Test Accuracy: 0.89910000
# Saving the model state dictionary for Epoch: 1 with Test loss: 0.36701960
#
# Epoch: 2/30, Train Loss: 0.34717686, Test Loss: 0.30738459, Test Accuracy: 0.91190000
# Saving the model state dictionary for Epoch: 2 with Test loss: 0.30738459
#
# Epoch: 3/30, Train Loss: 0.30732483, Test Loss: 0.28202964, Test Accuracy: 0.91920000
# Saving the model state dictionary for Epoch: 3 with Test loss: 0.28202964
#
# Epoch: 4/30, Train Loss: 0.28470957, Test Loss: 0.26738453, Test Accuracy: 0.92340000
# Saving the model state dictionary for Epoch: 4 with Test loss: 0.26738453
#
# Epoch: 5/30, Train Loss: 0.26611404, Test Loss: 0.25192591, Test Accuracy: 0.92850000
# Saving the model state dictionary for Epoch: 5 with Test loss: 0.25192591
#
# Epoch: 6/30, Train Loss: 0.24947860, Test Loss: 0.24040385, Test Accuracy: 0.93060000
# Saving the model state dictionary for Epoch: 6 with Test loss: 0.24040385
#
# Epoch: 7/30, Train Loss: 0.23380982, Test Loss: 0.21960505, Test Accuracy: 0.93730000
# Saving the model state dictionary for Epoch: 7 with Test loss: 0.21960505
#
# Epoch: 8/30, Train Loss: 0.21806011, Test Loss: 0.20676307, Test Accuracy: 0.94120000
# Saving the model state dictionary for Epoch: 8 with Test loss: 0.20676307
#
# Epoch: 9/30, Train Loss: 0.20409072, Test Loss: 0.19645491, Test Accuracy: 0.94430000
# Saving the model state dictionary for Epoch: 9 with Test loss: 0.19645491
#
# Epoch: 10/30, Train Loss: 0.19185066, Test Loss: 0.18493871, Test Accuracy: 0.94680000
# Saving the model state dictionary for Epoch: 10 with Test loss: 0.18493871
#
# Epoch: 11/30, Train Loss: 0.18012594, Test Loss: 0.18012329, Test Accuracy: 0.94820000
# Saving the model state dictionary for Epoch: 11 with Test loss: 0.18012329
#
# Epoch: 12/30, Train Loss: 0.16983751, Test Loss: 0.16863950, Test Accuracy: 0.95030000
# Saving the model state dictionary for Epoch: 12 with Test loss: 0.16863950
#
# Epoch: 13/30, Train Loss: 0.16059776, Test Loss: 0.15834870, Test Accuracy: 0.95300000
# Saving the model state dictionary for Epoch: 13 with Test loss: 0.15834870
#
# Epoch: 14/30, Train Loss: 0.15224879, Test Loss: 0.15155062, Test Accuracy: 0.95660000
# Saving the model state dictionary for Epoch: 14 with Test loss: 0.15155062
#
# Epoch: 15/30, Train Loss: 0.14463973, Test Loss: 0.14697802, Test Accuracy: 0.95790000
# Saving the model state dictionary for Epoch: 15 with Test loss: 0.14697802
#
# Epoch: 16/30, Train Loss: 0.13744488, Test Loss: 0.14107044, Test Accuracy: 0.95790000
# Saving the model state dictionary for Epoch: 16 with Test loss: 0.14107044
#
# Epoch: 17/30, Train Loss: 0.13128996, Test Loss: 0.13714553, Test Accuracy: 0.95960000
# Saving the model state dictionary for Epoch: 17 with Test loss: 0.13714553
#
# Epoch: 18/30, Train Loss: 0.12515858, Test Loss: 0.13097585, Test Accuracy: 0.96030000
# Saving the model state dictionary for Epoch: 18 with Test loss: 0.13097585
#
# Epoch: 19/30, Train Loss: 0.11968963, Test Loss: 0.12549428, Test Accuracy: 0.96310000
# Saving the model state dictionary for Epoch: 19 with Test loss: 0.12549428
#
# Epoch: 20/30, Train Loss: 0.11464411, Test Loss: 0.12302676, Test Accuracy: 0.96420000
# Saving the model state dictionary for Epoch: 20 with Test loss: 0.12302676
#
# Epoch: 21/30, Train Loss: 0.10970054, Test Loss: 0.12089144, Test Accuracy: 0.96490000
# Saving the model state dictionary for Epoch: 21 with Test loss: 0.12089144
#
# Epoch: 22/30, Train Loss: 0.10565501, Test Loss: 0.11496056, Test Accuracy: 0.96630000
# Saving the model state dictionary for Epoch: 22 with Test loss: 0.11496056
#
# Epoch: 23/30, Train Loss: 0.10158822, Test Loss: 0.11225218, Test Accuracy: 0.96720000
# Saving the model state dictionary for Epoch: 23 with Test loss: 0.11225218
#
# Epoch: 24/30, Train Loss: 0.09784295, Test Loss: 0.10855564, Test Accuracy: 0.96700000
# Saving the model state dictionary for Epoch: 24 with Test loss: 0.10855564
#
# Epoch: 25/30, Train Loss: 0.09413514, Test Loss: 0.10565454, Test Accuracy: 0.96810000
# Saving the model state dictionary for Epoch: 25 with Test loss: 0.10565454
#
# Epoch: 26/30, Train Loss: 0.09095708, Test Loss: 0.10307910, Test Accuracy: 0.96950000
# Saving the model state dictionary for Epoch: 26 with Test loss: 0.10307910
#
# Epoch: 27/30, Train Loss: 0.08756196, Test Loss: 0.10580064, Test Accuracy: 0.96730000
#
# Epoch: 28/30, Train Loss: 0.08477972, Test Loss: 0.10064730, Test Accuracy: 0.96960000
# Saving the model state dictionary for Epoch: 28 with Test loss: 0.10064730
#
# Epoch: 29/30, Train Loss: 0.08192667, Test Loss: 0.09737126, Test Accuracy: 0.97040000
# Saving the model state dictionary for Epoch: 29 with Test loss: 0.09737126
#
# Epoch: 30/30, Train Loss: 0.07938247, Test Loss: 0.09574135, Test Accuracy: 0.97200000
# Saving the model state dictionary for Epoch: 30 with Test loss: 0.09574135
#
# ===== Entering Adagrad optimizer =====
#
#
# Epoch: 1/30, Train Loss: 0.23213363, Test Loss: 0.11738745, Test Accuracy: 0.96450000
# Saving the model state dictionary for Epoch: 1 with Test loss: 0.11738745
#
# Epoch: 2/30, Train Loss: 0.09432254, Test Loss: 0.09438058, Test Accuracy: 0.97050000
# Saving the model state dictionary for Epoch: 2 with Test loss: 0.09438058
#
# Epoch: 3/30, Train Loss: 0.06605093, Test Loss: 0.08347996, Test Accuracy: 0.97360000
# Saving the model state dictionary for Epoch: 3 with Test loss: 0.08347996
#
# Epoch: 4/30, Train Loss: 0.05007579, Test Loss: 0.07760865, Test Accuracy: 0.97510000
# Saving the model state dictionary for Epoch: 4 with Test loss: 0.07760865
#
# Epoch: 5/30, Train Loss: 0.03951054, Test Loss: 0.07566961, Test Accuracy: 0.97650000
# Saving the model state dictionary for Epoch: 5 with Test loss: 0.07566961
#
# Epoch: 6/30, Train Loss: 0.03173047, Test Loss: 0.07237263, Test Accuracy: 0.97640000
# Saving the model state dictionary for Epoch: 6 with Test loss: 0.07237263
#
# Epoch: 7/30, Train Loss: 0.02616244, Test Loss: 0.06778589, Test Accuracy: 0.97810000
# Saving the model state dictionary for Epoch: 7 with Test loss: 0.06778589
#
# Epoch: 8/30, Train Loss: 0.02178134, Test Loss: 0.06883968, Test Accuracy: 0.97850000
#
# Epoch: 9/30, Train Loss: 0.01843629, Test Loss: 0.06679303, Test Accuracy: 0.97960000
# Saving the model state dictionary for Epoch: 9 with Test loss: 0.06679303
#
# Epoch: 10/30, Train Loss: 0.01560085, Test Loss: 0.06731879, Test Accuracy: 0.97920000
#
# Epoch: 11/30, Train Loss: 0.01329781, Test Loss: 0.06802900, Test Accuracy: 0.97880000
#
# Epoch: 12/30, Train Loss: 0.01164608, Test Loss: 0.06810071, Test Accuracy: 0.98000000
#
# Epoch: 13/30, Train Loss: 0.01021801, Test Loss: 0.06746099, Test Accuracy: 0.97910000
#
# Epoch: 14/30, Train Loss: 0.00896264, Test Loss: 0.06798226, Test Accuracy: 0.97940000
#
# Epoch: 15/30, Train Loss: 0.00801887, Test Loss: 0.06754481, Test Accuracy: 0.97970000
#
# Epoch: 16/30, Train Loss: 0.00718256, Test Loss: 0.06780689, Test Accuracy: 0.97970000
#
# Epoch: 17/30, Train Loss: 0.00644142, Test Loss: 0.06731923, Test Accuracy: 0.97980000
#
# Epoch: 18/30, Train Loss: 0.00586928, Test Loss: 0.06824956, Test Accuracy: 0.97960000
#
# Epoch: 19/30, Train Loss: 0.00533875, Test Loss: 0.06847706, Test Accuracy: 0.97930000
#
# Epoch: 20/30, Train Loss: 0.00488933, Test Loss: 0.06781764, Test Accuracy: 0.97970000
#
# Epoch: 21/30, Train Loss: 0.00453271, Test Loss: 0.06828868, Test Accuracy: 0.97990000
#
# Epoch: 22/30, Train Loss: 0.00418392, Test Loss: 0.06862948, Test Accuracy: 0.97970000
#
# Epoch: 23/30, Train Loss: 0.00387636, Test Loss: 0.06845760, Test Accuracy: 0.97920000
#
# Epoch: 24/30, Train Loss: 0.00362709, Test Loss: 0.06827736, Test Accuracy: 0.97970000
#
# Epoch: 25/30, Train Loss: 0.00339161, Test Loss: 0.06864117, Test Accuracy: 0.97970000
#
# Epoch: 26/30, Train Loss: 0.00317656, Test Loss: 0.06907862, Test Accuracy: 0.97970000
#
# Epoch: 27/30, Train Loss: 0.00298970, Test Loss: 0.06913919, Test Accuracy: 0.98000000
#
# Epoch: 28/30, Train Loss: 0.00282543, Test Loss: 0.06861829, Test Accuracy: 0.97990000
#
# Epoch: 29/30, Train Loss: 0.00266976, Test Loss: 0.06979744, Test Accuracy: 0.97970000
#
# Epoch: 30/30, Train Loss: 0.00253352, Test Loss: 0.06947169, Test Accuracy: 0.97980000
#
# ===== Entering Adadelta optimizer =====
#
#
# Epoch: 1/30, Train Loss: 0.43465602, Test Loss: 0.23754450, Test Accuracy: 0.93010000
# Saving the model state dictionary for Epoch: 1 with Test loss: 0.23754450
#
# Epoch: 2/30, Train Loss: 0.21463192, Test Loss: 0.17415550, Test Accuracy: 0.94890000
# Saving the model state dictionary for Epoch: 2 with Test loss: 0.17415550
#
# Epoch: 3/30, Train Loss: 0.15344012, Test Loss: 0.13496506, Test Accuracy: 0.96010000
# Saving the model state dictionary for Epoch: 3 with Test loss: 0.13496506
#
# Epoch: 4/30, Train Loss: 0.11881636, Test Loss: 0.11434331, Test Accuracy: 0.96530000
# Saving the model state dictionary for Epoch: 4 with Test loss: 0.11434331
#
# Epoch: 5/30, Train Loss: 0.09621407, Test Loss: 0.10077715, Test Accuracy: 0.96840000
# Saving the model state dictionary for Epoch: 5 with Test loss: 0.10077715
#
# Epoch: 6/30, Train Loss: 0.08041784, Test Loss: 0.09106292, Test Accuracy: 0.97110000
# Saving the model state dictionary for Epoch: 6 with Test loss: 0.09106292
#
# Epoch: 7/30, Train Loss: 0.06931621, Test Loss: 0.08190573, Test Accuracy: 0.97490000
# Saving the model state dictionary for Epoch: 7 with Test loss: 0.08190573
#
# Epoch: 8/30, Train Loss: 0.05923928, Test Loss: 0.07753055, Test Accuracy: 0.97430000
# Saving the model state dictionary for Epoch: 8 with Test loss: 0.07753055
#
# Epoch: 9/30, Train Loss: 0.05182350, Test Loss: 0.07170408, Test Accuracy: 0.97760000
# Saving the model state dictionary for Epoch: 9 with Test loss: 0.07170408
#
# Epoch: 10/30, Train Loss: 0.04605516, Test Loss: 0.07137207, Test Accuracy: 0.97810000
# Saving the model state dictionary for Epoch: 10 with Test loss: 0.07137207
#
# Epoch: 11/30, Train Loss: 0.04031866, Test Loss: 0.07223707, Test Accuracy: 0.97810000
#
# Epoch: 12/30, Train Loss: 0.03616931, Test Loss: 0.06729644, Test Accuracy: 0.97870000
# Saving the model state dictionary for Epoch: 12 with Test loss: 0.06729644
#
# Epoch: 13/30, Train Loss: 0.03176121, Test Loss: 0.06472166, Test Accuracy: 0.97960000
# Saving the model state dictionary for Epoch: 13 with Test loss: 0.06472166
#
# Epoch: 14/30, Train Loss: 0.02841431, Test Loss: 0.06610497, Test Accuracy: 0.97930000
#
# Epoch: 15/30, Train Loss: 0.02567987, Test Loss: 0.06432862, Test Accuracy: 0.98040000
# Saving the model state dictionary for Epoch: 15 with Test loss: 0.06432862
#
# Epoch: 16/30, Train Loss: 0.02276090, Test Loss: 0.06192144, Test Accuracy: 0.98140000
# Saving the model state dictionary for Epoch: 16 with Test loss: 0.06192144
#
# Epoch: 17/30, Train Loss: 0.02032123, Test Loss: 0.05953446, Test Accuracy: 0.98100000
# Saving the model state dictionary for Epoch: 17 with Test loss: 0.05953446
#
# Epoch: 18/30, Train Loss: 0.01803010, Test Loss: 0.06387561, Test Accuracy: 0.97990000
#
# Epoch: 19/30, Train Loss: 0.01634830, Test Loss: 0.06042919, Test Accuracy: 0.98050000
#
# Epoch: 20/30, Train Loss: 0.01473810, Test Loss: 0.05992018, Test Accuracy: 0.98110000
#
# Epoch: 21/30, Train Loss: 0.01308995, Test Loss: 0.06133645, Test Accuracy: 0.98010000
#
# Epoch: 22/30, Train Loss: 0.01185582, Test Loss: 0.06170358, Test Accuracy: 0.98130000
#
# Epoch: 23/30, Train Loss: 0.01090155, Test Loss: 0.06228406, Test Accuracy: 0.98070000
#
# Epoch: 24/30, Train Loss: 0.00967477, Test Loss: 0.06354126, Test Accuracy: 0.98060000
#
# Epoch: 25/30, Train Loss: 0.00880745, Test Loss: 0.06126407, Test Accuracy: 0.98110000
#
# Epoch: 26/30, Train Loss: 0.00794088, Test Loss: 0.06400530, Test Accuracy: 0.98030000
#
# Epoch: 27/30, Train Loss: 0.00725229, Test Loss: 0.06111668, Test Accuracy: 0.98180000
#
# Epoch: 28/30, Train Loss: 0.00666438, Test Loss: 0.06136767, Test Accuracy: 0.98080000
#
# Epoch: 29/30, Train Loss: 0.00594389, Test Loss: 0.06086021, Test Accuracy: 0.98150000
#
# Epoch: 30/30, Train Loss: 0.00552422, Test Loss: 0.06189005, Test Accuracy: 0.98100000
#
# ===== Entering Adam optimizer =====
#
#
# Epoch: 1/30, Train Loss: 0.42916302, Test Loss: 0.23028137, Test Accuracy: 0.93280000
# Saving the model state dictionary for Epoch: 1 with Test loss: 0.23028137
#
# Epoch: 2/30, Train Loss: 0.19802081, Test Loss: 0.16388693, Test Accuracy: 0.94960000
# Saving the model state dictionary for Epoch: 2 with Test loss: 0.16388693
#
# Epoch: 3/30, Train Loss: 0.14365007, Test Loss: 0.13233918, Test Accuracy: 0.96000000
# Saving the model state dictionary for Epoch: 3 with Test loss: 0.13233918
#
# Epoch: 4/30, Train Loss: 0.10980483, Test Loss: 0.10587702, Test Accuracy: 0.96710000
# Saving the model state dictionary for Epoch: 4 with Test loss: 0.10587702
#
# Epoch: 5/30, Train Loss: 0.08673050, Test Loss: 0.09290349, Test Accuracy: 0.97150000
# Saving the model state dictionary for Epoch: 5 with Test loss: 0.09290349
#
# Epoch: 6/30, Train Loss: 0.06973320, Test Loss: 0.08070870, Test Accuracy: 0.97390000
# Saving the model state dictionary for Epoch: 6 with Test loss: 0.08070870
#
# Epoch: 7/30, Train Loss: 0.05664280, Test Loss: 0.07941083, Test Accuracy: 0.97540000
# Saving the model state dictionary for Epoch: 7 with Test loss: 0.07941083
#
# Epoch: 8/30, Train Loss: 0.04610804, Test Loss: 0.07569271, Test Accuracy: 0.97490000
# Saving the model state dictionary for Epoch: 8 with Test loss: 0.07569271

# %%
fig=plt.figure(figsize=(20, 10))
plt.plot(np.arange(1, no_epochs+1), adagrad_sparseness_list, label="Adagrad Sparseness", color='g')
plt.plot(np.arange(1, no_epochs+1), adadelta_sparseness_list, label="Adadelta Sparseness", color='b')
plt.plot(np.arange(1, no_epochs+1), adam_sparseness_list, label="Adam Sparseness", color='y')
plt.plot(np.arange(1, no_epochs+1), sgd_sparseness_list, label="SGD Sparseness", color='r')
plt.xlabel('Epochs')
plt.ylabel('Sparsity')
plt.ylim(0, 1)
plt.title("Sparsity Plot")
plt.legend(loc='best')
plt.show()

# %%
fig=plt.figure(figsize=(20, 10))
plt.plot(np.arange(1, no_epochs+1), adagrad_test_acc, label="Adagrad Test Accuracy", color='g')
plt.plot(np.arange(1, no_epochs+1), adadelta_test_acc, label="Adadelta Test Accuracy", color='b')
plt.plot(np.arange(1, no_epochs+1), adam_test_acc, label="Adam Test Accuracy", color='y')
plt.plot(np.arange(1, no_epochs+1), sgd_test_acc, label="SGD Test Accuracy", color='r')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.ylim(0.85, 1)
plt.title("Accuracy Plot")
plt.legend(loc='best')
plt.show()
