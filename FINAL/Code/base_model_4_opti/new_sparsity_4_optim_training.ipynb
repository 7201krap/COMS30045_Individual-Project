# %% [markdown]
# <a href="https://colab.research.google.com/github/7201krap/PYTORCH_project/blob/main/new_sparsity_4_optim_training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
from torchvision import transforms
import torchvision.datasets as datasets
import matplotlib.pyplot as plt
import numpy as np
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
torch.manual_seed(1234)
np.random.seed(1234)

# %%
mnist_trainset = datasets.MNIST(root='./data', train=True, 
                                download=True, 
                                transform=transforms.Compose([transforms.ToTensor()]))

mnist_testset  = datasets.MNIST(root='./data', 
                                train=False, 
                                download=True, 
                                transform=transforms.Compose([transforms.ToTensor()]))

train_dataloader = torch.utils.data.DataLoader(mnist_trainset, 
                                               batch_size=50, 
                                               shuffle=True)

test_dataloader  = torch.utils.data.DataLoader(mnist_testset, 
                                               batch_size=50, 
                                               shuffle=False)

print("Training dataset size: ", len(mnist_trainset))
print("Testing dataset size: ",  len(mnist_testset))
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ./data/MNIST/raw/train-images-idx3-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ./data/MNIST/raw/train-images-idx3-ubyte.gz to ./data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ./data/MNIST/raw/train-labels-idx1-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ./data/MNIST/raw/train-labels-idx1-ubyte.gz to ./data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw/t10k-images-idx3-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ./data/MNIST/raw/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw
# Processing...
# Done!
# Training dataset size:  60000
# Testing dataset size:  10000
# /usr/local/lib/python3.7/dist-packages/torchvision/datasets/mnist.py:480: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /pytorch/torch/csrc/utils/tensor_numpy.cpp:141.)
#   return torch.from_numpy(parsed.astype(m[2], copy=False)).view(*s)

# %%
# ************* modify this section for later use *************
# Define the model 
class Model(torch.nn.Module):
    def __init__(self):
        super(Model, self).__init__()

        # modify this section for later use 
        self.linear_1 = torch.nn.Linear(784, 256)
        self.linear_2 = torch.nn.Linear(256, 10)
        self.sigmoid12  = torch.nn.Sigmoid()

        self.layer_activations = dict()

    def forward(self, x):

        # modify this section for later use 
        x = x.reshape(x.size(0), -1)
        x = self.linear_1(x)
        x = self.sigmoid12(x)
        pred = self.linear_2(x)
        return pred
# ************* modify this section for later use *************

# %%
def get_activation(model, layer_name):    
    def hook(module, input, output):
        model.layer_activations[layer_name] = output
    return hook

# %%
def sparsity_calculator(final_spareness):
    sparseness_list = list()
    for single_epoch_spareness in final_spareness:

        hidden_layer_activation_list = single_epoch_spareness
        hidden_layer_activation_list = torch.stack(hidden_layer_activation_list)
        layer_activations_list = torch.reshape(hidden_layer_activation_list, (60000, 256))

        layer_activations_list = torch.abs(layer_activations_list)  # modified 
        num_neurons = layer_activations_list.shape[1]
        population_sparseness = (np.sqrt(num_neurons) - (torch.sum(layer_activations_list, dim=1) / torch.sqrt(torch.sum(layer_activations_list ** 2, dim=1)))) / (np.sqrt(num_neurons) - 1)
        mean_sparseness_per_epoch = torch.mean(population_sparseness)

        sparseness_list.append(mean_sparseness_per_epoch)

    return sparseness_list

# %%
def model_factory(optimizer_name):
    '''
    optimizer_name : choose one of Adagrad, Adadelta, SGD, and Adam 

    '''
    my_model = Model()
    print("my_model:", my_model)
    my_model.to(device)

    # ************* modify this section for later use *************
    # modify this section for later use 
    my_model.sigmoid12.register_forward_hook(get_activation(my_model, 's12'))
    # ************* modify this section for later use *************

    if optimizer_name == 'Adadelta':
        my_optimizer = torch.optim.Adadelta(my_model.parameters(), lr=1.0)

    elif optimizer_name == 'Adagrad':
        my_optimizer = torch.optim.Adagrad(my_model.parameters(), lr=0.1)

    elif optimizer_name == 'SGD':
        my_optimizer = torch.optim.SGD(my_model.parameters(), lr=0.1)

    elif optimizer_name == 'Adam':
        my_optimizer = torch.optim.Adam(my_model.parameters(), lr=0.001)

    else:
        print("ERROR")
    
    print("my_optimizer:", my_optimizer)
    test_acc, sparseness_list = sparsity_trainer(optimizer=my_optimizer, model=my_model)

    print(test_acc)
    print(sparseness_list)

    # ************* modify this section for later use *************
    file_saver = open(f"sparsity_4_optim_training_{optimizer_name}.txt", "w")
    # ************* modify this section for later use *************
    file_saver.write(str(test_acc)+'\n'+str(sparseness_list)+'\n\n')
    file_saver.close()

    # ************* modify this section for later use *************
    if optimizer_name == 'Adadelta':
        # !cp sparsity_4_optim_training_Adadelta.txt /content/drive/MyDrive
    
    elif optimizer_name == 'Adagrad':
        # !cp sparsity_4_optim_training_Adagrad.txt /content/drive/MyDrive

    elif optimizer_name == 'SGD':
        # !cp sparsity_4_optim_training_SGD.txt /content/drive/MyDrive

    elif optimizer_name == 'Adam':
        # !cp sparsity_4_optim_training_Adam.txt /content/drive/MyDrive
    # ************* modify this section for later use *************

    else:
        print("ERROR")

# %%
def sparsity_trainer(optimizer, model):
    criterion = torch.nn.CrossEntropyLoss()
    no_epochs = 30

    train_loss = list()
    test_loss  = list()
    test_acc   = list()

    # ************* modify this section for later use *************
    final_spareness_12 = list()
    # ************* modify this section for later use *************

    best_test_loss = 1
    for epoch in range(no_epochs):
        total_train_loss = 0
        total_test_loss = 0

        # ************* modify this section for later use *************
        hidden_layer_activation_list_12 = list()
        # ************* modify this section for later use *************

        # training
        # set up training mode 
        model.train()
        for itr, (image, label) in enumerate(train_dataloader):
            image, label = image.to(device), label.to(device)

            optimizer.zero_grad()

            pred = model(image)

            loss = criterion(pred, label)
            total_train_loss += loss.item()

            loss.backward()
            optimizer.step()

            # ***************** sparsity calculation ***************** #
            hidden_layer_activation_list_12.append(model.layer_activations['s12'])

        # this conains activations for all epochs 
        final_spareness_12.append(hidden_layer_activation_list_12)
        # ***************** sparsity calculation ***************** #

        total_train_loss = total_train_loss / (itr + 1)
        train_loss.append(total_train_loss)

        # testing 
        # change to evaluation mode 
        model.eval()
        total = 0
        for itr, (image, label) in enumerate(test_dataloader):
            image, label = image.to(device), label.to(device)

            pred = model(image)

            loss = criterion(pred, label)
            total_test_loss += loss.item()

            # we now need softmax because we are testing.
            pred = torch.nn.functional.softmax(pred, dim=1)
            for i, p in enumerate(pred):
                if label[i] == torch.max(p.data, 0)[1]:
                    total = total + 1

        # caculate accuracy 
        accuracy = total / len(mnist_testset)

        # append accuracy here
        test_acc.append(accuracy)

        # append test loss here 
        total_test_loss = total_test_loss / (itr + 1)
        test_loss.append(total_test_loss)

        print('\nEpoch: {}/{}, Train Loss: {:.8f}, Test Loss: {:.8f}, Test Accuracy: {:.8f}'.format(epoch + 1, no_epochs, total_train_loss, total_test_loss, accuracy))

        if total_test_loss < best_test_loss:
            best_test_loss = total_test_loss
            print("Saving the model state dictionary for Epoch: {} with Test loss: {:.8f}".format(epoch + 1, total_test_loss))
            torch.save(model.state_dict(), "model.dth")


    # ***************** sparsity calculation ***************** #
    sparsity_list12 = sparsity_calculator(final_spareness_12)

    print(sparsity_list12)

    average_sparsity = list()
    for i in range(no_epochs):
        average_sparsity.append( (sparsity_list12[i].item()) / 1 )
    # ***************** sparsity calculation ***************** #

    print("average_sparsity:", average_sparsity)

    return test_acc, average_sparsity

# %% [markdown]
# # Adadelta

# %%
model_factory('Adadelta')
# Out:
# my_model: Model(
#   (linear_1): Linear(in_features=784, out_features=256, bias=True)
#   (linear_2): Linear(in_features=256, out_features=10, bias=True)
#   (sigmoid12): Sigmoid()
# )
# my_optimizer: Adadelta (
# Parameter Group 0
#     eps: 1e-06
#     lr: 1.0
#     rho: 0.9
#     weight_decay: 0
# )
#
# Epoch: 1/30, Train Loss: 0.43482734, Test Loss: 0.25056328, Test Accuracy: 0.92680000
# Saving the model state dictionary for Epoch: 1 with Test loss: 0.25056328
#
# Epoch: 2/30, Train Loss: 0.21552304, Test Loss: 0.17478676, Test Accuracy: 0.94670000
# Saving the model state dictionary for Epoch: 2 with Test loss: 0.17478676
#
# Epoch: 3/30, Train Loss: 0.15641612, Test Loss: 0.13820602, Test Accuracy: 0.95740000
# Saving the model state dictionary for Epoch: 3 with Test loss: 0.13820602
#
# Epoch: 4/30, Train Loss: 0.12157690, Test Loss: 0.11924306, Test Accuracy: 0.96300000
# Saving the model state dictionary for Epoch: 4 with Test loss: 0.11924306
#
# Epoch: 5/30, Train Loss: 0.09919056, Test Loss: 0.09831684, Test Accuracy: 0.96860000
# Saving the model state dictionary for Epoch: 5 with Test loss: 0.09831684
#
# Epoch: 6/30, Train Loss: 0.08336800, Test Loss: 0.09016022, Test Accuracy: 0.97190000
# Saving the model state dictionary for Epoch: 6 with Test loss: 0.09016022
#
# Epoch: 7/30, Train Loss: 0.07088853, Test Loss: 0.08719795, Test Accuracy: 0.97320000
# Saving the model state dictionary for Epoch: 7 with Test loss: 0.08719795
#
# Epoch: 8/30, Train Loss: 0.06153279, Test Loss: 0.07796417, Test Accuracy: 0.97520000
# Saving the model state dictionary for Epoch: 8 with Test loss: 0.07796417
#
# Epoch: 9/30, Train Loss: 0.05413196, Test Loss: 0.07215949, Test Accuracy: 0.97700000
# Saving the model state dictionary for Epoch: 9 with Test loss: 0.07215949
#
# Epoch: 10/30, Train Loss: 0.04688475, Test Loss: 0.07165624, Test Accuracy: 0.97650000
# Saving the model state dictionary for Epoch: 10 with Test loss: 0.07165624
#
# Epoch: 11/30, Train Loss: 0.04203057, Test Loss: 0.07021961, Test Accuracy: 0.97680000
# Saving the model state dictionary for Epoch: 11 with Test loss: 0.07021961
#
# Epoch: 12/30, Train Loss: 0.03695013, Test Loss: 0.07518681, Test Accuracy: 0.97650000
#
# Epoch: 13/30, Train Loss: 0.03292638, Test Loss: 0.06627988, Test Accuracy: 0.97940000
# Saving the model state dictionary for Epoch: 13 with Test loss: 0.06627988
#
# Epoch: 14/30, Train Loss: 0.02905201, Test Loss: 0.06293267, Test Accuracy: 0.98030000
# Saving the model state dictionary for Epoch: 14 with Test loss: 0.06293267
#
# Epoch: 15/30, Train Loss: 0.02590495, Test Loss: 0.06158078, Test Accuracy: 0.98020000
# Saving the model state dictionary for Epoch: 15 with Test loss: 0.06158078
#
# Epoch: 16/30, Train Loss: 0.02330130, Test Loss: 0.06297808, Test Accuracy: 0.97920000
#
# Epoch: 17/30, Train Loss: 0.02085337, Test Loss: 0.05992444, Test Accuracy: 0.98110000
# Saving the model state dictionary for Epoch: 17 with Test loss: 0.05992444
#
# Epoch: 18/30, Train Loss: 0.01860578, Test Loss: 0.06213609, Test Accuracy: 0.98040000
#
# Epoch: 19/30, Train Loss: 0.01655125, Test Loss: 0.06208906, Test Accuracy: 0.98020000
#
# Epoch: 20/30, Train Loss: 0.01466604, Test Loss: 0.05816114, Test Accuracy: 0.98150000
# Saving the model state dictionary for Epoch: 20 with Test loss: 0.05816114
#
# Epoch: 21/30, Train Loss: 0.01332531, Test Loss: 0.06010362, Test Accuracy: 0.98110000
#
# Epoch: 22/30, Train Loss: 0.01189256, Test Loss: 0.05997108, Test Accuracy: 0.98140000
#
# Epoch: 23/30, Train Loss: 0.01074991, Test Loss: 0.06014585, Test Accuracy: 0.98140000
#
# Epoch: 24/30, Train Loss: 0.00972292, Test Loss: 0.06088047, Test Accuracy: 0.98090000
#
# Epoch: 25/30, Train Loss: 0.00874879, Test Loss: 0.06209752, Test Accuracy: 0.98090000
#
# Epoch: 26/30, Train Loss: 0.00798673, Test Loss: 0.06282990, Test Accuracy: 0.98130000
#
# Epoch: 27/30, Train Loss: 0.00720308, Test Loss: 0.05958402, Test Accuracy: 0.98200000
#
# Epoch: 28/30, Train Loss: 0.00660240, Test Loss: 0.06011285, Test Accuracy: 0.98150000
#
# Epoch: 29/30, Train Loss: 0.00585278, Test Loss: 0.05981551, Test Accuracy: 0.98100000
#
# Epoch: 30/30, Train Loss: 0.00549971, Test Loss: 0.06033825, Test Accuracy: 0.98150000
# [tensor(0.1503, grad_fn=<MeanBackward0>), tensor(0.2254, grad_fn=<MeanBackward0>), tensor(0.2614, grad_fn=<MeanBackward0>), tensor(0.2820, grad_fn=<MeanBackward0>), tensor(0.2939, grad_fn=<MeanBackward0>), tensor(0.3013, grad_fn=<MeanBackward0>), tensor(0.3079, grad_fn=<MeanBackward0>), tensor(0.3123, grad_fn=<MeanBackward0>), tensor(0.3149, grad_fn=<MeanBackward0>), tensor(0.3185, grad_fn=<MeanBackward0>), tensor(0.3194, grad_fn=<MeanBackward0>), tensor(0.3222, grad_fn=<MeanBackward0>), tensor(0.3222, grad_fn=<MeanBackward0>), tensor(0.3237, grad_fn=<MeanBackward0>), tensor(0.3242, grad_fn=<MeanBackward0>), tensor(0.3227, grad_fn=<MeanBackward0>), tensor(0.3246, grad_fn=<MeanBackward0>), tensor(0.3254, grad_fn=<MeanBackward0>), tensor(0.3264, grad_fn=<MeanBackward0>), tensor(0.3254, grad_fn=<MeanBackward0>), tensor(0.3249, grad_fn=<MeanBackward0>), tensor(0.3254, grad_fn=<MeanBackward0>), tensor(0.3256, grad_fn=<MeanBackward0>), tensor(0.3248, grad_fn=<MeanBackward0>), tensor(0.3256, grad_fn=<MeanBackward0>), tensor(0.3248, grad_fn=<MeanBackward0>), tensor(0.3253, grad_fn=<MeanBackward0>), tensor(0.3254, grad_fn=<MeanBackward0>), tensor(0.3251, grad_fn=<MeanBackward0>), tensor(0.3249, grad_fn=<MeanBackward0>)]
# average_sparsity: [0.15029017627239227, 0.22535523772239685, 0.2614114284515381, 0.2820297181606293, 0.29386210441589355, 0.30131229758262634, 0.30790767073631287, 0.3123033344745636, 0.31488463282585144, 0.3184674382209778, 0.3193831443786621, 0.32216307520866394, 0.3221874237060547, 0.32371214032173157, 0.32415771484375, 0.3226933479309082, 0.32460740208625793, 0.3253915011882782, 0.3263701796531677, 0.3253672420978546, 0.3248648941516876, 0.3253776431083679, 0.3256395161151886, 0.324758380651474, 0.32559341192245483, 0.3248141407966614, 0.3253192603588104, 0.3253854811191559, 0.3250991404056549, 0.324880450963974]
# [0.9268, 0.9467, 0.9574, 0.963, 0.9686, 0.9719, 0.9732, 0.9752, 0.977, 0.9765, 0.9768, 0.9765, 0.9794, 0.9803, 0.9802, 0.9792, 0.9811, 0.9804, 0.9802, 0.9815, 0.9811, 0.9814, 0.9814, 0.9809, 0.9809, 0.9813, 0.982, 0.9815, 0.981, 0.9815]
# [0.15029017627239227, 0.22535523772239685, 0.2614114284515381, 0.2820297181606293, 0.29386210441589355, 0.30131229758262634, 0.30790767073631287, 0.3123033344745636, 0.31488463282585144, 0.3184674382209778, 0.3193831443786621, 0.32216307520866394, 0.3221874237060547, 0.32371214032173157, 0.32415771484375, 0.3226933479309082, 0.32460740208625793, 0.3253915011882782, 0.3263701796531677, 0.3253672420978546, 0.3248648941516876, 0.3253776431083679, 0.3256395161151886, 0.324758380651474, 0.32559341192245483, 0.3248141407966614, 0.3253192603588104, 0.3253854811191559, 0.3250991404056549, 0.324880450963974]

# %% [markdown]
# # Adagrad

# %%
model_factory('Adagrad')
# Out:
# my_model: Model(
#   (linear_1): Linear(in_features=784, out_features=256, bias=True)
#   (linear_2): Linear(in_features=256, out_features=10, bias=True)
#   (sigmoid12): Sigmoid()
# )
# my_optimizer: Adagrad (
# Parameter Group 0
#     eps: 1e-10
#     initial_accumulator_value: 0
#     lr: 0.1
#     lr_decay: 0
#     weight_decay: 0
# )
#
# Epoch: 1/30, Train Loss: 0.23718886, Test Loss: 0.12977516, Test Accuracy: 0.95950000
# Saving the model state dictionary for Epoch: 1 with Test loss: 0.12977516
#
# Epoch: 2/30, Train Loss: 0.09642065, Test Loss: 0.10092658, Test Accuracy: 0.96840000
# Saving the model state dictionary for Epoch: 2 with Test loss: 0.10092658
#
# Epoch: 3/30, Train Loss: 0.06664428, Test Loss: 0.08550377, Test Accuracy: 0.97230000
# Saving the model state dictionary for Epoch: 3 with Test loss: 0.08550377
#
# Epoch: 4/30, Train Loss: 0.04915988, Test Loss: 0.07767118, Test Accuracy: 0.97540000
# Saving the model state dictionary for Epoch: 4 with Test loss: 0.07767118
#
# Epoch: 5/30, Train Loss: 0.03803864, Test Loss: 0.07441393, Test Accuracy: 0.97520000
# Saving the model state dictionary for Epoch: 5 with Test loss: 0.07441393
#
# Epoch: 6/30, Train Loss: 0.03025761, Test Loss: 0.07197807, Test Accuracy: 0.97610000
# Saving the model state dictionary for Epoch: 6 with Test loss: 0.07197807
#
# Epoch: 7/30, Train Loss: 0.02474231, Test Loss: 0.06945075, Test Accuracy: 0.97720000
# Saving the model state dictionary for Epoch: 7 with Test loss: 0.06945075
#
# Epoch: 8/30, Train Loss: 0.02030326, Test Loss: 0.06954807, Test Accuracy: 0.97740000
#
# Epoch: 9/30, Train Loss: 0.01700789, Test Loss: 0.06827952, Test Accuracy: 0.97770000
# Saving the model state dictionary for Epoch: 9 with Test loss: 0.06827952
#
# Epoch: 10/30, Train Loss: 0.01447830, Test Loss: 0.06662981, Test Accuracy: 0.97840000
# Saving the model state dictionary for Epoch: 10 with Test loss: 0.06662981
#
# Epoch: 11/30, Train Loss: 0.01241379, Test Loss: 0.06758368, Test Accuracy: 0.97830000
#
# Epoch: 12/30, Train Loss: 0.01059499, Test Loss: 0.06751415, Test Accuracy: 0.97830000
#
# Epoch: 13/30, Train Loss: 0.00921490, Test Loss: 0.06693609, Test Accuracy: 0.97910000
#
# Epoch: 14/30, Train Loss: 0.00811866, Test Loss: 0.06725046, Test Accuracy: 0.97900000
#
# Epoch: 15/30, Train Loss: 0.00709274, Test Loss: 0.06733680, Test Accuracy: 0.97830000
#
# Epoch: 16/30, Train Loss: 0.00636019, Test Loss: 0.06739756, Test Accuracy: 0.97910000
#
# Epoch: 17/30, Train Loss: 0.00572026, Test Loss: 0.06714072, Test Accuracy: 0.97890000
#
# Epoch: 18/30, Train Loss: 0.00518920, Test Loss: 0.06819753, Test Accuracy: 0.97870000
#
# Epoch: 19/30, Train Loss: 0.00469056, Test Loss: 0.06811867, Test Accuracy: 0.97850000
#
# Epoch: 20/30, Train Loss: 0.00426798, Test Loss: 0.06838907, Test Accuracy: 0.97900000
#
# Epoch: 21/30, Train Loss: 0.00393872, Test Loss: 0.06816522, Test Accuracy: 0.97920000
#
# Epoch: 22/30, Train Loss: 0.00362471, Test Loss: 0.06862192, Test Accuracy: 0.97940000
#
# Epoch: 23/30, Train Loss: 0.00334990, Test Loss: 0.06923180, Test Accuracy: 0.97910000
#
# Epoch: 24/30, Train Loss: 0.00311754, Test Loss: 0.06913381, Test Accuracy: 0.97880000
#
# Epoch: 25/30, Train Loss: 0.00290044, Test Loss: 0.06951448, Test Accuracy: 0.97890000
#
# Epoch: 26/30, Train Loss: 0.00272266, Test Loss: 0.06990538, Test Accuracy: 0.97910000
#
# Epoch: 27/30, Train Loss: 0.00254067, Test Loss: 0.07048355, Test Accuracy: 0.97900000
#
# Epoch: 28/30, Train Loss: 0.00239491, Test Loss: 0.06990519, Test Accuracy: 0.97950000
#
# Epoch: 29/30, Train Loss: 0.00226480, Test Loss: 0.07003555, Test Accuracy: 0.97920000
#
# Epoch: 30/30, Train Loss: 0.00213280, Test Loss: 0.07051157, Test Accuracy: 0.97940000
# [tensor(0.6677, grad_fn=<MeanBackward0>), tensor(0.6500, grad_fn=<MeanBackward0>), tensor(0.6409, grad_fn=<MeanBackward0>), tensor(0.6350, grad_fn=<MeanBackward0>), tensor(0.6314, grad_fn=<MeanBackward0>), tensor(0.6287, grad_fn=<MeanBackward0>), tensor(0.6254, grad_fn=<MeanBackward0>), tensor(0.6239, grad_fn=<MeanBackward0>), tensor(0.6213, grad_fn=<MeanBackward0>), tensor(0.6191, grad_fn=<MeanBackward0>), tensor(0.6176, grad_fn=<MeanBackward0>), tensor(0.6156, grad_fn=<MeanBackward0>), tensor(0.6142, grad_fn=<MeanBackward0>), tensor(0.6129, grad_fn=<MeanBackward0>), tensor(0.6113, grad_fn=<MeanBackward0>), tensor(0.6101, grad_fn=<MeanBackward0>), tensor(0.6091, grad_fn=<MeanBackward0>), tensor(0.6082, grad_fn=<MeanBackward0>), tensor(0.6068, grad_fn=<MeanBackward0>), tensor(0.6060, grad_fn=<MeanBackward0>), tensor(0.6047, grad_fn=<MeanBackward0>), tensor(0.6043, grad_fn=<MeanBackward0>), tensor(0.6031, grad_fn=<MeanBackward0>), tensor(0.6028, grad_fn=<MeanBackward0>), tensor(0.6020, grad_fn=<MeanBackward0>), tensor(0.6013, grad_fn=<MeanBackward0>), tensor(0.6010, grad_fn=<MeanBackward0>), tensor(0.6001, grad_fn=<MeanBackward0>), tensor(0.5999, grad_fn=<MeanBackward0>), tensor(0.5993, grad_fn=<MeanBackward0>)]
# average_sparsity: [0.6677160263061523, 0.6500390768051147, 0.6409025192260742, 0.6349623799324036, 0.6314451694488525, 0.6287227869033813, 0.6254186034202576, 0.6238889098167419, 0.62134850025177, 0.6190751194953918, 0.6176216006278992, 0.6155683398246765, 0.6142316460609436, 0.6129173040390015, 0.6113104820251465, 0.610136091709137, 0.6091098189353943, 0.6081664562225342, 0.6067577004432678, 0.6059694290161133, 0.6046584844589233, 0.6042684316635132, 0.6031368374824524, 0.6027711033821106, 0.6020296812057495, 0.6012812256813049, 0.6010290384292603, 0.6001312732696533, 0.5998842716217041, 0.5992931127548218]
# [0.9595, 0.9684, 0.9723, 0.9754, 0.9752, 0.9761, 0.9772, 0.9774, 0.9777, 0.9784, 0.9783, 0.9783, 0.9791, 0.979, 0.9783, 0.9791, 0.9789, 0.9787, 0.9785, 0.979, 0.9792, 0.9794, 0.9791, 0.9788, 0.9789, 0.9791, 0.979, 0.9795, 0.9792, 0.9794]
# [0.6677160263061523, 0.6500390768051147, 0.6409025192260742, 0.6349623799324036, 0.6314451694488525, 0.6287227869033813, 0.6254186034202576, 0.6238889098167419, 0.62134850025177, 0.6190751194953918, 0.6176216006278992, 0.6155683398246765, 0.6142316460609436, 0.6129173040390015, 0.6113104820251465, 0.610136091709137, 0.6091098189353943, 0.6081664562225342, 0.6067577004432678, 0.6059694290161133, 0.6046584844589233, 0.6042684316635132, 0.6031368374824524, 0.6027711033821106, 0.6020296812057495, 0.6012812256813049, 0.6010290384292603, 0.6001312732696533, 0.5998842716217041, 0.5992931127548218]

# %% [markdown]
# # SGD

# %%
model_factory('SGD')
# Out:
# my_model: Model(
#   (linear_1): Linear(in_features=784, out_features=256, bias=True)
#   (linear_2): Linear(in_features=256, out_features=10, bias=True)
#   (sigmoid12): Sigmoid()
# )
# my_optimizer: SGD (
# Parameter Group 0
#     dampening: 0
#     lr: 0.1
#     momentum: 0
#     nesterov: False
#     weight_decay: 0
# )
#
# Epoch: 1/30, Train Loss: 0.77229016, Test Loss: 0.36556621, Test Accuracy: 0.89740000
# Saving the model state dictionary for Epoch: 1 with Test loss: 0.36556621
#
# Epoch: 2/30, Train Loss: 0.34719833, Test Loss: 0.30601284, Test Accuracy: 0.91130000
# Saving the model state dictionary for Epoch: 2 with Test loss: 0.30601284
#
# Epoch: 3/30, Train Loss: 0.30693888, Test Loss: 0.28060609, Test Accuracy: 0.92130000
# Saving the model state dictionary for Epoch: 3 with Test loss: 0.28060609
#
# Epoch: 4/30, Train Loss: 0.28483134, Test Loss: 0.27108764, Test Accuracy: 0.92220000
# Saving the model state dictionary for Epoch: 4 with Test loss: 0.27108764
#
# Epoch: 5/30, Train Loss: 0.26674319, Test Loss: 0.24900326, Test Accuracy: 0.93030000
# Saving the model state dictionary for Epoch: 5 with Test loss: 0.24900326
#
# Epoch: 6/30, Train Loss: 0.24984935, Test Loss: 0.23398064, Test Accuracy: 0.93260000
# Saving the model state dictionary for Epoch: 6 with Test loss: 0.23398064
#
# Epoch: 7/30, Train Loss: 0.23336247, Test Loss: 0.22511649, Test Accuracy: 0.93520000
# Saving the model state dictionary for Epoch: 7 with Test loss: 0.22511649
#
# Epoch: 8/30, Train Loss: 0.21804447, Test Loss: 0.20816296, Test Accuracy: 0.94010000
# Saving the model state dictionary for Epoch: 8 with Test loss: 0.20816296
#
# Epoch: 9/30, Train Loss: 0.20462472, Test Loss: 0.19458867, Test Accuracy: 0.94520000
# Saving the model state dictionary for Epoch: 9 with Test loss: 0.19458867
#
# Epoch: 10/30, Train Loss: 0.19214305, Test Loss: 0.18808595, Test Accuracy: 0.94570000
# Saving the model state dictionary for Epoch: 10 with Test loss: 0.18808595
#
# Epoch: 11/30, Train Loss: 0.18089217, Test Loss: 0.17587552, Test Accuracy: 0.94900000
# Saving the model state dictionary for Epoch: 11 with Test loss: 0.17587552
#
# Epoch: 12/30, Train Loss: 0.17059864, Test Loss: 0.16796683, Test Accuracy: 0.94990000
# Saving the model state dictionary for Epoch: 12 with Test loss: 0.16796683
#
# Epoch: 13/30, Train Loss: 0.16099815, Test Loss: 0.15870854, Test Accuracy: 0.95330000
# Saving the model state dictionary for Epoch: 13 with Test loss: 0.15870854
#
# Epoch: 14/30, Train Loss: 0.15282047, Test Loss: 0.15348154, Test Accuracy: 0.95580000
# Saving the model state dictionary for Epoch: 14 with Test loss: 0.15348154
#
# Epoch: 15/30, Train Loss: 0.14522061, Test Loss: 0.14678260, Test Accuracy: 0.95770000
# Saving the model state dictionary for Epoch: 15 with Test loss: 0.14678260
#
# Epoch: 16/30, Train Loss: 0.13832390, Test Loss: 0.13840950, Test Accuracy: 0.96100000
# Saving the model state dictionary for Epoch: 16 with Test loss: 0.13840950
#
# Epoch: 17/30, Train Loss: 0.13196634, Test Loss: 0.13653209, Test Accuracy: 0.95970000
# Saving the model state dictionary for Epoch: 17 with Test loss: 0.13653209
#
# Epoch: 18/30, Train Loss: 0.12606080, Test Loss: 0.12942022, Test Accuracy: 0.96280000
# Saving the model state dictionary for Epoch: 18 with Test loss: 0.12942022
#
# Epoch: 19/30, Train Loss: 0.12032454, Test Loss: 0.12580063, Test Accuracy: 0.96360000
# Saving the model state dictionary for Epoch: 19 with Test loss: 0.12580063
#
# Epoch: 20/30, Train Loss: 0.11546896, Test Loss: 0.12108934, Test Accuracy: 0.96530000
# Saving the model state dictionary for Epoch: 20 with Test loss: 0.12108934
#
# Epoch: 21/30, Train Loss: 0.11083578, Test Loss: 0.11918581, Test Accuracy: 0.96410000
# Saving the model state dictionary for Epoch: 21 with Test loss: 0.11918581
#
# Epoch: 22/30, Train Loss: 0.10652338, Test Loss: 0.11451459, Test Accuracy: 0.96600000
# Saving the model state dictionary for Epoch: 22 with Test loss: 0.11451459
#
# Epoch: 23/30, Train Loss: 0.10224386, Test Loss: 0.11202619, Test Accuracy: 0.96680000
# Saving the model state dictionary for Epoch: 23 with Test loss: 0.11202619
#
# Epoch: 24/30, Train Loss: 0.09870039, Test Loss: 0.10751366, Test Accuracy: 0.96800000
# Saving the model state dictionary for Epoch: 24 with Test loss: 0.10751366
#
# Epoch: 25/30, Train Loss: 0.09506041, Test Loss: 0.10633760, Test Accuracy: 0.96880000
# Saving the model state dictionary for Epoch: 25 with Test loss: 0.10633760
#
# Epoch: 26/30, Train Loss: 0.09156718, Test Loss: 0.10264896, Test Accuracy: 0.96910000
# Saving the model state dictionary for Epoch: 26 with Test loss: 0.10264896
#
# Epoch: 27/30, Train Loss: 0.08833942, Test Loss: 0.10154048, Test Accuracy: 0.96900000
# Saving the model state dictionary for Epoch: 27 with Test loss: 0.10154048
#
# Epoch: 28/30, Train Loss: 0.08558544, Test Loss: 0.09941065, Test Accuracy: 0.97010000
# Saving the model state dictionary for Epoch: 28 with Test loss: 0.09941065
#
# Epoch: 29/30, Train Loss: 0.08267791, Test Loss: 0.09813298, Test Accuracy: 0.97020000
# Saving the model state dictionary for Epoch: 29 with Test loss: 0.09813298
#
# Epoch: 30/30, Train Loss: 0.07989562, Test Loss: 0.09521272, Test Accuracy: 0.97110000
# Saving the model state dictionary for Epoch: 30 with Test loss: 0.09521272
# [tensor(0.0564, grad_fn=<MeanBackward0>), tensor(0.0854, grad_fn=<MeanBackward0>), tensor(0.0954, grad_fn=<MeanBackward0>), tensor(0.1053, grad_fn=<MeanBackward0>), tensor(0.1153, grad_fn=<MeanBackward0>), tensor(0.1253, grad_fn=<MeanBackward0>), tensor(0.1349, grad_fn=<MeanBackward0>), tensor(0.1441, grad_fn=<MeanBackward0>), tensor(0.1528, grad_fn=<MeanBackward0>), tensor(0.1598, grad_fn=<MeanBackward0>), tensor(0.1665, grad_fn=<MeanBackward0>), tensor(0.1726, grad_fn=<MeanBackward0>), tensor(0.1775, grad_fn=<MeanBackward0>), tensor(0.1825, grad_fn=<MeanBackward0>), tensor(0.1869, grad_fn=<MeanBackward0>), tensor(0.1903, grad_fn=<MeanBackward0>), tensor(0.1939, grad_fn=<MeanBackward0>), tensor(0.1971, grad_fn=<MeanBackward0>), tensor(0.1999, grad_fn=<MeanBackward0>), tensor(0.2025, grad_fn=<MeanBackward0>), tensor(0.2046, grad_fn=<MeanBackward0>), tensor(0.2068, grad_fn=<MeanBackward0>), tensor(0.2087, grad_fn=<MeanBackward0>), tensor(0.2104, grad_fn=<MeanBackward0>), tensor(0.2122, grad_fn=<MeanBackward0>), tensor(0.2138, grad_fn=<MeanBackward0>), tensor(0.2151, grad_fn=<MeanBackward0>), tensor(0.2167, grad_fn=<MeanBackward0>), tensor(0.2180, grad_fn=<MeanBackward0>), tensor(0.2194, grad_fn=<MeanBackward0>)]
# average_sparsity: [0.056356754153966904, 0.08541419357061386, 0.09537645429372787, 0.10528265684843063, 0.11534861475229263, 0.12533506751060486, 0.13492539525032043, 0.14408989250659943, 0.1527518779039383, 0.159843310713768, 0.16648289561271667, 0.17257237434387207, 0.17747724056243896, 0.18246422708034515, 0.18685176968574524, 0.19026903808116913, 0.19391445815563202, 0.1971086859703064, 0.1998548060655594, 0.2024638056755066, 0.20463287830352783, 0.2067839503288269, 0.20868147909641266, 0.21039368212223053, 0.21222682297229767, 0.21377821266651154, 0.21505744755268097, 0.2167075127363205, 0.2180374711751938, 0.2194182276725769]
# [0.8974, 0.9113, 0.9213, 0.9222, 0.9303, 0.9326, 0.9352, 0.9401, 0.9452, 0.9457, 0.949, 0.9499, 0.9533, 0.9558, 0.9577, 0.961, 0.9597, 0.9628, 0.9636, 0.9653, 0.9641, 0.966, 0.9668, 0.968, 0.9688, 0.9691, 0.969, 0.9701, 0.9702, 0.9711]
# [0.056356754153966904, 0.08541419357061386, 0.09537645429372787, 0.10528265684843063, 0.11534861475229263, 0.12533506751060486, 0.13492539525032043, 0.14408989250659943, 0.1527518779039383, 0.159843310713768, 0.16648289561271667, 0.17257237434387207, 0.17747724056243896, 0.18246422708034515, 0.18685176968574524, 0.19026903808116913, 0.19391445815563202, 0.1971086859703064, 0.1998548060655594, 0.2024638056755066, 0.20463287830352783, 0.2067839503288269, 0.20868147909641266, 0.21039368212223053, 0.21222682297229767, 0.21377821266651154, 0.21505744755268097, 0.2167075127363205, 0.2180374711751938, 0.2194182276725769]

# %% [markdown]
# # Adam

# %%
model_factory('Adam')
# Out:
# my_model: Model(
#   (linear_1): Linear(in_features=784, out_features=256, bias=True)
#   (linear_2): Linear(in_features=256, out_features=10, bias=True)
#   (sigmoid12): Sigmoid()
# )
# my_optimizer: Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.001
#     weight_decay: 0
# )
#
# Epoch: 1/30, Train Loss: 0.43013016, Test Loss: 0.23038319, Test Accuracy: 0.93350000
# Saving the model state dictionary for Epoch: 1 with Test loss: 0.23038319
#
# Epoch: 2/30, Train Loss: 0.19845420, Test Loss: 0.16318714, Test Accuracy: 0.95180000
# Saving the model state dictionary for Epoch: 2 with Test loss: 0.16318714
#
# Epoch: 3/30, Train Loss: 0.14409275, Test Loss: 0.13112965, Test Accuracy: 0.96150000
# Saving the model state dictionary for Epoch: 3 with Test loss: 0.13112965
#
# Epoch: 4/30, Train Loss: 0.11007065, Test Loss: 0.10521115, Test Accuracy: 0.96910000
# Saving the model state dictionary for Epoch: 4 with Test loss: 0.10521115
#
# Epoch: 5/30, Train Loss: 0.08675428, Test Loss: 0.09378187, Test Accuracy: 0.97180000
# Saving the model state dictionary for Epoch: 5 with Test loss: 0.09378187
#
# Epoch: 6/30, Train Loss: 0.07006374, Test Loss: 0.08096124, Test Accuracy: 0.97590000
# Saving the model state dictionary for Epoch: 6 with Test loss: 0.08096124
#
# Epoch: 7/30, Train Loss: 0.05699459, Test Loss: 0.07811322, Test Accuracy: 0.97590000
# Saving the model state dictionary for Epoch: 7 with Test loss: 0.07811322
#
# Epoch: 8/30, Train Loss: 0.04634903, Test Loss: 0.07456356, Test Accuracy: 0.97660000
# Saving the model state dictionary for Epoch: 8 with Test loss: 0.07456356
#
# Epoch: 9/30, Train Loss: 0.03831605, Test Loss: 0.07117033, Test Accuracy: 0.97780000
# Saving the model state dictionary for Epoch: 9 with Test loss: 0.07117033
#
# Epoch: 10/30, Train Loss: 0.03116941, Test Loss: 0.06739555, Test Accuracy: 0.98000000
# Saving the model state dictionary for Epoch: 10 with Test loss: 0.06739555
#
# Epoch: 11/30, Train Loss: 0.02555423, Test Loss: 0.06667478, Test Accuracy: 0.97990000
# Saving the model state dictionary for Epoch: 11 with Test loss: 0.06667478
#
# Epoch: 12/30, Train Loss: 0.02080868, Test Loss: 0.06638725, Test Accuracy: 0.97950000
# Saving the model state dictionary for Epoch: 12 with Test loss: 0.06638725
#
# Epoch: 13/30, Train Loss: 0.01690935, Test Loss: 0.06281901, Test Accuracy: 0.97990000
# Saving the model state dictionary for Epoch: 13 with Test loss: 0.06281901
#
# Epoch: 14/30, Train Loss: 0.01330700, Test Loss: 0.06899784, Test Accuracy: 0.97890000
#
# Epoch: 15/30, Train Loss: 0.01106236, Test Loss: 0.06525876, Test Accuracy: 0.97980000
#
# Epoch: 16/30, Train Loss: 0.00848057, Test Loss: 0.06817348, Test Accuracy: 0.97920000
#
# Epoch: 17/30, Train Loss: 0.00698429, Test Loss: 0.06676263, Test Accuracy: 0.97960000
#
# Epoch: 18/30, Train Loss: 0.00547083, Test Loss: 0.06740024, Test Accuracy: 0.98010000
#
# Epoch: 19/30, Train Loss: 0.00480950, Test Loss: 0.07052146, Test Accuracy: 0.97950000
#
# Epoch: 20/30, Train Loss: 0.00362121, Test Loss: 0.07191904, Test Accuracy: 0.98000000
#
# Epoch: 21/30, Train Loss: 0.00258812, Test Loss: 0.07331077, Test Accuracy: 0.98060000
#
# Epoch: 22/30, Train Loss: 0.00234628, Test Loss: 0.07124675, Test Accuracy: 0.98020000
#
# Epoch: 23/30, Train Loss: 0.00173858, Test Loss: 0.07269171, Test Accuracy: 0.98110000
#
# Epoch: 24/30, Train Loss: 0.00202080, Test Loss: 0.07442364, Test Accuracy: 0.98050000
#
# Epoch: 25/30, Train Loss: 0.00109320, Test Loss: 0.07514408, Test Accuracy: 0.98110000
#
# Epoch: 26/30, Train Loss: 0.00076435, Test Loss: 0.07953331, Test Accuracy: 0.97950000
#
# Epoch: 27/30, Train Loss: 0.00227620, Test Loss: 0.08126477, Test Accuracy: 0.98090000
#
# Epoch: 28/30, Train Loss: 0.00053937, Test Loss: 0.08105319, Test Accuracy: 0.98060000
#
# Epoch: 29/30, Train Loss: 0.00035571, Test Loss: 0.08218981, Test Accuracy: 0.98100000
#
# Epoch: 30/30, Train Loss: 0.00033691, Test Loss: 0.08346478, Test Accuracy: 0.98130000
# [tensor(0.1610, grad_fn=<MeanBackward0>), tensor(0.2104, grad_fn=<MeanBackward0>), tensor(0.2309, grad_fn=<MeanBackward0>), tensor(0.2428, grad_fn=<MeanBackward0>), tensor(0.2511, grad_fn=<MeanBackward0>), tensor(0.2569, grad_fn=<MeanBackward0>), tensor(0.2611, grad_fn=<MeanBackward0>), tensor(0.2655, grad_fn=<MeanBackward0>), tensor(0.2677, grad_fn=<MeanBackward0>), tensor(0.2705, grad_fn=<MeanBackward0>), tensor(0.2728, grad_fn=<MeanBackward0>), tensor(0.2742, grad_fn=<MeanBackward0>), tensor(0.2754, grad_fn=<MeanBackward0>), tensor(0.2768, grad_fn=<MeanBackward0>), tensor(0.2778, grad_fn=<MeanBackward0>), tensor(0.2790, grad_fn=<MeanBackward0>), tensor(0.2804, grad_fn=<MeanBackward0>), tensor(0.2806, grad_fn=<MeanBackward0>), tensor(0.2815, grad_fn=<MeanBackward0>), tensor(0.2829, grad_fn=<MeanBackward0>), tensor(0.2826, grad_fn=<MeanBackward0>), tensor(0.2845, grad_fn=<MeanBackward0>), tensor(0.2842, grad_fn=<MeanBackward0>), tensor(0.2854, grad_fn=<MeanBackward0>), tensor(0.2861, grad_fn=<MeanBackward0>), tensor(0.2853, grad_fn=<MeanBackward0>), tensor(0.2874, grad_fn=<MeanBackward0>), tensor(0.2882, grad_fn=<MeanBackward0>), tensor(0.2865, grad_fn=<MeanBackward0>), tensor(0.2864, grad_fn=<MeanBackward0>)]
# average_sparsity: [0.16104082763195038, 0.21042154729366302, 0.2309374064207077, 0.24280038475990295, 0.2510928511619568, 0.25688430666923523, 0.26106828451156616, 0.2654922902584076, 0.26773086190223694, 0.270490437746048, 0.2727768123149872, 0.2742057740688324, 0.27544963359832764, 0.27680253982543945, 0.2778049409389496, 0.2789705991744995, 0.28037989139556885, 0.28055810928344727, 0.28152602910995483, 0.28292784094810486, 0.28256386518478394, 0.2845227122306824, 0.2842356860637665, 0.28535738587379456, 0.28613054752349854, 0.28534582257270813, 0.2874344289302826, 0.2881717085838318, 0.2865111231803894, 0.2863735854625702]
# [0.9335, 0.9518, 0.9615, 0.9691, 0.9718, 0.9759, 0.9759, 0.9766, 0.9778, 0.98, 0.9799, 0.9795, 0.9799, 0.9789, 0.9798, 0.9792, 0.9796, 0.9801, 0.9795, 0.98, 0.9806, 0.9802, 0.9811, 0.9805, 0.9811, 0.9795, 0.9809, 0.9806, 0.981, 0.9813]
# [0.16104082763195038, 0.21042154729366302, 0.2309374064207077, 0.24280038475990295, 0.2510928511619568, 0.25688430666923523, 0.26106828451156616, 0.2654922902584076, 0.26773086190223694, 0.270490437746048, 0.2727768123149872, 0.2742057740688324, 0.27544963359832764, 0.27680253982543945, 0.2778049409389496, 0.2789705991744995, 0.28037989139556885, 0.28055810928344727, 0.28152602910995483, 0.28292784094810486, 0.28256386518478394, 0.2845227122306824, 0.2842356860637665, 0.28535738587379456, 0.28613054752349854, 0.28534582257270813, 0.2874344289302826, 0.2881717085838318, 0.2865111231803894, 0.2863735854625702]
