# %% [markdown]
# <a href="https://colab.research.google.com/github/7201krap/PYTORCH_project/blob/main/sparsity_1_HL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
from torchvision import transforms
import torchvision.datasets as datasets
import matplotlib.pyplot as plt
import numpy as np
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
torch.manual_seed(1234)
np.random.seed(1234)

# %%
mnist_trainset = datasets.MNIST(root='./data', train=True, 
                                download=True, 
                                transform=transforms.Compose([transforms.ToTensor()]))

mnist_testset  = datasets.MNIST(root='./data', 
                                train=False, 
                                download=True, 
                                transform=transforms.Compose([transforms.ToTensor()]))

train_dataloader = torch.utils.data.DataLoader(mnist_trainset, 
                                               batch_size=50, 
                                               shuffle=True)

test_dataloader  = torch.utils.data.DataLoader(mnist_testset, 
                                               batch_size=50, 
                                               shuffle=False)

print("Training dataset size: ", len(mnist_trainset))
print("Testing dataset size: ",  len(mnist_testset))
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ./data/MNIST/raw/train-images-idx3-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ./data/MNIST/raw/train-images-idx3-ubyte.gz to ./data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ./data/MNIST/raw/train-labels-idx1-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ./data/MNIST/raw/train-labels-idx1-ubyte.gz to ./data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw/t10k-images-idx3-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ./data/MNIST/raw/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw
# Processing...
# Done!
# Training dataset size:  60000
# Testing dataset size:  10000
# /usr/local/lib/python3.6/dist-packages/torchvision/datasets/mnist.py:480: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /pytorch/torch/csrc/utils/tensor_numpy.cpp:141.)
#   return torch.from_numpy(parsed.astype(m[2], copy=False)).view(*s)

# %%
# ************* modify this section for later use *************
# Define the model 
class Model(torch.nn.Module):
    def __init__(self):
        super(Model, self).__init__()

        # modify this section for later use 
        self.linear_1 = torch.nn.Linear(784, 256)
        self.linear_2 = torch.nn.Linear(256, 10)
        self.sigmoid12  = torch.nn.Sigmoid()

        self.layer_activations = dict()

    def forward(self, x):

        # modify this section for later use 
        x = x.reshape(x.size(0), -1)
        x = self.linear_1(x)
        x = self.sigmoid12(x)
        pred = self.linear_2(x)
        return pred
# ************* modify this section for later use *************

# %%
def get_activation(model, layer_name):    
    def hook(module, input, output):
        model.layer_activations[layer_name] = output
    return hook

# %%
def sparsity_calculator(final_spareness):
    sparseness_list = list()
    for single_epoch_spareness in final_spareness:

        hidden_layer_activation_list = single_epoch_spareness
        hidden_layer_activation_list = torch.stack(hidden_layer_activation_list)
        layer_activations_list = torch.reshape(hidden_layer_activation_list, (10000, 256))

        layer_activations_list = torch.abs(layer_activations_list)  # modified 
        num_neurons = layer_activations_list.shape[1]
        population_sparseness = (np.sqrt(num_neurons) - (torch.sum(layer_activations_list, dim=1) / torch.sqrt(torch.sum(layer_activations_list ** 2, dim=1)))) / (np.sqrt(num_neurons) - 1)
        mean_sparseness_per_epoch = torch.mean(population_sparseness)

        sparseness_list.append(mean_sparseness_per_epoch)

    return sparseness_list

# %%
def model_factory(optimizer_name):
    '''
    optimizer_name : choose one of Adagrad, Adadelta, SGD, and Adam 

    '''
    my_model = Model()
    print("my_model:", my_model)
    my_model.to(device)

    # ************* modify this section for later use *************
    # modify this section for later use 
    my_model.sigmoid12.register_forward_hook(get_activation(my_model, 's12'))
    # ************* modify this section for later use *************

    if optimizer_name == 'Adadelta':
        my_optimizer = torch.optim.Adadelta(my_model.parameters(), lr=1.0)

    elif optimizer_name == 'Adagrad':
        my_optimizer = torch.optim.Adagrad(my_model.parameters(), lr=0.1)

    elif optimizer_name == 'SGD':
        my_optimizer = torch.optim.SGD(my_model.parameters(), lr=0.1)

    elif optimizer_name == 'Adam':
        my_optimizer = torch.optim.Adam(my_model.parameters(), lr=0.001)

    else:
        print("ERROR")
    
    print("my_optimizer:", my_optimizer)
    test_acc, sparseness_list = sparsity_trainer(optimizer=my_optimizer, model=my_model)
    # ************* modify this section for later use *************
    file_saver = open(f"1HL_sparsity_{optimizer_name}.txt", "w")
    # ************* modify this section for later use *************
    file_saver.write(str(test_acc)+'\n'+str(sparseness_list)+'\n\n')
    file_saver.close()

    # ************* modify this section for later use *************
    if optimizer_name == 'Adadelta':
        # !cp 1HL_sparsity_Adadelta.txt /content/drive/MyDrive
    
    elif optimizer_name == 'Adagrad':
        # !cp 1HL_sparsity_Adagrad.txt /content/drive/MyDrive

    elif optimizer_name == 'SGD':
        # !cp 1HL_sparsity_SGD.txt /content/drive/MyDrive

    elif optimizer_name == 'Adam':
        # !cp 1HL_sparsity_Adam.txt /content/drive/MyDrive
    # ************* modify this section for later use *************

    else:
        print("ERROR")

# %%
def sparsity_trainer(optimizer, model):
    criterion = torch.nn.CrossEntropyLoss()
    no_epochs = 50

    train_loss = list()
    test_loss  = list()
    test_acc   = list()

    # ************* modify this section for later use *************
    final_spareness_12 = list()
    # ************* modify this section for later use *************

    best_test_loss = 1
    for epoch in range(no_epochs):
        total_train_loss = 0
        total_test_loss = 0

        # ************* modify this section for later use *************
        hidden_layer_activation_list_12 = list()
        # ************* modify this section for later use *************

        # training
        # set up training mode 
        model.train()
        for itr, (image, label) in enumerate(train_dataloader):
            image, label = image.to(device), label.to(device)

            optimizer.zero_grad()

            pred = model(image)

            loss = criterion(pred, label)
            total_train_loss += loss.item()

            loss.backward()
            optimizer.step()

        total_train_loss = total_train_loss / (itr + 1)
        train_loss.append(total_train_loss)

        # testing 
        # change to evaluation mode 
        model.eval()
        total = 0
        for itr, (image, label) in enumerate(test_dataloader):
            image, label = image.to(device), label.to(device)

            pred = model(image)

            loss = criterion(pred, label)
            total_test_loss += loss.item()

            # we now need softmax because we are testing.
            pred = torch.nn.functional.softmax(pred, dim=1)
            for i, p in enumerate(pred):
                if label[i] == torch.max(p.data, 0)[1]:
                    total = total + 1

            # ***************** sparsity calculation ***************** #
            hidden_layer_activation_list_12.append(model.layer_activations['s12'])

        # this conains activations for all epochs 
        final_spareness_12.append(hidden_layer_activation_list_12)
        # ***************** sparsity calculation ***************** #

        # caculate accuracy 
        accuracy = total / len(mnist_testset)

        # append accuracy here
        test_acc.append(accuracy)

        # append test loss here 
        total_test_loss = total_test_loss / (itr + 1)
        test_loss.append(total_test_loss)

        print('\nEpoch: {}/{}, Train Loss: {:.8f}, Test Loss: {:.8f}, Test Accuracy: {:.8f}'.format(epoch + 1, no_epochs, total_train_loss, total_test_loss, accuracy))

        if total_test_loss < best_test_loss:
            best_test_loss = total_test_loss
            print("Saving the model state dictionary for Epoch: {} with Test loss: {:.8f}".format(epoch + 1, total_test_loss))
            torch.save(model.state_dict(), "model.dth")


    # ***************** sparsity calculation ***************** #
    sparsity_list12 = sparsity_calculator(final_spareness_12)

    print(sparsity_list12)

    average_sparsity = list()
    for i in range(no_epochs):
        average_sparsity.append( (sparsity_list12[i].item()) / 1 )
    # ***************** sparsity calculation ***************** #

    print("average_sparsity:", average_sparsity)

    return test_acc, average_sparsity

# %% [markdown]
# # Adadelta

# %%
model_factory('Adadelta')
# Out:
# my_model: Model(
#   (linear_1): Linear(in_features=784, out_features=256, bias=True)
#   (linear_2): Linear(in_features=256, out_features=10, bias=True)
#   (sigmoid12): Sigmoid()
# )
# my_optimizer: Adadelta (
# Parameter Group 0
#     eps: 1e-06
#     lr: 1.0
#     rho: 0.9
#     weight_decay: 0
# )
#
# Epoch: 1/50, Train Loss: 0.43482734, Test Loss: 0.25056329, Test Accuracy: 0.92680000
# Saving the model state dictionary for Epoch: 1 with Test loss: 0.25056329
#
# Epoch: 2/50, Train Loss: 0.21552304, Test Loss: 0.17478676, Test Accuracy: 0.94670000
# Saving the model state dictionary for Epoch: 2 with Test loss: 0.17478676
#
# Epoch: 3/50, Train Loss: 0.15641612, Test Loss: 0.13820603, Test Accuracy: 0.95740000
# Saving the model state dictionary for Epoch: 3 with Test loss: 0.13820603
#
# Epoch: 4/50, Train Loss: 0.12157689, Test Loss: 0.11924306, Test Accuracy: 0.96300000
# Saving the model state dictionary for Epoch: 4 with Test loss: 0.11924306
#
# Epoch: 5/50, Train Loss: 0.09919056, Test Loss: 0.09831683, Test Accuracy: 0.96860000
# Saving the model state dictionary for Epoch: 5 with Test loss: 0.09831683
#
# Epoch: 6/50, Train Loss: 0.08336800, Test Loss: 0.09016022, Test Accuracy: 0.97190000
# Saving the model state dictionary for Epoch: 6 with Test loss: 0.09016022
#
# Epoch: 7/50, Train Loss: 0.07088854, Test Loss: 0.08719796, Test Accuracy: 0.97320000
# Saving the model state dictionary for Epoch: 7 with Test loss: 0.08719796
#
# Epoch: 8/50, Train Loss: 0.06153279, Test Loss: 0.07796416, Test Accuracy: 0.97520000
# Saving the model state dictionary for Epoch: 8 with Test loss: 0.07796416
#
# Epoch: 9/50, Train Loss: 0.05413195, Test Loss: 0.07215949, Test Accuracy: 0.97700000
# Saving the model state dictionary for Epoch: 9 with Test loss: 0.07215949
#
# Epoch: 10/50, Train Loss: 0.04688474, Test Loss: 0.07165625, Test Accuracy: 0.97650000
# Saving the model state dictionary for Epoch: 10 with Test loss: 0.07165625
#
# Epoch: 11/50, Train Loss: 0.04203057, Test Loss: 0.07021960, Test Accuracy: 0.97680000
# Saving the model state dictionary for Epoch: 11 with Test loss: 0.07021960
#
# Epoch: 12/50, Train Loss: 0.03695013, Test Loss: 0.07518681, Test Accuracy: 0.97650000
#
# Epoch: 13/50, Train Loss: 0.03292638, Test Loss: 0.06627988, Test Accuracy: 0.97940000
# Saving the model state dictionary for Epoch: 13 with Test loss: 0.06627988
#
# Epoch: 14/50, Train Loss: 0.02905201, Test Loss: 0.06293269, Test Accuracy: 0.98030000
# Saving the model state dictionary for Epoch: 14 with Test loss: 0.06293269
#
# Epoch: 15/50, Train Loss: 0.02590495, Test Loss: 0.06158078, Test Accuracy: 0.98020000
# Saving the model state dictionary for Epoch: 15 with Test loss: 0.06158078
#
# Epoch: 16/50, Train Loss: 0.02330130, Test Loss: 0.06297808, Test Accuracy: 0.97920000
#
# Epoch: 17/50, Train Loss: 0.02085337, Test Loss: 0.05992444, Test Accuracy: 0.98110000
# Saving the model state dictionary for Epoch: 17 with Test loss: 0.05992444
#
# Epoch: 18/50, Train Loss: 0.01860578, Test Loss: 0.06213611, Test Accuracy: 0.98040000
#
# Epoch: 19/50, Train Loss: 0.01655125, Test Loss: 0.06208909, Test Accuracy: 0.98020000
#
# Epoch: 20/50, Train Loss: 0.01466604, Test Loss: 0.05816112, Test Accuracy: 0.98150000
# Saving the model state dictionary for Epoch: 20 with Test loss: 0.05816112
.32710152864456177, 0.3268286883831024, 0.3268653452396393, 0.32802456617355347, 0.3264581561088562, 0.3277241587638855, 0.3267463743686676, 0.32694771885871887, 0.32681921124458313, 0.32717353105545044, 0.3274466395378113, 0.3268374502658844, 0.32780519127845764, 0.32677730917930603, 0.32716575264930725, 0.3269147574901581, 0.32744187116622925, 0.32752081751823425, 0.32767367362976074, 0.32754260301589966, 0.32774361968040466, 0.3273734748363495]

# %% [markdown]
# # Adagrad

# %%
model_factory('Adagrad')
# Out:
# my_model: Model(
#   (linear_1): Linear(in_features=784, out_features=256, bias=True)
#   (linear_2): Linear(in_features=256, out_features=10, bias=True)
#   (sigmoid12): Sigmoid()
# )
# my_optimizer: Adagrad (
# Parameter Group 0
#     eps: 1e-10
#     initial_accumulator_value: 0
#     lr: 0.1
#     lr_decay: 0
#     weight_decay: 0
# )
#
# Epoch: 1/50, Train Loss: 0.25135552, Test Loss: 0.13348238, Test Accuracy: 0.95990000
# Saving the model state dictionary for Epoch: 1 with Test loss: 0.13348238
#
# Epoch: 2/50, Train Loss: 0.10659374, Test Loss: 0.10479500, Test Accuracy: 0.96900000
# Saving the model state dictionary for Epoch: 2 with Test loss: 0.10479500
#
# Epoch: 3/50, Train Loss: 0.07623379, Test Loss: 0.09452979, Test Accuracy: 0.97040000
# Saving the model state dictionary for Epoch: 3 with Test loss: 0.09452979
#
# Epoch: 4/50, Train Loss: 0.05851073, Test Loss: 0.08373763, Test Accuracy: 0.97420000
# Saving the model state dictionary for Epoch: 4 with Test loss: 0.08373763
#
# Epoch: 5/50, Train Loss: 0.04662944, Test Loss: 0.07940203, Test Accuracy: 0.97560000
# Saving the model state dictionary for Epoch: 5 with Test loss: 0.07940203
#
# Epoch: 6/50, Train Loss: 0.03800374, Test Loss: 0.07703720, Test Accuracy: 0.97730000
# Saving the model state dictionary for Epoch: 6 with Test loss: 0.07703720
#
# Epoch: 7/50, Train Loss: 0.03129917, Test Loss: 0.07578279, Test Accuracy: 0.97830000
# Saving the model state dictionary for Epoch: 7 with Test loss: 0.07578279
#
# Epoch: 8/50, Train Loss: 0.02631623, Test Loss: 0.07411670, Test Accuracy: 0.97720000
# Saving the model state dictionary for Epoch: 8 with Test loss: 0.07411670
#
# Epoch: 9/50, Train Loss: 0.02242687, Test Loss: 0.07439375, Test Accuracy: 0.97700000
#
# Epoch: 10/50, Train Loss: 0.01923755, Test Loss: 0.07221924, Test Accuracy: 0.97860000
# Saving the model state dictionary for Epoch: 10 with Test loss: 0.07221924
#
# Epoch: 11/50, Train Loss: 0.01656274, Test Loss: 0.07082122, Test Accuracy: 0.97840000
# Saving the model state dictionary for Epoch: 11 with Test loss: 0.07082122
#
# Epoch: 12/50, Train Loss: 0.01441189, Test Loss: 0.06916087, Test Accuracy: 0.98000000
# Saving the model state dictionary for Epoch: 12 with Test loss: 0.06916087
#
# Epoch: 13/50, Train Loss: 0.01248071, Test Loss: 0.07048734, Test Accuracy: 0.97870000
#
# Epoch: 14/50, Train Loss: 0.01099331, Test Loss: 0.06976460, Test Accuracy: 0.97910000
#
# Epoch: 15/50, Train Loss: 0.00970197, Test Loss: 0.06965812, Test Accuracy: 0.97960000
#
# Epoch: 16/50, Train Loss: 0.00872678, Test Loss: 0.06839904, Test Accuracy: 0.98090000
# Saving the model state dictionary for Epoch: 16 with Test loss: 0.06839904
#
# Epoch: 17/50, Train Loss: 0.00786464, Test Loss: 0.06895862, Test Accuracy: 0.98050000
#
# average_sparsity: [0.6971657276153564, 0.6897940635681152, 0.6787534952163696, 0.6780958771705627, 0.6742496490478516, 0.6711394190788269, 0.6668443083763123, 0.6645599007606506, 0.6618591547012329, 0.6613250970840454, 0.6589482426643372, 0.6568078398704529, 0.653549313545227, 0.6515516638755798, 0.6516708731651306, 0.6502717733383179, 0.6499350666999817, 0.6487435698509216, 0.6468861103057861, 0.6467048525810242, 0.6462650299072266, 0.6450108289718628, 0.644701361656189, 0.6445121765136719, 0.6435844898223877, 0.6428960561752319, 0.6414518356323242, 0.6413413286209106, 0.640205442905426, 0.6404607892036438, 0.6400943994522095, 0.6400875449180603, 0.6385765671730042, 0.6387317180633545, 0.6382706761360168, 0.6375303864479065, 0.6373518705368042, 0.6371421217918396, 0.6368277072906494, 0.6365136504173279, 0.6363269686698914, 0.6358401775360107, 0.6353412866592407, 0.6354501843452454, 0.6352260112762451, 0.6349728107452393, 0.6340988874435425, 0.6344486474990845, 0.6337839961051941, 0.6339491009712219]

# %% [markdown]
# # SGD

# %%
model_factory('SGD')
# Out:
# my_model: Model(
#   (linear_1): Linear(in_features=784, out_features=256, bias=True)
#   (linear_2): Linear(in_features=256, out_features=10, bias=True)
#   (sigmoid12): Sigmoid()
# )
# my_optimizer: SGD (
# Parameter Group 0
#     dampening: 0
#     lr: 0.1
#     momentum: 0
#     nesterov: False
#     weight_decay: 0
# )
#
# Epoch: 1/50, Train Loss: 0.76722120, Test Loss: 0.36326990, Test Accuracy: 0.89850000
# Saving the model state dictionary for Epoch: 1 with Test loss: 0.36326990
#
# Epoch: 2/50, Train Loss: 0.34651690, Test Loss: 0.30301376, Test Accuracy: 0.91230000
# Saving the model state dictionary for Epoch: 2 with Test loss: 0.30301376
#
# Epoch: 3/50, Train Loss: 0.30611468, Test Loss: 0.28335072, Test Accuracy: 0.91870000
# Saving the model state dictionary for Epoch: 3 with Test loss: 0.28335072
#
# Epoch: 4/50, Train Loss: 0.28328271, Test Loss: 0.26756004, Test Accuracy: 0.92440000
# Saving the model state dictionary for Epoch: 4 with Test loss: 0.26756004
#
# Epoch: 5/50, Train Loss: 0.26497809, Test Loss: 0.25494479, Test Accuracy: 0.92880000
# Saving the model state dictionary for Epoch: 5 with Test loss: 0.25494479
#
# Epoch: 6/50, Train Loss: 0.24806357, Test Loss: 0.24668049, Test Accuracy: 0.92590000
# Saving the model state dictionary for Epoch: 6 with Test loss: 0.24668049
#
# Epoch: 7/50, Train Loss: 0.23211571, Test Loss: 0.22040316, Test Accuracy: 0.93490000
# Saving the model state dictionary for Epoch: 7 with Test loss: 0.22040316
#
# Epoch: 8/50, Train Loss: 0.21798452, Test Loss: 0.21727757, Test Accuracy: 0.93680000
# Saving the model state dictionary for Epoch: 8 with Test loss: 0.21727757
#
# Epoch: 9/50, Train Loss: 0.20461510, Test Loss: 0.19467803, Test Accuracy: 0.94310000
# Saving the model state dictionary for Epoch: 9 with Test loss: 0.19467803
#
# Epoch: 10/50, Train Loss: 0.19233812, Test Loss: 0.18515901, Test Accuracy: 0.94650000
# Saving the model state dictionary for Epoch: 10 with Test loss: 0.18515901
#
# Epoch: 11/50, Train Loss: 0.18166276, Test Loss: 0.18048549, Test Accuracy: 0.94780000
# Saving the model state dictionary for Epoch: 11 with Test loss: 0.18048549
#
# Epoch: 12/50, Train Loss: 0.17136233, Test Loss: 0.16910887, Test Accuracy: 0.95100000
# Saving the model state dictionary for Epoch: 12 with Test loss: 0.16910887
#
# Epoch: 13/50, Train Loss: 0.16238347, Test Loss: 0.16341982, Test Accuracy: 0.95180000
# Saving the model state dictionary for Epoch: 13 with Test loss: 0.16341982
#
# Epoch: 14/50, Train Loss: 0.15405645, Test Loss: 0.15461945, Test Accuracy: 0.95480000
# Saving the model state dictionary for Epoch: 14 with Test loss: 0.15461945
#
# Epoch: 15/50, Train Loss: 0.14626926, Test Loss: 0.14632130, Test Accuracy: 0.95630000
# Saving the model state dictionary for Epoch: 15 with Test loss: 0.14632130
#
# Epoch: 16/50, Train Loss: 0.13907618, Test Loss: 0.14484052, Test Accuracy: 0.95650000
# Saving the model state dictionary for Epoch: 16 with Test loss: 0.14484052
#
# Epoch: 17/50, Train Loss: 0.13269684, Test Loss: 0.13702268, Test Accuracy: 0.95930000
# Saving the model state dictionary for Epoch: 17 with Test loss: 0.13702268
#
# Epoch: 18/50, Train Loss: 0.12664279, Test Loss: 0.13261708, Test Accuracy: 0.96060000
# Saving the model state dictionary for Epoch: 18 with Test loss: 0.13261708
#
# Epoch: 19/50, Train Loss: 0.12116181, Test Loss: 0.12797155, Test Accuracy: 0.96190000
# Saving the model state dictionary for Epoch: 19 with Test loss: 0.12797155
#
# Epoch: 20/50, Train Loss: 0.11595722, Test Loss: 0.12630370, Test Accuracy: 0.96250000
# Saving the model state dictionary for Epoch: 20 with Test loss: 0.12630370
#
# Epoch: 21/50, Train Loss: 0.11094526, Test Loss: 0.12136584, Test Accuracy: 0.96440000
# Saving the model state dictionary for Epoch: 21 with Test loss: 0.12136584
#
# Epoch: 22/50, Train Loss: 0.10666263, Test Loss: 0.11572381, Test Accuracy: 0.96460000
# Saving the model state dictionary for Epoch: 22 with Test loss: 0.11572381
#
# Epoch: 23/50, Train Loss: 0.10260664, Test Loss: 0.11295463, Test Accuracy: 0.96570000
# Saving the model state dictionary for Epoch: 23 with Test loss: 0.11295463
#
# Epoch: 24/50, Train Loss: 0.09865280, Test Loss: 0.10915224, Test Accuracy: 0.96660000
# Saving the model state dictionary for Epoch: 24 with Test loss: 0.10915224
#
# Epoch: 25/50, Train Loss: 0.09491268, Test Loss: 0.10961767, Test Accuracy: 0.96740000
#
# Epoch: 26/50, Train Loss: 0.09148390, Test Loss: 0.10529070, Test Accuracy: 0.96810000
# Saving the model state dictionary for Epoch: 26 with Test loss: 0.10529070
#
# Epoch: 27/50, Train Loss: 0.08817180, Test Loss: 0.10334536, Test Accuracy: 0.96690000
# Saving the model state dictionary for Epoch: 27 with Test loss: 0.10334536
#
# Epoch: 28/50, Train Loss: 0.08501304, Test Loss: 0.10110797, Test Accuracy: 0.96950000
# Saving the model state dictionary for Epoch: 28 with Test loss: 0.10110797
#
# Epoch: 29/50, Train Loss: 0.08217962, Test Loss: 0.09837822, Test Accuracy: 0.96920000
# Saving the model state dictionary for Epoch: 29 with Test loss: 0.09837822
#
# Epoch: 30/50, Train Loss: 0.07937957, Test Loss: 0.09890317, Test Accuracy: 0.97040000
#
# Epoch: 31/50, Train Loss: 0.07693886, Test Loss: 0.09457889, Test Accuracy: 0.97060000
# Saving the model state dictionary for Epoch: 31 with Test loss: 0.09457889
#
# Epoch: 32/50, Train Loss: 0.07465171, Test Loss: 0.09300950, Test Accuracy: 0.97190000
# Saving the model state dictionary for Epoch: 32 with Test loss: 0.09300950
#
# Epoch: 33/50, Train Loss: 0.07231642, Test Loss: 0.09069616, Test Accuracy: 0.97160000
# Saving the model state dictionary for Epoch: 33 with Test loss: 0.09069616
#
# Epoch: 34/50, Train Loss: 0.07006858, Test Loss: 0.09097907, Test Accuracy: 0.97190000
#
# Epoch: 35/50, Train Loss: 0.06790723, Test Loss: 0.08967026, Test Accuracy: 0.97150000
# Saving the model state dictionary for Epoch: 35 with Test loss: 0.08967026
#
# Epoch: 36/50, Train Loss: 0.06590752, Test Loss: 0.08917385, Test Accuracy: 0.97190000
# Saving the model state dictionary for Epoch: 36 with Test loss: 0.08917385
#
# Epoch: 37/50, Train Loss: 0.06406447, Test Loss: 0.08636223, Test Accuracy: 0.97410000
# Saving the model state dictionary for Epoch: 37 with Test loss: 0.08636223
#
# Epoch: 38/50, Train Loss: 0.06209159, Test Loss: 0.08760535, Test Accuracy: 0.97460000
#
# Epoch: 39/50, Train Loss: 0.06062713, Test Loss: 0.08341309, Test Accuracy: 0.97350000
# Saving the model state dictionary for Epoch: 39 with Test loss: 0.08341309
#
# Epoch: 40/50, Train Loss: 0.05871512, Test Loss: 0.08403056, Test Accuracy: 0.97340000
#
# Epoch: 41/50, Train Loss: 0.05708844, Test Loss: 0.08247105, Test Accuracy: 0.97390000
# Saving the model state dictionary for Epoch: 41 with Test loss: 0.08247105
#
# Epoch: 42/50, Train Loss: 0.05558765, Test Loss: 0.08062421, Test Accuracy: 0.97500000
# Saving the model state dictionary for Epoch: 42 with Test loss: 0.08062421
#
# Epoch: 43/50, Train Loss: 0.05417070, Test Loss: 0.08042447, Test Accuracy: 0.97420000
# Saving the model state dictionary for Epoch: 43 with Test loss: 0.08042447
#
# Epoch: 44/50, Train Loss: 0.05263397, Test Loss: 0.07841749, Test Accuracy: 0.97550000
# Saving the model state dictionary for Epoch: 44 with Test loss: 0.07841749
#
# Epoch: 45/50, Train Loss: 0.05129648, Test Loss: 0.07774983, Test Accuracy: 0.97630000
# Saving the model state dictionary for Epoch: 45 with Test loss: 0.07774983
#
# Epoch: 46/50, Train Loss: 0.04993409, Test Loss: 0.08208709, Test Accuracy: 0.97460000
#
# Epoch: 47/50, Train Loss: 0.04861959, Test Loss: 0.07742374, Test Accuracy: 0.97610000
# Saving the model state dictionary for Epoch: 47 with Test loss: 0.07742374
#
# Epoch: 48/50, Train Loss: 0.04739187, Test Loss: 0.07824593, Test Accuracy: 0.97550000
#
# Epoch: 49/50, Train Loss: 0.04632846, Test Loss: 0.07674925, Test Accuracy: 0.97550000
# Saving the model state dictionary for Epoch: 49 with Test loss: 0.07674925
#
# Epoch: 50/50, Train Loss: 0.04509575, Test Loss: 0.07681502, Test Accuracy: 0.97610000
# [tensor(0.0797, grad_fn=<MeanBackward0>), tensor(0.0928, grad_fn=<MeanBackward0>), tensor(0.1023, grad_fn=<MeanBackward0>), tensor(0.1117, grad_fn=<MeanBackward0>), tensor(0.1206, grad_fn=<MeanBackward0>), tensor(0.1296, grad_fn=<MeanBackward0>), tensor(0.1384, grad_fn=<MeanBackward0>), tensor(0.1466, grad_fn=<MeanBackward0>), tensor(0.1540, grad_fn=<MeanBackward0>), tensor(0.1609, grad_fn=<MeanBackward0>), tensor(0.1668, grad_fn=<MeanBackward0>), tensor(0.1724, grad_fn=<MeanBackward0>), tensor(0.1773, grad_fn
# Out:
# my_model: Model(
#   (linear_1): Linear(in_features=784, out_features=256, bias=True)
#   (linear_2): Linear(in_features=256, out_features=10, bias=True)
#   (sigmoid12): Sigmoid()
# )
# my_optimizer: Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.001
#     weight_decay: 0
# )
#
# Epoch: 1/50, Train Loss: 0.42741568, Test Loss: 0.22363867, Test Accuracy: 0.93370000
# Saving the model state dictionary for Epoch: 1 with Test loss: 0.22363867
#
# Epoch: 2/50, Train Loss: 0.19307748, Test Loss: 0.16054030, Test Accuracy: 0.95160000
# Saving the model state dictionary for Epoch: 2 with Test loss: 0.16054030
#
# Epoch: 3/50, Train Loss: 0.13964687, Test Loss: 0.12472796, Test Accuracy: 0.96280000
# Saving the model state dictionary for Epoch: 3 with Test loss: 0.12472796
#
# Epoch: 4/50, Train Loss: 0.10673910, Test Loss: 0.10497052, Test Accuracy: 0.96700000
# Saving the model state dictionary for Epoch: 4 with Test loss: 0.10497052
#
# Epoch: 5/50, Train Loss: 0.08448474, Test Loss: 0.09221254, Test Accuracy: 0.97140000
# Saving the model state dictionary for Epoch: 5 with Test loss: 0.09221254
#
# Epoch: 6/50, Train Loss: 0.06774295, Test Loss: 0.07966647, Test Accuracy: 0.97510000
# Saving the model state dictionary for Epoch: 6 with Test loss: 0.07966647
#
# Epoch: 7/50, Train Loss: 0.05551532, Test Loss: 0.07441193, Test Accuracy: 0.97690000
# Saving the model state dictionary for Epoch: 7 with Test loss: 0.07441193
#
# Epoch: 8/50, Train Loss: 0.04535962, Test Loss: 0.07023771, Test Accuracy: 0.97800000
# Saving the model state dictionary for Epoch: 8 with Test loss: 0.07023771
#
# Epoch: 9/50, Train Loss: 0.03649109, Test Loss: 0.06530507, Test Accuracy: 0.98030000
# Saving the model state dictionary for Epoch: 9 with Test loss: 0.06530507
#
# Epoch: 10/50, Train Loss: 0.02971831, Test Loss: 0.06583611, Test Accuracy: 0.98050000
#
# Epoch: 11/50, Train Loss: 0.02413566, Test Loss: 0.06275426, Test Accuracy: 0.98050000
# Saving the model state dictionary for Epoch: 11 with Test loss: 0.06275426
#
# Epoch: 12/50, Train Loss: 0.01971154, Test Loss: 0.06272200, Test Accuracy: 0.98020000
# Saving the model state dictionary for Epoch: 12 with Test loss: 0.06272200
#
# Epoch: 13/50, Train Loss: 0.01540774, Test Loss: 0.06045270, Test Accuracy: 0.98100000
# Saving the model state dictionary for Epoch: 13 with Test loss: 0.06045270
#
# Epoch: 14/50, Train Loss: 0.01265546, Test Loss: 0.06003264, Test Accuracy: 0.98210000
# Saving the model state dictionary for Epoch: 14 with Test loss: 0.06003264
#
# Epoch: 15/50, Train Loss: 0.00994931, Test Loss: 0.06305531, Test Accuracy: 0.98150000
#
# Epoch: 16/50, Train Loss: 0.00783306, Test Loss: 0.06412739, Test Accuracy: 0.98090000
#
# Epoch: 17/50, Train Loss: 0.00617066, Test Loss: 0.06354828, Test Accuracy: 0.98110000
#
# Epoch: 18/50, Train Loss: 0.00501095, Test Loss: 0.06225180, Test Accuracy: 0.98110000
#
# Epoch: 19/50, Train Loss: 0.00403042, Test Loss: 0.06876272, Test Accuracy: 0.97970000
#
# Epoch: 20/50, Train Loss: 0.00295108, Test Loss: 0.07539083, Test Accuracy: 0.97930000
#
# Epoch: 21/50, Train Loss: 0.00232588, Test Loss: 0.06687716, Test Accuracy: 0.98100000
#
# Epoch: 22/50, Train Loss: 0.00227105, Test Loss: 0.07152149, Test Accuracy: 0.98120000
#
# Epoch: 23/50, Train Loss: 0.00162385, Test Loss: 0.06930664, Test Accuracy: 0.98210000
#
# Epoch: 24/50, Train Loss: 0.00173733, Test Loss: 0.07443560, Test Accuracy: 0.98120000
#
# Epoch: 25/50, Train Loss: 0.00118082, Test Loss: 0.06995258, Test Accuracy: 0.98270000
#
# Epoch: 26/50, Train Loss: 0.00061512, Test Loss: 0.07224008, Test Accuracy: 0.98250000
#
# Epoch: 27/50, Train Loss: 0.00059657, Test Loss: 0.07593773, Test Accuracy: 0.98150000
#
# Epoch: 28/50, Train Loss: 0.00171953, Test Loss: 0.07312348, Test Accuracy: 0.98240000
#
# Epoch: 29/50, Train Loss: 0.00032640, Test Loss: 0.07354839, Test Accuracy: 0.98260000
#
# Epoch: 30/50, Train Loss: 0.00026017, Test Loss: 0.07686363, Test Accuracy: 0.98220000
#
# Epoch: 31/50, Train Loss: 0.00049575, Test Loss: 0.09352466, Test Accuracy: 0.97810000
#
# Epoch: 32/50, Train Loss: 0.00137588, Test Loss: 0.07792026, Test Accuracy: 0.98220000
#
# Epoch: 33/50, Train Loss: 0.00019657, Test Loss: 0.07704096, Test Accuracy: 0.98240000
#
# Epoch: 34/50, Train Loss: 0.00014612, Test Loss: 0.07768330, Test Accuracy: 0.98250000
#
# Epoch: 35/50, Train Loss: 0.00012703, Test Loss: 0.08139472, Test Accuracy: 0.98200000
#
# Epoch: 36/50, Train Loss: 0.00072620, Test Loss: 0.10938596, Test Accuracy: 0.97600000
#
# Epoch: 37/50, Train Loss: 0.00087740, Test Loss: 0.08787197, Test Accuracy: 0.98110000
#
# Epoch: 38/50, Train Loss: 0.00011868, Test Loss: 0.08415556, Test Accuracy: 0.98190000
#
# Epoch: 39/50, Train Loss: 0.00008492, Test Loss: 0.08496426, Test Accuracy: 0.98200000
#
# Epoch: 40/50, Train Loss: 0.00007116, Test Loss: 0.08456033, Test Accuracy: 0.98240000
#
# Epoch: 41/50, Train Loss: 0.00008293, Test Loss: 0.08882115, Test Accuracy: 0.98250000
#
# Epoch: 42/50, Train Loss: 0.00143467, Test Loss: 0.08679678, Test Accuracy: 0.98080000
#
# Epoch: 43/50, Train Loss: 0.00009579, Test Loss: 0.08506178, Test Accuracy: 0.98270000
#
# Epoch: 44/50, Train Loss: 0.00005930, Test Loss: 0.08559119, Test Accuracy: 0.98220000
#
# Epoch: 45/50, Train Loss: 0.00004815, Test Loss: 0.08663393, Test Accuracy: 0.98240000
#
# Epoch: 46/50, Train Loss: 0.00003972, Test Loss: 0.08773768, Test Accuracy: 0.98260000
#
# Epoch: 47/50, Train Loss: 0.00003522, Test Loss: 0.09108359, Test Accuracy: 0.98170000
#
# Epoch: 48/50, Train Loss: 0.00109460, Test Loss: 0.09465501, Test Accuracy: 0.98050000
#
# Epoch: 49/50, Train Loss: 0.00008524, Test Loss: 0.09259537, Test Accuracy: 0.98120000
#
# Epoch: 50/50, Train Loss: 0.00004014, Test Loss: 0.09275062, Test Accuracy: 0.98150000
