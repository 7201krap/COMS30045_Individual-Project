# %% [markdown]
# <a href="https://colab.research.google.com/github/7201krap/PYTORCH_project/blob/main/sparsity_batch_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
from torchvision import transforms
import torchvision.datasets as datasets
import matplotlib.pyplot as plt
import numpy as np
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
torch.manual_seed(1234)
np.random.seed(1234)

# %%
mnist_trainset = datasets.MNIST(root='./data', train=True, 
                                download=True, 
                                transform=transforms.Compose([transforms.ToTensor()]))

mnist_testset  = datasets.MNIST(root='./data', 
                                train=False, 
                                download=True, 
                                transform=transforms.Compose([transforms.ToTensor()]))

train_dataloader = torch.utils.data.DataLoader(mnist_trainset, 
                                               batch_size=1, 
                                               shuffle=True)

test_dataloader  = torch.utils.data.DataLoader(mnist_testset, 
                                               batch_size=1, 
                                               shuffle=False)

print("Training dataset size: ", len(mnist_trainset))
print("Testing dataset size: ",  len(mnist_testset))
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ./data/MNIST/raw/train-images-idx3-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ./data/MNIST/raw/train-images-idx3-ubyte.gz to ./data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ./data/MNIST/raw/train-labels-idx1-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ./data/MNIST/raw/train-labels-idx1-ubyte.gz to ./data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw/t10k-images-idx3-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ./data/MNIST/raw/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw
# Processing...
# /usr/local/lib/python3.6/dist-packages/torchvision/datasets/mnist.py:480: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /pytorch/torch/csrc/utils/tensor_numpy.cpp:141.)
#   return torch.from_numpy(parsed.astype(m[2], copy=False)).view(*s)
# Done!
# Training dataset size:  60000
# Testing dataset size:  10000

# %%
# ************* modify this section for later use *************
# Define the model 
class Model(torch.nn.Module):
    def __init__(self):
        super(Model, self).__init__()

        # modify this section for later use 
        self.linear_1 = torch.nn.Linear(784, 256)
        self.linear_2 = torch.nn.Linear(256, 10)
        self.sigmoid12  = torch.nn.Sigmoid()

        self.layer_activations = dict()

    def forward(self, x):

        # modify this section for later use 
        x = x.reshape(x.size(0), -1)
        x = self.linear_1(x)
        x = self.sigmoid12(x)
        pred = self.linear_2(x)
        return pred
# ************* modify this section for later use *************

# %%
def get_activation(model, layer_name):    
    def hook(module, input, output):
        model.layer_activations[layer_name] = output
    return hook

# %%
def sparsity_calculator(final_spareness):
    sparseness_list = list()
    for single_epoch_spareness in final_spareness:

        hidden_layer_activation_list = single_epoch_spareness
        hidden_layer_activation_list = torch.stack(hidden_layer_activation_list)
        layer_activations_list = torch.reshape(hidden_layer_activation_list, (10000, 256))

        layer_activations_list = torch.abs(layer_activations_list)  # modified 
        num_neurons = layer_activations_list.shape[1]
        population_sparseness = (np.sqrt(num_neurons) - (torch.sum(layer_activations_list, dim=1) / torch.sqrt(torch.sum(layer_activations_list ** 2, dim=1)))) / (np.sqrt(num_neurons) - 1)
        mean_sparseness_per_epoch = torch.mean(population_sparseness)

        sparseness_list.append(mean_sparseness_per_epoch)

    return sparseness_list

# %%
def model_factory(optimizer_name):
    '''
    optimizer_name : choose one of Adagrad, Adadelta, SGD, and Adam 

    '''
    my_model = Model()
    print("my_model:", my_model)
    my_model.to(device)

    # ************* modify this section for later use *************
    # modify this section for later use 
    my_model.sigmoid12.register_forward_hook(get_activation(my_model, 's12'))
    # ************* modify this section for later use *************

    if optimizer_name == 'Adadelta':
        my_optimizer = torch.optim.Adadelta(my_model.parameters(), lr=1.0)

    elif optimizer_name == 'Adagrad':
        my_optimizer = torch.optim.Adagrad(my_model.parameters(), lr=0.1)

    elif optimizer_name == 'SGD':
        my_optimizer = torch.optim.SGD(my_model.parameters(), lr=0.1)

    elif optimizer_name == 'Adam':
        my_optimizer = torch.optim.Adam(my_model.parameters(), lr=0.001)

    else:
        print("ERROR")
    
    print("my_optimizer:", my_optimizer)
    test_acc, sparseness_list = sparsity_trainer(optimizer=my_optimizer, model=my_model)
    # ************* modify this section for later use *************
    file_saver = open(f"sparsity_batchsize_1_{optimizer_name}.txt", "w")
    # ************* modify this section for later use *************
    file_saver.write(str(test_acc)+'\n'+str(sparseness_list)+'\n\n')
    file_saver.close()

    # ************* modify this section for later use *************
    if optimizer_name == 'Adadelta':
        # !cp sparsity_batchsize_1_Adadelta.txt /content/drive/MyDrive
    
    elif optimizer_name == 'Adagrad':
        # !cp sparsity_batchsize_1_Adagrad.txt /content/drive/MyDrive

    elif optimizer_name == 'SGD':
        # !cp sparsity_batchsize_1_SGD.txt /content/drive/MyDrive

    elif optimizer_name == 'Adam':
        # !cp sparsity_batchsize_1_Adam.txt /content/drive/MyDrive
    # ************* modify this section for later use *************

    else:
        print("ERROR")

# %%
def sparsity_trainer(optimizer, model):
    criterion = torch.nn.CrossEntropyLoss()
    no_epochs = 30

    train_loss = list()
    test_loss  = list()
    test_acc   = list()

    # ************* modify this section for later use *************
    final_spareness_12 = list()
    # ************* modify this section for later use *************

    best_test_loss = 1
    for epoch in range(no_epochs):
        total_train_loss = 0
        total_test_loss = 0

        # ************* modify this section for later use *************
        hidden_layer_activation_list_12 = list()
        # ************* modify this section for later use *************

        # training
        # set up training mode 
        model.train()
        for itr, (image, label) in enumerate(train_dataloader):
            image, label = image.to(device), label.to(device)

            optimizer.zero_grad()

            pred = model(image)

            loss = criterion(pred, label)
            total_train_loss += loss.item()

            loss.backward()
            optimizer.step()

        total_train_loss = total_train_loss / (itr + 1)
        train_loss.append(total_train_loss)

        # testing 
        # change to evaluation mode 
        model.eval()
        total = 0
        for itr, (image, label) in enumerate(test_dataloader):
            image, label = image.to(device), label.to(device)

            pred = model(image)

            loss = criterion(pred, label)
            total_test_loss += loss.item()

            # we now need softmax because we are testing.
            pred = torch.nn.functional.softmax(pred, dim=1)
            for i, p in enumerate(pred):
                if label[i] == torch.max(p.data, 0)[1]:
                    total = total + 1

            # ***************** sparsity calculation ***************** #
            hidden_layer_activation_list_12.append(model.layer_activations['s12'])

        # this conains activations for all epochs 
        final_spareness_12.append(hidden_layer_activation_list_12)
        # ***************** sparsity calculation ***************** #

        # caculate accuracy 
        accuracy = total / len(mnist_testset)

        # append accuracy here
        test_acc.append(accuracy)

        # append test loss here 
        total_test_loss = total_test_loss / (itr + 1)
        test_loss.append(total_test_loss)

        print('\nEpoch: {}/{}, Train Loss: {:.8f}, Test Loss: {:.8f}, Test Accuracy: {:.8f}'.format(epoch + 1, no_epochs, total_train_loss, total_test_loss, accuracy))

        if total_test_loss < best_test_loss:
            best_test_loss = total_test_loss
            print("Saving the model state dictionary for Epoch: {} with Test loss: {:.8f}".format(epoch + 1, total_test_loss))
            torch.save(model.state_dict(), "model.dth")


    # ***************** sparsity calculation ***************** #
    sparsity_list12 = sparsity_calculator(final_spareness_12)

    print(sparsity_list12)

    average_sparsity = list()
    for i in range(no_epochs):
        average_sparsity.append( (sparsity_list12[i].item()) / 1 )
    # ***************** sparsity calculation ***************** #

    print("average_sparsity:", average_sparsity)

    return test_acc, average_sparsity

# %% [markdown]
# # Adadelta

# %%
model_factory('Adadelta')
# Out:
# my_model: Model(
#   (linear_1): Linear(in_features=784, out_features=256, bias=True)
#   (linear_2): Linear(in_features=256, out_features=10, bias=True)
#   (sigmoid12): Sigmoid()
# )
# my_optimizer: Adadelta (
# Parameter Group 0
#     eps: 1e-06
#     lr: 1.0
#     rho: 0.9
#     weight_decay: 0
# )
#
# Epoch: 1/30, Train Loss: 0.30961532, Test Loss: 0.20004023, Test Accuracy: 0.94760000
# Saving the model state dictionary for Epoch: 1 with Test loss: 0.20004023
#
# Epoch: 2/30, Train Loss: 0.17886424, Test Loss: 0.14577353, Test Accuracy: 0.96310000
# Saving the model state dictionary for Epoch: 2 with Test loss: 0.14577353
#
# Epoch: 3/30, Train Loss: 0.13607469, Test Loss: 0.13056480, Test Accuracy: 0.96710000
# Saving the model state dictionary for Epoch: 3 with Test loss: 0.13056480
#
# Epoch: 4/30, Train Loss: 0.11353151, Test Loss: 0.12474663, Test Accuracy: 0.96910000
# Saving the model state dictionary for Epoch: 4 with Test loss: 0.12474663
#
# Epoch: 5/30, Train Loss: 0.09612165, Test Loss: 0.09464677, Test Accuracy: 0.97560000
# Saving the model state dictionary for Epoch: 5 with Test loss: 0.09464677
#
# Epoch: 6/30, Train Loss: 0.08432496, Test Loss: 0.09746799, Test Accuracy: 0.97510000
#
# Epoch: 7/30, Train Loss: 0.07515441, Test Loss: 0.10635684, Test Accuracy: 0.97350000
#
# Epoch: 8/30, Train Loss: 0.06913489, Test Loss: 0.08646668, Test Accuracy: 0.97860000
# Saving the model state dictionary for Epoch: 8 with Test loss: 0.08646668
#
# Epoch: 9/30, Train Loss: 0.06413197, Test Loss: 0.08656863, Test Accuracy: 0.97890000
#
# Epoch: 10/30, Train Loss: 0.05897899, Test Loss: 0.08361835, Test Accuracy: 0.98100000
# Saving the model state dictionary for Epoch: 10 with Test loss: 0.08361835
#
# Epoch: 11/30, Train Loss: 0.05401387, Test Loss: 0.08829667, Test Accuracy: 0.97920000
#
# Epoch: 12/30, Train Loss: 0.05084665, Test Loss: 0.10350675, Test Accuracy: 0.97700000
#
# Epoch: 13/30, Train Loss: 0.04721460, Test Loss: 0.08862933, Test Accuracy: 0.97990000
#
# Epoch: 14/30, Train Loss: 0.04392236, Test Loss: 0.08800726, Test Accuracy: 0.98060000
#
# Epoch: 15/30, Train Loss: 0.04138999, Test Loss: 0.08905274, Test Accuracy: 0.97980000
#
# Epoch: 16/30, Train Loss: 0.03945890, Test Loss: 0.09408930, Test Accuracy: 0.97870000
#
# Epoch: 17/30, Train Loss: 0.03708892, Test Loss: 0.08822116, Test Accuracy: 0.98100000
#
# Epoch: 18/30, Train Loss: 0.03522630, Test Loss: 0.09453596, Test Accuracy: 0.97980000
#
# Epoch: 19/30, Train Loss: 0.03336617, Test Loss: 0.10126066, Test Accuracy: 0.97830000
#
# Epoch: 20/30, Train Loss: 0.03002339, Test Loss: 0.09579925, Test Accuracy: 0.97950000
#
# Epoch: 21/30, Train Loss: 0.03008997, Test Loss: 0.09143551, Test Accuracy: 0.98090000
#
# Epoch: 22/30, Train Loss: 0.02889846, Test Loss: 0.09691191, Test Accuracy: 0.98050000
#
# Epoch: 23/30, Train Loss: 0.02724444, Test Loss: 0.09548179, Test Accuracy: 0.98050000
#
# Epoch: 24/30, Train Loss: 0.02603492, Test Loss: 0.09954567, Test Accuracy: 0.98020000
#
# Epoch: 25/30, Train Loss: 0.02339556, Test Loss: 0.10464168, Test Accuracy: 0.97950000
#
# Epoch: 26/30, Train Loss: 0.02208333, Test Loss: 0.10236492, Test Accuracy: 0.97980000
#
# Epoch: 27/30, Train Loss: 0.02158722, Test Loss: 0.10076086, Test Accuracy: 0.97960000
#
# Epoch: 28/30, Train Loss: 0.02094857, Test Loss: 0.09946887, Test Accuracy: 0.97980000
#
# Epoch: 29/30, Train Loss: 0.01992807, Test Loss: 0.09744752, Test Accuracy: 0.98050000
#
# Epoch: 30/30, Train Loss: 0.01832495, Test Loss: 0.10340945, Test Accuracy: 0.98010000
# [tensor(0.2439, grad_fn=<MeanBackward0>), tensor(0.2485, grad_fn=<MeanBackward0>), tensor(0.2515, grad_fn=<MeanBackward0>), tensor(0.2442, grad_fn=<MeanBackward0>), tensor(0.2495, grad_fn=<MeanBackward0>), tensor(0.2464, grad_fn=<MeanBackward0>), tensor(0.2493, grad_fn=<MeanBackward0>), tensor(0.2461, grad_fn=<MeanBackward0>), tensor(0.2425, grad_fn=<MeanBackward0>), tensor(0.2451, grad_fn=<MeanBackward0>), tensor(0.2465, grad_fn=<MeanBackward0>), tensor(0.2434, grad_fn=<MeanBackward0>), tensor(0.2465, grad_fn=<MeanBackward0>), tensor(0.2462, grad_fn=<MeanBackward0>), tensor(0.2451, grad_fn=<MeanBackward0>), tensor(0.2468, grad_fn=<MeanBackward0>), tensor(0.2447, grad_fn=<MeanBackward0>), tensor(0.2413, grad_fn=<MeanBackward0>), tensor(0.2450, grad_fn=<MeanBackward0>), tensor(0.2430, grad_fn=<MeanBackward0>), tensor(0.2434, grad_fn=<MeanBackward0>), tensor(0.2439, grad_fn=<MeanBackward0>), tensor(0.2454, grad_fn=<MeanBackward0>), tensor(0.2431, grad_fn=<MeanBackward0>), tensor(0.2428, grad_fn=<MeanBackward0>), tensor(0.2439, grad_fn=<MeanBackward0>), tensor(0.2429, grad_fn=<MeanBackward0>), tensor(0.2410, grad_fn=<MeanBackward0>), tensor(0.2420, grad_fn=<MeanBackward0>), tensor(0.2413, grad_fn=<MeanBackward0>)]
# average_sparsity: [0.24388711154460907, 0.24848178029060364, 0.2515377998352051, 0.24423779547214508, 0.24947836995124817, 0.2463756650686264, 0.24934761226177216, 0.2461092323064804, 0.2424953132867813, 0.24514292180538177, 0.24648955464363098, 0.24343374371528625, 0.24654872715473175, 0.24618041515350342, 0.2451338917016983, 0.2468060553073883, 0.24471254646778107, 0.24132321774959564, 0.244985431432724, 0.24299314618110657, 0.2433626502752304, 0.24391093850135803, 0.24536725878715515, 0.24311694502830505, 0.24280375242233276, 0.24387475848197937, 0.24288897216320038, 0.24098561704158783, 0.24200396239757538, 0.24134323000907898]

# %% [markdown]
# # Adagrad

# %%
model_factory('Adagrad')
# Out:
# my_model: Model(
#   (linear_1): Linear(in_features=784, out_features=256, bias=True)
#   (linear_2): Linear(in_features=256, out_features=10, bias=True)
#   (sigmoid12): Sigmoid()
# )
# my_optimizer: Adagrad (
# Parameter Group 0
#     eps: 1e-10
#     initial_accumulator_value: 0
#     lr: 0.1
#     lr_decay: 0
#     weight_decay: 0
# )
#
# Epoch: 1/30, Train Loss: 0.20056434, Test Loss: 0.12074211, Test Accuracy: 0.96360000
# Saving the model state dictionary for Epoch: 1 with Test loss: 0.12074211
#
# Epoch: 2/30, Train Loss: 0.08875025, Test Loss: 0.09658355, Test Accuracy: 0.96980000
# Saving the model state dictionary for Epoch: 2 with Test loss: 0.09658355
#
# Epoch: 3/30, Train Loss: 0.06039658, Test Loss: 0.08410916, Test Accuracy: 0.97470000
# Saving the model state dictionary for Epoch: 3 with Test loss: 0.08410916
#
# Epoch: 4/30, Train Loss: 0.04495033, Test Loss: 0.07961262, Test Accuracy: 0.97580000
# Saving the model state dictionary for Epoch: 4 with Test loss: 0.07961262
#
# Epoch: 5/30, Train Loss: 0.03469421, Test Loss: 0.07640021, Test Accuracy: 0.97720000
# Saving the model state dictionary for Epoch: 5 with Test loss: 0.07640021
#
# Epoch: 6/30, Train Loss: 0.02706318, Test Loss: 0.07544706, Test Accuracy: 0.97720000
# Saving the model state dictionary for Epoch: 6 with Test loss: 0.07544706
#
# Epoch: 7/30, Train Loss: 0.02179065, Test Loss: 0.07341756, Test Accuracy: 0.97770000
# Saving the model state dictionary for Epoch: 7 with Test loss: 0.07341756
#
# Epoch: 8/30, Train Loss: 0.01755539, Test Loss: 0.07203568, Test Accuracy: 0.97880000
# Saving the model state dictionary for Epoch: 8 with Test loss: 0.07203568
#
# Epoch: 9/30, Train Loss: 0.01434270, Test Loss: 0.07075325, Test Accuracy: 0.97990000
# Saving the model state dictionary for Epoch: 9 with Test loss: 0.07075325
#
# Epoch: 10/30, Train Loss: 0.01176654, Test Loss: 0.07079817, Test Accuracy: 0.97920000
#
# Epoch: 11/30, Train Loss: 0.00985789, Test Loss: 0.06914260, Test Accuracy: 0.97990000
# Saving the model state dictionary for Epoch: 11 with Test loss: 0.06914260
#
# Epoch: 12/30, Train Loss: 0.00819353, Test Loss: 0.07015170, Test Accuracy: 0.97970000
#
# Epoch: 13/30, Train Loss: 0.00697503, Test Loss: 0.06959458, Test Accuracy: 0.98010000
#
# Epoch: 14/30, Train Loss: 0.00601797, Test Loss: 0.07014828, Test Accuracy: 0.97960000
#
# Epoch: 15/30, Train Loss: 0.00521370, Test Loss: 0.06914889, Test Accuracy: 0.98010000
#
# Epoch: 16/30, Train Loss: 0.00455502, Test Loss: 0.06932625, Test Accuracy: 0.98010000
#
# Epoch: 17/30, Train Loss: 0.00403428, Test Loss: 0.06923016, Test Accuracy: 0.98090000
#
# Epoch: 18/30, Train Loss: 0.00359762, Test Loss: 0.06939482, Test Accuracy: 0.98070000
#
# Epoch: 19/30, Train Loss: 0.00321903, Test Loss: 0.06996905, Test Accuracy: 0.98070000
#
# Epoch: 20/30, Train Loss: 0.00292040, Test Loss: 0.07012765, Test Accuracy: 0.98060000
#
# Epoch: 21/30, Train Loss: 0.00264567, Test Loss: 0.06998605, Test Accuracy: 0.98110000
#
# Epoch: 22/30, Train Loss: 0.00239964, Test Loss: 0.07096900, Test Accuracy: 0.98120000
#
# Epoch: 23/30, Train Loss: 0.00219145, Test Loss: 0.07102140, Test Accuracy: 0.98090000
#
# Epoch: 24/30, Train Loss: 0.00201069, Test Loss: 0.07062328, Test Accuracy: 0.98100000
#
# Epoch: 25/30, Train Loss: 0.00184765, Test Loss: 0.07125814, Test Accuracy: 0.98060000
#
# Epoch: 26/30, Train Loss: 0.00170789, Test Loss: 0.07131117, Test Accuracy: 0.98140000
#
# Epoch: 27/30, Train Loss: 0.00157741, Test Loss: 0.07198716, Test Accuracy: 0.98100000
#
# Epoch: 28/30, Train Loss: 0.00146743, Test Loss: 0.07193060, Test Accuracy: 0.98130000
#
# Epoch: 29/30, Train Loss: 0.00137224, Test Loss: 0.07205518, Test Accuracy: 0.98140000
#
# Epoch: 30/30, Train Loss: 0.00128412, Test Loss: 0.07255087, Test Accuracy: 0.98120000
# [tensor(0.7246, grad_fn=<MeanBackward0>), tensor(0.7119, grad_fn=<MeanBackward0>), tensor(0.7036, grad_fn=<MeanBackward0>), tensor(0.6964, grad_fn=<MeanBackward0>), tensor(0.6856, grad_fn=<MeanBackward0>), tensor(0.6782, grad_fn=<MeanBackward0>), tensor(0.6744, grad_fn=<MeanBackward0>), tensor(0.6718, grad_fn=<MeanBackward0>), tensor(0.6620, grad_fn=<MeanBackward0>), tensor(0.6625, grad_fn=<MeanBackward0>), tensor(0.6584, grad_fn=<MeanBackward0>), tensor(0.6548, grad_fn=<MeanBackward0>), tensor(0.6539, grad_fn=<MeanBackward0>), tensor(0.6505, grad_fn=<MeanBackward0>), tensor(0.6481, grad_fn=<MeanBackward0>), tensor(0.6457, grad_fn=<MeanBackward0>), tensor(0.6447, grad_fn=<MeanBackward0>), tensor(0.6420, grad_fn=<MeanBackward0>), tensor(0.6406, grad_fn=<MeanBackward0>), tensor(0.6384, grad_fn=<MeanBackward0>), tensor(0.6380, grad_fn=<MeanBackward0>), tensor(0.6352, grad_fn=<MeanBackward0>), tensor(0.6351, grad_fn=<MeanBackward0>), tensor(0.6341, grad_fn=<MeanBackward0>), tensor(0.6318, grad_fn=<MeanBackward0>), tensor(0.6327, grad_fn=<MeanBackward0>), tensor(0.6312, grad_fn=<MeanBackward0>), tensor(0.6304, grad_fn=<MeanBackward0>), tensor(0.6297, grad_fn=<MeanBackward0>), tensor(0.6290, grad_fn=<MeanBackward0>)]
# average_sparsity: [0.7246357798576355, 0.7118945121765137, 0.70359206199646, 0.6963976621627808, 0.6855868697166443, 0.6781659722328186, 0.674439549446106, 0.6718297600746155, 0.6620482206344604, 0.6625243425369263, 0.6583940982818604, 0.6547510623931885, 0.653891384601593, 0.6504958868026733, 0.6480897665023804, 0.645731508731842, 0.6446788907051086, 0.6420144438743591, 0.6405813694000244, 0.638357400894165, 0.6380385756492615, 0.6351664662361145, 0.6350599527359009, 0.6340840458869934, 0.6317523717880249, 0.63273024559021, 0.6311526298522949, 0.6304250955581665, 0.6296882033348083, 0.6290398240089417]

# %% [markdown]
# # SGD

# %%
model_factory('SGD')
# Out:
# my_model: Model(
#   (linear_1): Linear(in_features=784, out_features=256, bias=True)
#   (linear_2): Linear(in_features=256, out_features=10, bias=True)
#   (sigmoid12): Sigmoid()
# )
# my_optimizer: SGD (
# Parameter Group 0
#     dampening: 0
#     lr: 0.1
#     momentum: 0
#     nesterov: False
#     weight_decay: 0
# )
#
# Epoch: 1/30, Train Loss: 0.23076054, Test Loss: 0.14371527, Test Accuracy: 0.95720000
# Saving the model state dictionary for Epoch: 1 with Test loss: 0.14371527
#
# Epoch: 2/30, Train Loss: 0.10183199, Test Loss: 0.11076129, Test Accuracy: 0.96710000
# Saving the model state dictionary for Epoch: 2 with Test loss: 0.11076129
#
# Epoch: 3/30, Train Loss: 0.07231377, Test Loss: 0.09405240, Test Accuracy: 0.97260000
# Saving the model state dictionary for Epoch: 3 with Test loss: 0.09405240
#
# Epoch: 4/30, Train Loss: 0.05381012, Test Loss: 0.11043996, Test Accuracy: 0.96860000
#
# Epoch: 5/30, Train Loss: 0.03920027, Test Loss: 0.09336395, Test Accuracy: 0.97440000
# Saving the model state dictionary for Epoch: 5 with Test loss: 0.09336395
#
# Epoch: 6/30, Train Loss: 0.03235014, Test Loss: 0.08881501, Test Accuracy: 0.97570000
# Saving the model state dictionary for Epoch: 6 with Test loss: 0.08881501
#
# Epoch: 7/30, Train Loss: 0.02415379, Test Loss: 0.09101757, Test Accuracy: 0.97760000
#
# Epoch: 8/30, Train Loss: 0.01914614, Test Loss: 0.10014333, Test Accuracy: 0.97610000
#
# Epoch: 9/30, Train Loss: 0.01405778, Test Loss: 0.07904103, Test Accuracy: 0.98040000
# Saving the model state dictionary for Epoch: 9 with Test loss: 0.07904103
#
# Epoch: 10/30, Train Loss: 0.00724886, Test Loss: 0.07715997, Test Accuracy: 0.98170000
# Saving the model state dictionary for Epoch: 10 with Test loss: 0.07715997
#
# Epoch: 11/30, Train Loss: 0.00397269, Test Loss: 0.07600267, Test Accuracy: 0.98140000
# Saving the model state dictionary for Epoch: 11 with Test loss: 0.07600267
#
# Epoch: 12/30, Train Loss: 0.00234887, Test Loss: 0.07600504, Test Accuracy: 0.98200000
#
# Epoch: 13/30, Train Loss: 0.00175854, Test Loss: 0.07773971, Test Accuracy: 0.98090000
#
# Epoch: 14/30, Train Loss: 0.00121190, Test Loss: 0.07731909, Test Accuracy: 0.98180000
#
# Epoch: 15/30, Train Loss: 0.00096767, Test Loss: 0.07867817, Test Accuracy: 0.98180000
#
# Epoch: 16/30, Train Loss: 0.00076397, Test Loss: 0.07853685, Test Accuracy: 0.98160000
#
# Epoch: 17/30, Train Loss: 0.00064205, Test Loss: 0.07891057, Test Accuracy: 0.98200000
#
# Epoch: 18/30, Train Loss: 0.00058111, Test Loss: 0.07902021, Test Accuracy: 0.98190000
#
# Epoch: 19/30, Train Loss: 0.00052265, Test Loss: 0.07952514, Test Accuracy: 0.98190000
#
# Epoch: 20/30, Train Loss: 0.00048330, Test Loss: 0.07956411, Test Accuracy: 0.98160000
#
# Epoch: 21/30, Train Loss: 0.00045025, Test Loss: 0.08043767, Test Accuracy: 0.98140000
#
# Epoch: 22/30, Train Loss: 0.00041919, Test Loss: 0.08037320, Test Accuracy: 0.98140000
#
# Epoch: 23/30, Train Loss: 0.00039093, Test Loss: 0.08079364, Test Accuracy: 0.98160000
#
# Epoch: 24/30, Train Loss: 0.00037023, Test Loss: 0.08131805, Test Accuracy: 0.98130000
#
# Epoch: 25/30, Train Loss: 0.00034975, Test Loss: 0.08221007, Test Accuracy: 0.98150000
#
# Epoch: 26/30, Train Loss: 0.00033337, Test Loss: 0.08223002, Test Accuracy: 0.98160000
#
# Epoch: 27/30, Train Loss: 0.00031655, Test Loss: 0.08231773, Test Accuracy: 0.98140000
#
# Epoch: 28/30, Train Loss: 0.00030156, Test Loss: 0.08242284, Test Accuracy: 0.98130000
#
# Epoch: 29/30, Train Loss: 0.00028910, Test Loss: 0.08261376, Test Accuracy: 0.98150000
#
# Epoch: 30/30, Train Loss: 0.00027631, Test Loss: 0.08320679, Test Accuracy: 0.98170000
# [tensor(0.6714, grad_fn=<MeanBackward0>), tensor(0.6847, grad_fn=<MeanBackward0>), tensor(0.6934, grad_fn=<MeanBackward0>), tensor(0.7002, grad_fn=<MeanBackward0>), tensor(0.6910, grad_fn=<MeanBackward0>), tensor(0.6975, grad_fn=<MeanBackward0>), tensor(0.6917, grad_fn=<MeanBackward0>), tensor(0.6897, grad_fn=<MeanBackward0>), tensor(0.6914, grad_fn=<MeanBackward0>), tensor(0.6862, grad_fn=<MeanBackward0>), tensor(0.6770, grad_fn=<MeanBackward0>), tensor(0.6728, grad_fn=<MeanBackward0>), tensor(0.6714, grad_fn=<MeanBackward0>), tensor(0.6670, grad_fn=<MeanBackward0>), tensor(0.6638, grad_fn=<MeanBackward0>), tensor(0.6624, grad_fn=<MeanBackward0>), tensor(0.6610, grad_fn=<MeanBackward0>), tensor(0.6600, grad_fn=<MeanBackward0>), tensor(0.6585, grad_fn=<MeanBackward0>), tensor(0.6580, grad_fn=<MeanBackward0>), tensor(0.6575, grad_fn=<MeanBackward0>), tensor(0.6565, grad_fn=<MeanBackward0>), tensor(0.6562, grad_fn=<MeanBackward0>), tensor(0.6551, grad_fn=<MeanBackward0>), tensor(0.6550, grad_fn=<MeanBackward0>), tensor(0.6543, grad_fn=<MeanBackward0>), tensor(0.6536, grad_fn=<MeanBackward0>), tensor(0.6534, grad_fn=<MeanBackward0>), tensor(0.6527, grad_fn=<MeanBackward0>), tensor(0.6522, grad_fn=<MeanBackward0>)]
# average_sparsity: [0.6713957786560059, 0.6847198605537415, 0.6934135556221008, 0.7001761794090271, 0.6910001039505005, 0.6975476145744324, 0.6916636228561401, 0.6896623373031616, 0.6914263367652893, 0.6862107515335083, 0.6770212054252625, 0.6728025078773499, 0.6714149117469788, 0.6670070886611938, 0.6638328433036804, 0.6623530983924866, 0.660971462726593, 0.6600178480148315, 0.658499538898468, 0.6579555869102478, 0.6574523448944092, 0.6564598679542542, 0.6562415957450867, 0.655096709728241, 0.6549668908119202, 0.6543229222297668, 0.6536387205123901, 0.6534331440925598, 0.6526852250099182, 0.6522182822227478]

# %% [markdown]
# # Adam

# %%
model_factory('Adam')
