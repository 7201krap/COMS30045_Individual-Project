# %% [markdown]
# <a href="https://colab.research.google.com/github/7201krap/PYTORCH_project/blob/main/sparsity_4_HL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
from torchvision import transforms
import torchvision.datasets as datasets
import matplotlib.pyplot as plt
import numpy as np
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
torch.manual_seed(1234)
np.random.seed(1234)

# %%
mnist_trainset = datasets.MNIST(root='./data', train=True, 
                                download=True, 
                                transform=transforms.Compose([transforms.ToTensor()]))

mnist_testset  = datasets.MNIST(root='./data', 
                                train=False, 
                                download=True, 
                                transform=transforms.Compose([transforms.ToTensor()]))

train_dataloader = torch.utils.data.DataLoader(mnist_trainset, 
                                               batch_size=50, 
                                               shuffle=True)

test_dataloader  = torch.utils.data.DataLoader(mnist_testset, 
                                               batch_size=50, 
                                               shuffle=False)

print("Training dataset size: ", len(mnist_trainset))
print("Testing dataset size: ",  len(mnist_testset))
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ./data/MNIST/raw/train-images-idx3-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ./data/MNIST/raw/train-images-idx3-ubyte.gz to ./data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ./data/MNIST/raw/train-labels-idx1-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ./data/MNIST/raw/train-labels-idx1-ubyte.gz to ./data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw/t10k-images-idx3-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ./data/MNIST/raw/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw
# Processing...
# Done!
# Training dataset size:  60000
# Testing dataset size:  10000
# /usr/local/lib/python3.6/dist-packages/torchvision/datasets/mnist.py:480: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /pytorch/torch/csrc/utils/tensor_numpy.cpp:141.)
#   return torch.from_numpy(parsed.astype(m[2], copy=False)).view(*s)

# %%
# ************* modify this section for later use *************
# Define the model 
class Model(torch.nn.Module):
    def __init__(self):
        super(Model, self).__init__()

        # modify this section for later use 
        self.linear_1 = torch.nn.Linear(784, 256)
        self.linear_2 = torch.nn.Linear(256, 256)
        self.linear_3 = torch.nn.Linear(256, 256)
        self.linear_4 = torch.nn.Linear(256, 256)
        self.linear_5 = torch.nn.Linear(256, 10)
        self.sigmoid12  = torch.nn.Sigmoid()
        self.sigmoid23  = torch.nn.Sigmoid()
        self.sigmoid34  = torch.nn.Sigmoid()
        self.sigmoid45  = torch.nn.Sigmoid()

        self.layer_activations = dict()

    def forward(self, x):

        # modify this section for later use 
        x = x.reshape(x.size(0), -1)
        x = self.linear_1(x)
        x = self.sigmoid12(x)
        x = self.linear_2(x)
        x = self.sigmoid23(x)
        x = self.linear_3(x)
        x = self.sigmoid34(x)
        x = self.linear_4(x)
        x = self.sigmoid45(x)
        pred = self.linear_5(x)
        return pred
# ************* modify this section for later use *************

# %%
def get_activation(model, layer_name):    
    def hook(module, input, output):
        model.layer_activations[layer_name] = output
    return hook

# %%
def sparsity_calculator(final_spareness):
    sparseness_list = list()
    for single_epoch_spareness in final_spareness:

        hidden_layer_activation_list = single_epoch_spareness
        hidden_layer_activation_list = torch.stack(hidden_layer_activation_list)
        layer_activations_list = torch.reshape(hidden_layer_activation_list, (10000, 256))

        layer_activations_list = torch.abs(layer_activations_list)  # modified 
        num_neurons = layer_activations_list.shape[1]
        population_sparseness = (np.sqrt(num_neurons) - (torch.sum(layer_activations_list, dim=1) / torch.sqrt(torch.sum(layer_activations_list ** 2, dim=1)))) / (np.sqrt(num_neurons) - 1)
        mean_sparseness_per_epoch = torch.mean(population_sparseness)

        sparseness_list.append(mean_sparseness_per_epoch)

    return sparseness_list

# %%
def model_factory(optimizer_name):
    '''
    optimizer_name : choose one of Adagrad, Adadelta, SGD, and Adam 

    '''
    my_model = Model()
    print("my_model:", my_model)
    my_model.to(device)

    # ************* modify this section for later use *************
    # modify this section for later use 
    my_model.sigmoid12.register_forward_hook(get_activation(my_model, 's12'))
    my_model.sigmoid23.register_forward_hook(get_activation(my_model, 's23'))
    my_model.sigmoid34.register_forward_hook(get_activation(my_model, 's34'))
    my_model.sigmoid45.register_forward_hook(get_activation(my_model, 's45'))
    # ************* modify this section for later use *************

    if optimizer_name == 'Adadelta':
        my_optimizer = torch.optim.Adadelta(my_model.parameters(), lr=1.0)

    elif optimizer_name == 'Adagrad':
        my_optimizer = torch.optim.Adagrad(my_model.parameters(), lr=0.1)

    elif optimizer_name == 'SGD':
        my_optimizer = torch.optim.SGD(my_model.parameters(), lr=0.1)

    elif optimizer_name == 'Adam':
        my_optimizer = torch.optim.Adam(my_model.parameters(), lr=0.001)

    else:
        print("ERROR")
    
    print("my_optimizer:", my_optimizer)
    test_acc, sparseness_list = sparsity_trainer(optimizer=my_optimizer, model=my_model)
    # ************* modify this section for later use *************
    file_saver = open(f"4HL_sparsity_{optimizer_name}.txt", "w")
    # ************* modify this section for later use *************
    file_saver.write(str(test_acc)+'\n'+str(sparseness_list)+'\n\n')
    file_saver.close()

    # ************* modify this section for later use *************
    if optimizer_name == 'Adadelta':
        # !cp 4HL_sparsity_Adadelta.txt /content/drive/MyDrive
    
    elif optimizer_name == 'Adagrad':
        # !cp 4HL_sparsity_Adagrad.txt /content/drive/MyDrive

    elif optimizer_name == 'SGD':
        # !cp 4HL_sparsity_SGD.txt /content/drive/MyDrive

    elif optimizer_name == 'Adam':
        # !cp 4HL_sparsity_Adam.txt /content/drive/MyDrive
    # ************* modify this section for later use *************

    else:
        print("ERROR")

# %%
def sparsity_trainer(optimizer, model):
    criterion = torch.nn.CrossEntropyLoss()
    no_epochs = 50

    train_loss = list()
    test_loss  = list()
    test_acc   = list()

    # ************* modify this section for later use *************
    final_spareness_12 = list()
    final_spareness_23 = list()
    final_spareness_34 = list()
    final_spareness_45 = list()
    # ************* modify this section for later use *************

    best_test_loss = 1
    for epoch in range(no_epochs):
        total_train_loss = 0
        total_test_loss = 0

        # ************* modify this section for later use *************
        hidden_layer_activation_list_12 = list()
        hidden_layer_activation_list_23 = list()
        hidden_layer_activation_list_34 = list()
        hidden_layer_activation_list_45 = list()
        # ************* modify this section for later use *************

        # training
        # set up training mode 
        model.train()
        for itr, (image, label) in enumerate(train_dataloader):
            image, label = image.to(device), label.to(device)

            optimizer.zero_grad()

            pred = model(image)

            loss = criterion(pred, label)
            total_train_loss += loss.item()

            loss.backward()
            optimizer.step()

        total_train_loss = total_train_loss / (itr + 1)
        train_loss.append(total_train_loss)

        # testing 
        # change to evaluation mode 
        model.eval()
        total = 0
        for itr, (image, label) in enumerate(test_dataloader):
            image, label = image.to(device), label.to(device)

            pred = model(image)

            loss = criterion(pred, label)
            total_test_loss += loss.item()

            # we now need softmax because we are testing.
            pred = torch.nn.functional.softmax(pred, dim=1)
            for i, p in enumerate(pred):
                if label[i] == torch.max(p.data, 0)[1]:
                    total = total + 1

            # ***************** sparsity calculation ***************** #
            hidden_layer_activation_list_12.append(model.layer_activations['s12'])
            hidden_layer_activation_list_23.append(model.layer_activations['s23'])
            hidden_layer_activation_list_34.append(model.layer_activations['s34'])
            hidden_layer_activation_list_45.append(model.layer_activations['s45'])

        # this conains activations for all epochs 
        final_spareness_12.append(hidden_layer_activation_list_12)
        final_spareness_23.append(hidden_layer_activation_list_23)
        final_spareness_34.append(hidden_layer_activation_list_34)
        final_spareness_45.append(hidden_layer_activation_list_45)
        # ***************** sparsity calculation ***************** #

        # caculate accuracy 
        accuracy = total / len(mnist_testset)

        # append accuracy here
        test_acc.append(accuracy)

        # append test loss here 
        total_test_loss = total_test_loss / (itr + 1)
        test_loss.append(total_test_loss)

        print('\nEpoch: {}/{}, Train Loss: {:.8f}, Test Loss: {:.8f}, Test Accuracy: {:.8f}'.format(epoch + 1, no_epochs, total_train_loss, total_test_loss, accuracy))

        if total_test_loss < best_test_loss:
            best_test_loss = total_test_loss
            print("Saving the model state dictionary for Epoch: {} with Test loss: {:.8f}".format(epoch + 1, total_test_loss))
            torch.save(model.state_dict(), "model.dth")


    # ***************** sparsity calculation ***************** #
    sparsity_list12 = sparsity_calculator(final_spareness_12)
    sparsity_list23 = sparsity_calculator(final_spareness_23)
    sparsity_list34 = sparsity_calculator(final_spareness_34)
    sparsity_list45 = sparsity_calculator(final_spareness_45)

    print(sparsity_list12)
    print(sparsity_list23)
    print(sparsity_list34)
    print(sparsity_list45)

    average_sparsity = list()
    for i in range(no_epochs):
        average_sparsity.append( (sparsity_list12[i].item() + sparsity_list23[i].item() + sparsity_list34[i].item() + sparsity_list45[i].item()) / 4 )

    # ***************** sparsity calculation ***************** #

    print("average_sparsity:", average_sparsity)

    return test_acc, average_sparsity

# %% [markdown]
# # Adadelta

# %%
model_factory('Adadelta')
# Out:
# my_model: Model(
#   (linear_1): Linear(in_features=784, out_features=256, bias=True)
#   (linear_2): Linear(in_features=256, out_features=256, bias=True)
#   (linear_3): Linear(in_features=256, out_features=256, bias=True)
#   (linear_4): Linear(in_features=256, out_features=256, bias=True)
#   (linear_5): Linear(in_features=256, out_features=10, bias=True)
#   (sigmoid12): Sigmoid()
#   (sigmoid23): Sigmoid()
#   (sigmoid34): Sigmoid()
#   (sigmoid45): Sigmoid()
# )
# my_optimizer: Adadelta (
# Parameter Group 0
#     eps: 1e-06
#     lr: 1.0
#     rho: 0.9
#     weight_decay: 0
# )
#
# Epoch: 1/50, Train Loss: 2.30746806, Test Loss: 2.30202828, Test Accuracy: 0.09580000
#
# Epoch: 2/50, Train Loss: 2.30127321, Test Loss: 2.29988619, Test Accuracy: 0.11350000
#
# Epoch: 3/50, Train Loss: 2.18322133, Test Loss: 1.78346960, Test Accuracy: 0.35970000
#
# Epoch: 4/50, Train Loss: 1.38807301, Test Loss: 1.05196524, Test Accuracy: 0.58940000
#
# Epoch: 5/50, Train Loss: 0.73925218, Test Loss: 0.40720799, Test Accuracy: 0.89020000
# Saving the model state dictionary for Epoch: 5 with Test loss: 0.40720799
#
# Epoch: 6/50, Train Loss: 0.35055105, Test Loss: 0.30235327, Test Accuracy: 0.91540000
# Saving the model state dictionary for Epoch: 6 with Test loss: 0.30235327
#
# Epoch: 7/50, Train Loss: 0.22971164, Test Loss: 0.18080222, Test Accuracy: 0.94850000
# Saving the model state dictionary for Epoch: 7 with Test loss: 0.18080222
#
# Epoch: 8/50, Train Loss: 0.16830985, Test Loss: 0.16071026, Test Accuracy: 0.95200000
# Saving the model state dictionary for Epoch: 8 with Test loss: 0.16071026
#
# Epoch: 9/50, Train Loss: 0.13468080, Test Loss: 0.14689394, Test Accuracy: 0.95620000
# Saving the model state dictionary for Epoch: 9 with Test loss: 0.14689394
#
# Epoch: 10/50, Train Loss: 0.11125843, Test Loss: 0.13769206, Test Accuracy: 0.96050000
# Saving the model state dictionary for Epoch: 10 with Test loss: 0.13769206
#
# Epoch: 11/50, Train Loss: 0.09575476, Test Loss: 0.12158648, Test Accuracy: 0.96510000
# Saving the model state dictionary for Epoch: 11 with Test loss: 0.12158648
#
# Epoch: 12/50, Train Loss: 0.08345702, Test Loss: 0.10658960, Test Accuracy: 0.96770000
# Saving the model state dictionary for Epoch: 12 with Test loss: 0.10658960
#
# Epoch: 13/50, Train Loss: 0.07242754, Test Loss: 0.10226144, Test Accuracy: 0.97110000
# Saving the model state dictionary for Epoch: 13 with Test loss: 0.10226144
#
# Epoch: 14/50, Train Loss: 0.06346313, Test Loss: 0.12266155, Test Accuracy: 0.96430000
#
# Epoch: 15/50, Train Loss: 0.05714242, Test Loss: 0.11185047, Test Accuracy: 0.97000000
#
# Epoch: 16/50, Train Loss: 0.04942246, Test Loss: 0.09444616, Test Accuracy: 0.97360000
# Saving the model state dictionary for Epoch: 16 with Test loss: 0.09444616
#
# Epoch: 17/50, Train Loss: 0.04504933, Test Loss: 0.08744242, Test Accuracy: 0.97590000
# Saving the model state dictionary for Epoch: 17 with Test loss: 0.08744242
#
# Epoch: 18/50, Train Loss: 0.03980248, Test Loss: 0.09040098, Test Accuracy: 0.97700000
#
# Epoch: 19/50, Train Loss: 0.03666460, Test Loss: 0.09473705, Test Accuracy: 0.97510000
#
# Epoch: 20/50, Train Loss: 0.03226419, Test Loss: 0.08644515, Test Accuracy: 0.97760000
# Saving the model state dictionary for Epoch: 20 with Test loss: 0.08644515
#
# Epoch: 21/50, Train Loss: 0.02791058, Test Loss: 0.09336979, Test Accuracy: 0.97580000
#
# Epoch: 22/50, Train Loss: 0.02439863, Test Loss: 0.10836138, Test Accuracy: 0.97450000
#
# Epoch: 23/50, Train Loss: 0.02249796, Test Loss: 0.09321684, Test Accuracy: 0.97700000
#
# Epoch: 24/50, Train Loss: 0.01903963, Test Loss: 0.09568256, Test Accuracy: 0.97730000
#
# Epoch: 25/50, Train Loss: 0.01696350, Test Loss: 0.09538523, Test Accuracy: 0.97780000
#
# Epoch: 26/50, Train Loss: 0.01522236, Test Loss: 0.09633715, Test Accuracy: 0.97810000
#
# Epoch: 27/50, Train Loss: 0.01188147, Test Loss: 0.10121652, Test Accuracy: 0.97800000
#
# Epoch: 28/50, Train Loss: 0.01160973, Test Loss: 0.09870198, Test Accuracy: 0.97860000
#
# Epoch: 29/50, Train Loss: 0.00892739, Test Loss: 0.09962072, Test Accuracy: 0.97890000
#
# Epoch: 30/50, Train Loss: 0.00832559, Test Loss: 0.12868255, Test Accuracy: 0.97400000
#
# Epoch: 31/50, Train Loss: 0.00778611, Test Loss: 0.11178751, Test Accuracy: 0.97860000
#
# Epoch: 32/50, Train Loss: 0.00701609, Test Loss: 0.11022323, Test Accuracy: 0.97830000
#
39850524067878723, 0.3989047035574913, 0.3999805599451065, 0.39935269951820374, 0.4000220149755478, 0.3995167836546898, 0.40120742470026016, 0.40125831216573715, 0.4005100727081299, 0.40017934143543243, 0.40161945670843124, 0.39913516491651535, 0.4002820998430252, 0.40030234679579735, 0.39980581030249596, 0.39924973249435425, 0.3991476409137249, 0.40001118555665016, 0.3991791158914566, 0.3996175192296505, 0.398356381803751, 0.3969818614423275, 0.3976045697927475, 0.39792096242308617, 0.3978043347597122, 0.39794081449508667, 0.3973494842648506, 0.3972882181406021, 0.3967374563217163, 0.3973778523504734]

# %% [markdown]
# # Adagrad

# %%
model_factory('Adagrad')
# Out:
# my_model: Model(
#   (linear_1): Linear(in_features=784, out_features=256, bias=True)
#   (linear_2): Linear(in_features=256, out_features=256, bias=True)
#   (linear_3): Linear(in_features=256, out_features=256, bias=True)
#   (linear_4): Linear(in_features=256, out_features=256, bias=True)
#   (linear_5): Linear(in_features=256, out_features=10, bias=True)
#   (sigmoid12): Sigmoid()
#   (sigmoid23): Sigmoid()
#   (sigmoid34): Sigmoid()
#   (sigmoid45): Sigmoid()
# )
# my_optimizer: Adagrad (
# Parameter Group 0
#     eps: 1e-10
#     initial_accumulator_value: 0
#     lr: 0.1
#     lr_decay: 0
#     weight_decay: 0
# )
#
# Epoch: 1/50, Train Loss: 2.41819022, Test Loss: 2.32539585, Test Accuracy: 0.09800000
#
# Epoch: 2/50, Train Loss: 2.32925108, Test Loss: 2.33123996, Test Accuracy: 0.09740000
#
# Epoch: 3/50, Train Loss: 2.32166393, Test Loss: 2.32314409, Test Accuracy: 0.11350000
#
# Epoch: 4/50, Train Loss: 2.31882390, Test Loss: 2.32085699, Test Accuracy: 0.09800000
#
# Epoch: 5/50, Train Loss: 2.31751980, Test Loss: 2.32146742, Test Accuracy: 0.09740000
#
# Epoch: 6/50, Train Loss: 2.31595872, Test Loss: 2.31645920, Test Accuracy: 0.10280000
#
# Epoch: 7/50, Train Loss: 2.31481079, Test Loss: 2.31099050, Test Accuracy: 0.09800000
#
# Epoch: 8/50, Train Loss: 2.24502957, Test Loss: 1.97606042, Test Accuracy: 0.19600000
#
# Epoch: 9/50, Train Loss: 1.13514087, Test Loss: 0.22670037, Test Accuracy: 0.94010000
# Saving the model state dictionary for Epoch: 9 with Test loss: 0.22670037
#
# Epoch: 10/50, Train Loss: 0.17001255, Test Loss: 0.13376148, Test Accuracy: 0.96120000
# Saving the model state dictionary for Epoch: 10 with Test loss: 0.13376148
#
# Epoch: 11/50, Train Loss: 0.10235569, Test Loss: 0.12185000, Test Accuracy: 0.96400000
# Saving the model state dictionary for Epoch: 11 with Test loss: 0.12185000
#
# Epoch: 12/50, Train Loss: 0.07277847, Test Loss: 0.11209685, Test Accuracy: 0.96810000
# Saving the model state dictionary for Epoch: 12 with Test loss: 0.11209685
#
# Epoch: 13/50, Train Loss: 0.05391278, Test Loss: 0.10854395, Test Accuracy: 0.97010000
# Saving the model state dictionary for Epoch: 13 with Test loss: 0.10854395
#
# Epoch: 14/50, Train Loss: 0.04107062, Test Loss: 0.09816240, Test Accuracy: 0.97260000
# Saving the model state dictionary for Epoch: 14 with Test loss: 0.09816240
#
# Epoch: 15/50, Train Loss: 0.03171357, Test Loss: 0.10247319, Test Accuracy: 0.97390000
#
# Epoch: 16/50, Train Loss: 0.02504778, Test Loss: 0.11104062, Test Accuracy: 0.97400000
#
# Epoch: 17/50, Train Loss: 0.01909214, Test Loss: 0.11198316, Test Accuracy: 0.97400000
#
), tensor(0.3689, grad_fn=<MeanBackward0>), tensor(0.3699, grad_fn=<MeanBackward0>), tensor(0.3674, grad_fn=<MeanBackward0>), tensor(0.3672, grad_fn=<MeanBackward0>), tensor(0.3634, grad_fn=<MeanBackward0>), tensor(0.3645, grad_fn=<MeanBackward0>), tensor(0.3634, grad_fn=<MeanBackward0>), tensor(0.3614, grad_fn=<MeanBackward0>), tensor(0.3626, grad_fn=<MeanBackward0>), tensor(0.3619, grad_fn=<MeanBackward0>), tensor(0.3599, grad_fn=<MeanBackward0>), tensor(0.3709, grad_fn=<MeanBackward0>), tensor(0.3723, grad_fn=<MeanBackward0>), tensor(0.3728, grad_fn=<MeanBackward0>), tensor(0.3716, grad_fn=<MeanBackward0>), tensor(0.3706, grad_fn=<MeanBackward0>), tensor(0.3702, grad_fn=<MeanBackward0>), tensor(0.3697, grad_fn=<MeanBackward0>), tensor(0.3693, grad_fn=<MeanBackward0>), tensor(0.3683, grad_fn=<MeanBackward0>), tensor(0.3682, grad_fn=<MeanBackward0>), tensor(0.3677, grad_fn=<MeanBackward0>), tensor(0.3675, grad_fn=<MeanBackward0>)]
# average_sparsity: [0.3205968588590622, 0.32063061743974686, 0.32067959755659103, 0.32073433697223663, 0.3207792788743973, 0.32636068761348724, 0.3264278545975685, 0.40391556918621063, 0.452566459774971, 0.4632968604564667, 0.465554878115654, 0.46764933317899704, 0.4649207070469856, 0.4667397290468216, 0.46786589175462723, 0.46762628108263016, 0.46768926829099655, 0.4685121476650238, 0.46991387754678726, 0.46885155886411667, 0.4671708196401596, 0.46756336838006973, 0.46813061088323593, 0.4676583781838417, 0.4657291918992996, 0.46485771983861923, 0.4642110615968704, 0.46409717202186584, 0.4636908993124962, 0.46345867216587067, 0.4624222293496132, 0.461957223713398, 0.46166496723890305, 0.461457222700119, 0.460772305727005, 0.4607868120074272, 0.46048693358898163, 0.46234891563653946, 0.4658469557762146, 0.4676324799656868, 0.46841008216142654, 0.4684407711029053, 0.4685400351881981, 0.4681556820869446, 0.4680226072669029, 0.4677567332983017, 0.46734070777893066, 0.46714746952056885, 0.466844841837883, 0.4666415601968765]

# %% [markdown]
# # SGD

# %%
model_factory('SGD')
# Out:
# my_model: Model(
#   (linear_1): Linear(in_features=784, out_features=256, bias=True)
#   (linear_2): Linear(in_features=256, out_features=256, bias=True)
#   (linear_3): Linear(in_features=256, out_features=256, bias=True)
#   (linear_4): Linear(in_features=256, out_features=256, bias=True)
#   (linear_5): Linear(in_features=256, out_features=10, bias=True)
#   (sigmoid12): Sigmoid()
#   (sigmoid23): Sigmoid()
#   (sigmoid34): Sigmoid()
#   (sigmoid45): Sigmoid()
# )
# my_optimizer: SGD (
# Parameter Group 0
#     dampening: 0
#     lr: 0.1
#     momentum: 0
#     nesterov: False
#     weight_decay: 0
# )
#
# Epoch: 1/50, Train Loss: 2.32315335, Test Loss: 2.30903591, Test Accuracy: 0.09820000
#
# Epoch: 2/50, Train Loss: 2.30906891, Test Loss: 2.30911063, Test Accuracy: 0.10320000
#
# Epoch: 3/50, Train Loss: 2.30566493, Test Loss: 2.30473552, Test Accuracy: 0.11350000
#
# Epoch: 4/50, Train Loss: 2.30376772, Test Loss: 2.30548496, Test Accuracy: 0.10100000
#
# Epoch: 5/50, Train Loss: 2.30315409, Test Loss: 2.30266628, Test Accuracy: 0.11350000
#
# Epoch: 6/50, Train Loss: 2.30291336, Test Loss: 2.30233922, Test Accuracy: 0.11350000
#
# Epoch: 7/50, Train Loss: 2.30252484, Test Loss: 2.30283901, Test Accuracy: 0.11350000
# Saving the model state dictionary for Epoch: 33 with Test loss: 0.49488015
#
# Epoch: 34/50, Train Loss: 0.46595173, Test Loss: 0.41601242, Test Accuracy: 0.89550000
# Saving the model state dictionary for Epoch: 34 with Test loss: 0.41601242
#
# Epoch: 35/50, Train Loss: 0.42113649, Test Loss: 0.40295441, Test Accuracy: 0.89890000
# Saving the model state dictionary for Epoch: 35 with Test loss: 0.40295441
#
# Epoch: 36/50, Train Loss: 0.38326158, Test Loss: 0.35731597, Test Accuracy: 0.90860000
# Saving the model state dictionary for Epoch: 36 with Test loss: 0.35731597
#
# Epoch: 37/50, Train Loss: 0.35746799, Test Loss: 0.36892720, Test Accuracy: 0.90110000
#
# Epoch: 38/50, Train Loss: 0.32986234, Test Loss: 0.32568435, Test Accuracy: 0.91700000
# Saving the model state dictionary for Epoch: 38 with Test loss: 0.32568435
#
# Epoch: 39/50, Train Loss: 0.30912769, Test Loss: 0.29942385, Test Accuracy: 0.92330000
# Saving the model state dictionary for Epoch: 39 with Test loss: 0.29942385
#
# Epoch: 40/50, Train Loss: 0.29016553, Test Loss: 0.28343501, Test Accuracy: 0.92690000
# Saving the model state dictionary for Epoch: 40 with Test loss: 0.28343501
#
# Epoch: 41/50, Train Loss: 0.27181090, Test Loss: 0.26919668, Test Accuracy: 0.92910000
# Saving the model state dictionary for Epoch: 41 with Test loss: 0.26919668
#
# Epoch: 42/50, Train Loss: 0.25264632, Test Loss: 0.28705950, Test Accuracy: 0.92650000
#
# Epoch: 43/50, Train Loss: 0.23388448, Test Loss: 0.24178806, Test Accuracy: 0.93540000
# Saving the model state dictionary for Epoch: 43 with Test loss: 0.24178806
#
# Epoch: 44/50, Train Loss: 0.21865813, Test Loss: 0.25449906, Test Accuracy: 0.93520000
#
# Epoch: 45/50, Train Loss: 0.20357840, Test Loss: 0.23847303, Test Accuracy: 0.93960000
# Saving the model state dictionary for Epoch: 45 with Test loss: 0.23847303
#
# Epoch: 46/50, Train Loss: 0.19323547, Test Loss: 0.22680750, Test Accuracy: 0.94070000
# Saving the model state dictionary for Epoch: 46 with Test loss: 0.22680750
#
# Epoch: 47/50, Train Loss: 0.18324335, Test Loss: 0.20620899, Test Accuracy: 0.94460000
# Saving the model state dictionary for Epoch: 47 with Test loss: 0.20620899
#
# Epoch: 48/50, Train Loss: 0.17500489, Test Loss: 0.20668521, Test Accuracy: 0.94450000
#
# Epoch: 49/50, Train Loss: 0.16426414, Test Loss: 0.20673490, Test Accuracy: 0.94380000
#
# Epoch: 50/50, Train Loss: 0.15847311, Test Loss: 0.22580398, Test Accuracy: 0.93880000
# [tensor(0.0050, grad_fn=<MeanBackward0>), tensor(0.0050, grad_fn=<MeanBackward0>), tensor(0.0051, grad_fn=<MeanBackward0>), tensor(0.0051, grad_fn=<MeanBackward0>), tensor(0.0052, grad_fn=<MeanBackward0>), tensor(0.0052, grad_fn=<MeanBackward0>), tensor(0.0053, grad_fn=<MeanBackward0>), tensor(0.0053, grad_fn=<MeanBackward0>), tensor(0.0054, gr
# average_sparsity: [0.009035348426550627, 0.008382768370211124, 0.00802029320038855, 0.007867653068387881, 0.00773040801868774, 0.007618976189405657, 0.0075777002348331735, 0.007503570741391741, 0.007474989659385756, 0.007454085935023613, 0.007402252565952949, 0.007390893777483143, 0.007367405698460061, 0.007398378846119158, 0.007412119914079085, 0.007467655130312778, 0.007564794737845659, 0.007666758086998016, 0.007968980818986893, 0.008500382537022233, 0.009004134335555136, 0.010887250420637429, 0.02403877885080874, 0.04004678549245, 0.0706070177257061, 0.10460402816534042, 0.12456478551030159, 0.1430625133216381, 0.13143142499029636, 0.1417810469865799, 0.15309476107358932, 0.16423430666327477, 0.1703992746770382, 0.1763467025011778, 0.18103162199258804, 0.18575506284832954, 0.19259759411215782, 0.1925140880048275, 0.1962235625833273, 0.19976531527936459, 0.20316720381379128, 0.203604469075799, 0.20596718788146973, 0.20545179769396782, 0.2056525405496359, 0.20799864456057549, 0.20997013337910175, 0.2110370583832264, 0.2129291519522667, 0.21408026479184628]

# %% [markdown]
# # Adam

# %%
model_factory('Adam')
# Out:
# my_model: Model(
#   (linear_1): Linear(in_features=784, out_features=256, bias=True)
#   (linear_2): Linear(in_features=256, out_features=256, bias=True)
#   (linear_3): Linear(in_features=256, out_features=256, bias=True)
#   (linear_4): Linear(in_features=256, out_features=256, bias=True)
#   (linear_5): Linear(in_features=256, out_features=10, bias=True)
#   (sigmoid12): Sigmoid()
#   (sigmoid23): Sigmoid()
#   (sigmoid34): Sigmoid()
#   (sigmoid45): Sigmoid()
# )
# my_optimizer: Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.001
#     weight_decay: 0
# )
#
# Epoch: 1/50, Train Loss: 0.63060462, Test Loss: 0.26807361, Test Accuracy: 0.92430000
# Saving the model state dictionary for Epoch: 1 with Test loss: 0.26807361
#
# Epoch: 2/50, Train Loss: 0.20602424, Test Loss: 0.17091358, Test Accuracy: 0.95030000
# Saving the model state dictionary for Epoch: 2 with Test loss: 0.17091358
#
# Epoch: 3/50, Train Loss: 0.13963423, Test Loss: 0.13862534, Test Accuracy: 0.96050000
# Saving the model state dictionary for Epoch: 3 with Test loss: 0.13862534
#
# Epoch: 4/50, Train Loss: 0.10679276, Test Loss: 0.11708060, Test Accuracy: 0.96550000
# Saving the model state dictionary for Epoch: 4 with Test loss: 0.11708060
#
# Epoch: 5/50, Train Loss: 0.08605077, Test Loss: 0.10161784, Test Accuracy: 0.96890000
# Saving the model state dictionary for Epoch: 5 with Test loss: 0.10161784
#
# Epoch: 6/50, Train Loss: 0.06997542, Test Loss: 0.10106366, Test Accuracy: 0.96990000
# Saving the model state dictionary for Epoch: 6 with Test loss: 0.10106366
#
# Epoch: 7/50, Train Loss: 0.05697624, Test Loss: 0.09878752, Test Accuracy: 0.97310000
# Saving the model state dictionary for Epoch: 7 with Test loss: 0.09878752
#
# Epoch: 8/50, Train Loss: 0.04864491, Test Loss: 0.08308134, Test Accuracy: 0.97660000
# Saving the model state dictionary for Epoch: 8 with Test loss: 0.08308134
#
# Epoch: 9/50, Train Loss: 0.03917250, Test Loss: 0.09710392, Test Accuracy: 0.97200000
#
