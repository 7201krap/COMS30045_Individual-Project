# %% [markdown]
# <a href="https://colab.research.google.com/github/7201krap/PYTORCH_project/blob/main/sparsity_5_HL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
from torchvision import transforms
import torchvision.datasets as datasets
import matplotlib.pyplot as plt
import numpy as np
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
torch.manual_seed(1234)
np.random.seed(1234)

# %%
mnist_trainset = datasets.MNIST(root='./data', train=True, 
                                download=True, 
                                transform=transforms.Compose([transforms.ToTensor()]))

mnist_testset  = datasets.MNIST(root='./data', 
                                train=False, 
                                download=True, 
                                transform=transforms.Compose([transforms.ToTensor()]))

train_dataloader = torch.utils.data.DataLoader(mnist_trainset, 
                                               batch_size=50, 
                                               shuffle=True)

test_dataloader  = torch.utils.data.DataLoader(mnist_testset, 
                                               batch_size=50, 
                                               shuffle=False)

print("Training dataset size: ", len(mnist_trainset))
print("Testing dataset size: ",  len(mnist_testset))
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ./data/MNIST/raw/train-images-idx3-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ./data/MNIST/raw/train-images-idx3-ubyte.gz to ./data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ./data/MNIST/raw/train-labels-idx1-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ./data/MNIST/raw/train-labels-idx1-ubyte.gz to ./data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw/t10k-images-idx3-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ./data/MNIST/raw/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw
# Processing...
# Done!
# Training dataset size:  60000
# Testing dataset size:  10000
# /usr/local/lib/python3.6/dist-packages/torchvision/datasets/mnist.py:480: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /pytorch/torch/csrc/utils/tensor_numpy.cpp:141.)
#   return torch.from_numpy(parsed.astype(m[2], copy=False)).view(*s)

# %%
# ************* modify this section for later use *************
# Define the model 
class Model(torch.nn.Module):
    def __init__(self):
        super(Model, self).__init__()

        # modify this section for later use 
        self.linear_1 = torch.nn.Linear(784, 256)
        self.linear_2 = torch.nn.Linear(256, 256)
        self.linear_3 = torch.nn.Linear(256, 256)
        self.linear_4 = torch.nn.Linear(256, 256)
        self.linear_5 = torch.nn.Linear(256, 256)
        self.linear_6 = torch.nn.Linear(256, 10)
        self.sigmoid12  = torch.nn.Sigmoid()
        self.sigmoid23  = torch.nn.Sigmoid()
        self.sigmoid34  = torch.nn.Sigmoid()
        self.sigmoid45  = torch.nn.Sigmoid()
        self.sigmoid56  = torch.nn.Sigmoid()

        self.layer_activations = dict()

    def forward(self, x):

        # modify this section for later use 
        x = x.reshape(x.size(0), -1)
        x = self.linear_1(x)
        x = self.sigmoid12(x)
        x = self.linear_2(x)
        x = self.sigmoid23(x)
        x = self.linear_3(x)
        x = self.sigmoid34(x)
        x = self.linear_4(x)
        x = self.sigmoid45(x)
        x = self.linear_5(x)
        x = self.sigmoid56(x)
        pred = self.linear_6(x)
        return pred
# ************* modify this section for later use *************

# %%
def get_activation(model, layer_name):    
    def hook(module, input, output):
        model.layer_activations[layer_name] = output
    return hook

# %%
def sparsity_calculator(final_spareness):
    sparseness_list = list()
    for single_epoch_spareness in final_spareness:

        hidden_layer_activation_list = single_epoch_spareness
        hidden_layer_activation_list = torch.stack(hidden_layer_activation_list)
        layer_activations_list = torch.reshape(hidden_layer_activation_list, (10000, 256))

        layer_activations_list = torch.abs(layer_activations_list)  # modified 
        num_neurons = layer_activations_list.shape[1]
        population_sparseness = (np.sqrt(num_neurons) - (torch.sum(layer_activations_list, dim=1) / torch.sqrt(torch.sum(layer_activations_list ** 2, dim=1)))) / (np.sqrt(num_neurons) - 1)
        mean_sparseness_per_epoch = torch.mean(population_sparseness)

        sparseness_list.append(mean_sparseness_per_epoch)

    return sparseness_list

# %%
def model_factory(optimizer_name):
    '''
    optimizer_name : choose one of Adagrad, Adadelta, SGD, and Adam 

    '''
    my_model = Model()
    print("my_model:", my_model)
    my_model.to(device)

    # ************* modify this section for later use *************
    # modify this section for later use 
    my_model.sigmoid12.register_forward_hook(get_activation(my_model, 's12'))
    my_model.sigmoid23.register_forward_hook(get_activation(my_model, 's23'))
    my_model.sigmoid34.register_forward_hook(get_activation(my_model, 's34'))
    my_model.sigmoid45.register_forward_hook(get_activation(my_model, 's45'))
    my_model.sigmoid56.register_forward_hook(get_activation(my_model, 's56'))
    # ************* modify this section for later use *************

    if optimizer_name == 'Adadelta':
        my_optimizer = torch.optim.Adadelta(my_model.parameters(), lr=1.0)

    elif optimizer_name == 'Adagrad':
        my_optimizer = torch.optim.Adagrad(my_model.parameters(), lr=0.1)

    elif optimizer_name == 'SGD':
        my_optimizer = torch.optim.SGD(my_model.parameters(), lr=0.1)

    elif optimizer_name == 'Adam':
        my_optimizer = torch.optim.Adam(my_model.parameters(), lr=0.001)

    else:
        print("ERROR")
    
    print("my_optimizer:", my_optimizer)
    test_acc, sparseness_list = sparsity_trainer(optimizer=my_optimizer, model=my_model)
    # ************* modify this section for later use *************
    file_saver = open(f"5HL_sparsity_{optimizer_name}.txt", "w")
    # ************* modify this section for later use *************
    file_saver.write(str(test_acc)+'\n'+str(sparseness_list)+'\n\n')
    file_saver.close()

    # ************* modify this section for later use *************
    if optimizer_name == 'Adadelta':
        # !cp 5HL_sparsity_Adadelta.txt /content/drive/MyDrive
    
    elif optimizer_name == 'Adagrad':
        # !cp 5HL_sparsity_Adagrad.txt /content/drive/MyDrive

    elif optimizer_name == 'SGD':
        # !cp 5HL_sparsity_SGD.txt /content/drive/MyDrive

    elif optimizer_name == 'Adam':
        # !cp 5HL_sparsity_Adam.txt /content/drive/MyDrive
    # ************* modify this section for later use *************

    else:
        print("ERROR")

# %%
def sparsity_trainer(optimizer, model):
    criterion = torch.nn.CrossEntropyLoss()
    no_epochs = 50

    train_loss = list()
    test_loss  = list()
    test_acc   = list()

    # ************* modify this section for later use *************
    final_spareness_12 = list()
    final_spareness_23 = list()
    final_spareness_34 = list()
    final_spareness_45 = list()
    final_spareness_56 = list()
    # ************* modify this section for later use *************

    best_test_loss = 1
    for epoch in range(no_epochs):
        total_train_loss = 0
        total_test_loss = 0

        # ************* modify this section for later use *************
        hidden_layer_activation_list_12 = list()
        hidden_layer_activation_list_23 = list()
        hidden_layer_activation_list_34 = list()
        hidden_layer_activation_list_45 = list()
        hidden_layer_activation_list_56 = list()
        # ************* modify this section for later use *************

        # training
        # set up training mode 
        model.train()
        for itr, (image, label) in enumerate(train_dataloader):
            image, label = image.to(device), label.to(device)

            optimizer.zero_grad()

            pred = model(image)

            loss = criterion(pred, label)
            total_train_loss += loss.item()

            loss.backward()
            optimizer.step()

        total_train_loss = total_train_loss / (itr + 1)
        train_loss.append(total_train_loss)

        # testing 
        # change to evaluation mode 
        model.eval()
        total = 0
        for itr, (image, label) in enumerate(test_dataloader):
            image, label = image.to(device), label.to(device)

            pred = model(image)

            loss = criterion(pred, label)
            total_test_loss += loss.item()

            # we now need softmax because we are testing.
            pred = torch.nn.functional.softmax(pred, dim=1)
            for i, p in enumerate(pred):
                if label[i] == torch.max(p.data, 0)[1]:
                    total = total + 1

            # ***************** sparsity calculation ***************** #
            hidden_layer_activation_list_12.append(model.layer_activations['s12'])
            hidden_layer_activation_list_23.append(model.layer_activations['s23'])
            hidden_layer_activation_list_34.append(model.layer_activations['s34'])
            hidden_layer_activation_list_45.append(model.layer_activations['s45'])
            hidden_layer_activation_list_56.append(model.layer_activations['s56'])

        # this conains activations for all epochs 
        final_spareness_12.append(hidden_layer_activation_list_12)
        final_spareness_23.append(hidden_layer_activation_list_23)
        final_spareness_34.append(hidden_layer_activation_list_34)
        final_spareness_45.append(hidden_layer_activation_list_45)
        final_spareness_56.append(hidden_layer_activation_list_56)
        # ***************** sparsity calculation ***************** #

        # caculate accuracy 
        accuracy = total / len(mnist_testset)

        # append accuracy here
        test_acc.append(accuracy)

        # append test loss here 
        total_test_loss = total_test_loss / (itr + 1)
        test_loss.append(total_test_loss)

        print('\nEpoch: {}/{}, Train Loss: {:.8f}, Test Loss: {:.8f}, Test Accuracy: {:.8f}'.format(epoch + 1, no_epochs, total_train_loss, total_test_loss, accuracy))

        if total_test_loss < best_test_loss:
            best_test_loss = total_test_loss
            print("Saving the model state dictionary for Epoch: {} with Test loss: {:.8f}".format(epoch + 1, total_test_loss))
            torch.save(model.state_dict(), "model.dth")


    # ***************** sparsity calculation ***************** #
    sparsity_list12 = sparsity_calculator(final_spareness_12)
    sparsity_list23 = sparsity_calculator(final_spareness_23)
    sparsity_list34 = sparsity_calculator(final_spareness_34)
    sparsity_list45 = sparsity_calculator(final_spareness_45)
    sparsity_list56 = sparsity_calculator(final_spareness_56)

    print(sparsity_list12)
    print(sparsity_list23)
    print(sparsity_list34)
    print(sparsity_list45)
    print(sparsity_list56)

    average_sparsity = list()
    for i in range(no_epochs):
        average_sparsity.append( (sparsity_list12[i].item() + sparsity_list23[i].item() + sparsity_list34[i].item() + sparsity_list45[i].item() + sparsity_list56[i].item()) / 5 )
    # ***************** sparsity calculation ***************** #

    print("average_sparsity:", average_sparsity)

    return test_acc, average_sparsity

# %% [markdown]
# # Adadelta

# %%
model_factory('Adadelta')
# Out:
# my_model: Model(
#   (linear_1): Linear(in_features=784, out_features=256, bias=True)
#   (linear_2): Linear(in_features=256, out_features=256, bias=True)
#   (linear_3): Linear(in_features=256, out_features=256, bias=True)
#   (linear_4): Linear(in_features=256, out_features=256, bias=True)
#   (linear_5): Linear(in_features=256, out_features=256, bias=True)
#   (linear_6): Linear(in_features=256, out_features=10, bias=True)
#   (sigmoid12): Sigmoid()
#   (sigmoid23): Sigmoid()
#   (sigmoid34): Sigmoid()
#   (sigmoid45): Sigmoid()
#   (sigmoid56): Sigmoid()
# )
# my_optimizer: Adadelta (
# Parameter Group 0
#     eps: 1e-06
#     lr: 1.0
#     rho: 0.9
#     weight_decay: 0
# )
#
# Epoch: 1/50, Train Loss: 2.30755125, Test Loss: 2.30164614, Test Accuracy: 0.11350000
#
# Epoch: 2/50, Train Loss: 2.30180220, Test Loss: 2.30179365, Test Accuracy: 0.11350000
#
# Epoch: 3/50, Train Loss: 2.30164154, Test Loss: 2.30163918, Test Accuracy: 0.11350000
#
# Epoch: 4/50, Train Loss: 2.30165143, Test Loss: 2.30126957, Test Accuracy: 0.11350000
#
# Epoch: 5/50, Train Loss: 2.30157961, Test Loss: 2.30127510, Test Accuracy: 0.11350000
#
# Epoch: 6/50, Train Loss: 2.30154829, Test Loss: 2.30109044, Test Accuracy: 0.11350000
#
# Epoch: 7/50, Train Loss: 2.30157550, Test Loss: 2.30115319, Test Accuracy: 0.11350000
#
# Epoch: 8/50, Train Loss: 2.30144651, Test Loss: 2.30109491, Test Accuracy: 0.11350000
#
# Epoch: 9/50, Train Loss: 2.30152204, Test Loss: 2.30146620, Test Accuracy: 0.11350000
#
# Epoch: 10/50, Train Loss: 2.30150002, Test Loss: 2.30095167, Test Accuracy: 0.11350000
#
# Epoch: 11/50, Train Loss: 2.30149307, Test Loss: 2.30129140, Test Accuracy: 0.11350000
#
# Epoch: 12/50, Train Loss: 2.30142035, Test Loss: 2.30099960, Test Accuracy: 0.11350000
#
# Epoch: 13/50, Train Loss: 2.30151436, Test Loss: 2.30136310, Test Accuracy: 0.11350000
#
# Epoch: 14/50, Train Loss: 2.30148068, Test Loss: 2.30132864, Test Accuracy: 0.11350000
#
# Epoch: 15/50, Train Loss: 2.30148078, Test Loss: 2.30121526, Test Accuracy: 0.11350000
#
# Epoch: 16/50, Train Loss: 2.30138045, Test Loss: 2.30151163, Test Accuracy: 0.11350000
#
# Epoch: 17/50, Train Loss: 2.30132344, Test Loss: 2.30071117, Test Accuracy: 0.11350000
#
# Epoch: 18/50, Train Loss: 2.30092661, Test Loss: 2.30011426, Test Accuracy: 0.11350000
#
# Epoch: 19/50, Train Loss: 2.19843484, Test Loss: 1.83227645, Test Accuracy: 0.25280000
#
# Epoch: 20/50, Train Loss: 1.54909410, Test Loss: 1.23491094, Test Accuracy: 0.50720000
#
# Epoch: 21/50, Train Loss: 1.10597432, Test Loss: 0.91629640, Test Accuracy: 0.65430000
# Saving the model state dictionary for Epoch: 21 with Test loss: 0.91629640
#
# Epoch: 22/50, Train Loss: 0.74409707, Test Loss: 0.51272172, Test Accuracy: 0.80620000
# Saving the model state dictionary for Epoch: 22 with Test loss: 0.51272172
#
# Epoch: 23/50, Train Loss: 0.43028091, Test Loss: 0.31522844, Test Accuracy: 0.91490000
# Saving the model state dictionary for Epoch: 23 with Test loss: 0.31522844
#
# Epoch: 24/50, Train Loss: 0.25973257, Test Loss: 0.22868082, Test Accuracy: 0.93700000
# Saving the model state dictionary for Epoch: 24 with Test loss: 0.22868082
#
# Epoch: 25/50, Train Loss: 0.20133999, Test Loss: 0.18775649, Test Accuracy: 0.94950000
# Saving the model state dictionary for Epoch: 25 with Test loss: 0.18775649
#
# Epoch: 26/50, Train Loss: 0.16793479, Test Loss: 0.16521870, Test Accuracy: 0.95420000
# Saving the model state dictionary for Epoch: 26 with Test loss: 0.16521870
#
# Epoch: 27/50, Train Loss: 0.14392202, Test Loss: 0.15053058, Test Accuracy: 0.95700000
# Saving the model state dictionary for Epoch: 27 with Test loss: 0.15053058
#
# Epoch: 28/50, Train Loss: 0.12330586, Test Loss: 0.14990695, Test Accuracy: 0.95720000
# Saving the model state dictionary for Epoch: 28 with Test loss: 0.14990695
#
# Epoch: 29/50, Train Loss: 0.10978656, Test Loss: 0.18744930, Test Accuracy: 0.94570000
#
# Epoch: 30/50, Train Loss: 0.09895964, Test Loss: 0.16141290, Test Accuracy: 0.95510000
#
# Epoch: 31/50, Train Loss: 0.08977335, Test Loss: 0.14812993, Test Accuracy: 0.95880000
# Saving the model state dictionary for Epoch: 31 with Test loss: 0.14812993
#
# Epoch: 32/50, Train Loss: 0.08012198, Test Loss: 0.15125635, Test Accuracy: 0.95820000
#
# Epoch: 33/50, Train Loss: 0.07280107, Test Loss: 0.12140314, Test Accuracy: 0.96710000
# Saving the model state dictionary for Epoch: 33 with Test loss: 0.12140314
#
# Epoch: 34/50, Train Loss: 0.06557641, Test Loss: 0.12513609, Test Accuracy: 0.96510000
#
# Epoch: 35/50, Train Loss: 0.06050118, Test Loss: 0.11759600, Test Accuracy: 0.96750000
# Saving the model state dictionary for Epoch: 35 with Test loss: 0.11759600
#
# Epoch: 36/50, Train Loss: 0.05554958, Test Loss: 0.10873079, Test Accuracy: 0.97140000
# Saving the model state dictionary for Epoch: 36 with Test loss: 0.10873079
#
# Epoch: 37/50, Train Loss: 0.04989282, Test Loss: 0.10921784, Test Accuracy: 0.97140000
#
# Epoch: 38/50, Train Loss: 0.04594382, Test Loss: 0.12659900, Test Accuracy: 0.96660000
#
# Epoch: 39/50, Train Loss: 0.04196653, Test Loss: 0.11771605, Test Accuracy: 0.97040000
#
# Epoch: 40/50, Train Loss: 0.03979913, Test Loss: 0.11011661, Test Accuracy: 0.97400000
#
# Epoch: 41/50, Train Loss: 0.03439994, Test Loss: 0.14437803, Test Accuracy: 0.96480000
#
# Epoch: 42/50, Train Loss: 0.03157305, Test Loss: 0.11426155, Test Accuracy: 0.97160000
#
# Epoch: 43/50, Train Loss: 0.02902207, Test Loss: 0.14372931, Test Accuracy: 0.96540000
#
# Epoch: 44/50, Train Loss: 0.02615280, Test Loss: 0.12924984, Test Accuracy: 0.97100000
#
# Epoch: 45/50, Train Loss: 0.02441401, Test Loss: 0.12294588, Test Accuracy: 0.97350000
#
# Epoch: 46/50, Train Loss: 0.02139638, Test Loss: 0.12380399, Test Accuracy: 0.97180000
#
# Epoch: 47/50, Train Loss: 0.01892860, Test Loss: 0.11928389, Test Accuracy: 0.97430000
#
# Epoch: 48/50, Train Loss: 0.01774140, Test Loss: 0.13943833, Test Accuracy: 0.97060000
#
# Epoch: 49/50, Train Loss: 0.01733369, Test Loss: 0.13701927, Test Accuracy: 0.97220000
#
# Epoch: 50/50, Train Loss: 0.01498757, Test Loss: 0.15179647, Test Accuracy: 0.96980000
# [tensor(0.0051, grad_fn=<MeanBackward0>), tensor(0.0051, grad_fn=<MeanBackward0>), tensor(0.0052, grad_fn=<MeanBackward0>), tensor(0.0053, grad_fn=<MeanBackward0>), tensor(0.0055, grad_fn=<MeanBackward0>), tensor(0.0056, grad_fn=<MeanBackward0>), tensor(0.0058, grad_fn=<MeanBackward0>), tensor(0.0060, grad_fn=<MeanBackward0>), tensor(0.0062, grad_fn=<MeanBackward0>), tensor(0.0065, grad_fn=<MeanBackward0>), tensor(0.0069, grad_fn=<MeanBackward0>), tensor(0.0073, grad_fn=<MeanBackward0>), tensor(0.0078, grad_fn=<Me
 0.3921775668859482, 0.39337320923805236, 0.39609397351741793, 0.3989843338727951, 0.39678704738616943, 0.3989520162343979, 0.40020119249820707, 0.40254882276058196, 0.40514047145843507, 0.4043063998222351, 0.4087286561727524, 0.40726429522037505, 0.40625945627689364, 0.4085886120796204, 0.40742106139659884, 0.4097871005535126, 0.4093144774436951, 0.4098275125026703, 0.4102430433034897, 0.41119904816150665, 0.4128982722759247, 0.41432845294475557]

# %% [markdown]
# # Adagrad

# %%
model_factory('Adagrad')
# Out:
# my_model: Model(
#   (linear_1): Linear(in_features=784, out_features=256, bias=True)
#   (linear_2): Linear(in_features=256, out_features=256, bias=True)
#   (linear_3): Linear(in_features=256, out_features=256, bias=True)
#   (linear_4): Linear(in_features=256, out_features=256, bias=True)
#   (linear_5): Linear(in_features=256, out_features=256, bias=True)
#   (linear_6): Linear(in_features=256, out_features=10, bias=True)
#   (sigmoid12): Sigmoid()
#   (sigmoid23): Sigmoid()
#   (sigmoid34): Sigmoid()
#   (sigmoid45): Sigmoid()
#   (sigmoid56): Sigmoid()
# )
# my_optimizer: Adagrad (
# Parameter Group 0
#     eps: 1e-10
#     initial_accumulator_value: 0
#     lr: 0.1
#     lr_decay: 0
#     weight_decay: 0
# )
#
# Epoch: 1/50, Train Loss: 2.41126095, Test Loss: 2.32394869, Test Accuracy: 0.09740000
#
# Epoch: 2/50, Train Loss: 2.32897436, Test Loss: 2.36121147, Test Accuracy: 0.09820000
#
# Epoch: 3/50, Train Loss: 2.32134433, Test Loss: 2.31869678, Test Accuracy: 0.11350000
#
# Epoch: 4/50, Train Loss: 2.31792858, Test Loss: 2.31844693, Test Accuracy: 0.09820000
#
# Epoch: 5/50, Train Loss: 2.31580836, Test Loss: 2.31190613, Test Accuracy: 0.09580000
#
# Epoch: 6/50, Train Loss: 2.31601657, Test Loss: 2.31554889, Test Accuracy: 0.09800000
#
# Epoch: 7/50, Train Loss: 2.31307005, Test Loss: 2.31049154, Test Accuracy: 0.10280000
#
# Epoch: 8/50, Train Loss: 2.31293394, Test Loss: 2.31008793, Test Accuracy: 0.10280000
#
# Epoch: 9/50, Train Loss: 2.31280753, Test Loss: 2.31037574, Test Accuracy: 0.11350000
#
# Epoch: 10/50, Train Loss: 2.31168192, Test Loss: 2.31775872, Test Accuracy: 0.10320000
#
# Epoch: 11/50, Train Loss: 2.31121339, Test Loss: 2.31405697, Test Accuracy: 0.10280000
#
# Epoch: 12/50, Train Loss: 2.31068573, Test Loss: 2.31068178, Test Accuracy: 0.11350000
#
# Epoch: 13/50, Train Loss: 2.31046881, Test Loss: 2.31479542, Test Accuracy: 0.10090000
#
# Epoch: 14/50, Train Loss: 2.31041236, Test Loss: 2.30308083, Test Accuracy: 0.10280000
#
# Epoch: 15/50, Train Loss: 2.30990739, Test Loss: 2.30446414, Test Accuracy: 0.11350000
#
# Epoch: 16/50, Train Loss: 2.30935372, Test Loss: 2.30234145, Test Accuracy: 0.11350000
#
# Epoch: 17/50, Train Loss: 2.30856869, Test Loss: 2.31188783, Test Accuracy: 0.10280000
#
# Epoch: 18/50, Train Loss: 2.30883907, Test Loss: 2.31044708, Test Accuracy: 0.10320000
#
# Epoch: 19/50, Train Loss: 2.30939496, Test Loss: 2.30669933, Test Accuracy: 0.09800000
#
# Epoch: 20/50, Train Loss: 2.30883104, Test Loss: 2.30542274, Test Accuracy: 0.10280000
#
# Epoch: 21/50, Train Loss: 2.30837910, Test Loss: 2.31031532, Test Accuracy: 0.10090000
#
ensor(0.2597, grad_fn=<MeanBackward0>), tensor(0.2597, grad_fn=<MeanBackward0>), tensor(0.2597, grad_fn=<MeanBackward0>), tensor(0.2597, grad_fn=<MeanBackward0>), tensor(0.2597, grad_fn=<MeanBackward0>), tensor(0.2597, grad_fn=<MeanBackward0>), tensor(0.2597, grad_fn=<MeanBackward0>), tensor(0.2597, grad_fn=<MeanBackward0>), tensor(0.2597, grad_fn=<MeanBackward0>), tensor(0.2597, grad_fn=<MeanBackward0>), tensor(0.2597, grad_fn=<MeanBackward0>), tensor(0.2597, grad_fn=<MeanBackward0>), tensor(0.2597, grad_fn=<MeanBackward0>), tensor(0.2597, grad_fn=<MeanBackward0>), tensor(0.2597, grad_fn=<MeanBackward0>), tensor(0.2597, grad_fn=<MeanBackward0>), tensor(0.2597, grad_fn=<MeanBackward0>), tensor(0.2597, grad_fn=<MeanBackward0>), tensor(0.2597, grad_fn=<MeanBackward0>), tensor(0.2597, grad_fn=<MeanBackward0>), tensor(0.2597, grad_fn=<MeanBackward0>), tensor(0.2597, grad_fn=<MeanBackward0>), tensor(0.2597, grad_fn=<MeanBackward0>), tensor(0.2597, grad_fn=<MeanBackward0>), tensor(0.2597, grad_fn=<MeanBackward0>), tensor(0.2597, grad_fn=<MeanBackward0>), tensor(0.2597, grad_fn=<MeanBackward0>), tensor(0.2597, grad_fn=<MeanBackward0>), tensor(0.2597, grad_fn=<MeanBackward0>), tensor(0.2597, grad_fn=<MeanBackward0>), tensor(0.2597, grad_fn=<MeanBackward0>), tensor(0.2597, grad_fn=<MeanBackward0>), tensor(0.2597, grad_fn=<MeanBackward0>), tensor(0.2597, grad_fn=<MeanBackward0>), tensor(0.2597, grad_fn=<MeanBackward0>), tensor(0.2597, grad_fn=<MeanBackward0>), tensor(0.2597, grad_fn=<MeanBackward0>), tensor(0.2597, grad_fn=<MeanBackward0>), tensor(0.2597, grad_fn=<MeanBackward0>), tensor(0.2597, grad_fn=<MeanBackward0>), tensor(0.2597, grad_fn=<MeanBackward0>), tensor(0.2597, grad_fn=<MeanBackward0>), tensor(0.2597, grad_fn=<MeanBackward0>), tensor(0.2597, grad_fn=<MeanBackward0>), tensor(0.2597, grad_fn=<MeanBackward0>), tensor(0.2597, grad_fn=<MeanBackward0>), tensor(0.2597, grad_fn=<MeanBackward0>), tensor(0.2597, grad_fn=<MeanBackward0>), tensor(0.2597, grad_fn=<MeanBackward0>), tensor(0.2597, grad_fn=<MeanBackward0>)]
# [tensor(0.3027, grad_fn=<MeanBackward0>), tensor(0.3027, grad_fn=<MeanBackward0>), tensor(0.3027, grad_fn=<MeanBackward0>), tensor(0.3027, grad_fn=<MeanBackward0>), tensor(0.3027, grad_fn=<MeanBackward0>), tensor(0.3027, grad_fn=<MeanBackward0>), tensor(0.3027, grad_fn=<MeanBackward0>), tensor(0.3027, grad_fn=<MeanBackward0>), tensor(0.3027, grad_fn=<MeanBackward0>), tensor(0.3027, grad_fn=<MeanBackward0>), tensor(0.3027, grad_fn=<MeanBackward0>), tensor(0.3027, grad_fn=<MeanBackward0>), tensor(0.3027, grad_fn=<MeanBackward0>), tensor(0.3027, grad_fn=<MeanBackward0>), tensor(0.3027, grad_fn=<MeanBackward0>), tensor(0.3027, grad_fn=<MeanBackward0>), tensor(0.3027, grad_fn=<MeanBackward0>), tensor(0.3027, grad_fn=<MeanBackward0>), tensor(0.3027, grad_fn=<MeanBackward0>), tensor(0.3027, grad_fn=<MeanBackward0>), tensor(0.3027, grad_fn=<MeanBackward0>), tensor(0.3027, grad_fn=<MeanBackward0>), tensor(0.3027, grad_fn=<MeanBackward0>), tensor(0.3027, grad_fn=<MeanBackward0>), tensor(0.3027, grad_fn=<MeanBackward0>), tensor(0.3027, grad_fn=<MeanBackward0>), tensor(0.3027, grad_fn=<MeanBackward0>), tensor(0.3027, grad_fn=<MeanBackward0>), tensor(0.3027, grad_fn=<MeanBackward0>), tensor(0.3027, grad_fn=<MeanBackward0>), tensor(0.3027, grad_fn=<MeanBackward0>), tensor(0.3027, grad_fn=<MeanBackward0>), tensor(0.3027, grad_fn=<MeanBackward0>), tensor(0.3027, grad_fn=<MeanBackward0>), tensor(0.3027, grad_fn=<MeanBackward0>), tensor(0.3027, grad_fn=<MeanBackward0>), tensor(0.3027, grad_fn=<MeanBackward0>), tensor(0.3027, grad_fn=<MeanBackward0>), tensor(0.3027, grad_fn=<MeanBackward0>), tensor(0.3027, grad_fn=<MeanBackward0>), tensor(0.3027, grad_fn=<MeanBackward0>), tensor(0.3027, grad_fn=<MeanBackward0>), tensor(0.3027, grad_fn=<MeanBackward0>), tensor(0.3027, grad_fn=<MeanBackward0>), tensor(0.3027, grad_fn=<MeanBackward0>), tensor(0.3027, grad_fn=<MeanBackward0>), tensor(0.3027, grad_fn=<MeanBackward0>), tensor(0.3027, grad_fn=<MeanBackward0>), tensor(0.3027, grad_fn=<MeanBackward0>), tensor(0.3027, grad_fn=<MeanBackward0>)]
# [tensor(0.2750, grad_fn=<MeanBackward0>), tensor(0.2750, grad_fn=<MeanBackward0>), tensor(0.2750, grad_fn=<MeanBackward0>), tensor(0.2750, grad_fn=<MeanBackward0>), tensor(0.2750, grad_fn=<MeanBackward0>), tensor(0.2750, grad_fn=<MeanBackward0>), tensor(0.2750, grad_fn=<MeanBackward0>), tensor(0.2750, grad_fn=<MeanBackward0>), tensor(0.2750, grad_fn=<MeanBackward0>), tensor(0.2750, grad_fn=<MeanBackward0>), tensor(0.2750, grad_fn=<MeanBackward0>), tensor(0.2750, grad_fn=<MeanBackward0>), tensor(0.2750, grad_fn=<MeanBackward0>), tensor(0.2750, grad_fn=<MeanBackward0>), tensor(0.2750, grad_fn=<MeanBackward0>), tensor(0.2750, grad_fn=<MeanBackward0>), tensor(0.2750, grad_fn=<MeanBackward0>), tensor(0.2750, grad_fn=<MeanBackward0>), tensor(0.2750, grad_fn=<MeanBackward0>), tensor(0.2750, grad_fn=<MeanBackward0>), tensor(0.2750, grad_fn=<MeanBackward0>), tensor(0.2750, grad_fn=<MeanBackward0>), tensor(0.2750, grad_fn=<MeanBackward0>), tensor(0.2750, grad_fn=<MeanBackward0>), tensor(0.2750, grad_fn=<MeanBackward0>), tensor(0.2750, grad_fn=<MeanBackward0>), tensor(0.2750, grad_fn=<MeanBackward0>), tensor(0.2750, grad_fn=<MeanBackward0>), tensor(0.2750, grad_fn=<MeanBackward0>), tensor(0.2750, grad_fn=<MeanBackward0>), tensor(0.2750, grad_fn=<MeanBackward0>), tensor(0.2750, grad_fn=<MeanBackward0>), tensor(0.2750, grad_fn=<MeanBackward0>), tensor(0.2750, grad_fn=<MeanBackward0>), tensor(0.2750, grad_fn=<MeanBackward0>), tensor(0.2750, grad_fn=<MeanBackward0>), tensor(0.2750, grad_fn=<MeanBackward0>), tensor(0.2750, grad_fn=<MeanBackward0>), tensor(0.2750, grad_fn=<MeanBackward0>), tensor(0.2750, grad_fn=<MeanBackward0>), tensor(0.2750, grad_fn=<MeanBackward0>), tensor(0.2750, grad_fn=<MeanBackward0>), tensor(0.2750, grad_fn=<MeanBackward0>), tensor(0.2750, grad_fn=<MeanBackward0>), tensor(0.2750, grad_fn=<MeanBackward0>), tensor(0.2750, grad_fn=<MeanBackward0>), tensor(0.2750, grad_fn=<MeanBackward0>), tensor(0.2750, grad_fn=<MeanBackward0>), tensor(0.2750, grad_fn=<MeanBackward0>), tensor(0.2750, grad_fn=<MeanBackward0>)]
# [tensor(0.3213, grad_fn=<MeanBackward0>), tensor(0.3213, grad_fn=<MeanBackward0>), tensor(0.3213, grad_fn=<MeanBackward0>), tensor(0.3213, grad_fn=<MeanBackward0>), tensor(0.3213, grad_fn=<MeanBackward0>), tensor(0.3213, grad_fn=<MeanBackward0>), tensor(0.3213, grad_fn=<MeanBackward0>), tensor(0.3213, grad_fn=<MeanBackward0>), tensor(0.3213, grad_fn=<MeanBackward0>), tensor(0.3213, grad_fn=<MeanBackward0>), tensor(0.3213, grad_fn=<MeanBackward0>), tensor(0.3213, grad_fn=<MeanBackward0>), tensor(0.3213, grad_fn=<MeanBackward0>), tensor(0.3213, grad_fn=<MeanBackward0>), tensor(0.3213, grad_fn=<MeanBackward0>), tensor(0.3213, grad_fn=<MeanBackward0>), tensor(0.3213, grad_fn=<MeanBackward0>), tensor(0.3213, grad_fn=<MeanBackward0>), tensor(0.3213, grad_fn=<MeanBackward0>), tensor(0.3213, grad_fn=<MeanBackward0>), tensor(0.3213, grad_fn=<MeanBackward0>), tensor(0.3213, grad_fn=<MeanBackward0>), tensor(0.3213, grad_fn=<MeanBackward0>), tensor(0.3213, grad_fn=<MeanBackward0>), tensor(0.3213, grad_fn=<MeanBackward0>), tensor(0.3213, grad_fn=<MeanBackward0>), tensor(0.3213, grad_fn=<MeanBackward0>), tensor(0.3213, grad_fn=<MeanBackward0>), tensor(0.3213, grad_fn=<MeanBackward0>), tensor(0.3213, grad_fn=<MeanBackward0>), tensor(0.3213, grad_fn=<MeanBackward0>), tensor(0.3213, grad_fn=<MeanBackward0>), tensor(0.3213, grad_fn=<MeanBackward0>), tensor(0.3213, grad_fn=<MeanBackward0>), tensor(0.3213, grad_fn=<MeanBackward0>), tensor(0.3213, grad_fn=<MeanBackward0>), tensor(0.3213, grad_fn=<MeanBackward0>), tensor(0.3213, grad_fn=<MeanBackward0>), tensor(0.3213, grad_fn=<MeanBackward0>), tensor(0.3213, grad_fn=<MeanBackward0>), tensor(0.3213, grad_fn=<MeanBackward0>), tensor(0.3213, grad_fn=<MeanBackward0>), tensor(0.3213, grad_fn=<MeanBackward0>), tensor(0.3213, grad_fn=<MeanBackward0>), tensor(0.3213, grad_fn=<MeanBackward0>), tensor(0.3213, grad_fn=<MeanBackward0>), tensor(0.3213, grad_fn=<MeanBackward0>), tensor(0.3213, grad_fn=<MeanBackward0>), tensor(0.3213, grad_fn=<MeanBackward0>), tensor(0.3213, grad_fn=<MeanBackward0>)]
# [tensor(0.3803, grad_fn=<MeanBackward0>), tensor(0.3803, grad_fn=<MeanBackward0>), tensor(0.3803, grad_fn=<MeanBackward0>), tensor(0.3803, grad_fn=<MeanBackward0>), tensor(0.3803, grad_fn=<MeanBackward0>), tensor(0.3803, grad_fn=<MeanBackward0>), tensor(0.3803, grad_fn=<MeanBackward0>), tensor(0.3803, grad_fn=<MeanBackward0>), tensor(0.3803, grad_fn=<MeanBackward0>), tensor(0.3803, grad_fn=<MeanBackward0>), tensor(0.3803, grad_fn=<MeanBackward0>), tensor(0.3803, grad_fn=<MeanBackward0>), tensor(0.3803, grad_fn=<MeanBackward0>), tensor(0.3803, grad_fn=<MeanBackward0>), tensor(0.3803, grad_fn=<MeanBackward0>), tensor(0.3803, grad_fn=<MeanBackward0>), tensor(0.3803, grad_fn=<MeanBackward0>), tensor(0.3803, grad_fn=<MeanBackward0>), tensor(0.3803, grad_fn=<MeanBackward0>), tensor(0.3803, grad_fn=<MeanBackward0>), tensor(0.3803, grad_fn=<MeanBackward0>), tensor(0.3803, grad_fn=<MeanBackward0>), tensor(0.3803, grad_fn=<MeanBackward0>), tensor(0.3803, grad_fn=<MeanBackward0>), tensor(0.3803, grad_fn=<MeanBackward0>), tensor(0.3803, grad_fn=<MeanBackward0>), tensor(0.3803, grad_fn=<MeanBackward0>), tensor(0.3803, grad_fn=<MeanBackward0>), tensor(0.3803, grad_fn=<MeanBackward0>), tensor(0.3803, grad_fn=<MeanBackward0>), tensor(0.3803, grad_fn=<MeanBackward0>), tensor(0.3803, grad_fn=<MeanBackward0>), tensor(0.3803, grad_fn=<MeanBackward0>), tensor(0.3803, grad_fn=<MeanBackward0>), tensor(0.3803, grad_fn=<MeanBackward0>), tensor(0.3803, grad_fn=<MeanBackward0>), tensor(0.3803, grad_fn=<MeanBackward0>), tensor(0.3803, grad_fn=<MeanBackward0>), tensor(0.3803, grad_fn=<MeanBackward0>), tensor(0.3803, grad_fn=<MeanBackward0>), tensor(0.3803, grad_fn=<MeanBackward0>), tensor(0.3803, grad_fn=<MeanBackward0>), tensor(0.3803, grad_fn=<MeanBackward0>), tensor(0.3803, grad_fn=<MeanBackward0>), tensor(0.3803, grad_fn=<MeanBackward0>), tensor(0.3803, grad_fn=<MeanBackward0>), tensor(0.3803, grad_fn=<MeanBackward0>), tensor(0.3803, grad_fn=<MeanBackward0>), tensor(0.3803, grad_fn=<MeanBackward0>), tensor(0.3803, grad_fn=<MeanBackward0>)]
# average_sparsity: [0.30780250430107114, 0.30780251026153566, 0.3078025460243225, 0.3078026056289673, 0.30780261754989624, 0.30780258774757385, 0.3078025996685028, 0.3078026592731476, 0.30780269503593444, 0.30780268311500547, 0.3078027248382568, 0.30780273079872134, 0.30780274868011476, 0.30780277252197263, 0.3078027844429016, 0.30780280828475953, 0.307802814245224, 0.3078028321266174, 0.3078028440475464, 0.3078028619289398, 0.30780288577079773, 0.3078028976917267, 0.30780290961265566, 0.3078029274940491, 0.3078029751777649, 0.3078029930591583, 0.3078029751777649, 0.3078030288219452, 0.30780303478240967, 0.3078030824661255, 0.3078030824661255, 0.307803076505661, 0.3078031182289124, 0.30780314803123476, 0.3078031539916992, 0.3078031837940216, 0.3078031957149506, 0.307803213596344, 0.30780322551727296, 0.30780324935913084, 0.3078032612800598, 0.30780327320098877, 0.30780330300331116, 0.3078033149242401, 0.30780333280563354, 0.3078033447265625, 0.3078033685684204, 0.30780338048934935, 0.3078033983707428, 0.30780341625213625]

# %% [markdown]
# # SGD

# %%
model_factory('SGD')
# Out:
# my_model: Model(
#   (linear_1): Linear(in_features=784, out_features=256, bias=True)
#   (linear_2): Linear(in_features=256, out_features=256, bias=True)
#   (linear_3): Linear(in_features=256, out_features=256, bias=True)
#   (linear_4): Linear(in_features=256, out_features=256, bias=True)
#   (linear_5): Linear(in_features=256, out_features=256, bias=True)
#   (linear_6): Linear(in_features=256, out_features=10, bias=True)
#   (sigmoid12): Sigmoid()
#   (sigmoid23): Sigmoid()
#   (sigmoid34): Sigmoid()
#   (sigmoid45): Sigmoid()
#   (sigmoid56): Sigmoid()
# )
# my_optimizer: SGD (
# Parameter Group 0
#     dampening: 0
#     lr: 0.1
#     momentum: 0
#     nesterov: False
#     weight_decay: 0
# )
#
# Epoch: 1/50, Train Loss: 2.32514800, Test Loss: 2.31485855, Test Accuracy: 0.11350000
#
# Epoch: 2/50, Train Loss: 2.30932106, Test Loss: 2.30733582, Test Accuracy: 0.10280000
#
# Epoch: 3/50, Train Loss: 2.30535526, Test Loss: 2.30372149, Test Accuracy: 0.11350000
#
# Epoch: 4/50, Train Loss: 2.30402741, Test Loss: 2.30359469, Test Accuracy: 0.11350000
#
# Epoch: 5/50, Train Loss: 2.30332512, Test Loss: 2.30275147, Test Accuracy: 0.10320000
#
# Epoch: 6/50, Train Loss: 2.30257311, Test Loss: 2.30165910, Test Accuracy: 0.11350000
#
# Epoch: 7/50, Train Loss: 2.30250776, Test Loss: 2.30113794, Test Accuracy: 0.11350000
#
# Epoch: 8/50, Train Loss: 2.30266905, Test Loss: 2.30118412, Test Accuracy: 0.11350000
#
# Epoch: 9/50, Train Loss: 2.30219999, Test Loss: 2.30260989, Test Accuracy: 0.10100000
#
# Epoch: 10/50, Train Loss: 2.30225868, Test Loss: 2.30139723, Test Accuracy: 0.11350000
#
# Epoch: 11/50, Train Loss: 2.30215774, Test Loss: 2.30150217, Test Accuracy: 0.11350000
#
# Epoch: 12/50, Train Loss: 2.30198129, Test Loss: 2.30273411, Test Accuracy: 0.10280000
#
# Epoch: 13/50, Train Loss: 2.30207878, Test Loss: 2.30145789, Test Accuracy: 0.11350000
#
# Epoch: 14/50, Train Loss: 2.30195855, Test Loss: 2.30229508, Test Accuracy: 0.09580000
MeanBackward0>), tensor(0.0003, grad_fn=<MeanBackward0>), tensor(0.0003, grad_fn=<MeanBackward0>), tensor(0.0004, grad_fn=<MeanBackward0>), tensor(0.0002, grad_fn=<MeanBackward0>), tensor(0.0004, grad_fn=<MeanBackward0>), tensor(0.0002, grad_fn=<MeanBackward0>), tensor(0.0003, grad_fn=<MeanBackward0>), tensor(0.0004, grad_fn=<MeanBackward0>), tensor(0.0002, grad_fn=<MeanBackward0>), tensor(0.0003, grad_fn=<MeanBackward0>), tensor(0.0003, grad_fn=<MeanBackward0>), tensor(0.0004, grad_fn=<MeanBackward0>), tensor(0.0003, grad_fn=<MeanBackward0>), tensor(0.0003, grad_fn=<MeanBackward0>), tensor(0.0003, grad_fn=<MeanBackward0>), tensor(0.0003, grad_fn=<MeanBackward0>), tensor(0.0003, grad_fn=<MeanBackward0>), tensor(0.0003, grad_fn=<MeanBackward0>), tensor(0.0003, grad_fn=<MeanBackward0>)]
# average_sparsity: [0.009504351299256086, 0.009066777350381017, 0.008835927164182068, 0.008679342712275684, 0.008589558722451329, 0.008512018341571092, 0.00847229773644358, 0.008421564614400268, 0.008398301794659346, 0.008338932215701788, 0.008305404044222087, 0.008280992694199085, 0.00827218177728355, 0.008228979335399345, 0.008200367412064225, 0.00817746330285445, 0.008179670601384715, 0.008165897015715018, 0.008130201179301366, 0.00812122539500706, 0.008097484486643224, 0.008083146368153393, 0.008065376587910577, 0.008050907857250423, 0.008031988044967875, 0.008027695259079337, 0.008028262836160139, 0.008005876978859305, 0.008003851829562337, 0.00798513923655264, 0.00798041174421087, 0.007963799295248463, 0.00795300142490305, 0.007966487400699407, 0.007928833714686334, 0.007949589699273929, 0.00791253729548771, 0.007920457766158507, 0.007943073305068538, 0.007889879390131683, 0.007891055312938988, 0.007898200355703012, 0.00789706694195047, 0.007879834523191676, 0.007880343205761165, 0.00787177959573455, 0.007871061959303916, 0.007865799218416214, 0.007857192616211251, 0.007855365559225901]

# %% [markdown]
# # Adam

# %%
model_factory('Adam')
# Out:
# my_model: Model(
#   (linear_1): Linear(in_features=784, out_features=256, bias=True)
#   (linear_2): Linear(in_features=256, out_features=256, bias=True)
#   (linear_3): Linear(in_features=256, out_features=256, bias=True)
#   (linear_4): Linear(in_features=256, out_features=256, bias=True)
#   (linear_5): Linear(in_features=256, out_features=256, bias=True)
#   (linear_6): Linear(in_features=256, out_features=10, bias=True)
#   (sigmoid12): Sigmoid()
#   (sigmoid23): Sigmoid()
#   (sigmoid34): Sigmoid()
#   (sigmoid45): Sigmoid()
#   (sigmoid56): Sigmoid()
# )
# my_optimizer: Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.001
#     weight_decay: 0
# )
#
# Epoch: 1/50, Train Loss: 0.80638047, Test Loss: 0.29394127, Test Accuracy: 0.91810000
# Saving the model state dictionary for Epoch: 1 with Test loss: 0.29394127
#
# Epoch: 2/50, Train Loss: 0.23412892, Test Loss: 0.19497290, Test Accuracy: 0.94560000
# Saving the model state dictionary for Epoch: 2 with Test loss: 0.19497290
#
# Epoch: 3/50, Train Loss: 0.15856719, Test Loss: 0.13926353, Test Accuracy: 0.96120000
# Saving the model state dictionary for Epoch: 3 with Test loss: 0.13926353
#
# Epoch: 4/50, Train Loss: 0.12374716, Test Loss: 0.13299615, Test Accuracy: 0.96130000
# Saving the model state dictionary for Epoch: 4 with Test loss: 0.13299615
#
# Epoch: 5/50, Train Loss: 0.09917848, Test Loss: 0.11242981, Test Accuracy: 0.96630000
# Epoch: 33/50, Train Loss: 0.00983401, Test Loss: 0.16268709, Test Accuracy: 0.96690000
#
# Epoch: 34/50, Train Loss: 0.00640243, Test Loss: 0.13342757, Test Accuracy: 0.97770000
#
# Epoch: 35/50, Train Loss: 0.01053193, Test Loss: 0.12865060, Test Accuracy: 0.97500000
#
# Epoch: 36/50, Train Loss: 0.00773576, Test Loss: 0.12521617, Test Accuracy: 0.97750000
#
# Epoch: 37/50, Train Loss: 0.00850658, Test Loss: 0.11692873, Test Accuracy: 0.97900000
#
# Epoch: 38/50, Train Loss: 0.00795715, Test Loss: 0.14883105, Test Accuracy: 0.97430000
#
# Epoch: 39/50, Train Loss: 0.00722881, Test Loss: 0.12510196, Test Accuracy: 0.98020000
#
# Epoch: 40/50, Train Loss: 0.00716871, Test Loss: 0.12419667, Test Accuracy: 0.98100000
#
# Epoch: 41/50, Train Loss: 0.00707406, Test Loss: 0.13304470, Test Accuracy: 0.97500000
#
# Epoch: 42/50, Train Loss: 0.00627130, Test Loss: 0.14963185, Test Accuracy: 0.97360000
#
# Epoch: 43/50, Train Loss: 0.00688232, Test Loss: 0.11630339, Test Accuracy: 0.98000000
#
# Epoch: 44/50, Train Loss: 0.00727136, Test Loss: 0.11857012, Test Accuracy: 0.98000000
#
# Epoch: 45/50, Train Loss: 0.00595044, Test Loss: 0.13890419, Test Accuracy: 0.97750000
#
# Epoch: 46/50, Train Loss: 0.00457648, Test Loss: 0.11877664, Test Accuracy: 0.98070000
#
# Epoch: 47/50, Train Loss: 0.00637535, Test Loss: 0.13806771, Test Accuracy: 0.97900000
#
# Epoch: 48/50, Train Loss: 0.00582231, Test Loss: 0.12400532, Test Accuracy: 0.97930000
#
# Epoch: 49/50, Train Loss: 0.00838584, Test Loss: 0.12424490, Test Accuracy: 0.98060000
#
# Epoch: 50/50, Train Loss: 0.00355148, Test Loss: 0.12682718, Test Accuracy: 0.97910000
# [tensor(0.2399, grad_fn=<MeanBackward0>), tensor(0.2637, grad_fn=<MeanBackward0>), tensor(0.2774, grad_fn=<MeanBackward0>), tensor(0.2888, grad_fn=<MeanBackward0>), tensor(0.2948, grad_fn=<MeanBackward0>), tensor(0.3000, grad_fn=<MeanBackward0>), tensor(0.3046, grad_fn=<MeanBackward0>), tensor(0.3069, grad_fn=<MeanBackward0>), tensor(0.3115, grad_fn=<MeanBackward0>), tensor(0.3145, grad_fn=<MeanBackward0>), tensor(0.3172, grad_fn=<MeanBackward0>), tensor(0.3155, grad_fn=<MeanBackward0>), tensor(0.3180, grad_fn=<MeanBackward0>), tensor(0.3204, grad_fn=<MeanBackward0>), tensor(0.3254, grad_fn=<MeanBackward0>), tensor(0.3266, grad_fn=<MeanBackward0>), tensor(0.3263, grad_fn=<MeanBackward0>), tensor(0.3304, grad_fn=<MeanBackward0>), tensor(0.3305, grad_fn=<MeanBackward0>), tensor(0.3321, grad_fn=<MeanBackward0>), tensor(0.3318, grad_fn=<MeanBackward0>), tensor(0.3345, grad_fn=<MeanBackward0>), tensor(0.3374, grad_fn=<MeanBackward0>), tensor(0