# %% [markdown]
# <a href="https://colab.research.google.com/github/7201krap/PYTORCH_project/blob/main/sparsity_2_HL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
from torchvision import transforms
import torchvision.datasets as datasets
import matplotlib.pyplot as plt
import numpy as np
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
torch.manual_seed(1234)
np.random.seed(1234)

# %%
mnist_trainset = datasets.MNIST(root='./data', train=True, 
                                download=True, 
                                transform=transforms.Compose([transforms.ToTensor()]))

mnist_testset  = datasets.MNIST(root='./data', 
                                train=False, 
                                download=True, 
                                transform=transforms.Compose([transforms.ToTensor()]))

train_dataloader = torch.utils.data.DataLoader(mnist_trainset, 
                                               batch_size=50, 
                                               shuffle=True)

test_dataloader  = torch.utils.data.DataLoader(mnist_testset, 
                                               batch_size=50, 
                                               shuffle=False)

print("Training dataset size: ", len(mnist_trainset))
print("Testing dataset size: ",  len(mnist_testset))
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ./data/MNIST/raw/train-images-idx3-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ./data/MNIST/raw/train-images-idx3-ubyte.gz to ./data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ./data/MNIST/raw/train-labels-idx1-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ./data/MNIST/raw/train-labels-idx1-ubyte.gz to ./data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw/t10k-images-idx3-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ./data/MNIST/raw/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw
# Processing...
# Done!
# Training dataset size:  60000
# Testing dataset size:  10000
# /usr/local/lib/python3.6/dist-packages/torchvision/datasets/mnist.py:480: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /pytorch/torch/csrc/utils/tensor_numpy.cpp:141.)
#   return torch.from_numpy(parsed.astype(m[2], copy=False)).view(*s)

# %%
# ************* modify this section for later use *************
# Define the model 
class Model(torch.nn.Module):
    def __init__(self):
        super(Model, self).__init__()

        # modify this section for later use 
        self.linear_1 = torch.nn.Linear(784, 256)
        self.linear_2 = torch.nn.Linear(256, 256)
        self.linear_3 = torch.nn.Linear(256, 10)
        self.sigmoid12  = torch.nn.Sigmoid()
        self.sigmoid23  = torch.nn.Sigmoid()

        self.layer_activations = dict()

    def forward(self, x):

        # modify this section for later use 
        x = x.reshape(x.size(0), -1)
        x = self.linear_1(x)
        x = self.sigmoid12(x)
        x = self.linear_2(x)
        x = self.sigmoid23(x)
        pred = self.linear_3(x)
        return pred

# ************* modify this section for later use *************

# %%
def get_activation(model, layer_name):    
    def hook(module, input, output):
        model.layer_activations[layer_name] = output
    return hook

# %%
def sparsity_calculator(final_spareness):
    sparseness_list = list()
    for single_epoch_spareness in final_spareness:

        hidden_layer_activation_list = single_epoch_spareness
        hidden_layer_activation_list = torch.stack(hidden_layer_activation_list)
        layer_activations_list = torch.reshape(hidden_layer_activation_list, (10000, 256))

        layer_activations_list = torch.abs(layer_activations_list)  # modified 
        num_neurons = layer_activations_list.shape[1]
        population_sparseness = (np.sqrt(num_neurons) - (torch.sum(layer_activations_list, dim=1) / torch.sqrt(torch.sum(layer_activations_list ** 2, dim=1)))) / (np.sqrt(num_neurons) - 1)
        mean_sparseness_per_epoch = torch.mean(population_sparseness)

        sparseness_list.append(mean_sparseness_per_epoch)

    return sparseness_list

# %%
def model_factory(optimizer_name):
    '''
    optimizer_name : choose one of Adagrad, Adadelta, SGD, and Adam 

    '''
    my_model = Model()
    print("my_model:", my_model)
    my_model.to(device)

    # ************* modify this section for later use *************
    # modify this section for later use 
    my_model.sigmoid12.register_forward_hook(get_activation(my_model, 's12'))
    my_model.sigmoid23.register_forward_hook(get_activation(my_model, 's23'))
    # ************* modify this section for later use *************

    if optimizer_name == 'Adadelta':
        my_optimizer = torch.optim.Adadelta(my_model.parameters(), lr=1.0)

    elif optimizer_name == 'Adagrad':
        my_optimizer = torch.optim.Adagrad(my_model.parameters(), lr=0.1)

    elif optimizer_name == 'SGD':
        my_optimizer = torch.optim.SGD(my_model.parameters(), lr=0.1)

    elif optimizer_name == 'Adam':
        my_optimizer = torch.optim.Adam(my_model.parameters(), lr=0.001)

    else:
        print("ERROR")
    
    print("my_optimizer:", my_optimizer)
    test_acc, sparseness_list = sparsity_trainer(optimizer=my_optimizer, model=my_model)
    # ************* modify this section for later use *************
    file_saver = open(f"2HL_sparsity_{optimizer_name}.txt", "w")
    # ************* modify this section for later use *************
    file_saver.write(str(test_acc)+'\n'+str(sparseness_list)+'\n\n')
    file_saver.close()

    # ************* modify this section for later use *************
    if optimizer_name == 'Adadelta':
        # !cp 2HL_sparsity_Adadelta.txt /content/drive/MyDrive
    
    elif optimizer_name == 'Adagrad':
        # !cp 2HL_sparsity_Adagrad.txt /content/drive/MyDrive

    elif optimizer_name == 'SGD':
        # !cp 2HL_sparsity_SGD.txt /content/drive/MyDrive

    elif optimizer_name == 'Adam':
        # !cp 2HL_sparsity_Adam.txt /content/drive/MyDrive
    # ************* modify this section for later use *************

    else:
        print("ERROR")

# %%
def sparsity_trainer(optimizer, model):
    criterion = torch.nn.CrossEntropyLoss()
    no_epochs = 50

    train_loss = list()
    test_loss  = list()
    test_acc   = list()

    # ************* modify this section for later use *************
    final_spareness_12 = list()
    final_spareness_23 = list()
    # ************* modify this section for later use *************

    best_test_loss = 1
    for epoch in range(no_epochs):
        total_train_loss = 0
        total_test_loss = 0

        # ************* modify this section for later use *************
        hidden_layer_activation_list_12 = list()
        hidden_layer_activation_list_23 = list()
        # ************* modify this section for later use *************

        # training
        # set up training mode 
        model.train()
        for itr, (image, label) in enumerate(train_dataloader):
            image, label = image.to(device), label.to(device)

            optimizer.zero_grad()

            pred = model(image)

            loss = criterion(pred, label)
            total_train_loss += loss.item()

            loss.backward()
            optimizer.step()

        total_train_loss = total_train_loss / (itr + 1)
        train_loss.append(total_train_loss)

        # testing 
        # change to evaluation mode 
        model.eval()
        total = 0
        for itr, (image, label) in enumerate(test_dataloader):
            image, label = image.to(device), label.to(device)

            pred = model(image)

            loss = criterion(pred, label)
            total_test_loss += loss.item()

            # we now need softmax because we are testing.
            pred = torch.nn.functional.softmax(pred, dim=1)
            for i, p in enumerate(pred):
                if label[i] == torch.max(p.data, 0)[1]:
                    total = total + 1

            # ***************** sparsity calculation ***************** #
            hidden_layer_activation_list_12.append(model.layer_activations['s12'])
            hidden_layer_activation_list_23.append(model.layer_activations['s23'])

        # this conains activations for all epochs 
        final_spareness_12.append(hidden_layer_activation_list_12)
        final_spareness_23.append(hidden_layer_activation_list_23)
        # ***************** sparsity calculation ***************** #

        # caculate accuracy 
        accuracy = total / len(mnist_testset)

        # append accuracy here
        test_acc.append(accuracy)

        # append test loss here 
        total_test_loss = total_test_loss / (itr + 1)
        test_loss.append(total_test_loss)

        print('\nEpoch: {}/{}, Train Loss: {:.8f}, Test Loss: {:.8f}, Test Accuracy: {:.8f}'.format(epoch + 1, no_epochs, total_train_loss, total_test_loss, accuracy))

        if total_test_loss < best_test_loss:
            best_test_loss = total_test_loss
            print("Saving the model state dictionary for Epoch: {} with Test loss: {:.8f}".format(epoch + 1, total_test_loss))
            torch.save(model.state_dict(), "model.dth")


    # ***************** sparsity calculation ***************** #
    sparsity_list12 = sparsity_calculator(final_spareness_12)
    sparsity_list23 = sparsity_calculator(final_spareness_23)

    print(sparsity_list12)
    print(sparsity_list23)

    average_sparsity = list()
    for i in range(no_epochs):
        average_sparsity.append( (sparsity_list12[i].item() + sparsity_list23[i].item()) / 2 )

    # ***************** sparsity calculation ***************** #

    print("average_sparsity:", average_sparsity)

    return test_acc, average_sparsity

# %% [markdown]
# # Adadelta

# %%
model_factory('Adadelta')
# Out:
# my_model: Model(
#   (linear_1): Linear(in_features=784, out_features=256, bias=True)
#   (linear_2): Linear(in_features=256, out_features=256, bias=True)
#   (linear_3): Linear(in_features=256, out_features=10, bias=True)
#   (sigmoid12): Sigmoid()
#   (sigmoid23): Sigmoid()
# )
# my_optimizer: Adadelta (
# Parameter Group 0
#     eps: 1e-06
#     lr: 1.0
#     rho: 0.9
#     weight_decay: 0
# )
#
# Epoch: 1/50, Train Loss: 0.66955220, Test Loss: 0.29091561, Test Accuracy: 0.91560000
# Saving the model state dictionary for Epoch: 1 with Test loss: 0.29091561
#
# Epoch: 2/50, Train Loss: 0.23864885, Test Loss: 0.17893777, Test Accuracy: 0.94570000
# Saving the model state dictionary for Epoch: 2 with Test loss: 0.17893777
#
# Epoch: 3/50, Train Loss: 0.16415371, Test Loss: 0.14251487, Test Accuracy: 0.95830000
# Saving the model state dictionary for Epoch: 3 with Test loss: 0.14251487
#
# Epoch: 4/50, Train Loss: 0.12487799, Test Loss: 0.10738104, Test Accuracy: 0.96570000
# Saving the model state dictionary for Epoch: 4 with Test loss: 0.10738104
#
# Epoch: 5/50, Train Loss: 0.09811718, Test Loss: 0.09940851, Test Accuracy: 0.96730000
# Saving the model state dictionary for Epoch: 5 with Test loss: 0.09940851
#
# Epoch: 6/50, Train Loss: 0.08101228, Test Loss: 0.09228468, Test Accuracy: 0.97040000
# Saving the model state dictionary for Epoch: 6 with Test loss: 0.09228468
#
# Epoch: 7/50, Train Loss: 0.06785859, Test Loss: 0.08866793, Test Accuracy: 0.97140000
# Saving the model state dictionary for Epoch: 7 with Test loss: 0.08866793
#
# Epoch: 8/50, Train Loss: 0.05707939, Test Loss: 0.07453738, Test Accuracy: 0.97680000
# Saving the model state dictionary for Epoch: 8 with Test loss: 0.07453738
#
# Epoch: 9/50, Train Loss: 0.04893696, Test Loss: 0.07658674, Test Accuracy: 0.97500000
#
# Epoch: 10/50, Train Loss: 0.04188914, Test Loss: 0.07907381, Test Accuracy: 0.97610000
#
# Epoch: 11/50, Train Loss: 0.03633562, Test Loss: 0.07478656, Test Accuracy: 0.97730000
#
# Epoch: 12/50, Train Loss: 0.03111513, Test Loss: 0.07411678, Test Accuracy: 0.97910000
# Saving the model state dictionary for Epoch: 12 with Test loss: 0.07411678
#
# Epoch: 13/50, Train Loss: 0.02710637, Test Loss: 0.07417858, Test Accuracy: 0.97810000
#
# Epoch: 14/50, Train Loss: 0.02241587, Test Loss: 0.07294737, Test Accuracy: 0.97870000
# Saving the model state dictionary for Epoch: 14 with Test loss: 0.07294737
#
# Epoch: 15/50, Train Loss: 0.01807552, Test Loss: 0.07262310, Test Accuracy: 0.97880000
# Saving the model state dictionary for Epoch: 15 with Test loss: 0.07262310
#
# Epoch: 16/50, Train Loss: 0.01542591, Test Loss: 0.07768821, Test Accuracy: 0.97850000
#
# Epoch: 17/50, Train Loss: 0.01277811, Test Loss: 0.07904741, Test Accuracy: 0.97990000
# Out:
# my_model: Model(
#   (linear_1): Linear(in_features=784, out_features=256, bias=True)
#   (linear_2): Linear(in_features=256, out_features=256, bias=True)
#   (linear_3): Linear(in_features=256, out_features=10, bias=True)
#   (sigmoid12): Sigmoid()
#   (sigmoid23): Sigmoid()
# )
# my_optimizer: Adagrad (
# Parameter Group 0
#     eps: 1e-10
#     initial_accumulator_value: 0
#     lr: 0.1
#     lr_decay: 0
#     weight_decay: 0
# )
#
# Epoch: 1/50, Train Loss: 0.36479942, Test Loss: 0.11435441, Test Accuracy: 0.96470000
# Saving the model state dictionary for Epoch: 1 with Test loss: 0.11435441
#
# Epoch: 2/50, Train Loss: 0.08309516, Test Loss: 0.08938555, Test Accuracy: 0.97250000
# Saving the model state dictionary for Epoch: 2 with Test loss: 0.08938555
#
# Epoch: 3/50, Train Loss: 0.05292972, Test Loss: 0.08081396, Test Accuracy: 0.97600000
# Saving the model state dictionary for Epoch: 3 with Test loss: 0.08081396
#
# Epoch: 4/50, Train Loss: 0.03426108, Test Loss: 0.07668488, Test Accuracy: 0.97710000
# Saving the model state dictionary for Epoch: 4 with Test loss: 0.07668488
#
# Epoch: 5/50, Train Loss: 0.02377200, Test Loss: 0.07671158, Test Accuracy: 0.97740000
#
# Epoch: 6/50, Train Loss: 0.01602211, Test Loss: 0.07569669, Test Accuracy: 0.97840000
# Saving the model state dictionary for Epoch: 6 with Test loss: 0.07569669
#
# Epoch: 7/50, Train Loss: 0.01119204, Test Loss: 0.07780352, Test Accuracy: 0.97880000
#
# Epoch: 8/50, Train Loss: 0.00800295, Test Loss: 0.07715009, Test Accuracy: 0.97890000
#
# Epoch: 9/50, Train Loss: 0.00567162, Test Loss: 0.07669492, Test Accuracy: 0.97950000
#
# Epoch: 10/50, Train Loss: 0.00407971, Test Loss: 0.08116733, Test Accuracy: 0.97940000
#
# Epoch: 11/50, Train Loss: 0.00314328, Test Loss: 0.08014267, Test Accuracy: 0.97980000
#
# Epoch: 12/50, Train Loss: 0.00240870, Test Loss: 0.08172264, Test Accuracy: 0.97960000
#
# Epoch: 13/50, Train Loss: 0.00190102, Test Loss: 0.08203331, Test Accuracy: 0.98070000
#
# Epoch: 14/50, Train Loss: 0.00155488, Test Loss: 0.08470930, Test Accuracy: 0.98000000
#
# Epoch: 15/50, Train Loss: 0.00132987, Test Loss: 0.08514685, Test Accuracy: 0.98010000
#
# Epoch: 16/50, Train Loss: 0.00110692, Test Loss: 0.08690391, Test Accuracy: 0.98040000
#
# Epoch: 17/50, Train Loss: 0.00095207, Test Loss: 0.08723589, Test Accuracy: 0.98010000
#
# Epoch: 18/50, Train Loss: 0.00082659, Test Loss: 0.08833368, Test Accuracy: 0.98020000
#
# Epoch: 19/50, Train Loss: 0.00072425, Test Loss: 0.08951716, Test Accuracy: 0.98060000
#
# Epoch: 20/50, Train Loss: 0.00063345, Test Loss: 0.09047467, Test Accuracy: 0.98060000
#
# Epoch: 21/50, Train Loss: 0.00055660, Test Loss: 0.09132079, Test Accuracy: 0.98060000
#
# Epoch: 22/50, Train Loss: 0.00049513, Test Loss: 0.09180747, Test Accuracy: 0.97990000
#
# Epoch: 23/50, Train Loss: 0.00044229, Test Loss: 0.09254393, Test Accuracy: 0.97980000
#
# Saving the model state dictionary for Epoch: 3 with Test loss: 0.34583926
#
# Epoch: 4/50, Train Loss: 0.34312607, Test Loss: 0.31302325, Test Accuracy: 0.90980000
# Saving the model state dictionary for Epoch: 4 with Test loss: 0.31302325
#
# Epoch: 5/50, Train Loss: 0.31391889, Test Loss: 0.29038461, Test Accuracy: 0.91460000
# Saving the model state dictionary for Epoch: 5 with Test loss: 0.29038461
#
# Epoch: 6/50, Train Loss: 0.28898874, Test Loss: 0.27226442, Test Accuracy: 0.92060000
# Saving the model state dictionary for Epoch: 6 with Test loss: 0.27226442
#
# Epoch: 7/50, Train Loss: 0.26564694, Test Loss: 0.24730697, Test Accuracy: 0.92800000
# Saving the model state dictionary for Epoch: 7 with Test loss: 0.24730697
#
# Epoch: 8/50, Train Loss: 0.24432781, Test Loss: 0.22944423, Test Accuracy: 0.93190000
# Saving the model state dictionary for Epoch: 8 with Test loss: 0.22944423
#
# Epoch: 9/50, Train Loss: 0.22555595, Test Loss: 0.21526347, Test Accuracy: 0.93660000
# Saving the model state dictionary for Epoch: 9 with Test loss: 0.21526347
#
# Epoch: 10/50, Train Loss: 0.20883532, Test Loss: 0.20461825, Test Accuracy: 0.93830000
# Saving the model state dictionary for Epoch: 10 with Test loss: 0.20461825
#
# Epoch: 11/50, Train Loss: 0.19262659, Test Loss: 0.19071021, Test Accuracy: 0.94280000
# Saving the model state dictionary for Epoch: 11 with Test loss: 0.19071021
#
# Epoch: 12/50, Train Loss: 0.17952831, Test Loss: 0.17340062, Test Accuracy: 0.94790000
# Saving the model state dictionary for Epoch: 12 with Test loss: 0.17340062
#
# Epoch: 13/50, Train Loss: 0.16750423, Test Loss: 0.16394282, Test Accuracy: 0.95070000
# Saving the model state dictionary for Epoch: 13 with Test loss: 0.16394282
#
# Epoch: 14/50, Train Loss: 0.15693102, Test Loss: 0.15610872, Test Accuracy: 0.95400000
# Saving the model state dictionary for Epoch: 14 with Test loss: 0.15610872
#
# Epoch: 15/50, Train Loss: 0.14776128, Test Loss: 0.14462971, Test Accuracy: 0.95650000
# Saving the model state dictionary for Epoch: 15 with Test loss: 0.14462971
#
# Epoch: 16/50, Train Loss: 0.13916551, Test Loss: 0.14137394, Test Accuracy: 0.95830000
# Saving the model state dictionary for Epoch: 16 with Test loss: 0.14137394
#
# Epoch: 17/50, Train Loss: 0.13124293, Test Loss: 0.13786579, Test Accuracy: 0.95820000
# Saving the model state dictionary for Epoch: 17 with Test loss: 0.13786579
#
# Epoch: 18/50, Train Loss: 0.12440401, Test Loss: 0.12946961, Test Accuracy: 0.96120000
# Saving the model state dictionary for Epoch: 18 with Test loss: 0.12946961
#
# Epoch: 19/50, Train Loss: 0.11770835, Test Loss: 0.13341577, Test Accuracy: 0.96060000
#
# Epoch: 20/50, Train Loss: 0.11186343, Test Loss: 0.12016612, Test Accuracy: 0.96420000
# Saving the model state dictionary for Epoch: 20 with Test loss: 0.12016612
#
# Epoch: 21/50, Train Loss: 0.10630880, Test Loss: 0.11287899, Test Accuracy: 0.96570000
# Saving the model state dictionary for Epoch: 21 with Test loss: 0.11287899
#
# Epoch: 22/50, Train Loss: 0.10135228, Test Loss: 0.11074166, Test Accuracy: 0.96580000
# Saving the model state dictionary for Epoch: 22 with Test loss: 0.11074166
#
# Epoch: 23/50, Train Loss: 0.09618739, Test Loss: 0.10684654, Test Accuracy: 0.96670000
# Saving the model state dictionary for Epoch: 23 with Test loss: 0.10684654
#
# Epoch: 24/50, Train Loss: 0.09198720, Test Loss: 0.10956699, Test Accuracy: 0.96730000
#
# Epoch: 25/50, Train Loss: 0.08753606, Test Loss: 0.11048701, Test Accuracy: 0.96520000
#
# Epoch: 26/50, Train Loss: 0.08429854, Test Loss: 0.09715599, Test Accuracy: 0.97000000
# Saving the model state dictionary for Epoch: 26 with Test loss: 0.09715599
#
# Epoch: 27/50, Train Loss: 0.08040133, Test Loss: 0.09378583, Test Accuracy: 0.97150000
# Saving the model state dictionary for Epoch: 27 with Test loss: 0.09378583
#
# Epoch: 28/50, Train Loss: 0.07683723, Test Loss: 0.09477379, Test Accuracy: 0.96940000
#
# Epoch: 29/50, Train Loss: 0.07341150, Test Loss: 0.09817359, Test Accuracy: 0.97040000
#
# Epoch: 30/50, Train Loss: 0.07050070, Test Loss: 0.09006046, Test Accuracy: 0.97190000
# Saving the model state dictionary for Epoch: 30 with Test loss: 0.09006046
#
# Epoch: 31/50, Train Loss: 0.06738373, Test Loss: 0.08661302, Test Accuracy: 0.97280000
# Saving the model state dictionary for Epoch: 31 with Test loss: 0.08661302
#
# Epoch: 32/50, Train Loss: 0.06476203, Test Loss: 0.08542472, Test Accuracy: 0.97380000
# Saving the model state dictionary for Epoch: 32 with Test loss: 0.08542472
#
# Epoch: 33/50, Train Loss: 0.06230761, Test Loss: 0.08570074, Test Accuracy: 0.97370000
#
# Epoch: 34/50, Train Loss: 0.05966893, Test Loss: 0.08285367, Test Accuracy: 0.97390000
# Saving the model state dictionary for Epoch: 34 with Test loss: 0.08285367
#
# Epoch: 35/50, Train Loss: 0.05720982, Test Loss: 0.08589645, Test Accuracy: 0.97310000
#
# Epoch: 36/50, Train Loss: 0.05475128, Test Loss: 0.07990008, Test Accuracy: 0.97480000
# Saving the model state dictionary for Epoch: 36 with Test loss: 0.07990008
#
# Epoch: 37/50, Train Loss: 0.05260997, Test Loss: 0.08208711, Test Accuracy: 0.97500000
#
# Epoch: 38/50, Train Loss: 0.05067344, Test Loss: 0.07917151, Test Accuracy: 0.97650000
# Saving the model state dictionary for Epoch: 38 with Test loss: 0.07917151
#
# Epoch: 39/50, Train Loss: 0.04828485, Test Loss: 0.07675327, Test Accuracy: 0.97540000
# Saving the model state dictionary for Epoch: 39 with Test loss: 0.07675327
#
# Epoch: 40/50, Train Loss: 0.04644238, Test Loss: 0.07744274, Test Accuracy: 0.97580000
#
# Epoch: 41/50, Train Loss: 0.04450753, Test Loss: 0.08109721, Test Accuracy: 0.97550000
#
# Epoch: 42/50, Train Loss: 0.04269828, Test Loss: 0.07636582, Test Accuracy: 0.97620000
# Saving the model state dictionary for Epoch: 42 with Test loss: 0.07636582
#
# Epoch: 43/50, Train Loss: 0.04108628, Test Loss: 0.07318365, Test Accuracy: 0.97790000
# average_sparsity: [0.05755450762808323, 0.07872353866696358, 0.0864078514277935, 0.09363297000527382, 0.10082340985536575, 0.10700673609972, 0.11329209432005882, 0.11815155670046806, 0.12344876304268837, 0.12763963267207146, 0.13058065995573997, 0.13345402106642723, 0.13552474230527878, 0.13826749473810196, 0.13959621265530586, 0.14107070118188858, 0.1426195092499256, 0.14334890991449356, 0.1442207396030426, 0.1452176608145237, 0.1459190435707569, 0.14659902080893517, 0.14704745635390282, 0.14718009904026985, 0.1484658531844616, 0.14839787036180496, 0.14866115897893906, 0.1486550197005272, 0.14901378378272057, 0.1489872708916664, 0.14945603162050247, 0.14999661222100258, 0.15004044398665428, 0.14984487742185593, 0.14999185502529144, 0.1503039039671421, 0.15071415156126022, 0.1500939019024372, 0.15099605172872543, 0.15056351572275162, 0.15122513473033905, 0.15040134638547897, 0.15085377544164658, 0.15068379789590836, 0.1508517600595951, 0.1512284241616726, 0.15113839879631996, 0.15172619000077248, 0.15156809985637665, 0.15165816992521286]

# %% [markdown]
# # Adam

# %%
model_factory('Adam')
# Out:
# my_model: Model(
#   (linear_1): Linear(in_features=784, out_features=256, bias=True)
#   (linear_2): Linear(in_features=256, out_features=256, bias=True)
#   (linear_3): Linear(in_features=256, out_features=10, bias=True)
#   (sigmoid12): Sigmoid()
#   (sigmoid23): Sigmoid()
# )
# my_optimizer: Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.001
#     weight_decay: 0
# )
#
# Epoch: 1/50, Train Loss: 0.46062646, Test Loss: 0.23019591, Test Accuracy: 0.93020000
# Saving the model state dictionary for Epoch: 1 with Test loss: 0.23019591
#
# Epoch: 2/50, Train Loss: 0.17090874, Test Loss: 0.13047612, Test Accuracy: 0.95990000
# Saving the model state dictionary for Epoch: 2 with Test loss: 0.13047612
#
# Epoch: 3/50, Train Loss: 0.11648787, Test Loss: 0.11877710, Test Accuracy: 0.96170000
# Saving the model state dictionary for Epoch: 3 with Test loss: 0.11877710
#
# Epoch: 4/50, Train Loss: 0.08605863, Test Loss: 0.09043822, Test Accuracy: 0.97080000
# Saving the model state dictionary for Epoch: 4 with Test loss: 0.09043822
#
# Epoch: 5/50, Train Loss: 0.06640637, Test Loss: 0.09237713, Test Accuracy: 0.97000000
#
# Epoch: 6/50, Train Loss: 0.05035246, Test Loss: 0.07154697, Test Accuracy: 0.97760000
# Saving the model state dictionary for Epoch: 6 with Test loss: 0.07154697
#
# Epoch: 7/50, Train Loss: 0.04009322, Test Loss: 0.07882152, Test Accuracy: 0.97500000
#
# Epoch: 8/50, Train Loss: 0.03004546, Test Loss: 0.07361696, Test Accuracy: 0.97700000
#
# Epoch: 9/50, Train Loss: 0.02533569, Test Loss: 0.07187619, Test Accuracy: 0.97880000
#
# Epoch: 10/50, Train Loss: 0.01969391, Test Loss: 0.07825237, Test Accuracy: 0.97680000
#
# Epoch: 11/50, Train Loss: 0.01594616, Test Loss: 0.08249766, Test Accuracy: 0.97710000
#
# Epoch: 12/50, Train Loss: 0.01354986, Test Loss: 0.07221701, Test Accuracy: 0.98080000
#
# Epoch: 13/50, Train Loss: 0.01049173, Test Loss: 0.07738711, Test Accuracy: 0.97870000
#
# Epoch: 14/50, Train Loss: 0.00932446, Test Loss: 0.08148368, Test Accuracy: 0.98040000
#
# Epoch: 15/50, Train Loss: 0.00801980, Test Loss: 0.08254577, Test Accuracy: 0.98050000
#
# Epoch: 16/50, Train Loss: 0.00426557, Test Loss: 0.09390508, Test Accuracy: 0.97670000
#
# Epoch: 17/50, Train Loss: 0.00904493, Test Loss: 0.08965676, Test Accuracy: 0.97960000
#
# Epoch: 18/50, Train Loss: 0.00360018, Test Loss: 0.09350511, Test Accuracy: 0.97990000
#
# Epoch: 19/50, Train Loss: 0.00577960, Test Loss: 0.09977472, Test Accuracy: 0.97780000
